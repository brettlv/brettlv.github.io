# %%
# Import required packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pylab import cm

# %matplotlib inline
# %config InlineBackend.figure_format='svg'

# %%
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 2

# %%
import pandas as pd
import numpy as np

# %%
revisit_NGC4151=pd.read_excel('/Volumes/ExtremeSSD/Papers_sources/NGC4151/NGC4151.xlsx')

# %%
revisit_NGC4151["zxipcfh Nn (1022 cm-2)"].fillna("0 ± 0", inplace = True)

# %%
revisit_NGC4151
# Out:
#     Component Obs zxipcfl Nn (1022 cm-2) zxipcfl log^ zxipcfh Nn (1022 cm-2)  \
# 0               1              8.9 ± 1.7    1.6 ± 0.1                  0 ± 0
# 1               2              4.7 ± 0.8    1.4 ± 0.1                  0 ± 0
# 2               3              5.5 ± 0.3   -0.4 ± 0.1                  0 ± 0
# 3               4              6.1 ± 1.0    1.5 ± 0.2              1.5 ± 0.7
# 4               5              7.6 ± 0.2    1.4 ± 0.1                18 ± 12
# 5               6              4.7 ± 0.3    1.2 ± 0.1                2 ± 0.6
# 6               7              3.0 ± 0.6   -1.7 ± 0.4                  0 ± 0
# 7               8              7.1 ± 0.9    1.3 ± 0.1                47 ± 21
# 8              10              4.7 ± 0.8    1.1 ± 0.2              2.2 ± 1.3
# 9              11              4.7 ± 0.3    1.1 ± 0.1              0.9 ± 0.7
# 10             12              6.3 ± 0.5    1.1 ± 0.1              6.1 ± 2.2
# ...

# %%
revisit_NGC4151.columns
# Out:
# Index(['Component Obs', 'zxipcfl Nn (1022 cm-2)', 'zxipcfl log^',
#        'zxipcfh Nn (1022 cm-2)', 'zxipcfh log £', 'zTBabs NH (1022 cm-2)',
#        'POh F (7-10) (log erg cm-2 s-1)', 'POh r', 'TBpcf cf',
#        'xillver F (6-6.8) (log erg cm-2 s-1)', 'bremss kT (keV)',
#        'bremss Ns (io-3)', 'X2/dof', 'Pnull'],
#       dtype='object')

# %%
revisit_NGC4151[revisit_NGC4151.columns[1]][0].split(' ± ')[0]
# Out:
# '8.9'

# %%
revisit_NGC4151[revisit_NGC4151.columns[5]][2].split('< ')[1]
# Out:
# '1.3'

# %% [markdown]
# ## def plot_data

# %%
def plot_data(data,col1,col2):
    x=data[col1]
    y=data[col2]
    for i,j in zip(x,y):
        #print(i,j)
        if i.find('±')>=0:
            x_i=i.split(' ± ')[0]
            x_err_i=i.split(' ± ')[1]
                              
        elif i.find('<')>=0:
            x_i=i.split('< ')[1]
            x_err_i=0           
            
        if j.find('±')>=0:    
            y_i,y_err_i=j.split(' ± ')[0],j.split(' ± ')[1]
            upper_lims=False
            
        elif j.find('<')>=0:
            y_i,y_err_i=j.split('< ')[1],0
            upper_lims=True           
        
        print(float(x_i),float(x_err_i),float(y_i),float(y_err_i))
        ax.errorbar(float(x_i),float(y_i),xerr=float(x_err_i),yerr=float(y_err_i),color='black',uplims=upper_lims)

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(3, 3))
# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])
col1=revisit_NGC4151.columns[6]
col2=revisit_NGC4151.columns[5]
print(col1,col2)
ax.set_ylabel(col2)
ax.set_xlabel(col1)
plot_data(revisit_NGC4151,col1,col2)
# Out:
# POh F (7-10) (log erg cm-2 s-1) zTBabs NH (1022 cm-2)
# -11.14 0.01 1.1 0.9
# -10.762 0.003 3.8 0.9
# -10.792 0.008 1.3 0.0
# -10.071 0.004 2.2 0.6
# -10.073 0.005 0.4 0.1
# -9.996 0.002 1.9 0.2
# -10.72 0.01 1.4 0.7
# -10.415 0.006 4.2 0.6
# -10.14 0.01 2.7 0.6
# -10.136 0.005 1.6 0.3
# -9.996 0.005 8.4 0.5
# -10.364 0.008 9.8 1.0
# -10.09 0.01 2.1 0.5
# -10.376 0.007 2.8 0.8
# -10.275 0.01 26.6 0.7
# -10.405 0.005 27.1 1.0
# -10.32 0.01 33.4 1.0
# -10.177 0.008 25.8 0.7
# -10.156 0.004 26.7 0.4
# -9.992 0.007 28.6 0.7
# -9.957 0.005 27.7 0.4
# -10.062 0.006 28.1 0.4

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(3, 3))
# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

col1=revisit_NGC4151.columns[6]
col2=revisit_NGC4151.columns[1]
ax.set_ylabel(col2)
ax.set_xlabel(col1)
print(col1,col2)
plot_data(revisit_NGC4151,col1,col2)
# Out:
# POh F (7-10) (log erg cm-2 s-1) zxipcfl Nn (1022 cm-2)
# -11.14 0.01 8.9 1.7
# -10.762 0.003 4.7 0.8
# -10.792 0.008 5.5 0.3
# -10.071 0.004 6.1 1.0
# -10.073 0.005 7.6 0.2
# -9.996 0.002 4.7 0.3
# -10.72 0.01 3.0 0.6
# -10.415 0.006 7.1 0.9
# -10.14 0.01 4.7 0.8
# -10.136 0.005 4.7 0.3
# -9.996 0.005 6.3 0.5
# -10.364 0.008 5.6 1.8
# -10.09 0.01 9.5 0.7
# -10.376 0.007 4.3 1.3
# -10.275 0.01 2.6 1.6
# -10.405 0.005 6.0 0.8
# -10.32 0.01 2.1 0.6
# -10.177 0.008 3.3 0.5
# -10.156 0.004 1.7 0.3
# -9.992 0.007 3.7 1.0
# -9.957 0.005 5.8 0.5
# -10.062 0.006 5.5 0.7

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(3, 3))
# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])
col1=revisit_NGC4151.columns[6]
col2=revisit_NGC4151.columns[3]
print(col1,col2)
ax.set_ylabel(col2)
ax.set_xlabel(col1)
ax.set_ylim(0.01,70)
plot_data(revisit_NGC4151,col1,col2)
# Out:
# POh F (7-10) (log erg cm-2 s-1) zxipcfh Nn (1022 cm-2)
# -11.14 0.01 0.0 0.0
# -10.762 0.003 0.0 0.0
# -10.792 0.008 0.0 0.0
# -10.071 0.004 1.5 0.7
# -10.073 0.005 18.0 12.0
# -9.996 0.002 2.0 0.6
# -10.72 0.01 0.0 0.0
# -10.415 0.006 47.0 21.0
# -10.14 0.01 2.2 1.3
# -10.136 0.005 0.9 0.7
# -9.996 0.005 6.1 2.2
# -10.364 0.008 4.5 3.3
# -10.09 0.01 1.1 0.5
# -10.376 0.007 9.4 3.0
# -10.275 0.01 32.0 10.0
# -10.405 0.005 13.0 7.0
# -10.32 0.01 19.0 10.0
# -10.177 0.008 13.0 4.0
# -10.156 0.004 11.0 6.0
# -9.992 0.007 12.0 5.0
# -9.957 0.005 6.3 1.0
# -10.062 0.006 4.1 1.8

# %%
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(3, 3))
# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

col1=revisit_NGC4151.columns[6]
col2=revisit_NGC4151.columns[7]
#ax.set_ylabel(col2)
ax.set_xlabel(col1)
ax.set_ylabel('$\Gamma$')
print(col1,col2)
plot_data(revisit_NGC4151,col1,col2)
# Out:
# POh F (7-10) (log erg cm-2 s-1) POh r
# -11.14 0.01 1.55 0.06
# -10.762 0.003 1.48 0.02
# -10.792 0.008 1.87 0.04
# -10.071 0.004 1.66 0.03
# -10.073 0.005 1.63 0.03
# -9.996 0.002 1.69 0.02
# -10.72 0.01 1.61 0.03
# -10.415 0.006 1.5 0.04
# -10.14 0.01 1.64 0.05
# -10.136 0.005 1.54 0.03
# -9.996 0.005 1.62 0.03
# -10.364 0.008 1.37 0.07
# -10.09 0.01 1.55 0.05
# -10.376 0.007 1.46 0.03
# -10.275 0.01 1.52 0.06
# -10.405 0.005 1.47 0.04
# -10.32 0.01 1.44 0.07
# -10.177 0.008 1.59 0.05
# -10.156 0.004 1.57 0.04
# -9.992 0.007 1.63 0.04
# -9.957 0.005 1.6 0.03
# -10.062 0.006 1.62 0.03
