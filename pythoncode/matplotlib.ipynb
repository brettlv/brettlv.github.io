# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')
import astropy
from astropy.time import Time
import matplotlib.ticker as ticker
import pyfits
import os
from matplotlib import animation

# %%
pwd
# Out:
# '/Users/brettlv/blog/brettlv.github.io/pythoncode'

# %%
path='/Users/brettlv/blog/brettlv.github.io/pythoncode'
#os.mkdir("Bfraction")
isExists = os.path.exists(path)
if not isExists:
    os.makedirs(path)
os.chdir(path)

# %%
length=8
width=length*0.618
fig=plt.figure(figsize=(length,width))
ax1=fig.add_subplot(1,1,1)

k=1.38*10**-23#J/K
h=6.626*10**-34#J*s
c=3*10**8#m
T=np.linspace(100,10100,6)#K

def Blamda(lamdawave,Tirr):
    blamda=2*h*c**2*lamdawave**(-5)*(np.e**(h*c/lamdawave/k/Tirr)-1)**-1
    return blamda

def Bf(f,Tirr):
    bf=2*h*f**3/c**2*(np.e**(h*f/k/Tirr)-1)**-1
    return bf

#x=np.linspace(0,10,1000)
x=np.logspace(8,18,num=1000,base=10)
for T_ in T:
    y=Bf(x,T_)
    plt.loglog(x,y,label='%d K'%T_)
    plt.legend()
    #plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    #plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    plt.title("Planck's law")
    plt.xlabel("frequency:Hz")
    plt.ylabel("Spectral radiance")
    plt.grid(True,alpha=0.3)
    plt.ylim(10**-20,1)
plt.savefig('/Users/brettlv/Desktop/plotfreq.pdf')
# Out:
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:16: RuntimeWarning: overflow encountered in power

# %%
length=8
width=length*0.618
fig=plt.figure(figsize=(length,width))
ax1=fig.add_subplot(1,1,1)

#x=np.linspace(0,10,1000)
x=np.linspace(10**13,0.2*10**16,1000)
for T_ in T:
    y=Bf(x,T_)
    plt.plot(x,y,label='%d K'%T_)
    plt.legend()
    #plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    #plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    plt.title("Planck's law")
    plt.xlabel("frequency:Hz")
    plt.ylabel("Spectral radiance")
    plt.grid(True,alpha=0.3)
plt.savefig('/Users/brettlv/Desktop/plotfreqlin.pdf')
# Out:
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:16: RuntimeWarning: overflow encountered in power

# %%
length=8
width=length*0.618
fig=plt.figure(figsize=(length,width))
ax1=fig.add_subplot(1,1,1)
lamda=np.logspace(-9,-1,num=1000,base=10)
for T_ in T:
    y=Blamda(lamda,T_)
    plt.loglog(lamda,y,label='%d K'%T_)
    plt.legend()
    #plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    #plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    plt.title("Planck's law")
    plt.xlabel("lamda:m")
    plt.ylabel("Spectral radiance")
    plt.grid(True,alpha=0.3)
    plt.ylim(10**-7,10**16)
plt.savefig('/Users/brettlv/Desktop/plotlamda.pdf')
# Out:
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:12: RuntimeWarning: overflow encountered in power

# %%
length=8
width=length*0.618
fig=plt.figure(figsize=(length,width))
ax1=fig.add_subplot(1,1,1)
lamda=np.linspace(10**-7,0.2*10**-5,1000)
lamdamum=lamda*10**6
for T_ in T:
    y=Blamda(lamda,T_)
    plt.plot(lamdamum,y,label='%d K'%T_)
    plt.legend()
    plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
    #plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
    plt.title("Planck's law")
    plt.xlabel("lamda:$\mu$m")
    plt.ylabel("Spectral radiance")
    plt.grid(True,alpha=0.3)
    plt.xlim(0,2)
    plt.ylim()
plt.savefig('/Users/brettlv/Desktop/plotlamdalin.pdf')
# Out:
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:12: RuntimeWarning: overflow encountered in power

# %%
from astropy import units as u

# %%
np.log10(0.25*10**-6)
# Out:
# -6.6020599913279625

# %%
x=np.arange(0,10,0.1)
lines=plt.plot(x,np.sin(x),x,np.cos(x))
f=plt.gcf()
plt.getp(f,"axes")

# %%
plt.figure(figsize=(8,6))
for idx,color in enumerate("rgbyck"):
    plt.subplot(320+idx+1,axisbg=color,alpha=0.01)
# Out:
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.figure(figsize=(8,6))
plt.subplot(411)
plt.subplot(412)
plt.subplot(412)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-143-e32a8874fc19> in <module>()
# ----> 1 from visual import *
#
# ModuleNotFoundError: No module named 'visual'

# %%
import matplotlib.pyplot as plt
import pyfits

import matplotlib.patheffects

# %%
fig = plt.figure(1, figsize=(8, 5))
fig.clf()

from pywcsgrid2.allsky_axes import make_allsky_axes_from_header

ax = make_allsky_axes_from_header(fig, rect=111, header=header,
                                      lon_center=0.)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d64f32c31e4c> in <module>()
#       2 fig.clf()
#       3
# ----> 4 from pywcsgrid2.allsky_axes import make_allsky_axes_from_header
#       5
#       6 ax = make_allsky_axes_from_header(fig, rect=111, header=header,
#
# ModuleNotFoundError: No module named 'pywcsgrid2'
