# %%
from astropy.io import fits
import os,sys

# %% [markdown]
# datadir='/Users/brettlv/Downloads/ESO_data_mrk1018/'

# %%
datadir_eso='/Volumes/ExtremeSSD/data_source/data_AGN/Mrk1018/ESO_bash_20150111/'

# %%
fitsname=[]
for i in os.listdir(datadir_eso):
    if i.endswith('fits') and i not in fitsname:
        fitsname.append(i)

# %%
fitsname
# Out:
# ['ADP.2016-06-01T15:13:10.350.fits',
#  '._ADP.2016-06-01T15:13:10.350.fits',
#  'ADP.2016-06-01T15:13:10.351.fits',
#  '._ADP.2016-06-01T15:13:10.351.fits']

# %% [markdown]
# for i in fitsname:
#     eso_data=fits.open(os.path.join(datadir_eso,i))
#     print(i,eso_data[0].header['DATE-OBS'])

# %%
eso_data=fits.open(os.path.join(datadir_eso,fitsname[0]))

# %%
eso_data.info()
# Out:
# Filename: /Volumes/ExtremeSSD/data_source/data_AGN/Mrk1018/ESO_bash_20150111/ADP.2016-06-01T15:13:10.350.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1274   ()
#   1  DATA          1 ImageHDU        43   (315, 315, 3681)   float32
# WARNING: File may have been truncated: actual file length (474128506) is smaller than the expected size (1461098880) [astropy.io.fits.file]

# %%
eso_data[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# DATASUM = '         0'         / data unit checksum updated 2016-05-31T07:04:25
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2016-04-27T11:50:45' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U4'         / ESO <TEL>
# INSTRUME= 'MUSE    '           / Instrument used.
# RA      =     31.5670710596463 / [deg] Image center (J2000)
# DEC     =    -0.29138746785225 / [deg] Image center (J2000)
# EQUINOX =                2000. / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate system
# ...

# %%
eso_data[0].header['DATE-OBS']
# Out:
# '2015-01-11T00:33:09.696'

# %% [markdown]
# eso_data[1].data['Classification']

# %%
eso_data[1].data.columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a23ce12e7f5f> in <module>
# ----> 1 eso_data[1].data.columns
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/utils/decorators.py in __get__(self, obj, owner)
#     775                     val = obj_dict.get(self._key, _NotFound)
#     776                     if val is _NotFound:
# --> 777                         val = self.fget(obj)
#     778                         obj_dict[self._key] = val
#     779             return val
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/image.py in data(self)
#     233             return
#     234
# --> 235         data = self._get_scaled_image_data(self._data_offset, self.shape)
#     236         self._update_header_scale_info(data.dtype)
#     237
#
# ...

# %%
eso_data_1=fits.open(os.path.join(datadir_eso,fitsname[1]),ignore_missing_simple=True)
# Out:
# WARNING: non-ASCII characters are present in the FITS file header and have been replaced by "?" characters [astropy.io.fits.util]
# WARNING: VerifyWarning: Error validating header for HDU #0 (note: Astropy uses zero-based indexing).
#     Header size is not multiple of 2880: 4096
# There may be extra bytes after the last HDU or the file is corrupted. [astropy.io.fits.hdu.hdulist]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-48468ab3ef82> in <module>
# ----> 1 eso_data_1=fits.open(os.path.join(datadir_eso,fitsname[1]),ignore_missing_simple=True)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     173         raise ValueError(f'Empty filename: {name!r}')
#     174
# ...

# %%
ESO_data_mrk1018_0=fits.open('/Volumes/ExtremeSSD/data_source/data_AGN/Mrk1018/ESO_data_mrk1018/ADP.2019-01-10T15:06:10.016.fits')

# %%
ESO_data_mrk1018_0[0].header#.info()
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# DATASUM = '0       '           / data unit checksum updated 2018-12-06T16:45:31
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2018-11-20T16:58:21' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'ESO     '           / European Southern Observatory
# MJD-OBS =       57772.10099498 / Obs start 2017-01-19T02:25:25.967
# DATE-OBS= '2017-01-19T02:25:25.966' / Date of observation
# EXPTIME =     29.9940013885498 / Total integration time.
# TELESCOP= 'ESO-VLT-U3'         / ESO telescope name
# RA      =            31.483224 / 02:05:55.9 RA (J2000) pointing
# ...

# %%
ESO_data_mrk1018_0[1].header#.info()
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  320 / width of table in bytes
# NAXIS2  =                  368 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   80 / number of fields in each row
# TTYPE1  = 'Sequence_number'    / label for field   1
# TFORM1  = '1J      '           / data format of field: 4-byte INTEGER
# EXTNAME = 'BRIAN   '
# DATASUM = '608469922'          / data unit checksum updated 2018-11-26T16:38:49
# TUNIT1  = 'Number  '           / physical unit of field
# TTYPE2  = 'Isophotal_flux'     / label for field   2
# TFORM2  = '1E      '           / data format of field: 4-byte REAL
# TUNIT2  = 'ADU     '           / physical unit of field
# ...
