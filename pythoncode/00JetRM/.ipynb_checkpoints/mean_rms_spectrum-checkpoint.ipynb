# %%
from adjustText import adjust_text
import matplotlib as mpl
def set_ax_tick(ax):
    ax.xaxis.set_tick_params(which='major', size=10, width=2, direction='in', top='on',)
    ax.xaxis.set_tick_params(which='minor', size=5, width=2, direction='in', top='on')
    ax.yaxis.set_tick_params(which='major', size=10, width=2, direction='in', right='on')
    ax.yaxis.set_tick_params(which='minor', size=5, width=2, direction='in', right='on')

def set_ax_locator(ax,xma=1,xmi=0.2,yma=1,ymi=0.2):
    ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(xma))
    ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(xmi))
    ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(yma))
    ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(ymi))
    
def plot_secax(ax,mi_interval=365,ma_interval=365*2,rotation=30,):
    secax1 = ax.secondary_xaxis('top', functions=(mjd2numsdate,datenums2mjd))
    secax1.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
    secax1.xaxis.set_major_locator(mdates.DayLocator(interval=ma_interval))
    secax1.xaxis.set_minor_locator(mdates.DayLocator(interval=mi_interval))
    secax1.xaxis.set_tick_params(which='major', size=10, width=2, direction='out')
    secax1.xaxis.set_tick_params(which='minor', size=5, width=2, direction='out')
    secax1.xaxis.set_tick_params(which='major', size=10, width=2, direction='out', rotation=rotation,)    
    
def set_ax_legend(ax,bbox_to_anchor=(0.01, 0.99)):
    ax.xaxis.set_tick_params(which='major', size=10, width=2, rotation=0,)
    handles, labels = ax.get_legend_handles_labels()
    # remove the errorbars
    #hdl = [h[0] for h in handles]
    hdl = handles
    labels_dict=dict(zip(labels, hdl)) #key,values
    by_label=OrderedDict(sorted(labels_dict.items(),key=lambda t:t[0]))
    #by_label = OrderedDict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), bbox_to_anchor=bbox_to_anchor,
              loc=2, numpoints=1,ncol=1,fontsize=11.)

def set_mag_ylim(ax):
    bottom, top = ax.set_ylim()
    if bottom< top:
        ax.set_ylim(top,bottom)   
        
        
def set_mag_xlim(ax):
    bottom, top = ax.set_xlim()
    if bottom< top:
        ax.set_xlim(top,bottom)

# %%
import os
import numpy as np
import pandas as pd
from astropy.table import Table
from scipy.stats import spearmanr#
from scipy.stats.stats import pearsonr

from astropy.cosmology import FlatLambdaCDM,Planck13,Planck15,z_at_value
from astropy import units as u
from astropy.cosmology import LambdaCDM
cosmo = LambdaCDM(H0=70, Om0=0.27, Ode0=0.73)


from astropy.time import Time
from astropy.time import TimeYearDayTime
from datetime import datetime
import time
from time import strftime,strptime
import calendar
from dateutil.parser import parse

#from adjustText import adjust_text
import matplotlib as mpl
import matplotlib.pyplot as plt
from pylab import cm
from collections import OrderedDict
#from adjustText import adjust_text

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
# Edit the font, font size, and axes width
mpl.rcParams['font.family'] = 'Times New Roman' #'Avenir'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 2
# Out:
# /var/folders/jp/4mwsn7_x6j9gnv1hl1dztqth0000gn/T/ipykernel_1793/3300942447.py:6: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
bbox_to_anchor=(0.99, 0.99)
ax.legend(by_label.values(), by_label.keys(), bbox_to_anchor=bbox_to_anchor,
              loc=2, numpoints=1,ncol=1,fontsize=11.)

# %%
pwd
# Out:
# '/Users/lyubing/blog/brettlv.github.io/pythoncode/00JetRM'

# %% [markdown]
# # [specutils](https://specutils.readthedocs.io/en/stable/spectrum1d.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.modeling.models import BlackBody
from astropy import units as u
from astropy.visualization import quantity_support

# %%
import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt
from specutils import Spectrum1D

# %% [markdown]
# flux = np.random.randn(200)*u.Jy
# wavelength_0 = np.arange(5100, 5300)*u.AA
# spec1d = Spectrum1D(spectral_axis=wavelength_0, flux=flux)
# ax = plt.subplots()[1]
# ax.plot(spec1d.spectral_axis, spec1d.flux)
# ax.set_xlabel("Dispersion")
# ax.set_ylabel("Flux")

# %% [markdown]
# ## FermiAGN_onespec

# %%
from specutils import Spectrum1D
#spec1d = Spectrum1D.read("/path/to/file.fits")  
spec1d = Spectrum1D.read("/Volumes/ExtremeSSD/00PKU_SCI/Fermi_AGN_optical_monitoring_program_at_Steward_Observatory/Sources/pks1510/pks1510/pks1510.fc.spec_081229.fits")
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 54829.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: UnitsWarning: 'erg/cm2/s/A' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %% [markdown]
# spec1d.flux,spec1d.spectral_axis,len(spec1d.spectral_axis)

# %% [markdown]
# spec1d.shift_spectrum_to(redshift=0.361)  # Equivalent: spec1d.redshift = 0.361
# spec1d.spectral_axis

# %%
z = 0.361
ax = plt.subplots()[1]  
ax.scatter(spec1d.spectral_axis/(1+z), spec1d.flux)  
ax.set_xlabel("$\lambda/(1+z)$")  
ax.set_ylabel("Flux")  
ax.set_xlim(4700,5120)
# Out:
# (4700.0, 5120.0)

# %% [markdown]
# # Fermi AGN_specs

# %%
# !open /Volumes/ExtremeSSD/00PKU_SCI/Fermi_AGN_optical_monitoring_program_at_Steward_Observatory/Sources/pks1510/pks1510

# %% [markdown]
# ## pks1510

# %%
from glob import glob
import numpy as np
from astropy.wcs import WCS
from astropy.io import fits

# glob searches through directories similar to the Unix shell
filelist = glob('/Volumes/ExtremeSSD/00PKU_SCI/Fermi_AGN_optical_monitoring_program_at_Steward_Observatory/Sources/pks1510/*/*.fc.spec*.fits')
# sort alphabetically - given the way the filenames are
# this also sorts in time
filelist.sort()

# %%
len(filelist)
# Out:
# 376

# %%
filelist

# %%
sp = fits.open(filelist[0])
sp.info()

header = sp[0].header

wcs = WCS(header)
#make index array
index = np.arange(header['NAXIS1'])

wavelength = wcs.wcs_pix2world(index[:,np.newaxis], 0)
print(wavelength.shape)
#wavelength

#Ahh, this has the wrong dimension. So we flatten it.
wavelength = wavelength.flatten()

print(len(wavelength))

flux_pks1510_0 = sp[0].data
# Out:
# Filename: /Volumes/ExtremeSSD/00PKU_SCI/Fermi_AGN_optical_monitoring_program_at_Steward_Observatory/Sources/pks1510/pks1510/pks1510.fc.spec_081229.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     107   (889,)   float32
# (889, 1)
# 889
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 54829.000000 from DATE-OBS'. [astropy.wcs.wcs]

# %%
wavelength

# %%
z = 0.361
ax = plt.subplots()[1]  
ax.plot(wavelength/(1+z), flux_pks1510_0)  
ax.set_xlabel("wavelength")  
ax.set_ylabel("Flux")  
ax.set_xlim(4700,5120)
# Out:
# (4700.0, 5120.0)

# %%
def read_spec(filename):
    '''Read a UVES spectrum from the ESO pipeline

    Parameters
    ----------
    filename : string
       name of the fits file with the data

    Returns
    -------
    wavelength : np.ndarray
        wavelength (in Ang)
    flux : np.ndarray
        flux (in erg/s/cm**2)
    date_obs : string
        time of observation
    '''
    sp = fits.open(filename)
    header = sp[0].header

    wcs = WCS(header)
    #make index array
    index = np.arange(header['NAXIS1'])

    wavelength = wcs.wcs_pix2world(index[:,np.newaxis], 0)
    wavelength = wavelength.flatten()
    flux = sp[0].data

    date_obs = header['Date-OBS']
    return wavelength, flux, date_obs

# %%
def plot_spec(filename,z = 0.361):
    wavelength, flux, date_obs=read_spec(filename)
    figure_n= 1
    fig = plt.figure(figsize=(4,figure_n*4))
    fig.subplots_adjust(hspace=0.0, wspace = 0.0)
    ax = fig.add_subplot(figure_n,1,1)    
    #ax = plt.subplots()[1]  
    ax.plot(wavelength/(1+z), flux)  
    ax.set_xlabel("wavelength/(1+%.2f)"%z)  
    ax.set_ylabel("Flux")  
    ax.set_xlim(4700,5120)
    ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
    return fig,ax

# %%
wavelength, flux, date_obs=read_spec(filelist[0])

# %%
plot_spec(filelist[0],z = 0.361)
# Out:
# (<Figure size 288x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'pks1510.fc.spec_081229.fits'}, xlabel='wavelength/(1+0.36)', ylabel='Flux'>)

# %% [markdown]
# plot_spec(filelist[1])

# %%
w, f, date_obs = read_spec(filelist[0])
print(w[0],w[1],w[-1],len(w))

# %%
for i, fname in enumerate(filelist):
    w, f, date_obs = read_spec(fname)
    print(w[0],w[1],w[1]-w[0],w[-1],len(w))
# Out:
# 4000.0 4004.0 4.0 7552.0 889
# 4000.5 4004.5 4.0 7548.5 888
# 4000.10009765625 4004.10009765625 4.0 7548.10009765625 888
# 3998.5 4002.5 4.0 7550.5 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.0 4004.0 4.0 7552.0 889
# 4000.9499511718773 4004.9499516487144 4.000000476837158 7548.950374126438 888
# 3999.85009765625 4003.85009765625 4.0 7551.85009765625 889
# 3998.60009765625 4002.60009765625 4.0 7550.60009765625 889
# 3998.4499511718773 4002.4499516487144 4.000000476837158 7550.450374603275 889
# 3999.39990234375 4003.39990234375 4.0 7551.39990234375 889
# 3998.89990234375 4002.89990234375 4.0 7550.89990234375 889
# 3998.35009765625 4002.35009765625 4.0 7550.35009765625 889
# 3998.64990234375 4002.64990234375 4.0 7550.64990234375 889
# 4001.800048828127 4005.8000485897082 3.999999761581421 7549.799837350846 888
# 3999.39990234375 4003.39990234375 4.0 7551.39990234375 889
# 3999.0 4003.0 4.0 7551.0 889
# 3999.27001953125 4003.27001953125 4.0 7551.27001953125 889
# 3999.85009765625 4003.85009765625 4.0 7551.85009765625 889
# 3999.3000488281227 4003.300048589704 3.999999761581421 7551.299837112423 889
# 3998.5 4002.5 4.0 7550.5 889
000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56801.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56803.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56804.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56805.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56827.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56828.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56829.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56830.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56831.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56832.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56833.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56834.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56858.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56860.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56863.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56921.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56922.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56923.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 56924.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57011.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57014.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57015.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57018.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57019.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57042.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57043.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57044.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57045.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57046.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57050.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57067.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57069.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57070.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57071.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57098.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57102.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57105.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57106.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57107.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57108.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57125.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57126.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57127.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57128.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57129.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57130.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57131.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57133.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57160.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57161.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57162.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57165.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57166.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57167.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57187.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57188.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57189.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57190.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57191.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57192.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57193.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57194.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57195.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57218.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57219.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57224.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57399.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57400.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57426.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57427.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57428.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57429.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57430.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57431.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57432.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57456.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57457.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57460.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57461.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57462.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57463.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57464.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57491.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57492.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57493.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57511.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57512.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57513.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57514.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57516.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57517.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57518.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57519.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57592.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57593.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57630.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57631.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57634.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57635.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57636.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57637.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57655.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57656.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57658.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57749.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57780.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57781.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57783.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57785.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57809.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57813.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57821.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57822.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57824.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57825.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57826.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57841.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57842.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57871.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57873.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57874.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57875.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57887.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57888.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57893.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57894.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57896.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57915.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57916.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57918.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57932.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57934.000000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 57936.000000 from DATE-OBS'. [astropy.wcs.wcs]

# %% [markdown]
# wavelength_s

# %% [markdown]
# wavelength_restframe

# %%
fluxs.shape

# %%
a = np.array([[1, 2], [3, 4],[5,6]])
np.std(a)

# %%
np.std(a, axis=0,) ,np.std(a, axis=0,ddof=1)

# %%
np.std(a, axis=1),np.std(a, axis=1,ddof=1)

# %%
a.shape

# %% [markdown]
# ### mean_spectrum

# %%
z_pks1510=0.361

# %%
figure_n= 1
fig = plt.figure(figsize=(6,figure_n*4))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1) 


#ax = plt.subplots()[1]  
#ax.plot(wavelength/(1+z), flux)  
wavelength_s=wavelength[:len_wavelength]
wavelength_restframe=wavelength_s/(1+z_pks1510)

ax.errorbar(wavelength_restframe,np.mean(fluxs,axis=0),ms=5,ls='',marker='.')
ax.set_xlabel("rest wavelength")  
ax.set_ylabel("Flux")  
ax.axvspan(4740-1,4771+1,alpha=0.1)

ax.set_xlim(4300,5100)
#ax.axvline(5007)
#ax.axvline(4990)
ax.axvline(4861)
ax.axvline(4341.68)
set_ax_tick(ax)
#ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
#return fig,ax

# %% [markdown]
# ### std_spectrum

# %%
figure_n= 1
fig = plt.figure(figsize=(6,figure_n*4))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1) 


#ax = plt.subplots()[1]  
#ax.plot(wavelength/(1+z), flux)  
wavelength_s=wavelength[:len_wavelength]
wavelength_restframe=wavelength_s/(1+z_pks1510)

ax.errorbar(wavelength_restframe,np.std(fluxs,axis=0,ddof=1),ms=5,ls='',marker='.')

ax.set_xlabel("rest wavelength")  
ax.set_ylabel("Flux")  


ax.axvspan(4740-1,4771+1,alpha=0.1)
ax.set_xlim(4500,5100)
ax.axvline(5007)
ax.axvline(4861)
set_ax_tick(ax)
#ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
#return fig,ax

# %% [markdown]
# ### sigma_line

# %% [markdown]
# $$\lambda_{0} = \frac{\int{\lambda f_{\lambda} d\lambda}}{\int{f} d \lambda}$$

# %% [markdown]
# $$ \sigma^2_{line}= \frac{\int{\lambda^2 f_{\lambda} d\lambda}}{\int{f} d \lambda} - \lambda_{0}^2 $$

# %%
mean_spec=np.mean(fluxs,axis=0)
rms_spec= np.std(fluxs,axis=0,ddof=1)

# %%
from astropy import units as u
import numpy as np
from specutils import Spectrum1D, SpectralRegion
from specutils.manipulation import extract_region

mean_Spec_q = mean_spec*(u.erg * u.cm**-2 * u.s**-1*u.AA**-1)
rms_Spec_q = rms_spec* (u.erg * u.cm**-2 * u.s**-1*u.AA**-1)

spec_region= SpectralRegion(4800*u.AA, 4930*u.AA)

mean_Spec_rest = Spectrum1D(spectral_axis=wavelength[:888]*u.AA/(1+z_pks1510), flux=mean_Spec_q, )
rms_Spec_rest = Spectrum1D(spectral_axis=wavelength[:888]*u.AA/(1+z_pks1510), flux=rms_Spec_q, )

sub_mean_Spec_rest = extract_region(mean_Spec_rest, spec_region)
sub_rms_Spec_rest = extract_region(rms_Spec_rest, spec_region)

# %%
delta_wavelength=4/(1+z_pks1510)

lambda_0=  np.sum(sub_mean_Spec_rest.spectral_axis*sub_mean_Spec_rest.flux*delta_wavelength)/np.sum(sub_mean_Spec_rest.flux*delta_wavelength)
sigma2_line= np.sum(sub_mean_Spec_rest.spectral_axis**2*sub_mean_Spec_rest.flux*delta_wavelength)/np.sum(sub_mean_Spec_rest.flux*delta_wavelength)- lambda_0**2
print(lambda_0,sigma2_line, sigma2_line**0.5)

print(sigma2_line**0.5*3.0e5 /(4861*u.AA),'km/s')
# Out:
# 4865.909319446675 Angstrom 1228.959424752742 Angstrom2 35.05651757880041 Angstrom
# 2163.537394289266 km/s

# %%
spec_region_continuum= SpectralRegion(4740*u.AA, 4770*u.AA)
sub_mean_Spec_rest_continuum = extract_region(mean_Spec_rest, spec_region_continuum)
sub_rms_Spec_rest_continuum = extract_region(rms_Spec_rest, spec_region_continuum)

# %%
sub_mean_Spec_rest_continuum_subtract=Spectrum1D(spectral_axis=sub_mean_Spec_rest.spectral_axis,flux=sub_mean_Spec_rest.flux-np.mean(sub_mean_Spec_rest_continuum.flux))
sub_rms_Spec_rest_continuum_subtract=Spectrum1D(spectral_axis=sub_rms_Spec_rest.spectral_axis,flux=sub_rms_Spec_rest.flux-np.mean(sub_rms_Spec_rest_continuum.flux))

# %%
f, ax = plt.subplots()  
#ax.step(sub_mean_Spec_rest.spectral_axis, sub_mean_Spec_rest.flux) 
#ax.scatter(sub_mean_Spec_rest_continuum.spectral_axis, sub_mean_Spec_rest_continuum.flux) 
ax.scatter(sub_mean_Spec_rest_continuum_subtract.spectral_axis, sub_mean_Spec_rest_continuum_subtract.flux) 

#ax.set_ylim(9e-16,1e-15)
#ax.axhline(max(sub_mean_Spec_rest.flux).value)
#ax.axhline(0.5*max(sub_mean_Spec_rest.flux).value)

# %%
f, ax = plt.subplots()  
#ax.step(sub_mean_Spec_rest.spectral_axis, sub_mean_Spec_rest.flux) 
#ax.scatter(sub_mean_Spec_rest_continuum.spectral_axis, sub_mean_Spec_rest_continuum.flux) 
ax.scatter(sub_rms_Spec_rest_continuum_subtract.spectral_axis, sub_rms_Spec_rest_continuum_subtract.flux)

# %%
np.mean(sub_mean_Spec_rest_continuum.flux)

# %%
f, ax = plt.subplots()  
#ax.step(sub_mean_Spec_rest.spectral_axis, sub_mean_Spec_rest.flux) 
ax.scatter(sub_mean_Spec_rest_continuum_subtract.spectral_axis, sub_mean_Spec_rest_continuum_subtract.flux) 

ax.axhline(max(sub_mean_Spec_rest_continuum_subtract.flux).value)
ax.axhline(0.5*max(sub_mean_Spec_rest_continuum_subtract.flux).value)

ax.axvline(4837.6193975)
ax.axvline(4884.64364438)

# %%
def get_FWHM_spec(spec):
    max_flux= np.max(spec.flux)
    max_flux_index=np.argmax(spec.flux)
    max_flux_lambda=spec.spectral_axis[max_flux_index]
    
    spec_lambda_left=spec.spectral_axis[:max_flux_index]
    spec_lambda_right=spec.spectral_axis[max_flux_index:]
    
    spec_left=spec.flux[:max_flux_index]
    spec_right=spec.flux[max_flux_index:]
    
    index_l=np.argmin(abs(spec_left-max_flux*0.5))  
    lambda_left=spec_lambda_left[index_l]
        
    index_r=np.argmin(abs(spec_right-max_flux*0.5))  
    lambda_right=spec_lambda_right[index_r]
    
    FWHM_spec=lambda_right- lambda_left
    
    return  lambda_left,lambda_right,FWHM_spec

# %%
get_FWHM_spec(sub_mean_Spec_rest_continuum_subtract)

# %%
get_FWHM_spec(sub_rms_Spec_rest_continuum_subtract)

# %%
f, ax = plt.subplots()
#ax.step(sub_rms_Spec_rest.spectral_axis, sub_rms_Spec_rest.flux)
ax.scatter(sub_rms_Spec_rest_continuum_subtract.spectral_axis, sub_rms_Spec_rest_continuum_subtract.flux)

ax.axhline(max(sub_rms_Spec_rest_continuum_subtract.flux).value)
ax.axhline(0.5*max(sub_rms_Spec_rest_continuum_subtract.flux).value)

ax.axvline(4840.55841293)
ax.axvline(4914.03379868)

# %% [markdown]
# np.max(sub_mean_Spec_rest.flux)

# %%
np.argmax(sub_mean_Spec_rest.flux)

# %%
sub_mean_Spec_rest.spectral_axis[np.argmax(sub_mean_Spec_rest.flux)]

# %%
f, ax = plt.subplots()  
ax.step(sub_rms_Spec_rest.spectral_axis, sub_rms_Spec_rest.flux)

# %%
fwhm(sub_mean_Spec_rest_continuum_subtract),fwhm(sub_rms_Spec_rest_continuum_subtract)

# %%
fwzi(sub_mean_Spec_rest),fwzi(sub_rms_Spec_rest)

# %%
gaussian_sigma_width(sub_mean_Spec_rest_continuum_subtract),gaussian_sigma_width(sub_rms_Spec_rest)

# %%
gaussian_fwhm(sub_mean_Spec_rest_continuum_subtract),gaussian_fwhm(sub_rms_Spec_rest)

# %%
FWHM_OBS= 47 * 3.0e5 / 4861
FWHM_inst= 1150
FWHM_correct= (FWHM_OBS**2-FWHM_inst**2)**0.5
print(FWHM_OBS,FWHM_inst,FWHM_correct)


rms_FWHM_OBS= 34 * 3.0e5 / 4861
rms_FWHM_inst= 1150
rms_FWHM_correct= (rms_FWHM_OBS**2-rms_FWHM_inst**2)**0.5
print(rms_FWHM_OBS,rms_FWHM_inst,rms_FWHM_correct)

# %%
sigm2_OBS= 35 * 3.0e5 / 4861
sigm2_inst= 1150
sigm2_correct= (sigm2_OBS**2-sigm2_inst**2)**0.5
print(sigm2_OBS,sigm2_inst,sigm2_correct)

# %%
fig = plt.figure(figsize=(4,figure_n*4))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1)    
#ax = plt.subplots()[1]  
ax.plot(mean_Spec_rest.spectral_axis, mean_Spec_rest.flux)  
ax.set_xlabel("rest wavelength")  
ax.set_ylabel("Flux")  
ax.set_xlim(4700,5120)
ax.axvline(4861)
set_ax_tick(ax)
#ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
#return fig,ax

# %%
fig = plt.figure(figsize=(4,figure_n*4))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1)    
#ax = plt.subplots()[1]  
ax.plot(rms_Spec.spectral_axis/(1+z_pks1510), rms_Spec.flux)  
ax.set_xlabel("rest wavelength")  
ax.set_ylabel("Flux")  
ax.set_xlim(4700,5120)
set_ax_tick(ax)
#ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
#return fig,ax

# %% [markdown]
# ## pks0736

# %%
# glob searches through directories similar to the Unix shell
filelist_pks0736 = glob('/Volumes/ExtremeSSD/00PKU_SCI/Fermi_AGN_optical_monitoring_program_at_Steward_Observatory/Sources/pks0736/*/*.fc.spec*.fits')
# sort alphabetically - given the way the filenames are
# this also sorts in time
filelist_pks0736.sort()

# %%
for i, fname in enumerate(filelist_pks0736):
    w, f, date_obs = read_spec(fname)
    print(w[0],w[1],w[1]-w[0],w[-1],len(w))

# %%
#len(wavelength)
len_wavelength=888
fluxs_pks0736 = np.zeros((len(filelist_pks0736), len_wavelength))
# date comes as string with 23 characters (dtype = 'S23')
dates_pks0736 = np.zeros((len(filelist_pks0736)), dtype = 'S23')

for i, fname in enumerate(filelist_pks0736):
    w, f, date_obs = read_spec(fname)
    
    fluxs_pks0736[i,:] = f[:len_wavelength]
    dates_pks0736[i] = date_obs

# %% [markdown]
# ### mean_spec

# %%
figure_n= 1
fig = plt.figure(figsize=(6,figure_n*4))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1) 

z_pks0736 = 0.189
#ax = plt.subplots()[1]  
#ax.plot(wavelength/(1+z), flux)  
wavelength_s=wavelength[:len_wavelength]
wavelength_restframe=wavelength_s/(1+z_pks0736)

ax.errorbar(wavelength_restframe,np.mean(fluxs_pks0736,axis=0),ms=5,ls='',marker='.')
ax.set_xlabel("rest wavelength")  
ax.set_ylabel("Flux")  
ax.set_xlim(4200-1,5200+1)
ax.axvline(5007)
ax.axvline(4861)
set_ax_tick(ax)
#ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
#return fig,ax

# %% [markdown]
# ### std_spec

# %%
figure_n= 1
fig = plt.figure(figsize=(6,figure_n*4))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1) 

z_pks0736 = 0.189
#ax = plt.subplots()[1]  
#ax.plot(wavelength/(1+z), flux)  
wavelength_s=wavelength[:len_wavelength]
wavelength_restframe=wavelength_s/(1+z_pks0736)

ax.errorbar(wavelength_restframe,np.std(fluxs_pks0736,axis=0,ddof=1),ms=5,ls='',marker='.')
ax.set_xlabel("rest wavelength")  
ax.set_ylabel("Flux")  
ax.set_xlim(4200-1,5200+1)
ax.axvline(5007)
ax.axvline(4861)
set_ax_tick(ax)
#ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
#return fig,ax

# %% [markdown]
# fluxs = np.zeros((len(filelist), len(wavelength)))
# #date comes as string with 23 characters (dtype = 'S23')
# dates = np.zeros((len(filelist)), dtype = 'S23')
#
# for i, fname in enumerate(filelist):
#     w, f, date_obs = read_spec(fname)
#     print(len(w),len(f))

# %% [markdown]
# ### sigma_line

# %%
mean_spec_pks0736=np.mean(fluxs_pks0736,axis=0)
rms_spec_pks0736= np.std(fluxs_pks0736,axis=0,ddof=1)

delta_wavelength=4
lambda_0_pks0736=  np.sum(wavelength[:888]*mean_spec_pks0736*4)/np.sum(mean_spec_pks0736*4)

sigma2_line_pks0736= np.sum(wavelength[:888]**2*mean_spec_pks0736*4)/np.sum(mean_spec_pks0736*4)- lambda_0_pks0736**2

# %%
print(sigma2_line_pks0736)

# %%
print(lambda_0,lambda_0_pks0736)

# %%
mean_Spec_pks0736 = Spectrum1D(spectral_axis=wavelength[:888]*u.AA, flux=mean_spec_pks0736*(u.erg * u.cm**-2 * u.s**-1*u.AA**-1) )
rms_Spec_pks0736 = Spectrum1D(spectral_axis=wavelength[:888]*u.AA, flux=rms_spec_pks0736* (u.erg * u.cm**-2 * u.s**-1*u.AA**-1) )

# %%
4861*(1+0.189)-200,4861*(1+0.189)+200

# %%
fwhm(mean_Spec_pks0736,SpectralRegion(5500*u.AA, 5900*u.AA))

# %%
gaussian_sigma_width(mean_Spec_pks0736), gaussian_fwhm(mean_Spec_pks0736) ,fwhm(mean_Spec_pks0736),fwzi(mean_Spec_pks0736)

# %%
with quantity_support():
    fig = plt.figure(figsize=(4,figure_n*4))
    fig.subplots_adjust(hspace=0.0, wspace = 0.0)
    ax = fig.add_subplot(figure_n,1,1)    
    #ax = plt.subplots()[1]  
    ax.plot(mean_Spec.spectral_axis/(1+z_pks0736), mean_Spec.flux)  
    #ax.set_xlabel("rest wavelength")  
    #ax.set_ylabel("mean Flux")  
    ax.set_xlim(4000-200,5600+200)
    set_ax_tick(ax)
    #ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
    #return fig,ax

# %%
with quantity_support():
    fig = plt.figure(figsize=(4,figure_n*4))
    fig.subplots_adjust(hspace=0.0, wspace = 0.0)
    ax = fig.add_subplot(figure_n,1,1)    
    #ax = plt.subplots()[1]  
    ax.plot(rms_Spec.spectral_axis/(1+z_pks0736), rms_Spec.flux)  
    #ax.set_xlabel("rest wavelength")  
    #ax.set_ylabel("rms Flux")  
    ax.set_xlim(4000-200,5600+200)
    set_ax_tick(ax)
    #ax.set_title('%s'%(filename.split('/')[-1]),pad=20)
    #return fig,ax

# %% [markdown]
# ## StdDevUncertainty

# %%
from specutils import Spectrum1D
from astropy.nddata import StdDevUncertainty

spec = Spectrum1D(spectral_axis=np.arange(5000, 5010)*u.AA, flux=np.random.sample(10)*u.Jy, uncertainty=StdDevUncertainty(np.random.sample(10) * 0.1))

# %% [markdown]
# ## [astropy-UVES](https://python4astronomers.github.io/astropy-UVES/UVES.html)

# %% [markdown]
# ## [analysis](https://specutils.readthedocs.io/en/stable/analysis.html)

# %% [markdown]
# ## noisy_gaussian

# %%
noisy_gaussian

# %%
flux

# %%
import numpy as np
from astropy import units as u
from astropy.nddata import StdDevUncertainty
from astropy.modeling import models
from specutils import Spectrum1D, SpectralRegion
np.random.seed(42)


spectral_axis = np.linspace(11., 1., 200) * u.GHz
spectral_model = models.Gaussian1D(amplitude=5*(2*np.pi*0.8**2)**-0.5*u.Jy, mean=5*u.GHz, stddev=0.8*u.GHz)
flux = spectral_model(spectral_axis)
flux += np.random.normal(0., 0.05, spectral_axis.shape) * u.Jy
uncertainty = StdDevUncertainty(0.2*np.ones(flux.shape)*u.Jy)
noisy_gaussian = Spectrum1D(spectral_axis=spectral_axis, flux=flux, uncertainty=uncertainty)


import matplotlib.pyplot as plt 
plt.step(noisy_gaussian.spectral_axis, noisy_gaussian.flux)

# %%
from specutils.analysis import snr
snr(noisy_gaussian)

# %%
snr(noisy_gaussian, SpectralRegion(6*u.GHz, 4*u.GHz))

# %%
from specutils.analysis import snr_derived
snr_derived(noisy_gaussian)

# %%
snr_derived(noisy_gaussian, SpectralRegion(6*u.GHz, 4*u.GHz))

# %% [markdown]
# ## Line Flux Estimates

# %%
from specutils.analysis import line_flux
line_flux(noisy_gaussian, SpectralRegion(7*u.GHz, 3*u.GHz))  

line_flux(noisy_gaussian).to(u.erg * u.cm**-2 * u.s**-1)

# %%
flux = line_flux(noisy_gaussian)
flux.uncertainty.to(u.erg * u.cm**-2 * u.s**-1)

# %%
line_flux(noisy_gaussian, SpectralRegion(7*u.GHz, 3*u.GHz))

# %%
from specutils.analysis import equivalent_width
noisy_gaussian_with_continuum = noisy_gaussian + 1*u.Jy
equivalent_width(noisy_gaussian_with_continuum)

# %%
equivalent_width(noisy_gaussian_with_continuum, regions=SpectralRegion(7*u.GHz, 3*u.GHz))

# %% [markdown]
# ## centroid

# %%
from specutils.analysis import centroid
centroid(noisy_gaussian, SpectralRegion(7*u.GHz, 3*u.GHz))

# %% [markdown]
# ## Line Widths

# %% [markdown]
# (if FWHM is in unit of wavelength, the width in km/sec is given by c . FWHM /l, with c is the speed of the light = 3.105 km/s). Example, suppose that the FWHM is of 2A at 6563A, the equivalent resolved velocity is about 90 km/s.

# %%
from specutils.analysis import gaussian_sigma_width, gaussian_fwhm, fwhm, fwzi

# %%
gaussian_sigma_width(noisy_gaussian)

# %%
gaussian_fwhm(noisy_gaussian)

# %%
fwhm(noisy_gaussian)

# %%
fwzi(noisy_gaussian)

# %% [markdown]
# ## Dust extinction

# %% [markdown]
# Dust extinction can be applied to Spectrum1D instances via their internal arrays, using the dust_extinction package (http://dust-extinction.readthedocs.io/en/latest)
#
# Below is an example of how to apply extinction.

# %%
astropy.modeling.physical_models.BlackBody

# %% [markdown]
# from astropy.modeling.blackbody import blackbody_lambda
# #from astropy.modeling.models import BlackBody
# from dust_extinction.parameter_averages import F99
#
# wave = np.logspace(np.log10(1000), np.log10(3e4), num=10) * u.AA
# flux = blackbody_lambda(wave, 10000 * u.K)
# spec = Spectrum1D(spectral_axis=wave, flux=flux)
#
# #define the model
# ext = F99(Rv=3.1)
#
# #extinguish (redden) the spectrum
# flux_ext = spec.flux * ext.extinguish(spec.spectral_axis, Ebv=0.5)
# spec_ext = Spectrum1D(spectral_axis=wave, flux=flux_ext)

# %%
from astropy.modeling.models import BlackBody
from dust_extinction.parameter_averages import F99

wave = np.logspace(np.log10(1000), np.log10(3e4), num=10) * u.AA
bb = BlackBody(10000 * u.K)
flux = bb(wave)

# %%
spec = Spectrum1D(spectral_axis=wave, flux=flux)

# define the model
ext = F99(Rv=3.1)

# extinguish (redden) the spectrum
flux_ext = spec.flux * ext.extinguish(spec.spectral_axis, Ebv=0.5)
spec_ext = Spectrum1D(spectral_axis=wave, flux=flux_ext)

# %%
with quantity_support():
    plt.figure()
    plt.semilogx(wave, flux,ls=':')
    plt.semilogx(wave, flux_ext,c='r',ls=':')
    
    plt.axvline(bb.nu_max.to(u.AA, equivalencies=u.spectral()).value, ls='--')
    
    plt.show()

# %%
bb_1 = BlackBody(temperature=5778*u.K)
wav_1 = np.arange(1000, 110000) * u.AA
flux_1  = bb_1(wav_1)

with quantity_support():
    plt.figure()
    plt.semilogx(wav_1, flux_1)
    plt.axvline(bb_1.nu_max.to(u.AA, equivalencies=u.spectral()).value, ls='--')
    plt.show()

# %% [markdown]
# ## Template Cross-correlation

# %%
from specutils.analysis import correlation

size = 200
spec_axis = np.linspace(4500., 6500., num=size) * u.AA
f1 = np.random.randn(size)*0.5 * u.Jy
f2 = np.random.randn(size)*0.5 * u.Jy
rest_value = 6000. * u.AA
mean1 = 5035. * u.AA
mean2 = 5015. * u.AA
g1 = models.Gaussian1D(amplitude=30 * u.Jy, mean=mean1, stddev=10. * u.AA)
g2 = models.Gaussian1D(amplitude=30 * u.Jy, mean=mean2, stddev=10. * u.AA)
flux1 = f1 + g1(spec_axis)
flux2 = f2 + g2(spec_axis)
uncertainty = StdDevUncertainty(0.2*np.ones(size)*u.Jy)
ospec = Spectrum1D(spectral_axis=spec_axis, flux=flux1, uncertainty=uncertainty, velocity_convention='optical', rest_value=rest_value)
tspec = Spectrum1D(spectral_axis=spec_axis, flux=flux2, uncertainty=uncertainty)
corr, lag = correlation.template_correlate(ospec, tspec)

# %%
plt.figure()
plt.scatter(corr, lag)
plt.semilogx()
plt.semilogy()
plt.axvline(bb_1.nu_max.to(u.AA, equivalencies=u.spectral()).value, ls='--')
plt.show()

# %%
#

# %%
figure_n= 1
fig = plt.figure(figsize=(6,figure_n*3))
fig.subplots_adjust(hspace=0.0, wspace = 0.0)
ax = fig.add_subplot(figure_n,1,1)

x=np.arange(5)
for index,i in enumerate(x):
    ax.scatter(index,i)
