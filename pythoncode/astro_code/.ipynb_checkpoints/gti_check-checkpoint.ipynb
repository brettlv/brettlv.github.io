# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import pyfits
import astropy.io.fits as fits

from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

# %%
lcpath='/Volumes/Brettlv_G_m/Astro_sources_data/V404cyg/V404cyg//nustar_v404/90102007002/grp_pipeline_products_10s/V404cygA01_sr.lc'
lightcurve=fits.open(lcpath)
header=lightcurve[0].header

print('originlc:')
#print(repr(header[:]),'\n')
obstime=header['DATE-OBS']
tstartlc=header['tstart']
#tstartlc=header['tstart']
print(obstime,tstartlc)
time=lightcurve[1].data['TIME']
count=lightcurve[1].data['RATE']
# Out:
# originlc:
# 2015-06-24T22:11:07 172880816.9999847

# %% [markdown]
# dmgti fits.lc gti.fits userlimit="rate<40&&rate>20"
# dmcopy "evt2.fits[@dmgti.gti]" evt2_dmgti.fits#

# %% [markdown]
# dmgti V404cygA01_sr.lc gti2040.fits userlimit="rate<40&&rate>20"
# dmgti V404cygA01_sr.lc gti4060.fits userlimit="rate<60&&rate>40"
# dmgti V404cygA01_sr.lc gti6080.fits userlimit="rate<80&&rate>60"
# dmgti V404cygA01_sr.lc gti80100.fits userlimit="rate<100&&rate>80"

# %%
plt.plot(time,count)
#plt.xlim(25845.,  25855)
#plt.ylim(0,120)

# %%
gtitime['start'][0]=np.array([tstartlc+29450])
gtitime['stop'][0]=np.array([tstartlc+29500])

# %%
for i in origin_gtitime:
    print(i[1]-i[0])
# Out:
# 0.025009512901306152
# 3338.775020956993
# 0.17500555515289307
# 6.525001883506775
# 0.17502093315124512
# 0.12503236532211304
# 0.07502859830856323
# 0.5250171422958374
# 0.12501710653305054
# 0.17500567436218262
# 0.12503236532211304
# 1.0249942541122437
# 0.17502093315124512
# 0.17502093315124512
# 0.025009512901306152
# 0.17500567436218262
# 0.12503236532211304
# 0.07502859830856323
# 1.775020956993103
# 0.07502859830856323
# 3307.775020956993
# 0.17499041557312012
# 0.12500184774398804
# 0.12500184774398804
# 18.024994254112244
# 0.2749980688095093
# 3.525001883506775
# 0.17502087354660034
# 0.12501710653305054
# 11.775020956993103
# 0.17502087354660034
# 0.12503236532211304
# 0.07502859830856323
# 0.12503236532211304
# 2.2750133275985718
# 0.17502087354660034
# 0.07502859830856323
# 0.17502093315124512
# 3.5250171422958374
# 0.17502093315124512
# 8.775020956993103
# 0.17502087354660034
# 0.07502859830856323
# 0.775020956993103
# 0.17500567436218262
# 3275.0249942541122
# 0.17499041557312012
# 18.274982810020447
# 3324.2750133275986
# 0.12500184774398804
# 19.274982810020447
# 0.17502087354660034
# 0.775020956993103
# 0.17502087354660034
# 0.12503236532211304
# 0.07502859830856323
# 2.5250171422958374
# 0.12503236532211304
# 0.07502859830856323
# 0.17502093315124512
# 0.12503236532211304
# 0.07502859830856323
# 3311.775020956993
# 0.17500567436218262
# 0.12500184774398804
# 19.524986624717712
# 2273.9999998807907
# 710.0249942541122
# 0.17499041557312012
# 0.12500184774398804
# 17.024994254112244
# 0.17500561475753784
# 0.12500184774398804
# 0.12501710653305054
# 12.77500569820404
# 2506.9999998807907
# 235.02499425411224
# 17.774990439414978
# 0.17499041557312012
# 0.12500184774398804
# 8.525017142295837
# 0.17499041557312012
# 0.024994254112243652
# 5.024994254112244
# 0.17499041557312012
# 0.12501710653305054
# 2772.9999999403954
# 16.525001883506775
# 0.17502093315124512
# 0.775020956993103
# 1.0250247716903687
# 3115.500022828579
# 17.525001883506775
# 0.17502087354660034
# 0.12503236532211304
# 1.2750133275985718
# 0.17502093315124512
# 0.12503236532211304
# 0.07502859830856323
# 0.775020956993103
# 0.17502093315124512
# 0.12503236532211304
# 0.5250171422958374
# 0.17502087354660034
# 0.12503236532211304
# 0.07504385709762573
# 0.7750362157821655
# 0.12503236532211304
# 0.775020956993103
# 0.12501710653305054
# 0.024994254112243652
# 0.12501710653305054
# 1.2749980688095093
# 3269.2749980688095
# 0.17499041557312012
# 19.024994254112244
# 0.12500184774398804
# 16.27499806880951
# 0.17500561475753784
# 0.07501333951950073
# 0.775020956993103
# 0.17500567436218262
# 0.12501710653305054
# 0.17502093315124512
# 3.7750056982040405
# 0.12503236532211304
# 1.2750133275985718
# 0.17502087354660034
# 0.12501710653305054
# 0.07502859830856323
# 0.5250018835067749
# 0.17502093315124512
# 0.07502859830856323
# 11.024994254112244
# 0.17502093315124512
# 0.07502859830856323
# 3.775020956993103
# 0.17503619194030762
# 0.12503236532211304
# 0.07502859830856323
# 3269.775020956993
# 16.524986624717712
# 0.17499041557312012
# 537.7500265836716

# %%
origin_gtitime[0][0]
# Out:
# 172880816.99998474

# %%
origin_gtitime[0][0]-172880816.9999847,origin_gtitime[0][1]-172880816.9999847
# Out:
# (2.9802322387695312e-08, 0.02500954270362854)

# %%
len(origin_gtitime)
# Out:
# 144

# %%
time[0]+tstartlc
# Out:
# 172880816.9999847

# %%
plt.figure(figsize=(12,6))
plt.subplot(111)
plt.plot(time,count,ls='',marker='.')

#gtitstart=tstartlc+29450
#gtitstop=tstartlc+29500

#gtitstart=29100
#gtitstop=29500

for i in origin_gtitime:
    #print(i[1]-i[0])
    if i[1]-i[0]>3000:
        gtitstart=i[0]-tstartlc
        gtitstop=i[1] -tstartlc       
        time_gti= np.logical_and(time>gtitstart,time<gtitstop)
        plt.plot(time[time_gti],count[time_gti],color='red',marker='.',ms=11)


plt.semilogy()
#plt.xlim(30000-1000,30000+1000)
plt.tight_layout()

# %%
plt.figure(figsize=(6,6))
plt.subplot(211)
plt.plot(time,count)
plt.semilogy()
plt.xlim(28000,30000)
plt.subplot(212)
plt.plot(time,count)
plt.xlim(28000,30000)
#plt.ylim(0,1200)
plt.tight_layout()

# %%
tstartlc

# %%
gtipath='/Volumes/Brettlv_G_m/Astro_sources_data/V404cyg/V404cyg//nustar_v404/90102007002/pipeline_out/V404cygA01_gti.fits'
#gtipath='/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_low_29250_29500.fits'
gti=fits.open(gtipath)
headergti=gti[0].header
gtitime=gti[1].data

# %%
origin_gtitime=gtitime.copy()

# %%
origin_gtitime[0]
# Out:
# (172880816.99998474, 172880817.02499425)

#           (1.72938891e+08, 1.72938891e+08),
#           (1.72938892e+08, 1.72938903e+08),
#           (1.72938903e+08, 1.72938903e+08),
#           (1.72938904e+08, 1.72938904e+08),
#           (1.72938904e+08, 1.72938908e+08),
#           (1.72938908e+08, 1.72938908e+08),
#           (1.72938908e+08, 1.72938909e+08),
#           (1.72938909e+08, 1.72938909e+08),
#           (1.72938909e+08, 1.72942179e+08),
#           (1.72942181e+08, 1.72942197e+08),
#           (1.72942197e+08, 1.72942197e+08),
#           (1.72944662e+08, 1.72945200e+08)],
#          dtype=(numpy.record, [('START', '>f8'), ('STOP', '>f8')]))

# %%
gtitime['start'][0],gtitime['stop'][0]
# Out:
# (172880816.99998474, 172880817.02499425)

# %%
gti_made= np.array([(1,2),(3,5),(12,100)])

# %%
gti_made
# Out:
# array([[  1,   2],
#        [  3,   5],
#        [ 12, 100]])

# %%
gti_made[:,0]
# Out:
# array([ 1,  3, 12])

# %%
import numpy as np
gti_made = np.rec.array([(1,2),(3,5),(12,100)],
                      formats='float64,float64',
                      names='START,STOP')

gti[1].data=gti_made

# %%
gti_made
# Out:
# rec.array([( 1.,   2.), ( 3.,   5.), (12., 100.)],
#           dtype=[('START', '<f8'), ('STOP', '<f8')])

# %%
gtitime['start'],gtitime['stop']
gtitime['start'][0]=np.array([tstartlc+29450])
gtitime['stop'][0]=np.array([tstartlc+29500])
gtitime['start'][1:]=0
gtitime['stop'][1:]=0
#gti.writeto('newgti_low_29450_29500.fits')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 gtitime['start'],gtitime['stop']
# ----> 2 gtitime['start'][0]=np.array([tstartlc+29450])
#       3 gtitime['stop'][0]=np.array([tstartlc+29500])
#       4 gtitime['start'][1:]=0
#
# NameError: name 'tstartlc' is not defined

# %%
gti=fits.open(gtipath)
headergti=gti[0].header
gtitime=gti[1].data
#gtitime['start'],gtitime['stop']
gtitime['start'][0]=np.array([tstartlc+29450])
gtitime['stop'][0]=np.array([tstartlc+29500])
gtitime['start'][1:]=0
gtitime['stop'][1:]=0
#gti.writeto('newgti.fits')

# %%
ls *gti*.fits

# %%
#gtitime=gti[1].data
#gtitime['start']-tstartlc,gtitime['stop']-tstartlc

# %%
gtitime[:3][0][0]-tstartlc,gtitime[:3][0][1]-tstartlc

# %%
gti=pyfits.open('newgti_low_29250_29500.fits')
gtitime=gti[1].data
gtitime[:3][0][0]-tstartlc,gtitime[:3][0][1]-tstartlc

# %%
ls newgti*

# %%
gti

# %%
gtitime=gti[1].data
#gtitime['start'],gtitime['stop']
gtitime['start'][0]=np.array([tstartlc+29250])
gtitime['stop'][0]=np.array([tstartlc+29280])
gtitime['start'][1:]=0
gtitime['stop'][1:]=0

# %%
gtitime.columns.info

# %%
#gtitime['start']=np.array([172880816.99998474])
#gtitime['stop']=np.array([172880917.02499425])

# %%
gtitime['start'][0],gtitime['stop'][0]

# %%
gtitime['start'][:3],gtitime['stop'][:3]

# %%
gti.writeto('newgti_low_29250_29500.fits')

# %%
ls newgti*

# %%
## gtipath='newgti_high.fits'
gti=pyfits.open(gtipath)
header=gti[1].data
header[:3]

# %%
pwd

# %%
gtipath='/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007003/pipeline_out/gti50.fits'
gti=pyfits.open(gtipath)
header=gti[1].data
header[:3]

# %% [markdown]
# export HEADAS=/Users/brettlv/src_heasoft/heasoft-6.22.1/x86_64-apple-darwin16.7.0/
# . $HEADAS/headas-init.sh
# source /Users/brettlv/src_heasoft/heasoft-6.22.1/CALDB/software/tools/caldbinit.sh

# %%
# !cp newgti_low.fits /Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_low.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_low srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=1 usrgtifile=./pipeline_out/newgti_low.fits

# %%
# !cp newgti_high.fits /Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_high.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_high srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=1 usrgtifile=./pipeline_out/newgti_high.fits

# %%
# !cp newgti_high_1.fits /Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_high_1.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_high_1 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=1 usrgtifile=./pipeline_out/newgti_high_1.fits

# %%
# !cp newgti_high_2.fits /Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_high_2.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_high_2 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=1 usrgtifile=./pipeline_out/newgti_high_2.fits

# %%
# !cp newgti_high_3.fits /Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_high_3.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_high_3 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=1 usrgtifile=./pipeline_out/newgti_high_3.fits

# %%
# !cp newgti_low_29250_29500.fits /Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/nustar_v404/90102007002/pipeline_out/newgti_low_29250_29500.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_low_29250_29500 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_low_29250_29500.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_le_20 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_20.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_20 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti20.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_20_40 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_2040.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_20_40 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti2040.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_40_60 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_4060.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_40_60 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti4060.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_60_80 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_6080.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_60_80 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti6080.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_80_100 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_80100.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_80_100 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti80100.fits

# %%
ls *pdf

# %%
# !open bb.pdf

# %%
#ciao for 7003
dmgti V404cygA01_sr.lc gti50100.fits userlimit="rate<100&&rate>50"

dmgti V404cygA01_sr.lc gti50.fits userlimit="rate<51&&rate>1"

dmgti V404cygA01_sr.lc gti5070.fits userlimit="rate<70&&rate>50"

dmgti V404cygA01_sr.lc gti7090.fits userlimit="rate<90&&rate>70"

dmgti V404cygA01_sr.lc gti3050.fits userlimit="rate<50&&rate>30"

dmgti V404cygA01_sr.lc gti1030.fits userlimit="rate<30&&rate>10"

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_50 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti50.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_50100 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti50100.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_1030 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti1030.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_3050 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti3050.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_5070 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti5070.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_7090 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/gti7090.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_29250_280 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_low_29250_29280.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_29280_400 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_low_29280_29400.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_29400_450 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_low_29400_29450.fits

# %%
nuproducts indir=./pipeline_out instrument=FPMA steminputs=V404cyg outdir=./grp_pipeline_products_29450_500 srcregionfile=./pipeline_out/src.reg bkgregionfile=./pipeline_out/bkg.reg rungrppha=yes grpmincounts=30 grppibadlow=35 grppibadhigh=1909  binsize=10 usrgtifile=./pipeline_out/newgti_low_29450_29500.fits
