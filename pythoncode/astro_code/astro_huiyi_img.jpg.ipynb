# %%
import numpy as np
import os,os.path
image='../../huiyi1.jpg'

import PIL
from PIL import Image
im=Image.open(image)
im.format, im.size, im.mode
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x830 at 0x108738FA0>

# %%
import __hello__
# Out:
# Hello world!
