# %% [markdown]
# Arxiv reading

# %% [markdown]
# arXiv:1903.05241  [pdf, ps, other]   astro-ph.HE
# Probing the Physical Properties of the Corona in Accreting Black Holes
#
# Authors: Nikita Kamraj, Andrew Fabian, Anne Lohfink, Mislav Baloković, Claudio Ricci, Kristin Madsen
#
#
# arXiv:1811.10657  [pdf, other]   astro-ph.GA astro-ph.HE
# doi
# 10.3847/1538-4357/aaf38b
# NuSTAR Hard X-ray View of Low-luminosity Active Galactic Nuclei: High-energy Cutoff and Truncated Thin Disk
#
# Authors: George Younes, Andrew Ptak, Luis C. Ho, Fu-Guo Xie, Yuichi Terasima, Feng Yuan, Daniela Huppenkothen, Mihoko Yukita
#
# arXiv:1712.02571  [pdf, other]   astro-ph.HE
# The evolution of GX 339-4 in the low-hard state as seen by NuSTAR and Swift
#
# arXiv:1310.3830  [pdf, ps, other]   astro-ph.HE
# doi
# 10.1088/0004-637X/780/1/78
# The Reflection Component from Cygnus X-1 in the Soft State Measured by NuSTAR and Suzaku
#
#
# arXiv:1301.7307  [pdf, other]   astro-ph.IM astro-ph.HE
# doi
# 10.1088/0004-637X/770/2/103
# The Nuclear Spectroscopic Telescope Array (NuSTAR) Mission
#
# Authors: Fiona A. Harrison, William W. Craig

# %% [markdown]
# # 2019

# %% [markdown]
# ## 04
# ### week1
# #### day2
# arXiv:1904.00106 [pdf, other]
# Using evolutionary algorithms to model relativistic jets: Application to NGC 1052
#
# arXiv:1904.00554 [pdf, other]
# On high-energy particles in accretion disk coronae of supermassive black holes: implications for MeV gamma rays and high-energy neutrinos from AGN cores
#
# arXiv:1904.00663 [pdf, ps, other]
# Polca SARA - Full polarization, direction-dependent calibration and sparse imaging for radio interferometry
# Jasleen Birdi, Audrey Repetti, Yves Wiaux
#
#
# arXiv:1904.00814 [pdf, other]
# Active galactic nuclei imaging programs of the RadioAstron mission
# Gabriele Bruni, Tuomas Savolainen, Jose Luis Gómez, Andrei P. Lobanov, Yuri Y. Kovalev
#
#
# arXiv:1904.00914 [pdf, ps, other]
# Unveiling the nature of compact object in the LMXB MAXI J1957+032 using Swift-XRT
# Aru Beri, D. Altamirano, R. Wijnands, N. Degenaar, A.S. Parikh, K. Yamaoka
#
# #### day3
#  arXiv:1904.01066 [pdf, other]
# CG X-1: an eclipsing Wolf-Rayet ULX in the Circinus galaxy
# Yanli Qiu, Roberto Soria, Song Wang, Grzegorz Wiktorowicz, Jifeng Liu, Yu Bai, Alexey Bogomazov, Rosanne Di Stefano, Dominic J. Walton, Xiaojie Xu
#
# arXiv:1904.01237 [pdf, ps, other]
# The Interstellar Medium: The Key Component in Galactic Evolution and Modern Cosmology
# Carl Heiles, Di Li, Naomi McClure-Griffiths, Lei Qian, Shu Liu
#
#
#
# !!! arXiv:1904.01365 [pdf, other]
# Imaging the AGN Torus in Cygnus
# C.L. Carilli (NRAO, MRAO), R.A. Perley, V. Dhawan (NRAO), D.A. Perley
#
#  arXiv:1904.01404 [pdf, ps, other]
# Exploring the Mass Segregation Effect of X-ray Sources in Globular Clusters: The Case of 47 Tucanae
# Zhongqun Cheng, Zhiyuan Li, Xiangdong Li, Xiaojie Xu, Taotao Fang
#
#
#
# #### day4
#
#
#  arXiv:1904.01598 [pdf, ps, other]
# A stochastic propagation model to the energy dependent rapid temporal behaviour of Cygnus X-1 as observed by AstroSat in the hard state
# Bari Maqbool
# A relatively simple model with the
# thermal Comptonization (nthcomp) (Zycki, Done & Smith ˙
# 1999) as the primary component, a reflection component(reflionx), disk emission (diskbb) and an interstellar absorption (tbabs) was used.
#
#
# arXiv:1904.01601 [pdf, other]
# Astro2020 Science White Paper: A Summary of Multimessenger Science with Galactic Binaries
# Thomas Kupfer (Kavli Institute for Theoretical Physics
#
#  arXiv:1904.01765 [pdf, other]
# A Fundamental Plane for Gamma-Ray Pulsars
# Constantinos Kalapotharakos
#
#  arXiv:1904.01773 [pdf, other]
# Astro2020: From Stars to Compact Objects: The Initial-Final Mass Relation
# Jessica R. Lu
#
#
#  arXiv:1904.02022 [pdf, other]
# On the Measurement of Fundamental Parameters of White Dwarfs in the Gaia Era
# P. Bergeron
#
# #### day5
# arXiv:1904.02180 [pdf, other]
# dynesty: A Dynamic Nested Sampling Package for Estimating Bayesian Posteriors and Evidences
# Joshua S Speagle
# Comments: 28 pages, 12 figures, submitted to MNRAS; code available at this https URL
# Subjects: Instrumentation and Methods for Astrophysics (astro-ph.IM); Computation (stat.CO)
#
#
#  arXiv:1904.02686 [pdf, other]
# A multi-wavelength pipeline for pulsar searches
# Maura Pilia, Alessio Trois, Matteo Bachetti, Alberto Pellizzoni, Giuseppe Atzeni, Elise Egron, Maria Noemi Iacolina, Sara Loru, Antonio Poddighe, Valentina Vacca
# Comments: Accepted for publications in Rendiconti Lincei as Proceedings of "A Decade of AGILE: Results
#
# ### week2
# #### day1
#  arXiv:1904.02718 [pdf, other]
# Astro 2020 Science White Paper: Joint Gravitational Wave and Electromagnetic Astronomy with LIGO and LSST in the 2020's
# Philip S. Cowperthwaite (Carnegie Observatories), Hsin-Yu Chen (Harvard/BHI), Ben Margalit (Columbia), Raffaella Margutti (Northwestern), Morgan May (Columbia), Brian Metzger (Columbia), Chris Pankow (Northwestern)
#
# arXiv:1904.02720 [pdf, other]
# Bottom-up Acceleration of Ultra-High-Energy Cosmic Rays in the Jets of Active Galactic Nuclei
# Rostom Mbarek, Damiano Caprioli
#
# arXiv:1904.02863 [pdf, other]
# Parallelized Inference for Gravitational-Wave Astronomy
# Colm Talbot, Rory Smith, Eric Thrane, Gregory B. Poole
# Comments: 5 pages, 3 figures, submitted to PRD, code can be found at this https URL this https URL this https URL
#
# arXiv:1904.02894 [pdf, ps, other]
# Jet Kinematics of the Quasar 4C +21.35 from Observations with the KaVA Very Long Baseline Interferometry Array
#
#
#  arXiv:1904.02950 [pdf, ps, other]
# Inclination effects on the X-ray emission of Galactic black-hole binaries
# P. Reig (FORTH, Univ. of Crete), N. Kylafis (Univ. of Crete, FORTH)
# Subjects: High Energy Astrophysical Phenomena (astro-ph.HE)
# Galactic black-hole X-ray binaries (BHBs) emit a compact, optically thick, mildly relativistic radio jet when they are in the hard and hard-intermediate states. In these states, BHBs exhibit a correlation between the time lag of hard photons with respect to softer ones and the photon index of the power law component that characterizes the X-ray spectral continuum above ∼ 10 keV. The correlation, however, shows large scatter. Our objective is to investigate the role that the inclination of the system plays on the correlation between the time lag and the photon index. We find that the correlation between the time lag and the photon index is tight in low-inclination systems and becomes weaker in high-inclination systems. The amplitude of the lags is also larger at low and intermediate inclination angles than at high inclination. Our jet model that reproduces the process of Comptonization in an extended jet can account for the observations remarkably well.
#
#
#  arXiv:1904.03095 [pdf, ps, other]
# Detection of a double-peaked Hα component from the accretion disc of NGC 4958
# T.V. Ricci, J.E. Steiner
#
# #### day2
#  arXiv:1904.03203 [pdf, other]
# Radiation pattern and outflow geometry: a new probe of black hole spin?
# W. Ishibashi, A. C. Fabian, C. S. Reynolds
#
#  arXiv:1904.03243 [pdf, other]
# Accelerating AGN jets to parsec scales using general relativistic MHD simulations
# Koushik Chatterjee
#
# arXiv:1904.03338 [pdf, other]
# Observational Constraints on the Feeding of Supermassive Black Holes
# Thaisa Storchi-Bergmann, Allan Schnorr-Müller
#
# arXiv:1904.03393 [pdf, ps, other]
# Supermassive black holes with high accretion rates in active galactic nuclei: X. Optical variability characteristics
#
# arXiv:1904.03694 [pdf, ps, other]
# Torus model properties of an ultra-hard X-ray selected sample of Seyfert galaxies
#
# arXiv:1904.03740 [pdf, other]
# The Accretion Disc-Jet Connection in Blazars
# Sagnick Mukherjee (1)
#
# arXiv:1904.03827 [pdf, other]
# Piercing Through Highly Obscured and Compton-thick AGNs in the Chandra Deep Fields: I. X-ray Spectral and Long-term Variability Analyses
#
#  arXiv:1904.03871 [pdf, ps, other]
# Astrophysical constraints on the proton-to-electron mass ratio with FAST
# Xi Chen, Simon P. Ellingsen, Ying Mei
#
#  arXiv:1904.03914 [pdf, ps, other]
# Polarization of changing-look quasars
# D. Hutsemékers, B. Agís González, F. Marin, D. Sluse, C. Ramos Almeida, J.-A. Acosta Pulido
# Comment
#
# arXiv:1904.04074 [pdf, ps, other]
# Alternative approach to gravity and MOND
# Jozef Klačka
#
# arXiv:1904.04108 [pdf, ps, other]
# A systematic TMRT observational study of Galactic 12C/13C ratios from Formaldehyde
# Y. T. Yan, J. S. Zhang, C. Henkel, T. Mufakharov, L. W. Jia, X. D. Tang, Y. J. Wu, J. Li, Z. A. Zeng, Y. X. Wang, Y. Q. Li, J. Huang, J. M. Jian
#
#
# #### day3
# arXiv:1904.04311 [pdf]
# Astro2020 APT White Paper: "Mind the gap": a call to redesign astronomy graduate education
# Amaya Moro-Martín
#
# arXiv:1904.04654 [pdf, other]
# Electric charge of black holes: Is it really always negligible?
# Michal Zajaček, Arman Tursunov
#
#  arXiv:1904.04684 [pdf, other]
# Comparison of SEDs of very massive radio-loud and radio-quiet AGN
# Maitrayee Gupta, Marek Sikora, Katarzyna Rusinek
#
#
# #### day4
#
# arXiv:1904.03827 [pdf, other]
# Piercing Through Highly Obscured and Compton-thick AGNs in the Chandra Deep Fields: I. X-ray Spectral and Long-term Variability Analyses
#
#
#
#  arXiv:1904.04835 [pdf, other]
# Accretion Feedback from newly-formed black holes and its implications for LIGO Sources
#
#
# arXiv:1904.04905 [pdf, ps, other]
# Ultraluminous X-ray sources with flat-topped noise and QPO
# K. Atapin, S. Fabrika, M. D. Caballero-Garcia
#
#
# arXiv:1904.04907 [pdf]
# The Detailed Science Case for the Maunakea Spectroscopic Explorer, 2019 edition
# The MSE Science Team: Carine Babusiaux, Maria Bergemann, Adam Burgasser, Sara Ellison, Daryl Haggard, Daniel Huber, Manoj Kaplinghat, Ting Li, Jennifer Marshall, Sarah Martell, Alan McConnachie, Will Percival, Aaron Robotham, Yue Shen, Sivarani Thirupathi, Kim-Vy Tran, Christophe Yeche, David Yong, Vardan Adibekyan, Victor Silva Aguirre, George Angelou, Martin Asplund, Michael Balogh, Projjwal Banerjee, Michele Bannister, Daniela Barría, Giuseppina Battaglia, Amelia Bayo, Keith Bechtol, Paul G. Beck, Timothy C. Beers, Earl P. Bellinger, Trystyn Berg, Joachim M. Bestenlehner, Maciej Bilicki, Bertram Bitsch, Joss Bland-Hawthorn, Adam S. Bolton, Alessandro Boselli, Jo Bovy, Angela Bragaglia, Derek Buzasi, Elisabetta Caffau, Jan Cami, Timothy Carleton, Luca Casagrande, Santi Cassisi, Márcio Catelan, et al. (215 additional authors not shown)
# Comments: 9 chapters, 301 pages, 100 figures. This version of the DSC is a comprehensive update of the original version, released in 2016, which can be downloaded at arXiv:1606.00043. A detailed summary of the design of MSE is available in the MSE Book 2018, available at arXiv:1810.08695
#
#
#
# arXiv:1904.04923 [pdf, other]
# The Event Horizon General Relativistic Magnetohydrodynamic Code Comparison Project
#
# arXiv:1904.04934 [pdf, other]
# Simulations of imaging the event horizon of Sagittarius A* from space
#
#
#
# #### day5
#
#  arXiv:1904.05368 [pdf, other]
# A magnetar-powered X-ray transient as the aftermath of a binary neutron-star merger
# Y. Q. Xue, X. C. Zheng
#
# arXiv:1904.05539 [pdf, ps, other]
# On the Polarized Nonthermal Emission from AR Scorpii
# J. Takata (HUST), K.S. Cheng (HKU)
#
#  arXiv:1904.05619 [pdf, ps, other]
# A Stochastic LBFGS Algorithm for Radio Interferometric Calibration
# Sarod Yatawatta, Lukas De Clercq, Hanno Spreeuw, Faruk Diblen
#
#  arXiv:1904.05482 [pdf, other]
# PSR J1926-0652: A Pulsar with Interesting Emission Properties Discovered at FAST
# Lei Zhang, Di Li, George Hobbs,
#
# arXiv:1904.05480 [pdf, ps, other]
# On the properties of a newborn magnetar powering the X-ray transient CDF-S XT2
#
#
# ### week3
# #### day1
#  arXiv:1904.05882 [pdf, ps, other]
# Planning the scientific applications of the Five-hundred-meter Aperture Spherical radio Telescope
# Di Li, John M. Dickey, Shu Liu
#
#  arXiv:1904.05895 [pdf, ps, other]
# Nonlinear Variability of Quasi-Periodic Oscillations in GX 339-4
# K. Arur, T. J. Maccarone
#
#  arXiv:1904.05920 [pdf, other]
# DeepStreaks: identifying fast-moving objects in the Zwicky Transient Facility data with deep learning
#
#  arXiv:1904.05922 [pdf, other]
# Transient processing and analysis using 𝙰𝙼𝙿𝙴𝙻: Alert Management, Photometry and Evaluation of Lightcurves
#
# arXiv:1904.05969 [pdf, other]
# The Galactic Centre Chimney
# G. Ponti, F. Hofmann, E. Churazov, M. R. Morris, F. Haberl, K. Nandra, R. Terrier, M. Clavel, A. Goldwurm
#
# arXiv:1904.06043 [pdf, other]
# Open Universe for Blazars: a new generation of astronomical products based on 14 years of Swift-XRT data
#
#
#  arXiv:1904.06146 [pdf, other]
# Reverberation mapping of narrow-line Seyfert 1 galaxy I Zwicky 1: black hole mass
#
# We report results of the first reverberation mapping campaign of I Zwicky 1 during 2014-2016, which showed unambiguous reverberations of the broad Hβ line emission to the varying optical continuum. From analysis using several methods, we obtain a reverberation lag of τHβ=37.2+4.5−4.9 days. Taking a virial factor of fBLR=1, we find a black hole mass of M∙=9.30+1.26−1.38×106M⊙ from the mean spectra. The accretion rate is estimated to be 203.9+61.0−65.8LEddc−2, suggesting a super-Eddington accretor, where LEdd is the Eddington luminosity and c is the speed of light.
#
#  arXiv:1904.06334 [pdf, other]
# The evolving X-ray spectrum of active galactic nuclei: evidence for an increasing reflection fraction with redshift
#
#
# #### day2
#
#
# arXiv:1904.06363 [pdf, other]
# A Bayesian Analysis of SDSS J0914+0853, a Low-Mass Dual AGN Candidate
#
#  arXiv:1904.06476 [pdf, ps, other]
# Investigating the origin of the Fe emission lines of the Seyfert 1 galaxy Mrk~205
#
#
#
# arXiv:1904.06767 [pdf, other]
# Mechanism of the Changing Look phenomenon in Active Galactic Nuclei
# Marzena Śniegowska, Bożena Czerny
# Comments: 7 pages, 5 figures, Submitted to ApJLetters, Comments welcome
# Subjects: Astrophysics of Galaxies (astro-ph.GA)
# Changing-look phenomenon observed now in a growing number of active galaxies challenges our understanding of the accretion process close to a black hole. We propose a simple explanation for periodic outbursts in sources operating at a few per cent of the Eddington limit. The mechanism is based on two relatively well understood phenomena: radiation pressure instability and formation of the inner optically thin Advection-Dominated Accretion Flow. The limit cycle behaviour takes place in a relatively narrow transition zone between the standard disk and optically thin flow. Large changes in the cold disk are due to the irradiation by the hot flow with accretion rate strongly varying during the cycle. The model gives quantitative predictions and works well for multiple outbursts of NGC 1566.
#
#
#  arXiv:1904.07057 [pdf, other]
# Inferring AGN jet parameters using Bayesian analysis of VLBI data with non-uniform jet model
# Ilya N. Pashchenko, Alexander V. Plavin
#
#
#
# arXiv:1904.07106 [pdf, ps, other]
# Reply to comment on: "An X-ray chimney extending hundreds of parsecs above and below the Galactic Centre"
# G. Ponti, F. Hofmann, E. Churazov, M. R. Morris, F. Haberl, K. Nandra R. Terrier, M. Clavel, A. Goldwurm
# Subjects: High Energy Astrophysical Phenomena (astro-ph.HE); Astrophysics of Galaxies (astro-ph.GA)
# In response to the comment posted by Nakashima et al. (arXiv:1903.11767), regarding prior claims for the features that we referred to as the Galactic Center Chimneys (2019, Nature, 567, 347), we point out the following:
# 1) The Nakashima et al. 2019 paper appeared in the arXiv on March 8th (1903.02571), after our paper was in the final stage of printing (accepted on January 30th). It is however interesting to see that the morphology of the brightest portions of the two results are in broad agreement (compare their Fig. 1 to our Extended Data Figs. 1 and 2).
# 2) Nakashima et al. 2013 ApJ 773, 20 claim the discovery of a blob of recombining plasma ~1deg south of Sgr A*, implying peculiar abundances. Again, their image (Fig. 1) agrees with the brightest portions of our images, although it does not show any direct connection between the plasma blob and the central parsec (e.g., such as the quasi-continuous chimney that we reported), nor evidence for an outflow from the center. We apologize for overlooking an appropriate citation to this contribution by Nakashima et al.
# 3) We fitted the XMM-Newton and Chandra data at the same position of the claimed recombining plasma and we did not find any clear-cut evidence for the presence of either an over-ionised plasma or peculiar abundances. Future X-ray calorimetric observations will presumably clarify this disagreement.
# 4) The continuity of the Chimney features, their quasi-symmetrical placement relative to Sgr A*, and their relatively sharp and well-defined edges are the essential features of our data that have led us to propose that the Chimneys are a unified columnar structure that represents a channel for the outflow of energy from the central region, possibly contributing to the stocking of the relativistic particle population manifested in the Fermi Bubbles.
#
# arXiv:1903.11767  [pdf, ps, other]   astro-ph.GA
# Comment on "An X-ray chimney extending hundreds of parsecs above and below the Galactic Centre" (2019, Nature, 567, 34)
#
# Authors: Shinya Nakashima, Katsuji Koyama, Q. Daniel Wang
#
# Abstract: A recent article "An X-ray chimney extending hundreds of parsecs above and below the Galactic Centre" (2019, Nature, 567, 34) reported the detection of chimney-like X-ray-emitting features above and below the Galactic Center from XMM-Newton observations. We note here that these features were already reported by our Suzaku papers: Nakashima et al. (2013, ApJ, 773, 20, arXiv:1310.4236) for the south… ▽ More
# Submitted 27 March, 2019; originally announced March 2019.
#
# arXiv:1903.02571  [pdf, other]   astro-ph.GA astro-ph.HE
# X-ray Observation of a Magnetized Hot Gas Outflow in the Galactic Center Region
#
# Authors: Shinya Nakashima, Katsuji Koyama, Q. Daniel Wang, Rei Enokiya
#
# Abstract: We report the discovery of a 1∘ scale X-ray plume in the northern Galactic Center (GC) region observed with Suzaku. The plume is located at (l, b) ∼ (0.∘2, 0.∘6), east of the radio lobe reported by previous studies. No significant X-ray excesses are found inside or to the west of the radio lobe. The spectrum of the plume exhibits strong emiss… ▽ More
# Submitted 6 March, 2019; originally announced March 2019.
#
#
#
#
#
# #### day3
# arXiv:1904.07243 [pdf, other]
# A Mechanism for Triple-Ridge Emission Structure of AGN Jets
# Taiki Ogihara, Kazuya Takahashi, Kenji Toma
#
#
#  arXiv:1904.07341 [pdf, other]
# A global view of the inner accretion/ejection flow around super massive black holes: radiation driven accretion disk winds in a physical context
#
#  arXiv:1904.07527 [pdf, ps, other]
# Modelling the multi-wavelength emissions from PSR B1259-63/LS 2883: the effects of the stellar disc on shock radiations
# A. M. Chen, J. Takata, S. X. Yi, Y. W. Yu, K. S. Cheng
# Comments: 14 pages, 6 figures
#
#  arXiv:1904.07540 [pdf, other]
# The rare extended radio-loud narrow-line Seyfert 1 galaxy SDSS J1030+5516 at high resolution
# Krisztina Éva Gabányi, Sándor Frey, Péter Veres, Attila Moór
# Comments: 9 pages, 2 figures; accepted for publication in Astrophysics and Space Science
# Subjects: Astrophysics of Galaxies (astro-ph.GA); High Energy Astrophysical Phenomena (astro-ph.HE)
# Recently, Rakshit et al. (2018) reported the discovery of SDSS J103024.95+551622.7, a radio-loud narrow-line Seyfert 1 galaxy having a ∼100 kpc scale double-lobed radio structure. Here we analyse archival radio interferometric imaging data taken with the Very Large Array (VLA) at 5 GHz, and with the Very Long Baseline Array (VLBA) at 4.3 and 7.6 GHz. Two hotspots and a compact core are detected with the VLA at arcsec scale, while a single milliarcsec-scale compact radio core is seen with the highest resolution VLBA observations. The Fermi Large Area Telescope did not detect γ-ray emission at the position of this source. In the mid-infrared, the Wide-field Infrared Survey Explorer satellite light curve, covering more than 7 years and including the most recent data points, hints on flux density variability at 3.4 μm. Our findings support the notion that this source is a young version of Fanaroff-Riley type II radio galaxies.
#
#
# arXiv:1904.07621 [pdf, other]
# Outflows in the Discs of Active Galaxies
# N. Menci, F. Fiore, C. Feruglio, A. Lamastra, F. Shankar, E. Piconcelli, E. Giallongo, A. Grazian
#
#  arXiv:1904.07803 [pdf, other]
# The X-ray binary GX 339-4/V821 Ara: the distance, inclination, evolutionary status and mass transfer
#
#
#
# #### day4
# arXiv:1904.07923 [pdf, other]
# Measurement of the spin of the M87 black hole from its observed twisted light
# Fabrizio Tamburini, Bo Thidé, Massimo Della Valle
#
#  arXiv:1904.07947 [pdf, other]
# Fast Radio Bursts
# E. Petroff, J. W. T. Hessels, D. R. Lorimer
#
# arXiv:1904.08110 [pdf, other]
# A candidate theory/model for Advection-Dominated-Accretion-Flow (ADAF)
# Hongsu Kim, Uicheol Jang, Yu Yi
#
#
#
#
#
# #### day5
# arXiv:1904.08406 [pdf, other]
# Revealing the differences in the SMBH accretion rate distributions of starburst and non-starburst galaxies
#
# arXiv:1904.08425 [pdf, other]
# Jet-cocoon outflows from neutron star mergers: structure, light curves, and fundamental physics
#
#
#
# arXiv:1904.08693 [pdf, other]
# Convolutional neural networks: a magic bullet for gravitational-wave detection?
#
# arXiv:1904.08867 [pdf, other]
# A joint deconvolution algorithm to combine single dish and interferometer data for wideband multi-term and mosaic imaging
# Urvashi Rau, Nikhil Naik, Timothy Braun
#
#
#
#
#
#
# ### week4
# #### day1
#
# arXiv:1904.08946 [pdf, ps, other]
# Rapid Luminosity Decline and Subsequent Reformation of the Innermost Dust Distribution in the Changing-look AGN Mrk 590
# Mitsuru Kokubo (Tohoku University), Takeo Minezaki (The University of Tokyo)
#
#
#  arXiv:1904.09112 [pdf, ps, other]
# Long-term spectral study of the black hole Cygnus X-1 using INTEGRAL
#
#  arXiv:1904.09242 [pdf, other]
# Ultra Light Boson Dark Matter and Event Horizon Telescope Observations of M87*
# Hooman Davoudiasl, Peter B. Denton
#
#
# #### day2
#
# arXiv:1904.09293 [pdf, other]
# Discovery and Early Evolution of ASASSN-19bt, the First TDE Detected by TESS
#
#
#  arXiv:1904.09313 [pdf, other]
# Astro2020 Science White Paper: Using X-Ray Polarimetry to Probe the Physics of Black Holes and Neutron Stars
#
# arXiv:1904.09326 [pdf, other]
# Disentangling nature from nurture: tracing the origin of seed black holes
#
#  arXiv:1904.09652 [pdf, other]
# X-ray cavities in the hot corona of the lenticular galaxy NGC~4477
# Yijia Li, Yuanyuan Su, Christine Jones
#
# arXiv:1904.09677 [pdf, other]
# Magnetic fields in accretion disks: a review
# Amir Jafari
#
#  arXiv:1904.09731 [pdf, other]
# Merge or survive: Number of Population III stars per minihalo
# Hajime Susa
#
#  arXiv:1904.09753 [pdf, ps, other]
# Fast orbital shrinkage of black hole X-ray binaries driven by circumbinary disks
# Wen-Cong Chen, Philipp Podsiadlowski
#
# arXiv:1904.09762 [pdf, other]
# Chandra, MDM, Swift, and NuSTAR observations confirming the SFXT nature of AX J1949.8+2534
#
#  arXiv:1904.09852 [pdf, other]
# Uncovering Red and Dusty Ultraluminous X-ray Sources with Spitzer
#
#
#
#
# #### day3
#
#
# arXiv:1904.10002 [pdf, other]
# Constraints on the Neutron Star Equation of State from GW170817
# Carolyn A. Raithel
#
#
# 1904.08111
# First Detection of Radio Linear Polarization of GRB Afterglow
# Y. Urata
#
# arXiv:1904.10012 [pdf, other]
# Astro2020 White Paper: On the Origin of the Initial Mass Function
#
#  arXiv:1904.10008 [pdf, other]
# Understanding the Engines and Progenitors of Gamma-Ray Bursts
# Chris L. Fryer, Nicole Lloyd-Ronning, Ryan Wollaeger, Brandon Wiggins, Jonah Miller, Josh Dolence, Ben Ryan, Carl E. Fields
#
# arXiv:1904.10116 [pdf, other]
# Tracing Black Hole and Galaxy Co-evolution in the Romulus Simulations
#
#  arXiv:1904.10222 [pdf, other]
# The first 100 ms of a long-lived magnetized neutron star formed in a binary neutron star merger
#
#
#
# arXiv:1904.10259 [pdf, other]
# Unveiling the 100 pc scale nuclear radio structure of NGC 6217 with e-MERLIN and the VLA
#
#  arXiv:1904.10286 [pdf, other]
# Generative deep fields: arbitrarily sized, random synthetic astronomical images through deep learning
#
# arXiv:1904.10433 [pdf, ps, other]
# Pulsating in unison at optical and X-ray energies: simultaneous high-time resolution observations of the transitional millisecond pulsar PSR J1023+0038
#
# arXiv:1904.10439 [pdf, other]
# Enhancing LSST Science with Euclid Synergy
#
#
# #### day4
#
# arXiv:1904.10484 [pdf, other]
# TurbuStat: Turbulence Statistics in Python
# Eric W. Koch, Ryan D. Boyden, Blakesley Burkhart, Adam Ginsburg, Jason L. Loeppky, Stella S.R. Offner
#
#
#
#  arXiv:1904.10488 [pdf, other]
# Gamma-Ray Bursts: Theoretical Issues and Developments
# P. Mészáros
#
# arXiv:1904.10513 [pdf, other]
# Correlations between supermassive black holes, hot atmospheres, and the total masses of early type galaxies
#
#
# arXiv:1904.10780 [pdf, other]
# SDSS-IV/SPIDERS: A Catalogue of X-Ray Selected AGN Properties; Spectral Properties and Black Hole Mass Estimates for SPIDERS SDSS DR14 Type 1 AGN
#
#
# arXiv:1904.10870 [pdf, other]
# Episodic Jets from Black Hole Accretion Disks
#
#
#  arXiv:1904.10912 [pdf, other]
# Spectral Variability of a Sample of Extreme Variability Quasars and Implications for the MgII Broad-line Region
# Qian Yang
#
#  arXiv:1904.10955 [pdf, other]
# Buried Black Hole Growth in IR-selected Mergers: New Results from Chandra
#
#
#
# #### day5
#
# arXiv:1904.10965 [pdf, other]
# Astrometric requirements for strong lensing time-delay cosmography
# Simon Birrer, Tommaso Treu
#
#  arXiv:1904.10970 [pdf, other]
# XMMU J181227.8-181234: a new ultracompact X-ray binary candidate
# A. J. Goodwin
#
# arXiv:1904.11311 [pdf, other]
# On the curious pulsation properties of the accreting millisecond pulsar IGR J17379-3747
# Peter Bult, Craig B. Markwardt, Diego Altamirano, Zaven Arzoumanian, Deepto Chakrabarty, Keith C. Gendreau, Sebastien Guillot, Gaurava K. Jaisawal, Paul. S. Ray, Tod E. Strohmayer
#
#
#  arXiv:1904.11133 [pdf, ps, other]
# Diagnosing the remnants of binary neutron star merger from GW170817/GRB170817A event
# Hou-Jun Lü, Jun Shen, Lin Lan, Jared Rice, Wei-Hua Lei, En-Wei Liang
#
#  arXiv:1904.11118 [pdf, ps, other]
# Ejection of Double knots from the radio core of PKS 1510--089 during the strong gamma-ray flares in 2015
# Jongho Park
#
#  arXiv:1904.11028 [pdf, other]
# A hard look at NGC 5347: revealing a nearby Compton-thick AGN
#
#
#  arXiv:1904.10973 [pdf, other]
# A New Class of Changing-Look LINERs
#
#
# arXiv:1904.10972 [pdf, other]
# The X-ray Halo Scaling Relations of Supermassive Black Holes
#
#
#
#
# ### week5
# #### day1
# arXiv:1904.11535 [pdf, other]
# Investigation of the Outburst Activity of the Black Hole Candidate GRS 1739-278
#
#  arXiv:1904.11644 [pdf, ps, other]
# Constraining Mass of Cygnus X-1 from Analysis of the Hard State Spectral Data using TCAF Solution
#
# arXiv:1904.11747 [pdf, other]
# CASA on the fringe: VLBI data processing in the CASA software package
#
# arXiv:1904.11840 [pdf, ps, other]
# X-ray transients after the accretion-induced collapse of white dwarfs
# Yun-Wei Yu, Aming Chen, Xiang-Dong Li
#
#
# arXiv:1904.11842 [pdf, other]
# Astro2020 Science White Paper: Populations of Black Holes in Binaries
#
#
# arXiv:1904.11845 [pdf, other]
# Astro2020 Science White Paper: Compact Stellar Jets
#
#  arXiv:1904.11966 [pdf, other]
# HACC Cosmological Simulations: First Data Release
#
#
#
#
#
#
# #### day2
#
#
# arXiv:1904.11995 [pdf, other]
# The Multi-Messenger Matrix: the Future of Neutron Star Merger Constraints on the Nuclear Equation of State
#
#
#
# arXiv:1904.12036 [pdf, other]
# Repeating Fast Radio Bursts from Magnetars with Low Magnetospheric Twist
# Zorawar Wadiasingh, Andrey Timokhin
# Comments: 10 pages, 3 figures, submitted to ApJ
#
#
# arXiv:1904.12261 [pdf, other]
# Tidal disruption events in active galactic nuclei
# Chi-Ho Chan, Tsvi Piran, Julian H. Krolik, Dekel Saban
# Comments: 14 pages, 11 figures, submitted to ApJ, movie at this https URL
# Subjects: High Energy Astrophysical Phenomena (astro-ph.HE)
#
# arXiv:1904.12263 [pdf, ps, other]
# Viewing angle constraint of LIGO/Virgo binary neutron star merger candidates with Fermi-GBM non-detection limits
#
#
# arXiv:1904.12408 [pdf, other]
# A universal energy distribution for FRB 121102
# F. Y. Wang (NJU), G. Q. Zhang (NJU)
# Comments: 16 pages, 1 figure, 6 tables
# Subjects: High Energy Astrophysical Phenomena (astro-ph.HE)
#
# arXiv:1904.12489 [pdf, other]
# A 6.7 GHz Methanol Maser Survey at High Galactic Latitudes
# Kai Yang, Xi Chen, Zhi-Qiang Shen, Xiao-Qiong Li, Jun-Zhi Wang, Dong-Rong Jiang, Juan Li, Jian Dong, Ya-Jun Wu, Hai-Hua Qiao, Zhiyuan Ren
# Comments: 27pages, 8 figures, 3 tables. Published in ApJ shao
#
# arXiv:1904.12678 [pdf, other]
# Making light of gravitational-waves
# Justine Tarrant, Geoff Beck, Sergio Colafrancesco

# %% [markdown]
# ## 05
# ### week1
# #### day3
#  arXiv:1904.12863 [pdf, other]
# The relativistic jet of the γ-ray emitting narrow-line Seyfert 1 galaxy PKS J1222+0413
#
#
#
# arXiv:1904.12876 [pdf, ps, other]
# SDSS J075101.42+291419.1: A Super-Eddington Accreting Quasar with Extreme X-ray Variability
# Hezhen Liu, B. Luo, W. N. Brandt, Michael S. Brotherton, Pu Du, S. C. Gallagher, Chen Hu, Ohad Shemmer, Jian-Min Wang
#
#  arXiv:1904.12890 [pdf, other]
# Supermassive Black Holes in the Early Universe
# Aaron Smith, Volker Bromm
#
#
#  arXiv:1904.12998 [pdf, other]
# Active Galactic Nucleus Pairs from the Sloan Digital Sky Survey. III. Chandra X-ray Observations Unveil Obscured Double Nuclei
# Meicun Hou, Xin Liu, Hengxiao Guo, Zhiyuan Li, Yue Shen, Paul Green
# Comments: 20 pages, 11 figures. Submitted to ApJ. Comments welcome
# Subjects: Astrophysics of Galaxies (astro-ph.GA)
#
# arXiv:1904.13044 [pdf, other]
# X-ray properties of two transient ULX candidates in galaxy NGC 7090
# Zhu Liu
#
#  arXiv:1904.13098 [pdf, other]
# DmpIRFs and DmpST: DAMPE Instrument Response Functions and Science Tools for Gamma-Ray Data Analysis
# Kai-Kai Duan
#
# arXiv:1904.13286 [pdf, other]
# The Host-Galaxy Properties of Type 1 Versus Type 2 Active Galactic Nuclei
#
#  arXiv:1904.13347 [pdf, other]
# Constraints on the redshift evolution of astrophysical feedback with Sunyaev-Zeldovich effect cross-correlations
# S. Pandey
#
#
#
#
# #### day4
#
#  arXiv:1905.00013 [pdf, other]
# The redshift evolution of X-ray and Sunyaev-Zel'dovich scaling relations in the FABLE simulations
# Nicholas A. Henden, Ewald Puchwein, Debora Sijacki
#
#
# arXiv:1905.00120 [pdf, other]
# Slim accretion disks: theory and observational consequences
# Bozena Czerny
#
#
# arXiv:1905.00145 [pdf, other]
# 80 minute light echo signalling a 10,000 solar mass black hole in a bulgeless dwarf galaxy
#
#  arXiv:1905.00366 [pdf, ps, other]
# Mass and spin measurements for the neutron star 4U1608-52 through the relativistic precession model
# Lise du Buisson, Sara E. Motta, Rob P. Fender
#
#
#
# #### day5
#
#
# arXiv:1905.00617 [pdf, ps, other]
# Black hole mass estimates in quasars - A comparative analysis of high- and low-ionization lines
#
# arXiv:1905.00632 [pdf, other]
# VLA Observations of Single Pulses from the Galactic Center Magnetar
#
# arXiv:1905.00677 [pdf]
# A low-frequency study of recently identified double-double radio galaxies
#
#
# arXiv:1905.00755 [pdf, other]
# Interpreting the distributions of FRB observables
# Liam Connor
#
#
# arXiv:1905.00781 [pdf, other]
# The Delay Time of Gravitational Wave -- Gamma-Ray Burst Associations
# Bing Zhang
#
#
# ### week2
# #### day1
#
# arXiv:1905.00897 [pdf, ps, other]
# Supergiant Fast X-ray Transients uncovered by the EXTraS project: flares reveal the development of magnetospheric instability in accreting neutron stars
#
#  arXiv:1905.00902 [pdf, other]
# MOCCA-SURVEY Database I. Intermediate mass black holes in Milky Way globular clusters and their connection to supermassive black holes
#
# arXiv:1905.00949 [pdf, ps, other]
# Optical and X-ray Correlations During the 2015 Outburst of the Black Hole V404 Cyg
#
#
#  arXiv:1905.01043 [pdf, ps, other]
# Time dependent spectral modeling of Markarian 421 during a violent outburst in 2010
#
# arXiv:1905.01159 [pdf, ps, other]
# Correcting the measured values of the rate of change of the spin and orbital periods of rotation powered pulsars
# Dhruv Pathak, Manjari Bagchi
#
# arXiv:1905.01184 [pdf, other]
# On the track to measure the apparent cosmic acceleration: observation test and forecast on FAST
#
#  arXiv:1905.01262 [pdf, other]
# Chandra X-ray spectroscopy of the focused wind in the Cygnus X-1 system III. Dipping in the low/hard state
#
#
# #### day2
# arXiv:1905.01308 [pdf, other]
# Evolution of the disc atmosphere in the X-ray binary MXB 1659-298, during its 2015-2017 outburst
#
# arXiv:1905.01315 [pdf, other]
# Do AGN triggering mechanisms vary with radio power? I.Optical morphologies of radio-intermediate HERGs
#
# arXiv:1905.01387 [pdf, other]
# Neutron Star Merger Remnants: Braking Indices, Gravitational Waves, and the Equation Of State
# Paul D. Lasky, Nikhil Sarin, Greg Ashton
#
# arXiv:1905.01419 [pdf, other]
# A Wide and Deep Exploration of Radio Galaxies with Subaru HSC (WERGS). II. Physical Properties derived from the SED Fitting with Optical, Infrared, and Radio Data
#
#
#  arXiv:1905.01448 [pdf, ps, other]
# Self-similar solutions for finite size advection-dominated accretion flows
# Rajiv Kumar, Wei-Min Gu
#
# arXiv:1905.01503 [pdf, other]
# REMAP: Determination of the inner edge of the dust torus in AGN by measuring time delays
#
#
# arXiv:1905.01538 [pdf, ps, other]
# Spectral Analysis of χ Class Data of GRS 1915+105 Using TCAF Solution
#
#
# arXiv:1905.01826 [pdf, other]
# MWA Tied-Array Processing I: Calibration and Beamformation
# S. M. Ord, S. E. Tremblay, S. J. McSweeney, N. D. R. Bhat, C. Sobey, D. A. Mitchell, P. J. Hancock, F. Kirsten
#
#  arXiv:1905.01905 [pdf, other]
# rPICARD: A CASA-based Calibration Pipeline for VLBI Data
# M. Janssen, C. Goddi, H. Falcke, D. van Rossum, I. van Bemmel, M. Kettenis, D. Small, I. Martí-Vidal
#
# arXiv:1905.01956 [pdf, other]
# Discovery of millihertz quasi-periodic oscillations in the X-ray binary EXO 0748--676
#
#
# arXiv:1905.02023 [pdf, ps, other]
# An evolving and mass dependent σsSFR-M⋆ relation for galaxies
#
#
# arXiv:1905.02143 [pdf, other]
# The Spin of M87*
# Rodrigo Nemmen
#
# arXiv:1905.02147 [pdf, ps, other]
# Spectral properties of NGC 4151 and the Estimation of black hole mass using TCAF solution
#
# #### day3
# arXiv:1905.02212 [pdf, other]
# COMP2CAT: hunting compact double radio sources in the local Universe
#
# arXiv:1905.02262 [pdf, other]
# Understanding extreme quasar optical variability with CRTS: II. Changing-state quasars
#
# arXiv:1905.02293 [pdf, other]
# Five new real-time detections of Fast Radio Bursts with UTMOST
#
#  arXiv:1905.02399 [pdf, other]
# Regulation of accretion by its outflow in a symbiotic star: the 2016 outflow fast state of MWC 560
#
# arXiv:1905.02415 [pdf, other]
# The UTMOST Survey for Magnetars, Intermittent pulsars, RRATs and FRBs I: System description and overview
#
# arXiv:1905.02429 [pdf, ps, other]
# How bright are fast optical bursts associated with fast radio bursts?
# Yuan-Pei Yang, Bing Zhang, Jian-Yan Wei
#
# arXiv:1905.02509 [pdf, other]
# Constraining coherent low frequency radio flares from compact binary mergers
# A. Rowlinson, G.E. Anderson
#
# arXiv:1905.02665 [pdf, other]
# GW170817 Afterglow Reveals that Short Gamma-Ray Bursts are Neutron Star Mergers
#
# arXiv:1905.02689 [pdf, other]
# The Unique Blazar OJ 287 and its Massive Binary Black Hole Central Engine
#
#
# #### day4
#
#
#  arXiv:1905.02723 [pdf, ps, other]
# On the primordial specific frequency of globular clusters in dwarf and giant elliptical galaxies
#
#  arXiv:1905.02731 [pdf, other]
# The Lense-Thirring timing-accretion plane for ULXs
# M. Middleton, P. C. Fragile, A. Ingram, T. P. Roberts
#
#  arXiv:1905.02732 [pdf, other]
# Slowing down of cosmic growth of supermassive black holes: Theoretical prediction of the Eddington ratio distribution
#
# arXiv:1905.02733 [pdf, other]
# X-ray Properties of Radio-Selected Dual Active Galactic Nuclei
#
#
# arXiv:1905.02773 [pdf, other]
# The Large High Altitude Air Shower Observatory (LHAASO) Science White Paper
# X. Bai (1 and 2)
#
#  arXiv:1905.02862 [pdf, ps, other]
# X-ray timing studies of the low-field magnetar CXOU J164710.2-455216
# Hongjun An, Robert Archibald
#
#  arXiv:1905.02904 [pdf, other]
# Initial results from a systematic search for changing-look active galactic nuclei selected via mid-infrared variability
#
#  arXiv:1905.02938 [pdf, other]
# SS433: a massive X-ray binary at advanced evolutionary stage
#
#  arXiv:1905.03063 [pdf, other]
# Identification of Young Stellar Object candidates in the Gaia DR2 x AllWISE catalogue with machine learning methods
# G. Marton
#
# arXiv:1905.03080 [pdf, other]
# Polarization studies of Rotating Radio Transients
#
#  arXiv:1905.03213 [pdf, ps, other]
# Parallel implementation of w-projection wide-field imaging
# Baoqiang Lao, Tao An, Ang Yu, Wenhui Zhang, Junyi Wang, Quan Guo, Shaoguang Guo, Xiaocong Wu
#
#
#
#
#
#
#
#
#
#
#
# #### day5
# arXiv:1905.03740 [pdf, ps, other]
# NGC 300 ULX1: spin evolution, super-Eddington accretion and outflows
# G. Vasilopoulos, M. Petropoulou, F. Koliopanos, P. S. Ray, C. D. Bailyn, F. Haberl, K. Gendreau
#
# arXiv:1905.03738 [pdf, other]
# Search for Ultra-High-Energy Neutrinos with the Telescope Array Surface Detector
#
# arXiv:1905.03683 [pdf, other]
# X-ray time lags in AGN: inverse-Compton scattering and spherical corona model
#
#  arXiv:1905.03656 [pdf, ps, other]
# Constraint on the maximum mass of neutron stars using GW170817 event
# Masaru Shibata
#
# arXiv:1905.03476 [pdf, ps, other]
# Large polar caps for twisted magnetosphere of rotating magnetars
# H. Tong
#
#
# [221]  arXiv:1905.03449 [pdf, other]
# Discovery of a radio transient in M81
#
#
#  arXiv:1905.03413 [pdf, ps, other]
# New constraints on Lorentz invariance violation with polarized gamma-ray bursts
# Jun-Jie Wei
#
#
# arXiv:1905.03413 [pdf, ps, other]
# New constraints on Lorentz invariance violation with polarized gamma-ray bursts
# Jun-Jie Wei
#
#  arXiv:1905.03383 [pdf, other]
# A broadband look at the old and new ULXs of NGC 6946
# Hannah P. Earnshaw
#
#
# ### week3
# #### day1
#  arXiv:1905.03784 [pdf, ps, other]
# Relation between gravitational mass and baryonic mass for non-rotating and rapidly rotating neutron stars
# He Gao
#
#
# arXiv:1905.03790 [pdf, other]
# Dark Matter Signatures of Supermassive Black Hole Binaries
# Smadar Naoz, Joseph Silk
#
#  arXiv:1905.03984 [pdf, other]
# Rossby Wave Instability and High-Frequency Quasi-Periodic Oscillations in accretion discs orbiting around black holes
# Peggy Varniere, Fabien Casse, Frederic Vincent
#
#
#
#
#
#
#
#
# #### day2
#
#
#  arXiv:1905.05160 [pdf, other]
# CHANG-ES XX. High Resolution Radio Continuum Images of Edge-on Galaxies and their AGNs -- Data Release 3
#
#
# arXiv:1905.05116 [pdf, other]
# Petabytes to Science
#
# arXiv:1905.05057 [pdf, other]
# A unified accretion-ejection paradigm for black hole X-ray binaries. IV. Replication of the 2010--2011 activity cycle of GX 339-4
# G. Marcel, J. Ferreira, M. Clavel, P-O. Petrucci, J. Malzac, S. Corbel, J. Rodriguez, R. Belmont, M. Coriat, G. Henri, F. Cangemi
#
# arXiv:1905.04984 [pdf]
# Radio core dominance of Fermi-LAT selected AGNs
#
# arXiv:1905.04944 [pdf, ps, other]
# Optical polarization properties of February 2010 outburst of the blazar Mrk 421
#
# arXiv:1905.04851 [pdf, ps, other]
# Jet Structure in the Afterglow Phase for Gamma-ray Bursts with a Precessing Jet
#
#
# arXiv:1905.04637 [pdf, ps, other]
# Effect of accreting tidally disrupted stars on the spin evolution of ∼106M⊙ black holes
# Xiaoxia Zhang (NAOC/XMU), Youjun Lu (NAOC), Zhu Liu (NAOC)
#
#  arXiv:1905.04553 [pdf, ps, other]
# Study of the long-term evolution of the accretion dynamics of GX 339-4
# U. Aneesha, S. Mandal, H. Sreehari
#
# arXiv:1905.04440 [pdf, other]
# NICER Observations of the 2018 Outburst of XTE J1810-197
#
# arXiv:1905.04330 [pdf, ps, other]
# Detection of Superluminal Motion in the X-ray Jet of M87
#
# arXiv:1905.04294 [pdf, other]
# Fruitbat: A Python Package for Estimating Redshifts of Fast Radio Bursts
# Adam J. Batten
#
#
#
#
#
# #### day3
# arXiv:1905.05184 [pdf]
# A Neutrino Beacon
# A.A. Jackson
# Comments: 13 pages
#
# arXiv:1905.05197 [pdf, ps, other]
# X-ray Binary Luminosity Function Scaling Relations for Local Galaxies Based on Subgalactic Modeling
# Bret D. Lehmer, Rafael T. Eufrasio, Panayiotis Tzanavaris, Antara Basu-Zych, Tassos Fragos, Andrea Prestwich, Mihoko Yukita, Andreas Zezas, Ann E. Hornschemeier, Andrew Ptak
# Comments: Accepted for publication in ApJS (37 pages, 16 figures, and 7 tables). Data products available (this https URL)
#
#  arXiv:1905.05209 [pdf, other]
# Intermediate mass black holes in globular clusters: effects on jerks and jounces of millisecond pulsars
# Federico Abbate, Mario Spera, Monica Colpi
#
# arXiv:1905.05214 [pdf, other]
# The Close AGN Reference Survey (CARS): Comparative analysis of the structural properties of star-forming and non-star-forming galaxy bars
#
# arXiv:1905.05321 [pdf, other]
# 50 years of energy extraction from rotating black hole: revisiting magnetic Penrose process
# Arman Tursunov, Naresh Dadhich
#
# arXiv:1905.05356 [pdf, ps, other]
# Spectral and Timing Analysis of the accretion-powered pulsar 4U 1626-67 observed with Suzaku and NuSTAR
#
# arXiv:1905.05399 [pdf, other]
# Contribution of Radio Halos to the Foreground for SKA EoR Experiments
#
# arXiv:1905.05414 [pdf, ps, other]
# Radio jet structures at ~100 parsec and larger scales of the γ-ray-emitting narrow-line Seyfert 1 galaxy PMN J0948+0022
#
#
#  arXiv:1905.05593 [pdf, other]
# Evidence for the radiation-pressure dominated accretion disk in bursting pulsar GRO J1744-28 using timing analysis
#
#  arXiv:1905.05616 [pdf, other]
# Can we constrain the neutron-star equation of state from QPO observations?
#
# arXiv:1905.05780 [pdf, other]
# Stronger Constraints on the Evolution of the MBH−σ∗ Relation up to z∼0.6
#
#
#
#
#
#
#
#
#
# #### day4
#
# arXiv:1905.05905 [pdf, ps, other]
# Polarization of Astrophysical Events with Precessing Jets
# Mi-Xiang Lan, Rui Xue, Dingrong Xiong, Wei-Hua Lei, Xue-Feng Wu, Zi-Gao Dai
# Comments: 21 pages, 6 figures, accepted by ApJ
#
# arXiv:1905.05915 [pdf, ps, other]
# Lijiang 2.4-meter Telescope and its Instruments
#
#
#  arXiv:1905.05996 [pdf, ps, other]
# A model for the radio/X-ray correlation in three neutron star low-mass X-ray binaries 4U 1728-34, Aql X-1 and EXO 1745-248
# Erlin Qiao (NAOC), B.F. Liu (NAOC)
#
#
# arXiv:1905.06046 [pdf]
# Towards high-resolution astronomical imaging
# Craig Mackay, David Buscher, Nahid Chowdhury, Ric Davies, Sasha Hinkley, Norbert Hubin, Paul Jorden, Richard Massey, Kieran O'Brien, Ian Parry, Jesper Skottfelt
# Comments: 6 pages, 7 figures, 11 contributors
#
# arXiv:1905.06086 [pdf, other]
# An Analytical Solution to the Coalescence Time of Compact Binary Systems
#
#
# #### day5
# arXiv:1905.06356 [pdf, other]
# Catching butterflies in the sky: Extended catalog of winged or X-shaped radio sources from the latest FIRST data release
#
#
# arXiv:1905.06423 [pdf, other]
# All at once: transient pulsations, spin down and a glitch from the Pulsating Ultraluminous X-ray Source M82 X-2
#
# arXiv:1905.06621 [pdf, ps, other]
# Origin and Evolution of the Multi-band Variability in the Flat Spectrum Radio Source 4C 38.41
#
# arXiv:1905.06623 [pdf, ps, other]
# Resolving the Innermost Geometry of Relativistic Jets in Active Galactic Nuclei
# Juan Carlos Algaba, Masanori Nakamura, Keiichi Asada, Sang Sung Lee
#
#
# arXiv:1905.06634 [pdf, other]
# The TeV-emitting radio galaxy 3C 264. VLBI kinematics and SED modeling
# B. Boccardi, G. Migliori, P. Grandi, E. Torresi, F. Mertens, V. Karamanavis, R. Angioni, C. Vignali
#
#  arXiv:1905.06818 [pdf, other]
# A Search for High-Energy Counterparts to Fast Radio Bursts
#
# arXiv:1905.06835 [pdf, other]
# Constraining a black hole companion for M87* through imaging by the Event Horizon Telescope
# Mohammadtaher Safarzadeh, Abraham Loeb, Mark Reid
#
#
#
# ### week4
# #### day1
#  arXiv:1905.06961 [pdf, other]
# CO Emission in Infrared-Selected Active Galactic Nuclei
# Allison Kirkpatrick, Chelsea Sharon, Erica Keller, Alexandra Pope
# Comments: accepted for publication in ApJ
#
# arXiv:1905.06964 [pdf, other]
# Broad-band X-ray analysis of local mid-infrared selected Compton-thick AGN candidates
# M.-M. La Caria, C. Vignali, G. Lanzuisi, C. Gruppioni, F. Pozzi
#
#  arXiv:1905.07132 [pdf, other]
# Fast Radio Burst Cosmology and HIRAX
# Amanda Weltman, Anthony Walters
#
#
# arXiv:1905.07424 [pdf, other]
# Galaxy Zoo: Probabilistic Morphology through Bayesian CNNs and Active Learning
# Mike Walmsley, Lewis Smith, Chris Lintott, Yarin Gal, Steven Bamford, Hugh Dickinson, Lucy Fortson, Sandor Kruk, Karen Masters, Claudia Scarlata, Brooke Simmons, Rebecca Smethurst, Darryl Wright
# Comments: Submitted to MNRAS
#
# arXiv:1905.07806 [pdf, other]
# All-Sky-ASTROGAM: The MeV Gamma-Ray Companion to Multimessenger Astronomy
#
# arXiv:1905.07929 [pdf, other]
# Statistical Study of Gamma-Ray Bursts with a Plateau Phase in the X-ray Afterglow
# C. H. Tang, Y. F. Huang, J. J. Geng, Z. B. Zhang
#
#
#
#
#
# #### day2
#
#
# arXiv:1905.08072 [pdf, ps, other]
# Long term variability of Swift J1753.5-0127]{Long term variability of Swift J1753.5-0127: X-ray spectral-temporal correlations during state transitions
# Qingcui Bu, Lian Tao, Yu Lu, Shuangnan Zhang, Liang Zhang, Yue Huang, Li Chen, Jinlu Qu, Xiang Ma
#
#
#
# arXiv:1905.08086 [pdf, ps, other]
# Cosmological test using the high-redshift detection rate of FSRQs with the Square Kilometer Array
# Kyle Leaf, Fulvio Melia
#
# arXiv:1905.08201 [pdf, other]
# On the Emergence of Thousands of Absorption Lines in the Quasar PG1411+442: A Clumpy High-Column Density Outflow from the Broad Emission-Line Region?
# Fred Hamann, Todd M. Tripp, David Rupke, Sylvain Veilleux
#
#
#
#
# #### day3
#  arXiv:1905.08250 [pdf, other]
# Ultra High Energy Cosmic Rays and the Highest Energies Universe
# Roberto Aloisio
# Comments: 8 pages, 8 pdf figures, invited review talk given at the 6th Symposium on Prospects in the Physics of Discrete Symmetries, DISCRETE 2018, Austrian Academy of Sciences, Vienna, November 26-30 2018. The present proceedings paper is mainly based on the review papers: arXiv:1707.08471 and arXiv:1707.06147 written by the author in the last three years. arXiv admin note: text overlap with arXiv:1812.10750, arXiv:1707.06188
# Subjects: High Energy Astrophysical Phenomena (astro-ph.HE)
#
# arXiv:1905.08262 [pdf, ps, other]
# Cosmological Information Contents on the Light-Cone
#
# arXiv:1905.08428 [pdf, ps, other]
# Hot Corona Properties of Swift/BAT detected AGN
#
#  arXiv:1905.08497 [pdf, other]
# An HI absorption distance to the black hole candidate X-ray binary MAXI J1535-571
#
#  arXiv:1905.08578 [pdf, other]
#  Vela X-1 as a laboratory for accretion in High-Mass X-ray Binaries
#
# arXiv:1905.08667 [pdf, other]
# Legacy Archive for Microwave Background Data Analysis (LAMBDA): An Overview
# G. E. Addison, E. R. Switzer, M. R. Greason, T. B. Griswold, T. Jaffe, N. Miller, N. P. Odegard, U. Prasad, J. L. Weiland
#
# arXiv:1905.08755 [pdf, other]
# Fermi GBM follow-up of LIGO-Virgo binary black hole mergers - detection prospects
# P. Veres, T. Dal Canton, E. Burns, A. Goldstein, T. B. Littenberg, N. Christensen, R. D. Preece
#
#
# #### day4
#
#
#  arXiv:1905.08817 [pdf, ps, other]
# A Study of the 20 Day Superorbital Modulation in the High-Mass X-ray Binary IGR J16493-4348
#
#  arXiv:1905.08830 [pdf, other]
# A definitive merger-AGN connection at z~0 with CFIS: mergers have an excess of AGN and AGN hosts are more frequently disturbed
#
# arXiv:1905.08847 [pdf, ps, other]
# Mega-Archive and the EURONEAR Tools for Datamining World Astronomical Images
#
# arXiv:1905.08978 [pdf, ps, other]
# Low-mass and High-mass Supermassive Blackholes In Radio-Loud AGNs Are Spun-up in Different Evolution Paths
# J. Wang, M. Z. Kong, S. F. Liu, D. W. Xu, Q. Zhang, J. Y. Wei
#
#
# [42]  arXiv:1905.09020 [pdf, ps, other]
# Optical Counterparts of an Ultraluminous X-Ray Source X-1 in NGC 2500
# N. Aksaker, A. Akyüz, S. Avdan, H. Avdan
#
#
#  arXiv:1905.09034 [pdf, other]
# AXS: A framework for fast astronomical data processing based on Apache Spark
#
#  arXiv:1905.09179 [pdf, other]
# Did GW170817 harbor a pulsar?
#
#  arXiv:1905.09253 [pdf, other]
# Broadband reflection spectroscopy of MAXI J1535-571 using AstroSat: Estimation of black hole mass and spin
#
# #### day5
#  arXiv:1905.09281 [pdf, other]
#
# GLOSTAR -- Radio Source Catalog I:
#
# arXiv:1905.09287 [pdf, other]
# AGN-Driven Outflows in Dwarf Galaxies
#
#  arXiv:1905.09299 [pdf, other]
# Reconstructing Probability Distributions with Gaussian Processes
# Thomas McClintock, Eduardo Rozo
#
#  arXiv:1905.09392 [pdf, other]
# Multi-epoch Low Radio Frequency Surveys of the Kepler K2 Mission Campaign Fields 3, 4, and 5 with the Murchison Widefield Array
# S.J. Tingay, P.J Hancock
#
#  arXiv:1905.09471 [pdf, other]
# Tidal disruption events onto stellar black holes in triples
#
#  arXiv:1905.09559 [pdf, other]
# Modelling the X-ray power spectra of AGN by using reprocessing echoes from an extended corona
# Poemwai Chainakun
#
#
#  arXiv:1905.09627 [pdf, other]
# HST unveils a compact mildly relativistic Broad Line Region in the candidate true type 2 NGC 3147
#
# arXiv:1905.09667 [pdf, other]
# Constraints on the collimated X-ray emission of SS 433 from the reflection on molecular clouds
# I. Khabibullin, S. Sazonov
#
#  arXiv:1905.09784 [pdf, other]
# Puzzling Blue Dips in the Black Hole Candidate Swift J1357.2-0933, from ULTRACAM, SALT, ATCA, Swift and NuSTAR
#
#
# arXiv:1905.09785 [pdf, ps, other]
# ALMA Polarimetry of AT2018cow
# K.Y. Huang, J. Shimoda, Y. Urata, K. Toma, K. Yamaoka, K. Asada, H. Nagai, S. Takahashi, G. Petitpas, M. Tashiro
#
#
#
#
#
# ### week5

# %% [markdown]
# ## 06
# ### week1
# #### day1
# #### day2
# #### day3
# #### day4
# #### day5
