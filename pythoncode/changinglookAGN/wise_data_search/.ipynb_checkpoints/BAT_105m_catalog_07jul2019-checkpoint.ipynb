# %%
import pandas as pd

# %%
BAT_105m_catalog_07jul2019=pd.read_csv('/Users/brettlv/Downloads/CLAGN_statistic_plot/BAT_105m_catalog_07jul2019.txt',
                                       delimiter="|",header=0,skiprows=1)
BAT_105m_catalog_07jul2019.columns

BAT_105m_catalog_07jul2019=BAT_105m_catalog_07jul2019[BAT_105m_catalog_07jul2019['                 TYPE'].notnull()]

# %%
BAT_105m_catalog_07jul2019
# Out:
#                          BAT_NAME       RA      DEC      SNR  \
# 1        1     SWIFT J0001.0-0708    0.228   -7.164     7.73
# 2        2     SWIFT J0001.6-7701    0.445  -77.000     6.32
# 3        3     SWIFT J0002.5+0323    0.613    3.365     5.50
# 4        4     SWIFT J0003.3+2737    0.856   27.643     5.98
# 5        5     SWIFT J0005.0+7021    0.934   70.358     8.52
# ...    ...                    ...      ...      ...      ...
# 1628  1628     SWIFT J2330.5-0228  352.624   -2.474     5.07
# 1629  1629     SWIFT J2333.0+0437  353.262    4.379     5.53
# 1630  1630     SWIFT J2343.0-5920  355.738  -59.325     5.37
# 1631  1631     SWIFT J2344.7-1573  356.167  -15.731     5.01
# 1632  1632     SWIFT J2355.9+2555  358.983   25.552     6.98
#
#                     COUNTERPART_NAME                       OTHER_NAME  \
# 1            2MASX J00004876-0709117
# 2                       Fairall 1203
# 3                           NGC 7811
# 4            2MASX J00032742+2739173
# 5            2MASX J00040192+7019185
# ...                              ...                              ...
# 1628                  MCG -01-59-027
# 1629                    LEDA 3092231
# 1630  APMUKS(BJ) B233953.42-593202.5
# 1631              SWIFT J2344.7-1573
# 1632                           VV697
#
#        CTPT_RA  CTPT_DEC      FLUX  ...  CONTA  GAMM GAMM.1 GAMM.2  \
# 1       0.2032   -7.1532     13.49  ...    0.0  2.21   1.80   2.70
# 2       0.4419  -76.9540     13.23  ...    0.0  1.62   1.22   2.04
# 3       0.6103    3.3519     10.79  ...    0.0  1.95   1.38   2.66
# 4       0.8643   27.6548     10.29  ...    0.0  2.12   1.61   2.73
# 5       1.0082   70.3217     13.41  ...    0.0  2.07   1.68   2.52
# ...        ...       ...       ...  ...    ...   ...    ...    ...
# 1628  352.6345   -2.4625     10.43  ...    0.0  1.85   1.21   2.67
# 1629  353.2771    4.4051      9.93  ...    0.0  2.16   1.58   2.90
# 1630  355.6517  -59.2565      6.97  ...    0.0  2.49   1.80   3.53
# 1631  356.1672  -15.7306      8.34  ...    0.0  2.19   1.38   3.70
# 1632  358.9588   25.5008     11.38  ...    0.0  2.17   1.65   2.84
#
#         CHI_SQ_R  REDSHIF    LUM  ASSOC_STREN          CL2  \
# 1           1.30   0.0375  43.64                        50
# 2           2.20   0.0584  44.03                        50
# 3           0.70   0.0255  43.20                        40
# 4           0.40   0.0396  43.58                        50
# 5           1.00   0.0960  44.49                        50
# ...          ...      ...    ...          ...          ...
# 1628        0.50   0.0334  43.43                        40
# 1629        0.20                                        70
# 1630        0.50                                        70
# 1631        1.40                                        14
# 1632        1.00   0.0571  43.95                        40
#
#                       TYPE
# 1                    Sy1.9
# 2                    Sy1.9
# 3                    Sy1.5
# 4                      Sy2
# 5                    Sy1.9
# ...                    ...
# 1628                   Sy1
# 1629           Unknown AGN
# 1630           Unknown AGN
# 1631       confused source
# 1632                   Sy1
#
# [1632 rows x 22 columns]

# %%
BAT_105m_Seyfert=BAT_105m_catalog_07jul2019[BAT_105m_catalog_07jul2019['                 TYPE'].str.contains('Sy')]
BAT_105m_Seyfert=BAT_105m_Seyfert.reset_index(drop=True)

# %%
BAT_105m_Seyfert
