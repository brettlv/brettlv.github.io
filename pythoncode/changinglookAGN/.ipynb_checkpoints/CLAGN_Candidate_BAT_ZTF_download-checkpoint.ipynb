# %%
import pandas as pd
import numpy as np

import time
import os
import sys

from astropy import config as _config
from astroquery.irsa import Irsa   
from astropy import units as u
from astropy.coordinates import SkyCoord
# Out:
# /var/folders/jp/4mwsn7_x6j9gnv1hl1dztqth0000gn/T/ipykernel_58811/394891970.py:9: DeprecationWarning: the ``irsa`` module has been moved to astroquery.ipac.irsa, please update your imports.
#   from astroquery.irsa import Irsa

# %%
from astroquery.ned import Ned
# Out:
# /var/folders/jp/4mwsn7_x6j9gnv1hl1dztqth0000gn/T/ipykernel_58811/863512024.py:1: DeprecationWarning: the ``ned`` module has been moved to astroquery.ipac.ned, please update your imports.
#   from astroquery.ned import Ned

# %%
import pandas as pd
import numpy as np
import os

def get_obsids(path):
    dirname=os.listdir(path)
    obsids=[]
    for i in dirname:
        if i.isdigit():
            obsids.append(i)
    obsids.sort()        
    return obsids

def drop_index(data):
    data=data.reset_index(drop=True)
    return data

# %%
from astropy.time import Time
from astropy.io import fits
import time
from matplotlib.pyplot import MultipleLocator
import matplotlib.dates as mdates

def datetime2mjd(x):
    mjd_ref=59000
    mjd_minus_mdates_num=mdates.date2num(convert_xaxis_time(mjd_ref))-mjd_ref
    
    x=mdates.date2num(x)
    y = x - mjd_minus_mdates_num   
    return y

def mjd2datetime(x):
    mjd_ref=59000
    mjd_minus_mdates_num=mdates.date2num(convert_xaxis_time(mjd_ref))-mjd_ref
    y= x + mjd_minus_mdates_num
    y= mdates.num2date(y)
    return y



def datenums2mjd(x):
    #x=mdates.date2num(x)
    mjd_ref=59000
    mjd_minus_mdates_num=mdates.date2num(convert_xaxis_time(mjd_ref))-mjd_ref
    y = x - mjd_minus_mdates_num   
    return y

def mjd2numsdate(x):
    mjd_ref=59000
    mjd_minus_mdates_num=mdates.date2num(convert_xaxis_time(mjd_ref))-mjd_ref
    
    y= x + mjd_minus_mdates_num
    #y= mdates.num2date(y)
    return y


def convert_xaxis_mjd(time):
    return Time(time).mjd   

def convert_xaxis_time(mjd):
    return Time(mjd,format='mjd').to_datetime()


def date2yday(x):
    """
    x is in matplotlib datenums, so they are floats.
    """
    y = x - mdates.date2num(datetime(2018, 1, 1))
    return y

def yday2date(x):
    """
    return a matplotlib datenum (x is days since start of year of 2018)
    """
    y = x + mdates.date2num(datetime(2018, 1, 1))
    return y


def convert_partial_year(numbers):
    datetimes=[]
    for number in numbers:
        year = int(number)
        d = timedelta(days=(number - year)*(365 + is_leap(year)))
        day_one = datetime(year,1,1)
        date = d + day_one
        datetimes.append(date)
    return datetimes


def is_leap(year):
    if not year%4 and  year%100 or not year%400:
        return True
    return False


def convert_mjd(times):
    timesmjd=[]
    for i in times:
        timesmjd.append(Time(i).mjd)
    return timesmjd  


def convert_date(times):
    timesdate=[]
    for i in times:
        timesdate.append(Time(i,format='mjd').datetime)
    return timesdate

def convert_date_single(time):
    timedate=Time(time,format='mjd').datetime
    return timedate

# %% [markdown]
# # ztfquery

# %%
from ztfquery import lightcurve

# %% [markdown]
# [ztf_api](https://irsa.ipac.caltech.edu/docs/program_interface/ztf_lightcurve_api.html)

# %%
# !echo $ZTFDATA

# %%
15*7
# Out:
# 105

# %%
table_=Ned.query_object('Mrk 1018')

# %%
table_=Ned.query_object('AT2021fxu')

# %%
table_
# Out:
# <Table length=0>
#  No.  Object Name    RA     DEC    Type  ... Photometry Points Positions Redshift Points Diameter Points Associations
#                   degrees degrees        ...
# int32    str30    float64 float64 object ...       int32         int32        int32           int32         int32
# ----- ----------- ------- ------- ------ ... ----------------- --------- --------------- --------------- ------------

# %%
table_['RA'].data[0]
# Out:
# 31.56662

# %% [markdown]
# os.mkdir('/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF/')

# %% [markdown]
# ## BAT_ZTF_dir

# %%
CLAGN_Candidate_BAT_ZTF_dir='/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF'

# %%
CLAGN_Candidate_BAT_ZTF_dir
# Out:
# '/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF'

# %%
CLAGN_Candidate_BAT_ZTF_dir_1='/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF_catflags=0/'

# %%
CLAGN_Candidate_BAT_ZTF_dir_1
# Out:
# '/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF_catflags=0/'

# %%
CLAGN_Candidate_BAT_ZTF_dir_2='/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/CLAGN_ZTF_catflags=0/'
if not os.path.exists(CLAGN_Candidate_BAT_ZTF_dir_2):
    os.mkdir(CLAGN_Candidate_BAT_ZTF_dir_2)

# %%
# !open /Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF_catflags=0/

# %% [markdown]
# ## CLAGN

# %% [markdown]
# ### CLAGN_list202206

# %%
CLAGN_list202206=pd.read_excel('/Users/lyubing/IHEPBox/data/data_clagn/CLAGN-20220609.xlsx')

# %% [markdown]
# name='Mrk590'
# result_table = Ned.query_object(name)

# %%
for index,name in enumerate(CLAGN_list202206['Name']):
    result_table = Ned.query_object(name)
    print(name)
    CLAGN_list202206.loc[index,'ra_deg']=result_table['RA'].data[0]
    CLAGN_list202206.loc[index,'dec_deg']=result_table['DEC'].data[0]
# Out:
# 1ES 1927+654
# 1H 0419-577
# 2MASS J01264811-0839481
# 2MASS J07451198+3809114
# 2MASS J09270231+0433080
# 2MASS J10022021+4509276
# 2MASS J10520355+1519294
# 2MASS J11132967+5313393
# 2MASS J12335916+0842112
# 2MASS J14284671+1723530
# 2MASS J14345529+5723449
# 2MASS J15361278+0342457
# 2MASS J15373408+4613585
# 2MASS J16011122+4745095
# 2MASS J16171142+0638333
# 2MASS J21020044+0005020
# 2MASS J22053771-0711147
# 2MASX J08284278+4544333
# 2MASX J09381221+0743398
# 2MASX J09483841+4030436
# 2MASX J10215228+4645158
# 2MASX J11180325+4506463
# 2MASX J16050519+4526348
# 2MASX J20075129-1108346
# 3C 390.3
# NGC 3786
# SDSSJ162829.17+432948.5
# B3 0749+460A
# NGC 5273
# NGC 4156
# 2MASX J13471874+0210579
# ESO 323-G77

# %%
CLAGN_list202206

# %% [markdown]
# ## CLAGN_Candidate_BAT

# %%
CLAGN_Candidate_BAT=pd.read_excel('/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/BAT_CLAGN_CANDIDATE.xlsx',
                                 )#dtype={'P-value':float}

# %%
CLAGN_Candidate_BAT
# Out:
#                         AGN    Type  Redshift  Luminosity    P-value
# 0                  NGC 526A  Sy 2.0    0.0191       43.78        0.0
# 1                  NGC 5548  Sy 1.5    0.0172       43.76        0.0
# 2                  NGC 4151  Sy 1.5    0.0033       43.17        0.0
# 3                   NGC 973  Sy 2.0    0.0162       43.46        0.0
# 4                  WKK 4374  Sy 1.9    0.0180       43.27   0.000001
# 5                  NGC 2617  Sy 1.8    0.0142       42.86   0.000014
# 6                  NGC 4507  Sy 1.9    0.0118       43.76   0.000075
# 7                      Mrk3  Sy 1.9    0.0135       43.79   0.000174
# 8   2MASX J04440903+2813003  Sy 2.0    0.0113       43.15   0.000255
# 9                  NGC 4388  Sy 2.0    0.0084       43.64  3.425E0-4
# 10                 NGC 2110  Sy 2.0    0.0078       43.65   0.000562
# 11  2MASX J10402231-4625264  Sy 2.0    0.0200       43.28   0.000584
# 12                  IC 4709  Sy 2.0    0.0169       43.40   0.001474
# 13                UGC 03601  Sy 1.9    0.0171       43.08   0.002155
# 14                 4C 50.55  Sy 1.2    0.0200       44.28   0.002635
# 15                 NGC 4235  Sy 1.2    0.0080       42.74   0.002786
# 16                 NGC 7679  Sy 2.0    0.0171       43.09   0.004352
# 17                 NGC 4945  Sy 2.0    0.0019       42.35   0.006731
# 18                 NGC 3281  Sy 2.0    0.0107       43.32   0.008343
# 19               4U 1344-60  Sy 1.9    0.0129       43.62   0.008459
# 20           MCG +04-48-002  Sy 2.0    0.0139       43.51   0.009586
# 21                 NGC 6300  Sy 2.0    0.0037       42.46    0.01056
# 22                 IC 4329A  Sy 1.5    0.0160       44.18    0.01145
# 23                 NGC 3079  Sy 2.0    0.0037       42.05    0.01145
# 24                  IC 2461  Sy 2.0    0.0075       42.38    0.01341
# 25                  NGC 788  Sy 2.0    0.0136       43.51    0.01418

# %%
for index,name in enumerate(CLAGN_Candidate_BAT['AGN']):
    result_table = Ned.query_object(name)
    CLAGN_Candidate_BAT.loc[index,'ra']=result_table['RA'].data[0]
    CLAGN_Candidate_BAT.loc[index,'dec']=result_table['DEC'].data[0]

# %%
CLAGN_Candidate_BAT#.columns
# Out:
#                         AGN    Type  Redshift  Luminosity    P-value  \
# 0                  NGC 526A  Sy 2.0    0.0191       43.78        0.0
# 1                  NGC 5548  Sy 1.5    0.0172       43.76        0.0
# 2                  NGC 4151  Sy 1.5    0.0033       43.17        0.0
# 3                   NGC 973  Sy 2.0    0.0162       43.46        0.0
# 4                  WKK 4374  Sy 1.9    0.0180       43.27   0.000001
# 5                  NGC 2617  Sy 1.8    0.0142       42.86   0.000014
# 6                  NGC 4507  Sy 1.9    0.0118       43.76   0.000075
# 7                      Mrk3  Sy 1.9    0.0135       43.79   0.000174
# 8   2MASX J04440903+2813003  Sy 2.0    0.0113       43.15   0.000255
# 9                  NGC 4388  Sy 2.0    0.0084       43.64  3.425E0-4
# 10                 NGC 2110  Sy 2.0    0.0078       43.65   0.000562
# 11  2MASX J10402231-4625264  Sy 2.0    0.0200       43.28   0.000584
# 12                  IC 4709  Sy 2.0    0.0169       43.40   0.001474
# 13                UGC 03601  Sy 1.9    0.0171       43.08   0.002155
# 14                 4C 50.55  Sy 1.2    0.0200       44.28   0.002635
# 15                 NGC 4235  Sy 1.2    0.0080       42.74   0.002786
# 16                 NGC 7679  Sy 2.0    0.0171       43.09   0.004352
# 17                 NGC 4945  Sy 2.0    0.0019       42.35   0.006731
# 18                 NGC 3281  Sy 2.0    0.0107       43.32   0.008343
# 19               4U 1344-60  Sy 1.9    0.0129       43.62   0.008459
# 20           MCG +04-48-002  Sy 2.0    0.0139       43.51   0.009586
# 21                 NGC 6300  Sy 2.0    0.0037       42.46    0.01056
# 22                 IC 4329A  Sy 1.5    0.0160       44.18    0.01145
# 23                 NGC 3079  Sy 2.0    0.0037       42.05    0.01145
# 24                  IC 2461  Sy 2.0    0.0075       42.38    0.01341
# 25                  NGC 788  Sy 2.0    0.0136       43.51    0.01418
#
#            ra       dec
# 0    20.97664 -35.06553
# 1   214.49806  25.13679
# 2   182.63574  39.40573
# 3    38.58379  32.50561
# 4   222.88805 -55.67733
# 5   128.91162  -4.08822
# 6   188.90263 -39.90926
# 7    93.90152  71.03753
# 8    71.03754  28.21686
# 9   186.44478  12.66209
# 10   88.04742  -7.45621
# 11  160.09393 -46.42380
# 12  276.08079 -56.36917
# 13  103.95636  40.00022
# 14  321.16354  50.97328
# 15  184.29117   7.19158
# 16  352.19459   3.51147
# 17  196.36449 -49.46821
# 18  157.96704 -34.85369
# 19  206.89981 -60.61772
# 20  307.14608  25.73333
# 21  259.24779 -62.82056
# 22  207.33028 -30.30944
# 23  150.49085  55.67979
# 24  139.99177  37.19126
# 25   30.27686  -6.81552

# %%
CLAGN_Candidate_BAT.head()

# %% [markdown]
# curl -X POST ztf.alerce.online/get_detections -d @- << EOF
# {
#    "oid":"ZTF18aaaadvs"
# }
# EOF

# %%
182.63574 39.40573

# %%
3.0/3600,1/3600

# %% [markdown]
# ## skycoor_J053449

# %%
skycoor_J053449= SkyCoord(ra='05:34:49.2', dec='+21:26:02.9',frame="icrs", unit="deg")

# %%
skycoor_J053449.ra.deg,skycoor_J053449.dec.deg
# Out:
# (5.580333333333333, 21.43413888888889)

# %% [markdown]
# # ZTF

# %% [markdown]
# ## def ztflc_show_in_jupyter

# %%
def ztflc_show_in_jupyter(data,name,band, showtoday=False, show_upperlimits=False, formattime=True,
             marker="o", mec="0.7", ms=7, ecolor="0.7", ls="None", zorder=4, **kwargs):
        """ kwargs goes to matplotlib's errorbar() """
        FILTER_COLORS = ["C2","C3","C1"]
        FILTER_CODE   = ["zg","zr","zi"]
        save_name=name.strip().replace(' ','_')
        

        from astropy import time
        import matplotlib.pyplot as mpl

        # ----------- #
        # Global      #
        # ----------- #
        lc_dataframe = data
        prop = dict(marker=marker, mec=mec, ms=ms, ecolor=ecolor, ls=ls, zorder=zorder)

        # ----------- #
        #
        # ----------- #
        fig = mpl.figure(figsize=[7,4])
        ax = fig.add_axes([0.1,0.15,0.8,0.75])
        for filter_ in np.unique(lc_dataframe["filtercode"]):
            d = lc_dataframe[lc_dataframe["filtercode"]==filter_]
            if filter_ in FILTER_CODE:
                prop["color"] = np.asarray(FILTER_COLORS)[np.where(np.asarray(FILTER_CODE)==filter_)][0]
            else:
                prop["color"] = "0.7"

            if formattime:
                dates = time.Time(np.asarray(d["mjd"].values, dtype="float"), format="mjd").datetime
            else:
                dates = d["mjd"]
            ax.errorbar(dates, d["mag"], 
                                yerr=d["magerr"],
                                **{**prop,**kwargs})

        ax.invert_yaxis()
        
        if show_upperlimits:
            for filter_ in np.unique(lc_dataframe["filtercode"]):
                d = lc_dataframe[lc_dataframe["filtercode"]==filter_]
                if filter_ in FILTER_CODE:
                    color = np.asarray(FILTER_COLORS)[np.where(np.asarray(FILTER_CODE)==filter_)][0]
                else:
                    color = "0.7"

                if formattime:
                    dates = time.Time(np.asarray(d["mjd"].values, dtype="float"), format="mjd").datetime
                else:
                    dates = d["mjd"]
                    
                ax.errorbar(dates, d["limitmag"], 
                            yerr=0.1, lolims=True,marker="None", ls="None", 
                            color=color, alpha=0.1,
                            )

        if showtoday:
            today_color = "0.7"
            import datetime
            today = time.Time(datetime.date.today().isoformat(),format="iso").mjd
            ax.axvline(today, ls="--", color=today_color, zorder=1, lw=1)
            ax.text(today, ax.get_ylim()[0]-0.05, "Today", va="bottom", ha="right", rotation=90, color=today_color)

        if formattime:
            from matplotlib import dates as mdates            
            locator = mdates.AutoDateLocator()
            formatter = mdates.ConciseDateFormatter(locator)
            ax.xaxis.set_major_locator(locator)
            ax.xaxis.set_major_formatter(formatter)
            ax.set_xlabel("Date")
        else:
            ax.set_xlabel("MJD")
        # - Labels

        ax.set_ylabel("mag")
        ax.set_title('%s_%s'%(name,band))

# %% [markdown]
# ## def ztflc_show

# %%
def ztflc_savepng(data,name,band, showtoday=False, show_upperlimits=False, formattime=True,
             marker="o", mec="0.7", ms=7, ecolor="0.7", ls="None", zorder=4, **kwargs):
        """ kwargs goes to matplotlib's errorbar() """
        FILTER_COLORS = ["C2","C3","C1"]
        FILTER_CODE   = ["zg","zr","zi"]
        save_name=name.strip().replace(' ','_')
        

        from astropy import time
        import matplotlib.pyplot as mpl

        # ----------- #
        # Global      #
        # ----------- #
        lc_dataframe = data
        prop = dict(marker=marker, mec=mec, ms=ms, ecolor=ecolor, ls=ls, zorder=zorder)

        # ----------- #
        #
        # ----------- #
        fig = mpl.figure(figsize=[7,4])
        ax = fig.add_axes([0.1,0.15,0.8,0.75])
        for filter_ in np.unique(lc_dataframe["filtercode"]):
            d = lc_dataframe[lc_dataframe["filtercode"]==filter_]
            if filter_ in FILTER_CODE:
                prop["color"] = np.asarray(FILTER_COLORS)[np.where(np.asarray(FILTER_CODE)==filter_)][0]
            else:
                prop["color"] = "0.7"

            if formattime:
                dates = time.Time(np.asarray(d["mjd"].values, dtype="float"), format="mjd").datetime
            else:
                dates = d["mjd"]
            ax.errorbar(dates, d["mag"], 
                                yerr=d["magerr"],
                                **{**prop,**kwargs})

        ax.invert_yaxis()
        
        if show_upperlimits:
            for filter_ in np.unique(lc_dataframe["filtercode"]):
                d = lc_dataframe[lc_dataframe["filtercode"]==filter_]
                if filter_ in FILTER_CODE:
                    color = np.asarray(FILTER_COLORS)[np.where(np.asarray(FILTER_CODE)==filter_)][0]
                else:
                    color = "0.7"

                if formattime:
                    dates = time.Time(np.asarray(d["mjd"].values, dtype="float"), format="mjd").datetime
                else:
                    dates = d["mjd"]
                    
                ax.errorbar(dates, d["limitmag"], 
                            yerr=0.1, lolims=True,marker="None", ls="None", 
                            color=color, alpha=0.1,
                            )

        if showtoday:
            today_color = "0.7"
            import datetime
            today = time.Time(datetime.date.today().isoformat(),format="iso").mjd
            ax.axvline(today, ls="--", color=today_color, zorder=1, lw=1)
            ax.text(today, ax.get_ylim()[0]-0.05, "Today", va="bottom", ha="right", rotation=90, color=today_color)

        if formattime:
            from matplotlib import dates as mdates            
            locator = mdates.AutoDateLocator()
            formatter = mdates.ConciseDateFormatter(locator)
            ax.xaxis.set_major_locator(locator)
            ax.xaxis.set_major_formatter(formatter)
            ax.set_xlabel("Date")
        else:
            ax.set_xlabel("MJD")
        # - Labels

        ax.set_ylabel("mag")
        ax.set_title('%s_%s'%(name,band))
        
        fig.savefig('%s/%s_%s.png'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band),
                   dpi=400, transparent=False, bbox_inches='tight')
        mpl.close()

# %% [markdown]
# ## NGC 4151

# %%
Name_index=2
print(CLAGN_Candidate_BAT.loc[Name_index,'AGN'])
print(CLAGN_Candidate_BAT.loc[Name_index,'ra'],CLAGN_Candidate_BAT.loc[Name_index,'dec'])
# Out:
# NGC 4151
# 182.63574 39.40573

# %%
pwd
# Out:
# '/Users/lyubing/blog/brettlv.github.io/pythoncode/changinglookAGN'

# %%
ls
# Out:
# BAT150month.ipynb
# BAT_105m_catalog_07jul2019.ipynb*
# CLAGN_Candidate_BAT_ZTF.ipynb*
# CLAGN_crossmatch.ipynb*
# CLAGN_ned_data/
# CLAGN_py3ads_adstex_arxiv.ipynb*
# CLAGN_wise_data/
# CLANG_statistic_for_data_planing.ipynb*
# Irsa_wise_astroquery.ipynb*
# Javelin_CCF_timelag.ipynb*
# LAMOST_CLAGN_Search.ipynb
# LLAGN_NED_name_redshift_search.ipynb*
# OXCLAGN_NuSTAR/
# QSO_wise.ipynb*
# Readme.md*
# Readme.py*
# Search data with CasJobs.ipynb
# Untitled.ipynb
# WISE_LLAGN_Quasar.ipynb*
# WISE_data_plot_hist.ipynb*
# WISE_download_plot.ipynb*
# WISE_timelag_lc.ipynb*
# ZTF_WWZ_timing_linjie.ipynb*
# changinglook_agn_list_ned_data_vla.ipynb*
# output/
# ztf_data_r_mjd_mag_magerr.txt*

# %%
Name_index=2
name=CLAGN_Candidate_BAT.loc[Name_index,'AGN']
save_name=name.strip().replace(' ','_')


print(CLAGN_Candidate_BAT.loc[Name_index,'AGN'])
print(CLAGN_Candidate_BAT.loc[Name_index,'ra'],CLAGN_Candidate_BAT.loc[Name_index,'dec'])

band='g'

data_g = lightcurve.LCQuery.download_data(circle=[CLAGN_Candidate_BAT.loc[Name_index,'ra'],
                                                  CLAGN_Candidate_BAT.loc[Name_index,'dec'],1.0/3600], 
                                          bandname=band,BAD_CATFLAGS_MASK=32768)
ztflc_show_in_jupyter(data_g,name,band)

#lc_g = lightcurve.LCQuery(data_g)
#lc_g.show()
# Out:
# NGC 4151
# 182.63574 39.40573

# %%
oids=[]
for oid in data_g['oid']:
    if oid not in oids:
        oids.append(oid)

# %%
oids
# Out:
# [715107400005470, 1713113300001769]

# %%
ztflc_show_in_jupyter(data_g[data_g['oid']==1713113300001769],name,band,formattime=False)

# %%
ztflc_show_in_jupyter(data_g[data_g['oid']==715107400005470],name,band,formattime=False)

# %%
Name_index=2
name=CLAGN_Candidate_BAT.loc[Name_index,'AGN']
save_name=name.strip().replace(' ','_')


print(CLAGN_Candidate_BAT.loc[Name_index,'AGN'])
print(CLAGN_Candidate_BAT.loc[Name_index,'ra'],CLAGN_Candidate_BAT.loc[Name_index,'dec'])

band='r'


data_r = lightcurve.LCQuery.download_data(circle=[CLAGN_Candidate_BAT.loc[Name_index,'ra'],
                                                  CLAGN_Candidate_BAT.loc[Name_index,'dec'],1.0/3600], 
                                          bandname=band,BAD_CATFLAGS_MASK=32768)
ztflc_show_in_jupyter(data_r,name,band)

#lc_g = lightcurve.LCQuery(data_g)
#lc_g.show()

# %%
Name_index=2
name=CLAGN_Candidate_BAT.loc[Name_index,'AGN']
save_name=name.strip().replace(' ','_')


print(CLAGN_Candidate_BAT.loc[Name_index,'AGN'])
print(CLAGN_Candidate_BAT.loc[Name_index,'ra'],CLAGN_Candidate_BAT.loc[Name_index,'dec'])

band='i'


data_i = lightcurve.LCQuery.download_data(circle=[CLAGN_Candidate_BAT.loc[Name_index,'ra'],
                                                  CLAGN_Candidate_BAT.loc[Name_index,'dec'],1.0/3600], 
                                          bandname=band,BAD_CATFLAGS_MASK=32768)
ztflc_show_in_jupyter(data_i,name,band)

#lc_g = lightcurve.LCQuery(data_g)
#lc_g.show()

# %% [markdown]
# ## BAT150m

# %%
BAT_150month_catalog=pd.read_csv('/Users/lyubing/IHEPBox/data/AGNmass/BAT_150mdata/BAT_150month_catalog.csv')

# %%
BAT_150month_data=pd.read_csv('/Users/lyubing/IHEPBox/data/AGNmass/BAT_150mdata/BAT_150month_data.csv')

# %%
BAT_150month_data_CTAGN=pd.read_csv('/Users/lyubing/IHEPBox/data/AGNmass/BAT_150mdata/BAT_150month_data_CTAGN.csv')

# %%
BAT_150month_catalog_zlessthan0dot3=BAT_150month_catalog[BAT_150month_catalog['z']<0.3]
BAT_150month_catalog_zlessthan0dot3=drop_index(BAT_150month_catalog_zlessthan0dot3)

# %%
# 14                 NGC 3079  0.00370  150.490850  55.679790
# 15                 NGC 3281  0.01067  157.967042 -34.853694
# 16                 NGC 3393  0.01250  162.097780 -25.162030
# 17               ESO 323-32  0.01600  193.334730 -41.635650
# 18                 NGC 4945  0.00190  196.363660 -49.467900
# 19          Circinus Galaxy  0.00140  213.291270 -65.339020
# 20                 NGC 5643  0.00400  218.169910 -44.174610
# 21                 NGC 5728  0.00930  220.599700 -17.253170
# 22            ESO 137-G 034  0.00900  248.808810 -58.080030
# 23                 NGC 6240  0.02450  253.245250   2.400990
# 24                 NGC 6552  0.02650  270.030460  66.615110
# 25                 NGC 6921  0.01450  307.146090  25.733380
# 26                 NGC 7130  0.01620  327.081210 -34.951310
# 27           NGC 7212 NED02  0.02670  331.758300  10.233470
# 28                 NGC 7479  0.00790  346.236120  12.322880
# 29             CGCG 475-040  0.03500  346.953600  22.710300
# 30                 NGC 7582  0.00520  349.598420 -42.370570
# 31                 NGC 7674  0.02892  351.986352   8.779035
#
#              Reference
# 0            Zhao+2020
# 1          Marchesi+18
# 2          Marchesi+18
# 3   Georgantopoulos+19
# 4            Zhao+2020
# 5          Marchesi+18
# 6          Marchesi+18
# 7          Marchesi+18
# 8          Marchesi+18
# 9          Marchesi+18
# 10      Torres-Albà+21
# 11      Torres-Albà+21
# 12           Traina+21
# 13              Oda+17
# 14         Marchesi+18
# 15           Zhao+2020
# 16         Marchesi+18
# 17      Torres-Albà+21
# 18         Marchesi+18
# 19          Arevalo+14
# 20         Marchesi+18
# 21           Zhao+2020
# 22  Georgantopoulos+19
# 23         Marchesi+18
# 24      Torres-Albà+21
# 25             Koss+16
# 26         Marchesi+18
# 27         Marchesi+18
# 28         Marchesi+18
# 29      Torres-Alba+21
# 30         Marchesi+18
# 31           Zhao+2019

# %% [markdown]
# ## million quasar

# %% [markdown]
# ## save_ztf_lc

# %%
CLAGN_Candidate_BAT_ZTF_dir
# Out:
# '/Volumes/ExtremeSSD/CLAGN_individual/CL_candidate/CLAGN_BAT_candidate/ZTF'

# %%
os.listdir(CLAGN_Candidate_BAT_ZTF_dir)
# Out:
# ['NGC_526A_g.csv',
#  'NGC_526A_i.csv',
#  'NGC_526A_r.csv',
#  'NGC_5548_g.csv',
#  'NGC_5548_i.csv',
#  'NGC_5548_r.csv',
#  'NGC_4151_g.csv',
#  'NGC_4151_i.csv',
#  'NGC_4151_r.csv',
#  'NGC_973_g.csv',
#  'NGC_973_i.csv',
#  'NGC_973_r.csv',
#  'WKK_4374_g.csv',
#  'WKK_4374_i.csv',
#  'WKK_4374_r.csv',
#  'NGC_2617_g.csv',
#  'NGC_2617_i.csv',
#  'NGC_2617_r.csv',
#  'NGC_4507_g.csv',
#  'NGC_4507_i.csv',
#  'NGC_4507_r.csv',
#  'Mrk3_g.csv',
#  'Mrk3_i.csv',
#  'Mrk3_r.csv',
#  '2MASX_J04440903+2813003_g.csv',
#  '2MASX_J04440903+2813003_i.csv',
#  '2MASX_J04440903+2813003_r.csv',
#  'NGC_4388_g.csv',
#  'NGC_4388_i.csv',
#  'NGC_4388_r.csv',
#  'NGC_2110_g.csv',
#  'NGC_2110_i.csv',
#  'NGC_2110_r.csv',
#  '2MASX_J10402231-4625264_g.csv',
#  '2MASX_J10402231-4625264_i.csv',
#  '2MASX_J10402231-4625264_r.csv',
#  'IC_4709_g.csv',
#  'IC_4709_i.csv',
#  'IC_4709_r.csv',
#  'UGC_03601_g.csv',
#  'UGC_03601_i.csv',
#  'UGC_03601_r.csv',
#  '4C_50.55_g.csv',
#  '4C_50.55_i.csv',
#  '4C_50.55_r.csv',
#  'NGC_4235_g.csv',
#  'NGC_4235_i.csv',
#  'NGC_4235_r.csv',
#  'NGC_7679_g.csv',
#  'NGC_7679_i.csv',
#  'NGC_7679_r.csv',
#  'NGC_4945_g.csv',
#  'NGC_4945_i.csv',
#  'NGC_4945_r.csv',
#  'NGC_3281_g.csv',
#  'NGC_3281_i.csv',
#  'NGC_3281_r.csv',
#  '4U_1344-60_g.csv',
#  '4U_1344-60_i.csv',
#  '4U_1344-60_r.csv',
#  'MCG_+04-48-002_g.csv',
#  'MCG_+04-48-002_i.csv',
#  'MCG_+04-48-002_r.csv',
#  'NGC_6300_g.csv',
#  'NGC_6300_i.csv',
#  'NGC_6300_r.csv',
#  'IC_4329A_g.csv',
#  'IC_4329A_i.csv',
#  'IC_4329A_r.csv',
#  'NGC_3079_g.csv',
#  'NGC_3079_i.csv',
#  'NGC_3079_r.csv',
#  'IC_2461_g.csv',
#  'IC_2461_i.csv',
#  'IC_2461_r.csv',
#  'NGC_788_g.csv',
#  'NGC_788_i.csv',
#  'NGC_788_r.csv',
#  'NGC_526A_g.png',
#  'NGC_526A_i.png',
#  'NGC_526A_r.png',
#  'NGC_5548_g.png',
#  'NGC_5548_i.png',
#  'NGC_5548_r.png',
#  'NGC_4151_g.png',
#  'NGC_4151_i.png',
#  'NGC_4151_r.png',
#  'NGC_973_g.png',
#  'NGC_973_i.png',
#  'NGC_973_r.png',
#  'WKK_4374_g.png',
#  'WKK_4374_i.png',
#  'WKK_4374_r.png',
#  'NGC_2617_g.png',
#  'NGC_2617_i.png',
#  'NGC_2617_r.png',
#  'NGC_4507_g.png',
#  'NGC_4507_i.png',
#  'NGC_4507_r.png',
#  'Mrk3_g.png',
#  'Mrk3_i.png',
#  'Mrk3_r.png',
#  '2MASX_J04440903+2813003_g.png',
#  '2MASX_J04440903+2813003_i.png',
#  '2MASX_J04440903+2813003_r.png',
#  'NGC_4388_g.png',
#  'NGC_4388_i.png',
#  'NGC_4388_r.png',
#  'NGC_2110_g.png',
#  'NGC_2110_i.png',
#  'NGC_2110_r.png',
#  '2MASX_J10402231-4625264_g.png',
#  '2MASX_J10402231-4625264_i.png',
#  '2MASX_J10402231-4625264_r.png',
#  'IC_4709_g.png',
#  'IC_4709_i.png',
#  'IC_4709_r.png',
#  'UGC_03601_g.png',
#  'UGC_03601_i.png',
#  'UGC_03601_r.png',
#  '4C_50.55_g.png',
#  '4C_50.55_i.png',
#  '4C_50.55_r.png',
#  'NGC_4235_g.png',
#  'NGC_4235_i.png',
#  'NGC_4235_r.png',
#  'NGC_7679_g.png',
#  'NGC_7679_i.png',
#  'NGC_7679_r.png',
#  'NGC_4945_g.png',
#  'NGC_4945_i.png',
#  'NGC_4945_r.png',
#  'NGC_3281_g.png',
#  'NGC_3281_i.png',
#  'NGC_3281_r.png',
#  '4U_1344-60_g.png',
#  '4U_1344-60_i.png',
#  '4U_1344-60_r.png',
#  'MCG_+04-48-002_g.png',
#  'MCG_+04-48-002_i.png',
#  'MCG_+04-48-002_r.png',
#  'NGC_6300_g.png',
#  'NGC_6300_i.png',
#  'NGC_6300_r.png',
#  'IC_4329A_g.png',
#  'IC_4329A_i.png',
#  'IC_4329A_r.png',
#  'NGC_3079_g.png',
#  'NGC_3079_i.png',
#  'NGC_3079_r.png',
#  'IC_2461_g.png',
#  'IC_2461_i.png',
#  'IC_2461_r.png',
#  'NGC_788_g.png',
#  'NGC_788_i.png',
#  'NGC_788_r.png']

# %%
ztf_bands=['g','i','r']

# %%
for Name_index,name in enumerate(CLAGN_Candidate_BAT['AGN']):
    save_name=name.strip().replace(' ','_')
    
    for band in ztf_bands:
        if not os.path.exists('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band)):
            data_g = lightcurve.LCQuery.download_data(circle=[CLAGN_Candidate_BAT.loc[Name_index,'ra'],CLAGN_Candidate_BAT.loc[Name_index,'dec'],1.0/3600], 
                                                  bandname=band,BAD_CATFLAGS_MASK=32768)
            data_g.to_csv('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band),index=False) 
            time.sleep(1+np.random.randint(2,5))  
        else:
            time.sleep(1)

# %%
len(CLAGN_Candidate_BAT)

# %%
26*3

# %%
Name_index=2
name=CLAGN_Candidate_BAT.loc[Name_index,'AGN']
print(name)
save_name=name.strip().replace(' ','_')
band=ztf_bands[0]
#
for band in ztf_bands:
    if os.path.exists('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band)):
        data=pd.read_csv('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band)) 
         #ztflc_savepng(data,name,band)
        #ztflc_show_in_jupyter(data,name,band,formattime=False)    
        ztflc_show_in_jupyter(data,name,band)
# Out:
# NGC 4151

# %% [markdown]
# for Name_index,name in enumerate(CLAGN_Candidate_BAT['AGN']):
#     save_name=name.strip().replace(' ','_')
#     for band in ztf_bands:
#         if os.path.exists('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band)):
#             data=pd.read_csv('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir,save_name,band))
#              ztflc_savepng(data,name,band)

# %%
ztflc_show(data,name,band)

# %%
data.columns

# %%
lc_g.#.data

# %%
data_i = lightcurve.LCQuery.download_data(circle=[299.412,50.55500,0.0014], bandname="i",BAD_CATFLAGS_MASK=15)

# %%
data_r_3arcsec= lightcurve.LCQuery.download_data(circle=[299.412,50.55500,3.0/3600], bandname="r",BAD_CATFLAGS_MASK=15)
print(len(data_r_3arcsec))

# %% [markdown]
# ## BAD_CATFLAGS_MASK=0

# %%
CLAGN_Candidate_BAT_ZTF_dir_1

# %%
for Name_index,name in enumerate(CLAGN_Candidate_BAT['AGN']):
    save_name=name.strip().replace(' ','_')
    
    for band in ztf_bands:
        if not os.path.exists('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir_1,save_name,band)):
            data_g = lightcurve.LCQuery.download_data(circle=[CLAGN_Candidate_BAT.loc[Name_index,'ra'],
                                                              CLAGN_Candidate_BAT.loc[Name_index,'dec'],1.0/3600], 
                                                  bandname=band,BAD_CATFLAGS_MASK=0)
            data_g.to_csv('%s/%s_%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir_1,save_name,band),index=False) 
            time.sleep(1+np.random.randint(2,5))  
        else:
            time.sleep(1)

# %% [markdown]
# ## save CLAGN_list data

# %%
CLAGN_Candidate_BAT_ZTF_dir_2='/Volumes/ExtremeSSD/data_source/ZTFdata/CLAGNztf/20230703/'

# %%
print(CLAGN_Candidate_BAT_ZTF_dir_2)
# Out:
# /Volumes/ExtremeSSD/data_source/ZTFdata/CLAGNztf/20230703/

# %%
for Name_index,name in enumerate(CLAGN_list202206['Name']):
    save_name=name.strip().replace(' ','_')
    
    #for band in ztf_bands:
    if not os.path.exists('%s/%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir_2,save_name)):
        data_g = lightcurve.LCQuery.download_data(circle=[CLAGN_list202206.loc[Name_index,'ra_deg'],
                                                          CLAGN_list202206.loc[Name_index,'dec_deg'],2.0/3600], 
                                                           #bandname=band,
                                                           BAD_CATFLAGS_MASK=32768)
        if len(data_g)>10:
            data_g.to_csv('%s/%s.csv'%(CLAGN_Candidate_BAT_ZTF_dir_2,save_name),index=False) 
            time.sleep(1+np.random.randint(3,10))  
    else:
        time.sleep(2)

# %% [markdown]
# for Name_index,name in enumerate(CLAGN_list202206['Name']):
#     save_name=name.strip().replace(' ','_')
#
#     if not os.path.exists('%s/%s_gir.csv'%(CLAGN_Candidate_BAT_ZTF_dir_2,save_name)):
#         data_g = lightcurve.LCQuery.download_data(circle=[CLAGN_list202206.loc[Name_index,'ra_deg'],
#                                                           CLAGN_list202206.loc[Name_index,'dec_deg'],1.0/3600],
#                                               bandname='g,i,r',BAD_CATFLAGS_MASK=0)
#         data_g.to_csv('%s/%s_gir.csv'%(CLAGN_Candidate_BAT_ZTF_dir_2,save_name),index=False)
#         time.sleep(1+np.random.randint(3,10))
#     else:
#         time.sleep(2)

# %%
# !ls /Volumes/ExtremeSSD/data_source/ZTFdata/CLAGNztf/20230703/*.csv | wc -l
# Out:
#      135

# %% [markdown]
# # LAMOST_ZTF

# %% [markdown]
# ## download lamost qso

# %%
lamostdr10_12_ztfdata='/Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12'
if not os.path.exists(lamostdr10_12_ztfdata):
    os.mkdir(lamostdr10_12_ztfdata)

# %%
import pandas as pd
pd_asera=pd.read_csv('/Users/lyubing/Downloads/dr10_dr11q12_asera_check.csv')

# %%
pd_asera_QSOandCandidates=pd_asera[pd_asera['label']<3]
pd_asera_QSOandCandidates=drop_index(pd_asera_QSOandCandidates)

# %%
len(pd_asera_QSOandCandidates)
# Out:
# 4526

# %%
for index,path in enumerate(pd_asera_QSOandCandidates['#cols: spUrl']):
    path_i= path[8:]
    
    hdul_i=fits.open(path_i)
    obsid_i= hdul_i[0].header['OBSID']
    ra=hdul_i[0].header['RA']
    dec=hdul_i[0].header['DEC']
    
    
    save_name= 'id%dra%.5f_dec%.5f'%(obsid_i,ra,dec)
    
    #for band in ztf_bands:
    if not os.path.exists('%s/%s.csv'%(lamostdr10_12_ztfdata,save_name)):
        data_g = lightcurve.LCQuery.download_data(circle=[ra,
                                                          dec,2.0/3600], 
                                                           #bandname=band,
                                                           BAD_CATFLAGS_MASK=32768)
            
        pd_ztf_i=data_g
        pd_ztf_i_zg=pd_ztf_i[pd_ztf_i['filtercode']=='zg']
        pd_ztf_i_zr=pd_ztf_i[pd_ztf_i['filtercode']=='zr']
        pd_ztf_i_zi=pd_ztf_i[pd_ztf_i['filtercode']=='zi']

        if len(pd_ztf_i_zg)>0 and len(pd_ztf_i_zr)>0:                
                data_g.to_csv('%s/%s.csv'%(lamostdr10_12_ztfdata,save_name),index=False) 
                time.sleep(1+np.random.randint(3,10))  
        else:
            print(index,save_name)
            #time.sleep(2)
# Out:
# 25 id937812105ra45.60576_dec10.02769
# 141 id948805173ra143.19367_dec15.53964
# 153 id948809196ra145.43437_dec17.06064
# 167 id948813134ra146.29346_dec16.95122
# 168 id948813143ra146.30575_dec17.12854
# 210 id949707015ra75.76135_dec10.07962
# 216 id949901104ra45.73807_dec45.47209
# 242 id950313070ra10.54126_dec23.48996
# 260 id961207206ra61.36798_dec4.16413
# 268 id963601015ra174.92533_dec6.51312
# 300 id964609094ra200.23356_dec2.70913
# 310 id964615203ra199.09498_dec2.66902
# 353 id965309047ra149.19257_dec38.76953
# 358 id965401015ra174.92533_dec6.51310
# 379 id965406153ra176.96141_dec7.43814
# 391 id965411231ra174.64254_dec9.84751
# 394 id965413059ra176.68215_dec8.20788
# 399 id965416142ra174.03857_dec10.03869
# 417 id966112125ra66.83378_dec-0.97807
# 432 id966307069ra113.24197_dec13.67856
# 439 id966311188ra112.18699_dec17.04387
# 440 id966312070ra113.17883_dec17.05359
# 452 id966402089ra154.95704_dec15.51593
# 456 id966403086ra155.22646_dec16.96335
# 482 id966410161ra154.97311_dec16.13190
# 520 id974202133ra203.38697_dec6.49293
# 521 id974202223ra202.92595_dec6.42603
# 528 id974212025ra205.23703_dec9.83818
# 532 id974702083ra196.93179_dec-4.48849
# 541 id974707174ra199.30062_dec-4.46561
# 542 id974707192ra199.28146_dec-4.70058
# 544 id974709071ra199.35618_dec-1.59862
# 546 id974709214ra199.34338_dec-2.41488
# 547 id974710095ra196.54039_dec-2.99085
# 548 id974711183ra198.48540_dec-0.72457
# 551 id975409047ra149.19257_dec38.76953
# 563 id975507174ra199.30062_dec-4.46561
# 565 id975509071ra199.35618_dec-1.59862
# 567 id975509214ra199.34338_dec-2.41488
# 568 id975510095ra196.54039_dec-2.99085
# 591 id976009047ra149.19257_dec38.76953
# 594 id977502162ra181.14916_dec-1.67160
# 604 id977505041ra182.10398_dec-0.77692
# 613 id977508188ra182.54501_dec-0.65250
# 615 id977511023ra181.48606_dec2.64796
# 617 id977512026ra183.21265_dec2.75990
# 620 id977512178ra183.48607_dec2.61552
# 636 id978206086ra160.69213_dec13.52717
# 650 id978302162ra181.14916_dec-1.67160
# 659 id978308188ra182.54501_dec-0.65250
# 661 id978312178ra183.48607_dec2.61552
# 687 id988701036ra199.85357_dec-0.62859
# 3983 id1088803249ra164.39958_dec25.39792
# 3996 id1088808069ra167.08722_dec25.39378
# 4016 id1088815034ra166.33800_dec27.19025
# 4046 id1089303116ra153.06398_dec2.30710
# 4104 id1089408228ra173.24075_dec17.99179
# 4109 id1089409202ra173.19743_dec18.73123
# 4152 id1090008123ra154.92937_dec0.69452
# 4157 id1090009158ra154.50362_dec2.66158
# 4162 id1090013139ra156.00445_dec2.59841
# 4169 id1098314127ra100.84136_dec49.76114
# 4188 id1101302156ra178.02452_dec-3.50440
# 4219 id1110603076ra171.24120_dec18.41554
# 4247 id1110609202ra173.19743_dec18.73123
# 4274 id1111702103ra213.28811_dec9.33645
# 4276 id1111702231ra213.43503_dec9.95796
# 4285 id1111705046ra214.31289_dec9.92211
# 4298 id1111707052ra215.48094_dec9.78475
# 4302 id1111708213ra215.01238_dec9.94793
# 4303 id1111708221ra215.01523_dec9.83419
# 4310 id1111711044ra215.09066_dec13.44385
# 4317 id1111712233ra215.25431_dec13.62433
# 4341 id1112908010ra175.27788_dec-2.39627
# 4352 id1112910161ra172.76626_dec-2.60007
# 4354 id1112912207ra176.27171_dec-0.43865
# 4364 id1113102236ra225.61531_dec20.98266
# 4386 id1113115080ra225.90954_dec23.58341
# 4389 id1113116126ra225.94935_dec24.45157
# 4390 id1113701016ra214.66119_dec2.02129
# 4391 id1113701033ra214.62336_dec1.78453
# 4397 id1113702062ra212.92048_dec2.68547
# 4398 id1113702088ra212.72691_dec2.26383
# 4407 id1113703076ra213.27120_dec3.61669
# 4412 id1113705099ra214.40952_dec2.57406
# 4417 id1113705150ra214.68828_dec3.06527
# 4418 id1113705215ra213.69547_dec2.58463
# 4421 id1113706008ra216.25002_dec2.67757
# 4425 id1113706206ra216.34345_dec2.71106
# 4426 id1113707146ra215.55527_dec1.71027
# 4435 id1113708181ra215.10675_dec2.70785
# 4447 id1113710112ra212.80613_dec3.02149
# 4464 id1113714019ra212.73069_dec4.88706
# 4466 id1113714091ra213.25270_dec4.47977
# 4467 id1113714133ra212.85795_dec4.64336
# 4471 id1113715024ra214.58009_dec4.69308
# 4475 id1113715193ra214.59556_dec4.42601
# 4484 id1113801087ra228.27258_dec3.49055
# 4485 id1113801092ra228.28061_dec3.58450
# 4487 id1113802097ra226.47727_dec3.56620
# 4494 id1113804159ra228.34340_dec5.21232
# 4495 id1113805031ra228.34320_dec3.69183
# 4499 id1113806177ra230.24039_dec4.49449

# %%
for index,path in enumerate(pd_asera_QSOandCandidates['#cols: spUrl']):
    path_i= path[8:]
    
    hdul_i=fits.open(path_i)
    obsid_i= hdul_i[0].header['OBSID']
    ra=hdul_i[0].header['RA']
    dec=hdul_i[0].header['DEC']
    
    
    save_name= 'id%dra%.5f_dec%.5f'%(obsid_i,ra,dec)
    
    path_ztf_i='%s/%s.csv'%(lamostdr10_12_ztfdata,save_name)

    if os.path.exists(path_ztf_i):
        #print(save_name)
        pd_ztf_i=pd.read_csv(path_ztf_i)           
        pd_ztf_i_zg=pd_ztf_i[pd_ztf_i['filtercode']=='zg']
        pd_ztf_i_zr=pd_ztf_i[pd_ztf_i['filtercode']=='zr']
        pd_ztf_i_zi=pd_ztf_i[pd_ztf_i['filtercode']=='zi']

        if len(pd_ztf_i_zg)<1:
            #print('rm %s'%path_ztf_i)
            os.remove(path_ztf_i)
            #os.system('rm %s'%path_ztf_i)
        elif len(pd_ztf_i_zr)<1:
            #print('rm %s'%path_ztf_i)
            #os.system('rm %s'%path_ztf_i) 
            os.remove(path_ztf_i)
        #elif len(pd_ztf_i_zi)<1:
            #print('rm %s'%path_ztf_i)
            #os.system('rm %s'%path_ztf_i) 
            #os.remove(path_ztf_i)

# %%
lamostdr10_12_ztfdata
# Out:
# '/Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12'

# %%
ls /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/*.csv | wc -l
# Out:
#     4280

# %%
ls /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/*.csv | wc -l
# Out:
#     4280

# %%
for index,path in enumerate(pd_asera_QSOandCandidates['#cols: spUrl']):
    path_i= path[8:]
    
    hdul_i=fits.open(path_i)
    obsid_i= hdul_i[0].header['OBSID']
    ra=hdul_i[0].header['RA']
    dec=hdul_i[0].header['DEC']
       
    save_name= 'id%dra%.5f_dec%.5f'%(obsid_i,ra,dec)
    print('%s/%s.csv'%(lamostdr10_12_ztfdata,save_name))
# Out:
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937801018ra44.35506_dec6.76205.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802019ra42.30639_dec6.90789.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802054ra42.55799_dec7.24886.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802059ra42.27189_dec7.13619.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802087ra42.24279_dec6.69545.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802213ra43.34877_dec6.52982.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802222ra43.32375_dec6.39050.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937802227ra42.95822_dec6.81634.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937803013ra43.31851_dec7.85917.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937803085ra42.82207_dec8.24906.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937804044ra43.89645_dec8.92669.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937804081ra44.53718_dec7.97731.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937804140ra43.79830_dec7.78970.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937805107ra43.48692_dec7.18163.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937805157ra42.85310_dec7.63888.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937806031ra45.61554_dec8.28100.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937808062ra45.17603_dec8.02514.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937808102ra44.78064_dec7.43189.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937808108ra44.90693_dec7.21822.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937809019ra44.72551_dec8.60762.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937809180ra45.28453_dec8.92567.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937810005ra41.85446_dec8.31326.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937810066ra42.51697_dec8.06627.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937810198ra42.04367_dec7.78158.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937811132ra43.65248_dec10.73081.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937812105ra45.60576_dec10.02769.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937813059ra46.13780_dec8.56619.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937814034ra41.91136_dec8.34492.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937814066ra42.26649_dec8.42795.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937816115ra43.50092_dec10.10844.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937816136ra42.99724_dec10.23416.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937816153ra43.04753_dec9.85113.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937816213ra42.40616_dec9.78087.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id937910127ra71.50029_dec2.08056.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938002127ra359.69357_dec46.81506.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938002212ra359.44023_dec46.56858.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938005173ra359.41489_dec47.54595.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938008048ra2.27231_dec48.24814.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938008128ra2.45449_dec47.52348.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938008217ra1.88887_dec47.15957.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938009085ra1.56907_dec49.86431.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938009227ra2.51678_dec48.55959.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938010063ra358.02401_dec48.05512.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938010114ra358.72464_dec47.79516.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938010172ra358.81466_dec47.51013.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938014062ra358.36240_dec48.48282.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938014204ra357.97764_dec48.84529.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938015009ra0.52737_dec49.58202.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938016137ra359.63818_dec50.35826.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938106046ra117.80912_dec68.29580.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938107228ra115.96730_dec66.93336.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938108235ra114.91379_dec68.11658.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938113226ra116.60996_dec69.01522.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id
csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1001707042ra215.79378_dec9.56587.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1001707042ra215.79378_dec9.56587.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003103061ra213.42101_dec3.75947.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003203106ra224.61374_dec11.03116.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003203106ra224.61374_dec11.03116.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009602053ra190.53001_dec12.24082.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009602053ra190.53001_dec12.24082.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009606040ra194.04761_dec13.39587.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009606127ra194.06842_dec13.19874.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009705112ra227.76773_dec3.68360.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009708091ra229.69331_dec4.86868.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1011102126ra250.64448_dec44.44073.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1016306208ra211.58305_dec24.17247.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948416179ra148.98008_dec47.63851.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003114104ra212.50197_dec4.45216.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009714119ra226.13481_dec5.87441.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948809222ra144.92119_dec16.77624.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009616130ra191.12182_dec15.45791.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948402223ra149.12488_dec44.39781.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948401093ra150.47986_dec44.44806.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id951501060ra150.13648_dec44.55665.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948401060ra150.13648_dec44.55665.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id949413040ra140.61199_dec40.58693.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009715138ra228.41054_dec6.10724.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948809126ra145.35540_dec16.71756.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948804174ra143.77475_dec16.43409.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id938813145ra10.40134_dec13.92592.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003113001ra216.68714_dec4.44819.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948409141ra152.30552_dec46.56753.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003111096ra214.28201_dec5.36771.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948416233ra149.66701_dec48.38512.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009707110ra229.92957_dec3.89766.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003212226ra227.18788_dec12.85577.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948403078ra149.12021_dec46.16687.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003106167ra216.63494_dec2.94590.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1009701196ra228.71483_dec2.71845.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id1003110234ra212.80613_dec3.02149.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948802250ra143.30081_dec14.98312.csv
# /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/id948415169ra149.58196_dec47.41885.csv

# %%
path_i=pd_asera_QSOandCandidates['#cols: spUrl'][0][8:]

# %%
hdul_i=fits.open(path_i)
obsid_i= hdul_i[0].header['OBSID']

# %%
obsid_i
# Out:
# 937801018

# %%
hdul_i[0].header['RA'],hdul_i[0].header['DEC']
# Out:
# (44.355063, 6.762051)

# %%
hdul_i[0].header
# Out:
# SIMPLE  =                    T /Primary Header created by MWRFITS v1.11b
# BITPIX  =                   16 /
# NAXIS   =                    0 / Number of array dimensions
# NAXIS1  =                 3909 /
# NAXIS2  =                    5 /
# EXTEND  =                    T /
#
# COMMENT --------FILE INFORMATION
# FILENAME= 'spec-59550-HD100305N461149M02_sp15-169.fits' /
# OBSID   =            948415169 / Unique number ID of this spectrum
# AUTHOR  = 'LAMOST Pipeline'    / Who compiled the information
# DATA_V  = 'LAMOST DR10 Q1'     / Data release version
# N_EXTEN =                    2 / The amount of extension
# NORM    =                    0 / 1 if there exists a normalizated spectrum
# ORIGIN  = 'NAOC-LAMOST'        / Organization responsible for creating this file
# DATE    = '2022-05-23T12:37:57' / Time when this HDU is created (UTC)
# COMMENT --------TELESCOPE PARAMETERS
# TELESCOP= 'LAMOST  '           / GuoShouJing Telescope
# LONGITUD=               117.58 / [deg] Longitude of site
# LATITUDE=                40.39 / [deg] Latitude of site
# FOCUS   =                19964 / [mm] Telescope focus
# CAMPRO  = 'NEWCAM  '           / Camera program name
# CAMVER  = 'v2.0    '           / Camera program version
# COMMENT --------OBSERVATION PARAMETERS
# DATE-OBS= '2021-12-01T21:15:00' / The observation median UTC
# DATE-BEG= '2021-12-02T04:28:12.950' / The observation start local time
# DATE-END= '2021-12-02T06:02:22.800' / The observation end local time
# LMJD    =                59550 / Local Modified Julian Day
# MJD     =                59549 / Modified Julian Day
# LMJMLIST= '85752268-85752300-85752331' / Local Modified Julian Minute list
# PLANID  = 'HD100305N461149M02' / Plan ID in use
# RA      =           149.581960 / [deg] Right ascension of object
# DEC     =            47.418851 / [deg] Declination of object
# RA_OBS  =           149.581960 / [deg] Right ascension during observing
# DEC_OBS =            47.418851 / [deg] Declination during observing
# OFFSET  =                    F / Whether there's a offset during observing
# OFFSET_V=                 0.00 / Offset value in arcsecond
# DESIG   = 'LAMOST J095819.67+472507.8' / Designation of LAMOST target
# FIBERID =                  169 / Fiber ID of Object
# CELL_ID = 'H2114   '           / Fiber Unit ID on the focal plane
# X_VALUE = '297.6213672280'     / [mm] X coordinate of object on the focal plane
# Y_VALUE = '-414.2056438970'    / [mm] Y coordinate of object on the focal plane
# OBJNAME = '262179463137139'    / Name of object
# OBJTYPE = 'Star    '           / Object type from input catalog
# TSOURCE = 'LEGAS_ZYX'          / Name of input catalog
# TCOMMENT= '1237657630055989275' / Target information
# TFROM   = 'DR9_dd  '           / Target catalog
# FIBERTYP= 'Obj     '           / Fiber type of object
# FIBERMAS=                    9 / Bitmask of warning values, 0 means all is well
# MAGTYPE = 'V       '           / Magnitude type of object
# MAG1    =                18.85 / [mag] Mag1 of object
# MAG2    =                99.00 / [mag] Mag2 of object
# MAG3    =                99.00 / [mag] Mag3 of object
# MAG4    =                99.00 / [mag] Mag4 of object
# MAG5    =                99.00 / [mag] Mag5 of object
# MAG6    =                99.00 / [mag] Mag6 of object
# MAG7    =                99.00 / [mag] Mag7 of object
# OBS_TYPE= 'OBJ     '           / The type of target (OBJ, FLAT, ARC or BIAS)
# OBSCOMM = 'Science '           / Science or Test
# RADECSYS= 'FK5     '           / Equatorial coordinate system
# EQUINOX =              2000.00 / Equinox in years
# LAMPLIST= 'lamphgcdne.dat'     / Arc lamp emission line list
# SKYLIST = 'skylines.dat'       / Sky emission line list
# NEXP    =                    3 / Number of valid exposures
# NEXP_B  =                    3 / Number of valid blue exposures
# NEXP_R  =                    3 / Number of valid red exposures
# EXPT_B  =              5400.00 / [s] Blue exposure duration time
# EXPT_R  =              5400.00 / [s] Red exposure duration time
# EXPTIME =              5400.00 / [s] Minimum of exposure time for all cameras
# BESTEXP =             85752268 / LMJM of the best exposure
# SCAMEAN =                 3.80 / [ADU] Mean level of scatter light
# COMMENT --------SPECTROGRAPH PARAMETERS
# SPID    =                   15 / Spectrograph ID
# SPRA    =          150.4249773 / [deg] Average RA of this spectrograph
# SPDEC   =           47.2459672 / [deg] Average DEC of this spectrograph
# SLIT_MOD= 'x2/3    '           / Slit mode, x1, x2/3 or x1/2
# COMMENT --------WEATHER CONDITION
# TEMPCCDB=              -274.00 / [deg] The temperature of blue CCD
# TEMPCCDR=              -274.00 / [deg] The temperature of red CCD
# SEEING  =                 3.70 / [arcsec] Seeing during exposure
# MOONPHA =                27.83 / [day] Moon phase for a 29.53 days period
# TEMP_AIR=                -2.00 / [deg] Temperature outside dome
# TEMP_FP =                 2.90 / [degree celsius] Temprature of the focalplane
# DEWPOINT=               -14.30 / [deg]
# DUST    = '        '           / Reservation
# HUMIDITY=                38.40 /
# WINDD   =               220.00 / [deg] Wind direction
# WINDS   =                 5.40 / [m/s] Wind speed
# SKYLEVEL= '        '           / Reservation
# COMMENT --------DATA REDUCTION PARAMETERS
# EXTRACT = 'aperture'           / Extraction method
# SFLATTEN=                    T / Super flat has been applied
# PCASKYSB=                    T / PCA sky-subtraction has been applied
# NSKIES  =                   49 / Sky fiber number
# SKYCHI2 =                  2.1 / Mean chi^2 of sky-subtraction
# SCHI2MIN=                  1.6 / Minimum chi^2 of sky-subtraction
# SCHI2MAX=                  2.5 / Maximum chi^2 of sky-subtraction
# NSTD    =                    4 / Number of (good) standard stars
# FSTAR   = '60-143-176-177'     / FiberID of flux standard stars
# FCBY    = 'catalog '           / Standard stars origin (auto, manual or catalog)
# HELIO   =                    T / Heliocentric correction
# HELIO_RV=            -22.84708 / [km/s] Heliocentric correction
# VACUUM  =                    T / Wavelengths are in vacuum
# NWORDER =                    2 / Number of linear-log10 coefficients
# WFITTYPE= 'LOG-LINEAR'         / Linear-log10 dispersion
# COEFF0  =               3.5682 / Central wavelength (log10) of first pixel
# COEFF1  =               0.0001 / Log10 dispersion per pixel
# WAT0_001= 'system=linear'      /
# WAT1_001= 'wtype=linear label=Wavelength units=Angstroms' /
# CRVAL1  =               3.5682 / Central wavelength (log10) of first pixel
# CD1_1   =               0.0001 / Log10 dispersion per pixel
# CRPIX1  =                    1 / Starting pixel (1-indexed)
# CTYPE1  = 'LINEAR  '           /
# DC-FLAG =                    1 / Log-linear flag
# COMMENT --------SPECTRA ANALYSIS RESULTS
# VERSPIPE= 'v2.9.8  '           / Version of Pipeline
# CLASS   = 'QSO     '           / Class of object
# SUBCLASS= 'Non     '           / Subclass of object
# Z       =                -9999 / Redshift of object
# Z_ERR   =                -9999 / Redshift error of object
# ZFLAG   = 'PIPELINE AND EYECHECK' / Which method computes the redshift
# SNRU    =                 0.37 / SNR of u filter
# SNRG    =                 0.96 / SNR of g filter
# SNRR    =                 1.32 / SNR of r filter
# SNRI    =                 1.37 / SNR of i filter
# SNRZ    =                 3.14 / SNR of z filter

# %% [markdown]
# ## dr10matchsdss16 deltaz<0.1

# %%
Fits_DR10_dir='/Users/lyubing/Downloads/LAMOST/LAMOST_DR10/'
LAMOST_dr10_qsobySDSS_dir=os.path.join(Fits_DR10_dir,'LAMOST_dr10_qsobySDSS/')

# %%
dr10matchsdss16files_fits_path=[]
dr10matchsdss16files_fits=os.listdir('/Users/lyubing/Downloads/LAMOST/LAMOST_DR10/LAMOST_dr10_qsobySDSS/')
for i in dr10matchsdss16files_fits:
    if i.endswith('fits.gz'):
        dr10matchsdss16files_fits_path.append(i)

# %%
LAMOSTDR10_SDSS16=pd.read_csv('/Users/lyubing/Downloads/LAMOST_青年研究员/LAMOST_DR10_SDSS16_brettlv_0.csv') #zwarning=0
LAMOSTDR10_SDSS16_QSO=LAMOSTDR10_SDSS16[LAMOSTDR10_SDSS16['class']=='QSO']
LAMOSTDR10_SDSS16_QSO=drop_index(LAMOSTDR10_SDSS16_QSO)

# %%
import os
lamostdr10_12_matchSDSS_ztfdata='/Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12_matchSDSS'
if not os.path.exists(lamostdr10_12_matchSDSS_ztfdata):
    os.mkdir(lamostdr10_12_matchSDSS_ztfdata)

# %%
pwd
# Out:
# '/Users/lyubing/blog/brettlv.github.io_origin/pythoncode/changinglookAGN'

# %%
lamostdr10_12_matchSDSS_ztfdata
# Out:
# '/Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12_matchSDSS'

# %%
# !open /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12_matchSDSS

# %%
ls /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/*.csv | wc -l
# Out:
#     4280

# %%
ls /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12/*.csv | wc -l
# Out:
#     4280

# %%
ls /Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12_matchSDSS/*.csv | wc -l
# Out:
#     1172

# %%
LAMOST_dr10_qsobySDSS_dir
# Out:
# '/Users/lyubing/Downloads/LAMOST/LAMOST_DR10/LAMOST_dr10_qsobySDSS/'

# %%
lamostdr10_12_matchSDSS_ztfdata
# Out:
# '/Volumes/ExtremeSSD/data_source/ZTFdata/LAMOSTdr10_12_matchSDSS'

# %% [markdown]
# Delta_z_lt0dot1_obs=[]
# Z_lamost=[]
# Z_SDSS=[]
#
# for i in dr10matchsdss16files_fits_path:
#     files_fits_path_i=os.path.join(LAMOST_dr10_qsobySDSS_dir,i)
#     if os.path.exists(files_fits_path_i):
#         hdul_i=fits.open(files_fits_path_i)
#         obsid_i= hdul_i[0].header['OBSID']
#
#         ra=hdul_i[0].header['RA']
#         dec=hdul_i[0].header['DEC']
#
#         if  len(LAMOSTDR10_SDSS16_QSO[LAMOSTDR10_SDSS16_QSO['OBSID']==obsid_i])>0:
#             LAMOSTDR10_SDSS16_QSO_i= LAMOSTDR10_SDSS16_QSO[LAMOSTDR10_SDSS16_QSO['OBSID']==obsid_i]
#             if abs(hdul_i[0].header['Z']-LAMOSTDR10_SDSS16_QSO_i['z2'].values[0])<0.1:
#                 Delta_z_lt0dot1_obs.append(files_fits_path_i)
#                 Z_lamost.append(hdul_i[0].header['Z'])
#                 Z_SDSS.append(LAMOSTDR10_SDSS16_QSO_i['z2'].values[0])
#
#                 #print('*****,',obsid_i)
#                 #print(hdul_i[0].header['Z'],hdul_i[0].header['Z_ERR'],LAMOSTDR10_SDSS16_QSO_i['z2'].values[0],hdul_i[0].header['Z']-LAMOSTDR10_SDSS16_QSO_i['z2'].values[0])
#                 #print(LAMOSTDR10_SDSS16_QSO_i)
#                 #print('************************')
#                 save_name= 'id%dra%.5f_dec%.5f'%(obsid_i,ra,dec)
#
#                 #for band in ztf_bands:
#                 if not os.path.exists('%s/%s.csv'%(lamostdr10_12_matchSDSS_ztfdata,save_name)):
#                     data_g = lightcurve.LCQuery.download_data(circle=[ra,
#                                                                       dec,2.0/3600],
#                                                                        #bandname=band,
#                                                                        BAD_CATFLAGS_MASK=32768)
#                     if len(data_g)>5:
#                         data_g.to_csv('%s/%s.csv'%(lamostdr10_12_matchSDSS_ztfdata,save_name),index=False)
#                         time.sleep(1+np.random.randint(3,10))
#                 else:
#                     time.sleep(2)
