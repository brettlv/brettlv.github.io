# %%
from lxml.html import parse
from urllib.request import urlopen
from pandas.io.parsers import TextParser
from pandas import Series
import urllib,requests
import pandas as pd
from bs4 import BeautifulSoup


url_nba='https://stats.nba.com/teams/advanced/?sort=W&dir=-1'
url_nba='https://www.basketball-reference.com/leagues/NBA_2019_ratings.html'
url_laker='https://www.basketball-reference.com/teams/LAL/2019.html'

def _unpack(row,kind='td'):
    elts=row.findall('.//%s' %kind)
    return [val.text_content() for val in elts]

def parse_options_data(table):
    rows=table.findall('.//tr')
    header=_unpack(rows[0],kind='th')
    data=[_unpack(r) for r in rows[1:]]
    #return data
    return TextParser(data,names=header).get_chunk()

parsedurl=parse(urlopen(url_laker))
url=parsedurl.getroot()
tables=url.findall('.//table')

url_link_pos_all=url.findall('.//a')
links=url.findall('.//a')
urls=[lnk.get('href') for lnk in url_link_pos_all]


urls_player=[]
for url in urls[243:280]:
    if (url[:8]=='/players'):
        urls_player.append(url)
len(urls_player)
print(urls_player) 

#print(urls_player)
# Out:
# ['/players/z/zubaciv01.html', '/players/i/ingrabr01.html', '/players/b/balllo01.html', '/players/k/kuzmaky01.html', '/players/h/hartjo01.html', '/players/w/wagnemo01.html', '/players/b/bongais01.html', '/players/c/caldwke01.html', '/players/r/rondora01.html', '/players/j/jamesle01.html', '/players/s/stephla01.html', '/players/m/mykhasv01.html', '/players/m/mcgeeja01.html', '/players/c/carusal01.html', '/players/b/beaslmi01.html', '/players/w/willijo04.html', '/players/c/chandty01.html']

# %%
len(tables)
# Out:
# 1

# %%
end=tables[0]
rows=end.findall('.//tr')
header=_unpack(rows[0],kind='th')
print(header)
data=[_unpack(r) for r in rows[:]]
data=TextParser(data,names=header[1:]).get_chunk()
data.to_csv('/Users/brettlv/blog/brettlv.github.io/pythoncode/laker.csv')
# Out:
# ['No.', 'Player', 'Pos', 'Ht', 'Wt', 'Birth Date', '\xa0', 'Exp', 'College']

# %%
listfirst=_unpack(rows[1],kind='td')
listfirst
# Out:
# ['Ivica Zubac', 'C', '7-1', '265', 'March 18, 1997', 'ba', '2', '']

# %%
len(rows)
# Out:
# 18

# %%
data
# Out:
#                       Player Pos    Ht   Wt         Birth Date     Exp  \
# 0                Ivica Zubac   C   7-1  265     March 18, 1997  ba   2
# 1             Brandon Ingram  SG   6-9  190  September 2, 1997  us   2
# 2                 Lonzo Ball  PG   6-6  190   October 27, 1997  us   1
# 3                 Kyle Kuzma  SF   6-9  220      July 24, 1995  us   1
# 4                  Josh Hart  SG   6-5  209      March 6, 1995  us   1
# 5              Moritz Wagner   C  6-11  245     April 26, 1997  de   R
# 6                Isaac Bonga   G   6-8  179   November 8, 1999  de   R
# 7   Kentavious Caldwell-Pope  SG   6-5  205  February 18, 1993  us   5
# 8                Rajon Rondo  PG   6-1  186  February 22, 1986  us  12
# 9               LeBron James  PF   6-8  250  December 30, 1984  us  15
# 10          Lance Stephenson  SG   6-5  230  September 5, 1990  us   8
# 11            Svi Mykhailiuk  SF   6-8  205      June 10, 1997  ua   R
# 12              JaVale McGee   C   7-0  270   January 19, 1988  us  10
# 13         Alex Caruso  (TW)   G   6-5  186  February 28, 1994  us   1
# 14           Michael Beasley  PF   6-9  235    January 9, 1989  us  10
# 15  Johnathan Williams  (TW)   C   6-9  228       May 22, 1995  us   R
# 16            Tyson Chandler   C   7-1  240    October 2, 1982  us  17
#
#                                        College
# 0                                          NaN
# 1                              Duke University
# 2        University of California, Los Angeles
# 3                           University of Utah
# 4                         Villanova University
# 5                       University of Michigan
# 6                                          NaN
# 7                        University of Georgia
# 8                       University of Kentucky
# 9                                          NaN
# 10                    University of Cincinnati
# 11                        University of Kansas
# 12                  University of Nevada, Reno
# 13                        Texas A&M University
# 14                     Kansas State University
# 15  University of Missouri, Gonzaga University
# 16                                         NaN

# %%
pwd
# Out:
# '/Users/brettlv/blog/brettlv.github.io/pythoncode'

# %%
import os
os.chdir('/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer')
#os.chdir('/Users/brettlv/blog/brettlv.github.io/pythoncode/laker.csv')

# %%
import re
import urllib,urllib.request;
from bs4 import BeautifulSoup
import requests,os

#通过url获取网页
def getHtml(url,name):
    # 要设置请求头，让服务器知道不是机器人
    user_agent = 'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)'
    headers = {'User-Agent': user_agent}
    html=requests.get(url).text
    soup=BeautifulSoup(html,'html.parser')
    pic_url = soup.find_all('img',src=re.compile(r'^https://.*?jpg$'))
    print(pic_url)
    for url in pic_url:
        img=url['src']
        pic=requests.get(img,timeout=1)
        file_name=name+'.jpg'
        with open(file_name,'wb') as fp:
            fp.write(pic.content)

# %% [markdown]
# for i,(playerurl,playername) in enumerate(zip(urls_player,data['Player'].values)):
#     getHtml('https://www.basketball-reference.com'+playerurl,playername)

# %%
data
# Out:
#                       Player Pos    Ht   Wt         Birth Date     Exp  \
# 0                Ivica Zubac   C   7-1  265     March 18, 1997  ba   2
# 1             Brandon Ingram  SG   6-9  190  September 2, 1997  us   2
# 2                 Lonzo Ball  PG   6-6  190   October 27, 1997  us   1
# 3                 Kyle Kuzma  SF   6-9  220      July 24, 1995  us   1
# 4                  Josh Hart  SG   6-5  209      March 6, 1995  us   1
# 5              Moritz Wagner   C  6-11  245     April 26, 1997  de   R
# 6                Isaac Bonga   G   6-8  179   November 8, 1999  de   R
# 7   Kentavious Caldwell-Pope  SG   6-5  205  February 18, 1993  us   5
# 8                Rajon Rondo  PG   6-1  186  February 22, 1986  us  12
# 9               LeBron James  PF   6-8  250  December 30, 1984  us  15
# 10          Lance Stephenson  SG   6-5  230  September 5, 1990  us   8
# 11            Svi Mykhailiuk  SF   6-8  205      June 10, 1997  ua   R
# 12              JaVale McGee   C   7-0  270   January 19, 1988  us  10
# 13         Alex Caruso  (TW)   G   6-5  186  February 28, 1994  us   1
# 14           Michael Beasley  PF   6-9  235    January 9, 1989  us  10
# 15  Johnathan Williams  (TW)   C   6-9  228       May 22, 1995  us   R
# 16            Tyson Chandler   C   7-1  240    October 2, 1982  us  17
#
#                                        College
# 0                                          NaN
# 1                              Duke University
# 2        University of California, Los Angeles
# 3                           University of Utah
# 4                         Villanova University
# 5                       University of Michigan
# 6                                          NaN
# 7                        University of Georgia
# 8                       University of Kentucky
# 9                                          NaN
# 10                    University of Cincinnati
# 11                        University of Kansas
# 12                  University of Nevada, Reno
# 13                        Texas A&M University
# 14                     Kansas State University
# 15  University of Missouri, Gonzaga University
# 16                                         NaN

# %%
data1=pd.read_html(url_laker)
data1
# Out:
# [     No.                    Player Pos    Ht   Wt         Birth Date     Exp  \
#  0   40.0               Ivica Zubac   C   7-1  265     March 18, 1997  ba   2
#  1   14.0            Brandon Ingram  SG   6-9  190  September 2, 1997  us   2
#  2    2.0                Lonzo Ball  PG   6-6  190   October 27, 1997  us   1
#  3    0.0                Kyle Kuzma  SF   6-9  220      July 24, 1995  us   1
#  4    3.0                 Josh Hart  SG   6-5  209      March 6, 1995  us   1
#  5   15.0             Moritz Wagner   C  6-11  245     April 26, 1997  de   R
#  6    NaN               Isaac Bonga   G   6-8  179   November 8, 1999  de   R
#  7    1.0  Kentavious Caldwell-Pope  SG   6-5  205  February 18, 1993  us   5
#  8    9.0               Rajon Rondo  PG   6-1  186  February 22, 1986  us  12
#  9   23.0              LeBron James  PF   6-8  250  December 30, 1984  us  15
#  10   6.0          Lance Stephenson  SG   6-5  230  September 5, 1990  us   8
#  11  10.0            Svi Mykhailiuk  SF   6-8  205      June 10, 1997  ua   R
#  12   7.0              JaVale McGee   C   7-0  270   January 19, 1988  us  10
#  13   NaN          Alex Caruso (TW)   G   6-5  186  February 28, 1994  us   1
#  14  11.0           Michael Beasley  PF   6-9  235    January 9, 1989  us  10
#  15  19.0   Johnathan Williams (TW)   C   6-9  228       May 22, 1995  us   R
#  16   5.0            Tyson Chandler   C   7-1  240    October 2, 1982  us  17
#
#                                         College
#  0                                          NaN
#  1                              Duke University
#  2        University of California, Los Angeles
#  3                           University of Utah
#  4                         Villanova University
#  5                       University of Michigan
#  6                                          NaN
#  7                        University of Georgia
#  8                       University of Kentucky
#  9                                          NaN
#  10                    University of Cincinnati
#  11                        University of Kansas
#  12                  University of Nevada, Reno
#  13                        Texas A&M University
#  14                     Kansas State University
#  15  University of Missouri, Gonzaga University
#  16                                         NaN  ]

# %%
data1=pd.read_html('https://www.basketball-reference.com/teams/LAL/2019.html#all_advanced')
data1
# Out:
# [     No.                    Player Pos    Ht   Wt         Birth Date     Exp  \
#  0   40.0               Ivica Zubac   C   7-1  265     March 18, 1997  ba   2
#  1   14.0            Brandon Ingram  SG   6-9  190  September 2, 1997  us   2
#  2    2.0                Lonzo Ball  PG   6-6  190   October 27, 1997  us   1
#  3    0.0                Kyle Kuzma  SF   6-9  220      July 24, 1995  us   1
#  4    3.0                 Josh Hart  SG   6-5  209      March 6, 1995  us   1
#  5   15.0             Moritz Wagner   C  6-11  245     April 26, 1997  de   R
#  6    NaN               Isaac Bonga   G   6-8  179   November 8, 1999  de   R
#  7    1.0  Kentavious Caldwell-Pope  SG   6-5  205  February 18, 1993  us   5
#  8    9.0               Rajon Rondo  PG   6-1  186  February 22, 1986  us  12
#  9   23.0              LeBron James  PF   6-8  250  December 30, 1984  us  15
#  10   6.0          Lance Stephenson  SG   6-5  230  September 5, 1990  us   8
#  11  10.0            Svi Mykhailiuk  SF   6-8  205      June 10, 1997  ua   R
#  12   7.0              JaVale McGee   C   7-0  270   January 19, 1988  us  10
#  13   NaN          Alex Caruso (TW)   G   6-5  186  February 28, 1994  us   1
#  14  11.0           Michael Beasley  PF   6-9  235    January 9, 1989  us  10
#  15  19.0   Johnathan Williams (TW)   C   6-9  228       May 22, 1995  us   R
#  16   5.0            Tyson Chandler   C   7-1  240    October 2, 1982  us  17
#
#                                         College
#  0                                          NaN
#  1                              Duke University
#  2        University of California, Los Angeles
#  3                           University of Utah
#  4                         Villanova University
#  5                       University of Michigan
#  6                                          NaN
#  7                        University of Georgia
#  8                       University of Kentucky
#  9                                          NaN
#  10                    University of Cincinnati
#  11                        University of Kansas
#  12                  University of Nevada, Reno
#  13                        Texas A&M University
#  14                     Kansas State University
#  15  University of Missouri, Gonzaga University
#  16                                         NaN  ]

# %%
lakersadv=pd.read_csv('/Users/brettlv/lakers')

# %%
lakersadv
# Out:
#     Rk                              player  Age   G   MP   PER    TS%   3PAr  \
# 0    1              LeBron James\jamesle01   34  22  766  26.9  0.609  0.298
# 1    2                Kyle Kuzma\kuzmaky01   23  22  679  13.9  0.547  0.376
# 2    3                 Lonzo Ball\balllo01   21  22  594  11.0  0.492  0.512
# 3    4            Brandon Ingram\ingrabr01   21  18  581  11.3  0.517  0.138
# 4    5                  Josh Hart\hartjo01   23  22  542  12.7  0.595  0.624
# 5    6              JaVale McGee\mcgeeja01   31  22  534  22.2  0.637  0.021
# 6    7  Kentavious Caldwell-Pope\caldwke01   25  22  459  10.3  0.535  0.566
# 7    8          Lance Stephenson\stephla01   28  22  334  14.5  0.522  0.383
# 8    9               Rajon Rondo\rondora01   32  11  278  13.8  0.508  0.239
# 9   10            Tyson Chandler\chandty01   36  12  250  10.4  0.600  0.000
# 10  11            Svi Mykhailiuk\mykhasv01   21  11  101   4.9  0.410  0.593
# 11  12        Johnathan Williams\willijo04   23   6   85  11.3  0.542  0.000
# 12  13               Ivica Zubac\zubaciv01   21   6   47  11.4  0.444  0.000
# 13  14           Michael Beasley\beaslmi01   30   7   46   7.7  0.541  0.100
# 14  15             Moritz Wagner\wagnemo01   21   3    7  -5.9  0.000  1.000
#
#       FTr  ORB%  ...   Unnamed: 17  OWS  DWS   WS  WS/48  Unnamed: 22  OBPM  \
# 0   0.390   3.1  ...           NaN  2.2  1.1  3.3  0.204          NaN   6.2
# 1   0.188   2.0  ...           NaN  0.4  0.6  1.1  0.074          NaN  -0.9
# 2   0.093   4.1  ...           NaN -0.1  0.7  0.7  0.054          NaN  -1.4
# 3   0.339   2.2  ...           NaN -0.3  0.5  0.3  0.021          NaN  -3.7
# 4   0.197   2.0  ...           NaN  0.5  0.7  1.2  0.106          NaN   0.3
# 5   0.216  10.4  ...           NaN  1.0  1.0  2.0  0.179          NaN  -0.2
# 6   0.329   2.1  ...           NaN  0.3  0.4  0.7  0.073          NaN  -1.3
# 7   0.117   4.2  ...           NaN  0.0  0.4  0.5  0.068          NaN  -1.1
# 8   0.091   3.8  ...           NaN  0.1  0.3  0.5  0.079          NaN  -1.2
# 9   0.567  13.2  ...           NaN  0.2  0.3  0.5  0.103          NaN  -2.7
# 10  0.296   2.1  ...           NaN -0.1  0.1 -0.1 -0.024          NaN  -4.2
# 11  0.263  13.8  ...           NaN  0.1  0.1  0.2  0.115          NaN  -1.2
# 12  0.286  22.7  ...           NaN  0.0  0.1  0.1  0.067          NaN  -4.5
# 13  0.250   7.0  ...           NaN -0.1  0.0  0.0 -0.050          NaN  -6.5
# 14  0.000   0.0  ...           NaN  0.0  0.0  0.0 -0.293          NaN  -9.9
#
#     DBPM   BPM  VORP
# 0    1.3   7.5   1.8
# 1   -1.4  -2.3  -0.1
# 2    1.2  -0.1   0.3
# 3   -0.7  -4.3  -0.3
# 4    0.8   1.1   0.4
# 5    4.5   4.3   0.9
# 6   -1.4  -2.7  -0.1
# 7   -0.3  -1.4   0.1
# 8    0.0  -1.3   0.1
# 9    1.2  -1.4   0.0
# 10  -2.6  -6.8  -0.1
# 11   0.2  -1.0   0.0
# 12   0.1  -4.4   0.0
# 13  -2.4  -9.0  -0.1
# 14  -4.1 -14.0   0.0
#
# [15 rows x 27 columns]

# %%
pwd
# Out:
# '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer'

# %%
mkdir /Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/TWplay

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt


from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,AnnotationBbox)
from matplotlib.cbook import get_sample_data
import os
import skimage.io as io
from skimage import data_dir

# %%
print(coll)
# Out:
# ['/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Alex Caruso\xa0\xa0(TW).jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Brandon Ingram.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Isaac Bonga.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Ivica Zubac.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/JaVale McGee.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Johnathan Williams\xa0\xa0(TW).jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Josh Hart.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Kentavious Caldwell-Pope.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Kyle Kuzma.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Lance Stephenson.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/LeBron James.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Lonzo Ball.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Michael Beasley.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Moritz Wagner.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Rajon Rondo.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Svi Mykhailiuk.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Tyson Chandler.jpg']

# %%
x,y
# Out:
# (array([-3.7, -4.5, -0.2, -1.2,  0.3, -1.3, -0.9, -1.1,  6.2, -1.4, -6.5,
#         -9.9, -1.2, -4.2, -2.7]),
#  array([-0.7,  0.1,  4.5,  0.2,  0.8, -1.4, -1.4, -0.3,  1.3,  1.2, -2.4,
#         -4.1,  0. , -2.6,  1.2]))

# %%
file_dir='/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/'
#imgslist=os.listdir(file_dir)
os.chdir(file_dir)
coll=io.ImageCollection(file_dir+'/*.jpg')
#print(coll)
#plt.figure(figsize=(16,16))
fig, ax = plt.subplots(figsize=(16,16))
#x=np.random.randint(50,120,30)
#x=np.linspace(50,200,30)
#y=np.random.randint(80,150,30)
#y=np.linspace(50,200,30)

x=lakersadv.sort_values('player')['OBPM'].values
y=lakersadv.sort_values('player')['DBPM'].values
print(min(x),max(x),min(y),max(y))
print(np.average(x),np.average(y))

for i,(logo_,x_,y_) in enumerate(zip(coll,x,y)):
    imagebox = OffsetImage(logo_, zoom=0.2)
    imagebox.image.axes = ax
    ab = AnnotationBbox(imagebox,xy = [x_,y_],xycoords='data',pad=0.0,)
    ax.add_artist(ab)
    
#img=Image.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/logonba/los-angeles-lakers-logo-vector-200x200.png')
#arr_img=plt.imread('/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/logonba/los-angeles-lakers-logo-vector-200x200.png',format='png')
#imagebox = OffsetImage(img, zoom=0.2)
#imagebox = OffsetImage(arr_img, zoom=0.3)
#imagebox.image.axes = ax
#ab = AnnotationBbox(imagebox,xy = [100,120],xycoords='data',pad=0.0,)
#ax.add_artist(ab)

#ax.plot(x,y,'o')
#ax.plot(np.linspace(100,120,10),np.linspace(100,120,10))
plt.vlines(0,-4.1,4.5)
plt.hlines(0,-9.9,6.2)
plt.xlabel('OBPM')
plt.ylabel('DBPM')
#plt.xlim(-9.9,6.2)
#plt.ylim(-4.1,4.5)
plt.title("OBPM_VS_DBPM_Lakers")
plt.grid()
#plt.savefig('/Users/brettlv/nba_12_01.png',dpi=300)
plt.show()
# Out:
# -9.9 6.2 -4.1 4.5
# -2.15333333333 -0.24

# %%
-9.9 6.2 -4.1 4.5
-2.15333333333 -0.24

# %%
print(coll)
# Out:
# ['/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Brandon Ingram.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Isaac Bonga.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Ivica Zubac.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/JaVale McGee.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Josh Hart.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Kentavious Caldwell-Pope.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Kyle Kuzma.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Lance Stephenson.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/LeBron James.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Lonzo Ball.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Michael Beasley.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Moritz Wagner.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Rajon Rondo.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Svi Mykhailiuk.jpg', '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer/Tyson Chandler.jpg']

# %%
lakersadv.sort_values('player')
# Out:
#     Rk                              player  Age   G   MP   PER    TS%   3PAr  \
# 3    4            Brandon Ingram\ingrabr01   21  18  581  11.3  0.517  0.138
# 12  13               Ivica Zubac\zubaciv01   21   6   47  11.4  0.444  0.000
# 5    6              JaVale McGee\mcgeeja01   31  22  534  22.2  0.637  0.021
# 11  12        Johnathan Williams\willijo04   23   6   85  11.3  0.542  0.000
# 4    5                  Josh Hart\hartjo01   23  22  542  12.7  0.595  0.624
# 6    7  Kentavious Caldwell-Pope\caldwke01   25  22  459  10.3  0.535  0.566
# 1    2                Kyle Kuzma\kuzmaky01   23  22  679  13.9  0.547  0.376
# 7    8          Lance Stephenson\stephla01   28  22  334  14.5  0.522  0.383
# 0    1              LeBron James\jamesle01   34  22  766  26.9  0.609  0.298
# 2    3                 Lonzo Ball\balllo01   21  22  594  11.0  0.492  0.512
# 13  14           Michael Beasley\beaslmi01   30   7   46   7.7  0.541  0.100
# 14  15             Moritz Wagner\wagnemo01   21   3    7  -5.9  0.000  1.000
# 8    9               Rajon Rondo\rondora01   32  11  278  13.8  0.508  0.239
# 10  11            Svi Mykhailiuk\mykhasv01   21  11  101   4.9  0.410  0.593
# 9   10            Tyson Chandler\chandty01   36  12  250  10.4  0.600  0.000
#
#       FTr  ORB%  ...   Unnamed: 17  OWS  DWS   WS  WS/48  Unnamed: 22  OBPM  \
# 3   0.339   2.2  ...           NaN -0.3  0.5  0.3  0.021          NaN  -3.7
# 12  0.286  22.7  ...           NaN  0.0  0.1  0.1  0.067          NaN  -4.5
# 5   0.216  10.4  ...           NaN  1.0  1.0  2.0  0.179          NaN  -0.2
# 11  0.263  13.8  ...           NaN  0.1  0.1  0.2  0.115          NaN  -1.2
# 4   0.197   2.0  ...           NaN  0.5  0.7  1.2  0.106          NaN   0.3
# 6   0.329   2.1  ...           NaN  0.3  0.4  0.7  0.073          NaN  -1.3
# 1   0.188   2.0  ...           NaN  0.4  0.6  1.1  0.074          NaN  -0.9
# 7   0.117   4.2  ...           NaN  0.0  0.4  0.5  0.068          NaN  -1.1
# 0   0.390   3.1  ...           NaN  2.2  1.1  3.3  0.204          NaN   6.2
# 2   0.093   4.1  ...           NaN -0.1  0.7  0.7  0.054          NaN  -1.4
# 13  0.250   7.0  ...           NaN -0.1  0.0  0.0 -0.050          NaN  -6.5
# 14  0.000   0.0  ...           NaN  0.0  0.0  0.0 -0.293          NaN  -9.9
# 8   0.091   3.8  ...           NaN  0.1  0.3  0.5  0.079          NaN  -1.2
# 10  0.296   2.1  ...           NaN -0.1  0.1 -0.1 -0.024          NaN  -4.2
# 9   0.567  13.2  ...           NaN  0.2  0.3  0.5  0.103          NaN  -2.7
#
#     DBPM   BPM  VORP
# 3   -0.7  -4.3  -0.3
# 12   0.1  -4.4   0.0
# 5    4.5   4.3   0.9
# 11   0.2  -1.0   0.0
# 4    0.8   1.1   0.4
# 6   -1.4  -2.7  -0.1
# 1   -1.4  -2.3  -0.1
# 7   -0.3  -1.4   0.1
# 0    1.3   7.5   1.8
# 2    1.2  -0.1   0.3
# 13  -2.4  -9.0  -0.1
# 14  -4.1 -14.0   0.0
# 8    0.0  -1.3   0.1
# 10  -2.6  -6.8  -0.1
# 9    1.2  -1.4   0.0
#
# [15 rows x 27 columns]

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
html=urlopen('https://www.basketball-reference.com/teams/LAL/2019.html#all_advanced')
soup = BeautifulSoup(html)
#soup.findAll('tr', limit=2)
# Out:
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/brettlv/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
