# %%
1,l,o,O,0,z,Z,2,I,i,l1l1l1好的。。。....

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')

from scipy import integrate
import astropy
from astropy.time import Time

import pyfits
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.stats import LombScargle
import matplotlib.ticker as ticker

import numpy as np
from numpy import cov,corrcoef
import matplotlib.pyplot as plt
import astropy.units as u
from scipy.optimize import curve_fit
import scipy
import scipy.stats as stats
import pandas as pd
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
1,l,z,i,I,2,0,o,O,L,

# %%
import math
from scipy.optimize import bisect
from scipy.optimize import brentq
from scipy.optimize import brenth
import numpy as np

M0=0.8#solar mass
R0=6500000#m

q=0.5
M1=0.55#solar mass

R1=R0*(M1/M0)**(-1/3)

M2=M1*q
R2=R1*(M2/M1)**(-1/3)
chirpmass=(M1*M2)**0.6/(M1+M2)**0.2#solar mass
mu_mass=M1*q/(1+q)#solar mass reduced mass
mu_mass1=M1*M2/(M1+M2)
print("mu_mass",mu_mass,mu_mass1)


G=6.67*10**-11
k=1.38*10**-23#J/K
h=6.626*10**-34#J*s

P=321.5#s obs orbit period
nu=1/P#s-1 obs orbit frequency
Pdot=3.72*10**-11
mudot=3.67*10**-16#obs mudot
msun=2*10**30#kg
r_sun=6.963*10**8#m
l_sun=3.828*10**33#erg/s
c=3*10**8#m

a_orbit=(G*(M1+M2)*msun/(4*np.pi**2*nu**2))**(1/3)#Kepler's third law
mudot_orbit=(2*np.pi)**(8/3)*96*0.2*(G*chirpmass*msun/c**3)**(5/3)*nu**(11/3)#Eq3.189
mudot_bygw=1.64*10**(-17)*(nu*1000)**5*mu_mass*(a_orbit*10**-8)**2 # Strohmayer2003 from Taylor&Weusberg1989

mass_rate=2*np.pi*mudot/5*(M1*msun*R1**3/G)**0.5 #kgs-1 Strohmayer2005
mass_rate_s=mass_rate/msun*365*86400
print("nu,P,mudot",nu,P,mudot)
print("M1,R1,R1/r_sun:",M1,R1,R1/r_sun)
print("M2,R2,R2/r_sun:",M2,R2,R2/r_sun)
print()



print("a_orbit,q:",a_orbit,q)
print("R2/a,a/r_sun,R2/r_sun:",R2/a_orbit,a_orbit/r_sun,R2/r_sun)

print("mudot_orbit",mudot_orbit)
print("mudot_bygw",mudot_bygw)
print("mudot_obs_orbit",mudot)
print("mass_rate:",mass_rate_s,"Msun/yr")


print()
T1=27000#K 
#T1=32400#K
Tirr=T1*(R1/a_orbit)**0.5
#T1=10**6*0.5
#Tirr=(0.12*2*R1**2/R2**2*T1**4)**0.25
print(T1,Tirr,"K")
print(Tirr/T1)

sigma=5.6704*10**-5# Stefan-Boltzmann constant erg cm-2s-1K-4
Lbol=4*np.pi*(a_orbit*100)**2*sigma*Tirr**4#erg/s
Lbol1=4*np.pi*(R1*100)**2*sigma*T1**4#erg/s
L_acc=G*M1*msun*mass_rate/R1*10**7#erg/s
print("L_acc",L_acc)
print("Lbol",Lbol,Lbol1)
L_gw=32/5*G**4/a_orbit**5/c**5*(M1**2*M2**2*(M1+M2)*msun**5)*10**7# erg/s # Strohmayer2005
print("L_gw",L_gw)

print()
mudotdot_orbit=4.95*10**(-30)*(nu*1000)**(19/3)*(chirpmass/0.871)**(10/3)#For GW emission alone
print("mudotdot_orbit",mudotdot_orbit)
mudotdot_puregw=11/3*mudot**2/nu
print("mudotdot_puregw",mudotdot_puregw)
# Out:
# mu_mass 0.18333333333333335 0.18333333333333335
# nu,P,mudot 0.003110419906687403 321.5 3.67e-16
# M1,R1,R1/r_sun: 0.55 7364712.354255161 0.010576924248535347
# M2,R2,R2/r_sun: 0.275 9278956.121546905 0.013326089503873194
#
# a_orbit,q: 66049672.00676796 0.5
# R2/a,a/r_sun,R2/r_sun: 0.1404845147542309 0.09485806693489582 0.013326089503873194
# mudot_orbit 3.825147066170582e-16
# mudot_bygw 3.8187543926107634e-16
# mudot_obs_orbit 3.67e-16
# mass_rate: 1.8664641337664913e-08 Msun/yr
#
# 27000 9015.842702791371 K
# 0.33392010010338413
# L_acc 1.1792496812837983e+35
# Lbol 2.0539515493539633e+32 2.0539515493539644e+32
# L_gw 2.5044848159238846e+35
#
# mudotdot_orbit 2.6966212996942207e-28
# mudotdot_puregw 1.5877588283333333e-28

# %%
flux=1.29*10**-12#ergcm-2s-1
d=(Lbol/flux/4/np.pi)**0.5 #cm
d_pc=d/3.08567756/10**18
print(d,Lbol,flux,d_pc)
# Out:
# 3.5595517418278423e+21 2.0539515493539633e+32 1.29e-12 1153.5721644966177

# %%
fig=plt.figure(figsize=(8,6))
wavelength=[3500,4800,6250,7650,2600,1928]
fraction=[11.9,12.7,13.5,14.8,13,7.4]
        
k=1.38*10**-23#J/K
h=6.626*10**-34#J*s
c=3*10**8#m
#Tirr=27000#K

def Blamda(lamdawave,Tirr):
    blamda=2*h*c**2*lamdawave**(-5)*(np.e**(h*c/lamdawave/k/Tirr)-1)**-1
    return blamda #W*sr**-1*m**-3~0.1*erg/s*sr**-1*cm**-3

# %%
11605*65 #K
1/0.026*300*65
# Out:
# 749999.9999999999

# %%
import numpy as np
from scipy import integrate
uv1=2600*10**-10
uv2=1928*10**-10

T1=27000#K

a1=Blamda(uv1,T1)/(1.9*10**-16)
a2=Blamda(uv2,T1)/(4.3*10**-16)
a0=(a1+a2)/2
print(a1,a2,a0,Blamda(uv1,T1),Blamda(uv2,T1))

waveA=np.linspace(100,25000,1000)
lamdawave=waveA*10**-10
fluxlamda=Blamda(lamdawave,T1)/a0
fluxlamda32400=Blamda(lamdawave,32400)/a0
fluxlamda750000=Blamda(lamdawave,750000)/a0
plt.plot(waveA,fluxlamda,label="T1:%d"%T1)
plt.plot(waveA,fluxlamda32400,label='T1=32400')
plt.plot(waveA,fluxlamda750000,label='T1=750000')

#plt.scatter(wavelengthbb*10**10,fluxbb)
plt.semilogy(True)
plt.semilogx(True)
plt.ylim(10**-18,10**-10)
plt.xlim(10**2,10**5)
plt.xlabel("$\lambda(\AA)$")
plt.ylabel("fluxdensity")
plt.grid(True,linestyle="-.",alpha=0.5)
plt.legend()
fluxtot=integrate.simps(fluxlamda,waveA)#total bolometric luminosity
print(a0,"total bolometric luminosity:",fluxtot)
d=((sigma*T1**4*4*np.pi*(R1*100)**2)/(4*np.pi*fluxtot))**0.5#cm
pc=3.08567756*10**18#cm
d_pc=d/pc

print(T1,Tirr,R1/r_sun,R2/r_sun)
print("distance:",d_pc,"pc")
# Out:
# 7.789363030908088e+31 6.981973957549965e+31 7.385668494229026e+31 1.4799789758725366e+16 3.002248801746485e+16
# 7.385668494229026e+31 total bolometric luminosity: 1.2939669359e-12
# 27000 27000 0.010576924248535347 0.013326089503873194
# distance: 1151.80254451 pc
