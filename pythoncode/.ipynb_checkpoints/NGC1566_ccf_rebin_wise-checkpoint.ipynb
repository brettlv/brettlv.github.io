# %%
from pylab import *
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


from matplotlib.ticker import NullFormatter  # useful for `logit` scale
from astropy.time import Time

from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

# %%
import os 
os.chdir('/Users/brettlv/timing_analysis/python_ccf_code/Release/PurePython/')

# %% [markdown]
# import os
# os.chdir('/Users/brettlv/timing_analysis/python_ccf_code/Release/CPython/')

# %%
ls

# %%
dcf_lists=[]
with open ('/Users/brettlv/Downloads/NGC1566/dcf_ngc1566.txt','r') as f:
    dcf_list=f.readlines()
    for line in dcf_list:
        dcf_lists.append(line.rstrip('\n'))

# %%
dcf_lists
# Out:
# ['/Users/brettlv/Downloads/NGC1566/dcf_ASAS_V_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_e12_xrt_fit_NGC1566.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w1mpro_allwise_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w1mpro_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w2mpro_allwise_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w2mpro_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w3mpro_allwise_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w4mpro_allwise_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_uvot-ubb.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_uvot-um2.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_uvot-uuu.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_uvot-uvv.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_uvot-uw1.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_uvot-uw2.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_wise_multi_w1mpro_ep_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_wise_multi_w2mpro_ep_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_wise_multi_w3mpro_ep_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_wise_multi_w4mpro_ep_data.csv',
#  '/Users/brettlv/Downloads/NGC1566/dcf_xrt_fit_NGC1566.csv']

# %%
fig, axs = plt.subplots(1, 1,figsize=(8,5))
for i in range(8,14):
    plot_dcf(i,dcf_lists)
plot_dcf(0,dcf_lists)    
    
plt.xlim(58000,59000)
# Out:
# (58000, 59000)

# %%
for i,j in enumerate(dcf_lists):
    print(i,j.split('/')[-1][4:-4])
# Out:
# (0, 'ASAS_V_data')
# (1, 'e12_xrt_fit_NGC1566')
# (2, 'neowise_w1mpro_allwise_data')
# (3, 'neowise_w1mpro_data')
# (4, 'neowise_w2mpro_allwise_data')
# (5, 'neowise_w2mpro_data')
# (6, 'neowise_w3mpro_allwise_data')
# (7, 'neowise_w4mpro_allwise_data')
# (8, 'uvot-ubb')
# (9, 'uvot-um2')
# (10, 'uvot-uuu')
# (11, 'uvot-uvv')
# (12, 'uvot-uw1')
# (13, 'uvot-uw2')
# (14, 'wise_multi_w1mpro_ep_data')
# (15, 'wise_multi_w2mpro_ep_data')
# (16, 'wise_multi_w3mpro_ep_data')
# (17, 'wise_multi_w4mpro_ep_data')
# (18, 'xrt_fit_NGC1566')

# %%
def plot_dcf(m,dcf_lists):
    dcf_path=dcf_lists[m]   
    dcf_data=pd.read_csv(dcf_path,header=None)
    plt.errorbar(dcf_data[0], dcf_data[1],dcf_data[2],fmt='.',label=dcf_path.split('/')[-1][4:-4])
    plt.legend(loc=(1.0,0.5))

# %%
fig, axs = plt.subplots(1, 1,figsize=(8,5))
for i in range(12):
    plt.vlines(56750+i*180,-24,-22.2)
plot_dcf(5,dcf_lists)

# %%
def get_new_range_datas(mjd1, flux1, err1,rangemin,rangemax):
    mjd_s=[]
    flux_s=[]
    err_s=[]
    for i,j,k in zip(mjd1, flux1, err1):
        if i>=rangemin and i<rangemax:
            mjd_s.append(i)
            flux_s.append(j)
            err_s.append(k)
    return np.array(mjd_s),np.array(flux_s),np.array(err_s)

# %%
def get_mean_and_err(mjd1, flux1, err1):
    mean_mjd=np.mean(mjd1)
    mean_flux=np.mean(flux1)
    flux_0=flux1-mean_flux
    size=len(mjd1)
    err=np.sqrt(np.sum(flux_0**2)/(size-1))/np.sqrt(size)*2.0
    err2=1.253*np.sum(abs(flux_0))/np.sqrt(size*(size-1))/np.sqrt(size)*2.0    
    return mean_mjd,mean_flux,err,err2

# %%
m=3
dcf_path=dcf_lists[m]
dcf_data=pd.read_csv(dcf_path ,header=None)

fig, axs = plt.subplots(1, 1,figsize=(8,5))
#plot_dcf(m,dcf_lists)

rebin_wise_mjd=[]
rebin_wise_flux=[]
rebin_wise_err=[]

for i in range(12):
    rangemin=56750+i*180-180
    rangemax=56750+i*180   
    mjd1, flux1, err1=get_new_range_datas(dcf_data[0], dcf_data[1],dcf_data[2],rangemin,rangemax)
    mean_mjd,mean_flux,err,err2=get_mean_and_err(mjd1, flux1, err1)
    print(mean_mjd,mean_flux,err,err2,len(mjd1))
    plt.errorbar(mean_mjd,mean_flux,err,fmt='.',marker='*')
    plt.vlines(56750+i*180,-24,-22.2)
    rebin_wise_mjd.append(mean_mjd)
    rebin_wise_flux.append(mean_flux)
    rebin_wise_err.append(err)
# Out:
# (56677.232660736925, -23.0161641025641, 0.007051931855717072, 0.0073885792952931755, 39)
# (56866.670712499705, -23.030600000000003, 0.0051878096518623825, 0.004742170256261645, 34)
# (57039.707184750005, -23.02690909090909, 0.007206080994950211, 0.007693352946550474, 33)
# (57228.48531015594, -23.0315, 0.008947805641968955, 0.007868151316255281, 32)
# (57400.85283333257, -23.02345142857143, 0.008232068351255133, 0.008372657357861885, 35)
# (57593.1111634125, -23.01972727272727, 0.007530348362059302, 0.00798369942589609, 44)
# (57761.73569595083, -23.034591666666667, 0.00753258602644959, 0.00743615310188466, 48)
# (57959.58553316588, -22.977388235294118, 0.007669035198139045, 0.007889126122780964, 34)
# (58123.30776760027, -22.84450810810811, 0.005269952096347856, 0.005344180764548391, 37)
# (58323.7415991457, -22.607862857142855, 0.007886723598786054, 0.005178355678741808, 35)
# (58483.771465625985, -22.9042, 0.0071787991958778405, 0.00728993271272954, 20)
# (58689.54529071087, -22.9891884057971, 0.005369230540207283, 0.005158272533046996, 69)

# %%
dcf_path
# Out:
# '/Users/brettlv/Downloads/NGC1566/dcf_neowise_w1mpro_data.csv'

# %%
rebin_neowise_w2=pd.DataFrame({'t':rebin_wise_mjd,'flux':rebin_wise_flux,'err':rebin_wise_err},index=None,columns=['t','flux','err'])

# %%
rebin_neowise_w2.to_csv('/Users/brettlv/Downloads/NGC1566/rebin_dcf_neowise_w2.csv',index=False,header=False)

# %%
rebin_neowise_w1=pd.DataFrame({'t':rebin_wise_mjd,'flux':rebin_wise_flux,'err':rebin_wise_err},index=None,columns=['t','flux','err'])    
rebin_neowise_w1.to_csv('/Users/brettlv/Downloads/NGC1566/rebin_dcf_neowise_w1.csv',index=False,header=False)

# %%
fig, axs = plt.subplots(1, 1,figsize=(8,5))
plt.errorbar(rebin_neowise_w1['t'],rebin_neowise_w1['flux'],rebin_neowise_w1['err'],fmt='.',marker='*')
plt.errorbar(rebin_neowise_w2['t'],rebin_neowise_w2['flux'],rebin_neowise_w2['err'],fmt='.',marker='*')
# Out:
# <Container object of 3 artists>

# %%
fig, axs = plt.subplots(1, 1,figsize=(8,5))
plot_dcf(0,dcf_lists)
plot_dcf(11,dcf_lists)
plt.xlim(58000,59000)
# Out:
# (58000, 59000)

# %%
''' 0 ASAS_V_data
    1 e12_xrt_fit_NGC1566
    2 neowise_w1mpro_allwise_data
    3 neowise_w1mpro_data
    4 neowise_w2mpro_allwise_data
    5 neowise_w2mpro_data
    6 neowise_w3mpro_allwise_data
    7 neowise_w4mpro_allwise_data
    8 uvot-ubb
    9 uvot-um2
    10 uvot-uuu
    11 uvot-uvv
    12 uvot-uw1
    13 uvot-uw2
    14 wise_multi_w1mpro_ep_data
    15 wise_multi_w2mpro_ep_data
    16 wise_multi_w3mpro_ep_data
    17 wise_multi_w4mpro_ep_data
    18 xrt_fit_NGC1566
    '''

# %%
pwd
# Out:
# u'/Users/brettlv/timing_analysis/python_ccf_code/Release/PurePython'
