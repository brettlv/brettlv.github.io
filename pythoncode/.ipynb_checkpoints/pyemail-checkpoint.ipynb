# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
 
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr
from email.header import Header
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage

#mkkneeuoshthbcjc 
my_sender='610721578@qq.com'    # 发件人邮箱账号
my_pass = 'tlejawmwdjzvbdcg'              # 发件人邮箱密码 授权
my_user='brettlvb@foxmail.com'      # 收件人邮箱账号，我这边发送给自己
def mail():
    try:
        message = MIMEMultipart() 
        mail_msg = """ 
        <p>填写邮件内容,python email test</p><p>
        <a href="http://www.runoob.com">这是一个链接</a></p>"""
        #邮件正文内容
        text=MIMEText(mail_msg,'html','utf-8') 
        message.attach(text)
        
        # 构造附件1，传送当前目录下的 test.txt 文件
        att1 = MIMEText(open('x1.txt', 'rb').read(), 'base64', 'utf-8')
        att1["Content-Type"] = 'application/octet-stream'
        # 这里的filename可以任意写，写什么名字，邮件中显示什么名字
        att1["Content-Disposition"] = 'attachment; filename="x1.txt"'
        message.attach(att1)
 
        # 构造附件2，传送当前目录下的 runoob.txt 文件
        att2 = MIMEText(open('y1.txt', 'rb').read(), 'base64', 'utf-8')
        att2["Content-Type"] = 'application/octet-stream'
        att2["Content-Disposition"] = 'attachment; filename="y1.txt"'
        message.attach(att2)
        
        message['From']=formataddr(["From brettlv",my_sender])  # 括号里的对应发件人邮箱昵称、发件人邮箱账号
        message['To']=formataddr(["FK",my_user])              # 括号里的对应收件人邮箱昵称、收件人邮箱账号
        message['Subject']="菜鸟教程python 发送邮件测试"                # 邮件的主题，也可以说是标题
        server=smtplib.SMTP_SSL("smtp.qq.com", 465)  # 发件人邮箱中的SMTP服务器，端口是25/465?
        #server.set_debugleverl(1)
        #server.ehlo("smtp.qq.com") 
        #server=smtplib.SMTP()
        #server.connect("smtp.qq.com",25)
        server.login(my_sender, my_pass)  # 括号中对应的是发件人邮箱账号、邮箱密码
        server.sendmail(my_sender,my_user,message.as_string())  # 括号中对应的是发件人邮箱账号、收件人邮箱账号、发送邮件
        server.quit()  # 关闭连接
        print("邮件发送成功")
    except smtplib.SMTPException as e:
        print("Error: 无法发送邮件",e)
mail()
# Out:
# 邮件发送成功

# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
 
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr
from email.header import Header
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage

#mkkneeuoshthbcjc 
my_sender='610721578@qq.com'    # 发件人邮箱账号
my_pass = 'tlejawmwdjzvbdcg'              # 发件人邮箱密码 授权
my_user='brettlv@icloud.com'      # 收件人邮箱账号，我这边发送给自己
def mail():
    try:
        message = MIMEMultipart() 
        mail_msg = """ 
        <p>填写邮件内容,python email test</p><p>
        <a href="http://www.runoob.com">这是一个链接</a></p>"""
        #邮件正文内容
        text=MIMEText(mail_msg,'html','utf-8') 
        message.attach(text)
        
        # 构造附件1，传送当前目录下的 test.txt 文件
        att1 = MIMEText(open('distributionofdistance.pdf', 'rb').read(), 'base64', 'utf-8')
        att1["Content-Type"] = 'application/octet-stream'
        # 这里的filename可以任意写，写什么名字，邮件中显示什么名字
        att1["Content-Disposition"] = 'attachment; filename="distributionofdistance.pdf"'
        message.attach(att1)
 

        message['From']=formataddr(["From brettlv",my_sender])  # 括号里的对应发件人邮箱昵称、发件人邮箱账号
        message['To']=formataddr(["FK",my_user])              # 括号里的对应收件人邮箱昵称、收件人邮箱账号
        message['Subject']="菜鸟教程python 发送邮件测试"                # 邮件的主题，也可以说是标题
        server=smtplib.SMTP_SSL("smtp.qq.com", 465)  # 发件人邮箱中的SMTP服务器，端口是25/465?
        #server.set_debugleverl(1)
        #server.ehlo("smtp.qq.com") 
        #server=smtplib.SMTP()
        #server.connect("smtp.qq.com",25)
        server.login(my_sender, my_pass)  # 括号中对应的是发件人邮箱账号、邮箱密码
        server.sendmail(my_sender,my_user,message.as_string())  # 括号中对应的是发件人邮箱账号、收件人邮箱账号、发送邮件
        server.quit()  # 关闭连接
        print("邮件发送成功")
    except smtplib.SMTPException as e:
        print("Error: 无法发送邮件",e)
mail()
# Out:
# 邮件发送成功

# %%
ls *.txt

# %%
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr
from email.header import Header
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
#for simple email
my_sender='610721578@qq.com'    # 发件人邮箱账号
my_pass = 'tlejawmwdjzvbdcg'              # 发件人邮箱密码 授权
my_user='brettlvb@foxmail.com'      # 收件人邮箱账号，我这边发送给自己
msg=MIMEText('Test')
msg['Subject']="HI"
msg['From']=my_sender
msg['To']=my_user
try:
    s = smtplib.SMTP_SSL('smtp.qq.com',465)
    s.login(my_sender,my_pass)
    s.sendmail(my_sender, my_user, msg.as_string())
    s.quit()
    print("邮件发送成功")
except smtplib.SMTPException as e:
    print("Error: 无法发送邮件",e)

# %%
dframe.to_csv('mycontact.csv')
mycontact=pd.read_csv('mycontact.csv')

# %%
nameandemail=mycontact.loc[:,['姓名','电子邮件']]

# %%
nameandemail
# Out:
#                                    姓名                                电子邮件
# 0                              ㄣ傷ぜ惢べ淚                    281310355@qq.com
# 1                                  郑豪                    372997140@qq.com
# 2                              ㄝ似梦Θ非梦                    425640702@qq.com
# 3                                   浪                    447267174@qq.com
# 4                                 王自立                    453697384@qq.com
# 5                                  华仔                    466197307@qq.com
# 6                                  李黎                    497255448@qq.com
# 7                                 何明明                    502159511@qq.com
# 8                            蓜、    ￣。                    569008566@qq.com
# 9                                 王江伟                    641086932@qq.com
# 10                           １、　  　wJ                    672905488@qq.com
# 11                             ǒ①苆瓍プ缘                    710309753@qq.com
# 12                               古筝王子                    714722534@qq.com
# 13                                 李新                    767366345@qq.com
# 14                          /mg陳维偉/mg                    276932080@qq.com
# 15                                 吕军                    303418768@qq.com
# 16                                小露姐                    344093520@qq.com
# 17                            摋掱/kn瀋堒                    358435199@qq.com
# 18                            冰点/fn柠檬                    361563589@qq.com
# 19                                邓永刚                    394099172@qq.com
# 20                                 蒋顺                    398112861@qq.com
# 21                                 张斌                    404963755@qq.com
# 22                           ▓随缘＠/xin                    410269648@qq.com
# 23                                张立志                    410502765@qq.com
# 24                                 虎叔                    464438440@qq.com
# 25                                 程哥                    495185229@qq.com
# 26                                印姐姐                    514035313@qq.com
# 27                                 邓强                    535202828@qq.com
# 28                               ★水晶★                    545277387@qq.com
# 29                             ピ╄壞女ピ╄                    654332092@qq.com
# ..                                ...                                 ...
# 87             ship-confirm@amazon.cn              ship-confirm@amazon.cn
# 88         noreply@webofknowledge.com          noreply@webofknowledge.com
# 89                                杨新平                   1442531748@qq.com
# 90                                 张慧                    918427558@qq.com
# 91                         yangyiping         yangyiping@mail.hust.edu.cn
# 92                                杨一平              yangyiping@hust.edu.cn
# 93                             拐角，失去你                   1147948463@qq.com
# 94                                 白雪                    531285394@qq.com
# 95                                程世亮                    418183147@qq.com
# 96                                 杨青                   1208792366@qq.com
# 97                        yaolingjixu                yaolingjixu@sina.com
# 98                            another                   2570759136@qq.com
# 99                                 伍洋                    397722371@qq.com
# 100                               王安润                   1239557174@qq.com
# 101                            同城找情乆人                   1420273441@qq.com
# 102                               吴章兴                   1157778477@qq.com
# 103                               万晓宁                    350114819@qq.com
# 104                               王艺洁                    942601252@qq.com
# 105                           天空中的幸福星                   1037262375@qq.com
# 106                           brettlv                     brettlv@126.com
# 107                           张俐 工图老师                      8430009@qq.com
# 108                               hub                hub@mail.hust.edu.cn
# 109                          yuanyuan                      zzzzyan@qq.com
# 110                            印象笔记国内       lvbing.f945736@m.yinxiang.com
# 111                            印象笔记手机  brettlvbing.bc4c537@m.yinxiang.com
# 112                            陈欢（同学）                   1071762466@qq.com
# 113                               余文飞                   wenfei@shao.ac.cn
# 114                          Wu Yajun                  wuyajun@shao.ac.cn
# 115                              qbhe                     qbhe@shao.ac.cn
# 116  中国天文科普网-天之文天文论坛-中国科学院天文科普网络委员会主办                  admin@astron.ac.cn
#
# [117 rows x 2 columns]

# %%
ls *csv
# Out:
# data.csv       ex1.csv        mycontact.csv

# %%
name=dframe['姓名']
email=dframe['电子邮件']

# %%
#for i in range(name.size):
    #print(name[i],email[i])
