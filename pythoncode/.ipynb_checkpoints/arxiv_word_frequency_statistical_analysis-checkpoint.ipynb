# %%
import time
#import urllib2# python2
import urllib#python3

import datetime
#from itertools import ifilter python2
from collections import Counter, defaultdict
import xml.etree.ElementTree as ET
import h5py
from bs4 import BeautifulSoup
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import bibtexparser

pd.set_option('mode.chained_assignment','warn')

# %%
import arxivchecker #new daily
import arxiv#query num 
import os
import time

# %%
import arxiv
import arxivchecker
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr
from email.header import Header
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
import os

from datetime import datetime

# %% [markdown]
# # scrapy paper

# %%
OAI = "{http://www.openarchives.org/OAI/2.0/}"
ARXIV = "{http://arxiv.org/OAI/arXiv/}"

def harvest(arxiv="physics:astro-ph",yearstart=2019):
    df = pd.DataFrame(columns=("title","abstract", "categories", "created", "id", "doi"))
    base_url = "http://export.arxiv.org/oai2?verb=ListRecords&"
    url = (base_url +
           "from=%i-01-01&until=%i-04-31&"%(yearstart,yearstart) +
           "metadataPrefix=arXiv&set=%s"%arxiv)
###04-31    
    while True:
        print("fetching", url)
        try:
            response = urllib.request.urlopen(url)
            
        except urllib.error.HTTPError as e:
            if e.code == 503:
                to = int(e.hdrs.get("retry-after", 30))
                print("Got 503. Retrying after {0:d} seconds.".format(to))

                time.sleep(to)
                continue
                
            else:
                raise
            
        xml = response.read()

        root = ET.fromstring(xml)

        for record in root.find(OAI+'ListRecords').findall(OAI+"record"):
            arxiv_id = record.find(OAI+'header').find(OAI+'identifier')
            meta = record.find(OAI+'metadata')
            info = meta.find(ARXIV+"arXiv")
            #author=info.find(ARXIV+"author").text
            created = info.find(ARXIV+"created").text
            created = datetime.datetime.strptime(created, "%Y-%m-%d")
            categories = info.find(ARXIV+"categories").text

            # if there is more than one DOI use the first one
            # often the second one (if it exists at all) refers
            # to an eratum or similar
            doi = info.find(ARXIV+"doi")
            if doi is not None:
                doi = doi.text.split()[0]                
            contents = {'title': info.find(ARXIV+"title").text,
                        #'author':info.find(ARXIV+"author").text,
                        'id': info.find(ARXIV+"id").text,#arxiv_id.text[4:],
                        'abstract': info.find(ARXIV+"abstract").text.strip(),
                        'created': created,
                        'categories': categories.split(),
                        'doi': doi,
                        }
            df = df.append(contents, ignore_index=True)
        # The list of articles returned by the API comes in chunks of
        # 1000 articles. The presence of a resumptionToken tells us that
        # there is more to be fetched.
        token = root.find(OAI+'ListRecords').find(OAI+"resumptionToken")
        if token is None or token.text is None:
            break
        else:
            url = base_url + "resumptionToken=%s"%(token.text)            
    return df

# %% [markdown]
# http://export.arxiv.org/oai2?verb=ListSets

# %%
df = harvest(arxiv="physics:astro-ph",yearstart=2020)

# %%
df.head()

# %%
df.to_csv('arxiv_astro-ph_2020.csv')

# %%
pwd

# %%
store = pd.HDFStore("/Users/thead/git/arxiv-experiments/hep-ex.h5")
#store['df'] = df
#df = store['df']
store.close()

# %% [markdown]
# arxivcheckerastroph2020=arxivchecker.scrape_arxiv('astro-ph',year=2020,number=1000)
# len(arxivcheckerastroph2020)
# papers=arxivchecker.check_keywords_from_papers(astroph201912,['AGN','XRB','IMBH','ULX','transient'])

# %%
# ?arxivchecker.scrape_arxiv

# %%
# ?arxivchecker.check_keywords

# %%
papers_keywords = arxivchecker.check_keywords('astro-ph', ['AGN','XRB','IMBH','ULX','transient','radio'],mute=True)

# %%
len(papers_keywords)
# Out:
# 22

# %%
#papers_scrape = arxivchecker.scrape_arxiv('astro-ph',year=2020,month=4) # April 2020

# %%
sortBy can be "relevance", "lastUpdatedDate", "submittedDate"
sortOrder can be either "ascending" or "descending"

# %%
# ?arxiv.query

# %%
paper_query=arxiv.query(query="cat:astro-ph AND abs:radio",
            max_results=100,
            start = 0,
            sort_by="lastUpdatedDate",
            sort_order="descending",
            prune=False,
            iterative=False,
            max_chunk_results=1000)

# %%
len(paper_query)
# Out:
# 100

# %%
for paper in paper_query:
    print(paper['title'],paper['updated'])
    #print(paper['abstract'])

# %% [markdown]
# ## def bar_plot

# %%
def bar_chart(items,title):
    """Make a bar chart showing the count associated with each key
    
    `items` is a list of (key, count) pairs.
    """
    width = 0.5
    ind = np.arange(len(items))
    fig, ax = plt.subplots(figsize=(8,8))
    rects1 = ax.bar(ind, list(zip(*items))[1], width, color='r')
    ax.set_xticks(ind+width)
    ax.set_xticklabels(list(zip(*items))[0])
    fig.autofmt_xdate()
    plt.title(title)
    plt.show()

# %% [markdown]
# # analysis and vocabulary

# %% [markdown]
# ## analysis astro2020 AND White Paper

# %%
from datetime import datetime
import os
import arxiv#query num 
now = datetime.now() # 获取当前datetime
print(now)
papersastro2020=arxiv.query(query="all:astro2020",max_results=1000)
astro2020filename='astro2020whitepaperuptodate%d-%d-%d.txt'%(now.year,now.month,now.day)
title='astro2020whitepaperuptodatetitle%d-%d-%d.txt'%(now.year,now.month,now.day)
summary='astro2020whitepaperuptodatesummary%d-%d-%d.txt'%(now.year,now.month,now.day)

if os.path.isfile(astro2020filename):
    os.remove(astro2020filename)
if os.path.isfile(title):
    os.remove(title)
if os.path.isfile(summary):
    os.remove(summary)    
    
for i in papersastro2020:
    with open(astro2020filename,'a') as f:
        f.write(i['id']+'\n'+i['title']+'\n'+i['summary']+'\n'+'\n')
    with open(title,'a') as f:
        f.write(i['title']+'\n')        
    with open(summary,'a') as f:
        f.write(i['summary']+'\n')
# Out:
# 2020-04-23 16:57:19.512154

# %%
len(papersastro2020)
# Out:
# 434

# %% [markdown]
# ## title-analysis

# %% [markdown]
# ### Counter

# %%
import jieba
from collections import Counter

with open(title) as f:
    s = f.read()    
    
word_list = list(jieba.cut(s.lower()))

print('分词总数:', len(word_list))
#print('示例:', word_list[:20])
words_count = Counter(word_list)
most_words = words_count.most_common(100)
#print(most_words)

from nltk.corpus import stopwords
from nltk.corpus import wordnet

stops = [word for word in stopwords.words('english')]
stops += ["=", "->"," ","\n","-",":",",","a",'x','(',')',"'","\"",'?','+',"$"]
stops +=['\\','.','/',';','~','','_']
stops +=['white','paper','astro2020']
#[!"#$&()*+,-./:;<=>?@[\\]^_{|}·~‘’]
         
words = filter(lambda w: w not in stops,
               word_list)
top_twenty_title = Counter(words).most_common(n=20)
for i in top_twenty_title:
    if wordnet.synsets(i[0]) and i[0].isalpha():
        print(i)
# Out:
# 分词总数: 10468
# ('science', 94)
# ('high', 38)
# ('astronomy', 38)
# ('cosmic', 38)
# ('astrophysics', 36)
# ('black', 34)
# ('ray', 31)
# ('galaxy', 30)
# ('stars', 27)
# ('gravitational', 26)
# ('next', 25)
# ('evolution', 22)
# ('wave', 22)
# ('physics', 22)
# ('holes', 22)
# ('resolution', 21)
# ('formation', 21)
# ('energy', 20)
# ('galaxies', 19)
# ('imaging', 19)

# %% [markdown]
# ### bar_plot

# %%
bar_chart(top_twenty_title,title='top_twenty word in title of Astro2020 White Paper')

# %% [markdown]
# ## summary-analysis

# %%
with open(summary) as f:
    s = f.read()    
word_list = list(jieba.cut(s.lower()))
#print('分词总数:', len(word_list))
#print('示例:', word_list[:20])
#words_count = Counter(word_list)
#most_words = words_count.most_common(100)
#print(most_words)

words = filter(lambda w: w not in stops,
               word_list)
top_twenty_summary = Counter(words).most_common(n=20)
for i in top_twenty_summary:
    if wordnet.synsets(i[0]) and i[0].isalpha():
        print(i)
# Out:
# ('high', 282)
# ('galaxies', 250)
# ('large', 238)
# ('observations', 233)
# ('formation', 224)
# ('stars', 223)
# ('science', 217)
# ('galaxy', 212)
# ('new', 204)
# ('mass', 189)
# ('ray', 184)
# ('resolution', 178)
# ('decade', 177)
# ('star', 175)
# ('evolution', 174)
# ('stellar', 172)
# ('next', 170)
# ('understanding', 167)
# ('black', 162)
# ('universe', 162)

# %%
ls *.txt
# Out:
# astro2020whitepaperuptodate2020-4-23.txt
# astro2020whitepaperuptodatesummary2020-4-23.txt
# astro2020whitepaperuptodatetitle2020-4-23.txt
# pos_list.txt
# ra_dec.txt
# ra_dec_tab.txt
# ra_dec_tab_byhand.txt
# searchresult.txt

# %%
bar_chart(top_twenty_summary,title='top_twenty word in abstract of Astro2020 White Paper')

# %% [markdown]
# ## all words in summary

# %%
with open(summary) as f:
    s = f.read()    
word_list = list(jieba.cut(s.lower()))
#print('分词总数:', len(word_list))
#print('示例:', word_list[:20])
#words_count = Counter(word_list)
#most_words = words_count.most_common(100)
#print(most_words)

words = filter(lambda w: w not in stops,
               word_list)
top_all_summary = Counter(words).most_common(n=10000)
#print(top_1000_summary)

# %%
with open('astro2020-voc-least-2.txt','a') as f:
    for i,j in top_all_summary:
        if wordnet.synsets(i) and i.isalpha() and j>1:
            f.write(i+'\t'+str(j)+'\n')

# %%
with open('astro2020-voc-least-1.txt','a') as f:
    for i,j in top_all_summary:
        if wordnet.synsets(i) and i.isalpha() and j>0:
            f.write(i+'\t'+str(j)+'\n')

# %%
with open(summary) as f:
    s = f.read()    
word_list = list(jieba.cut(s.lower()))
#print('分词总数:', len(word_list))
#print('示例:', word_list[:20])
#words_count = Counter(word_list)
#most_words = words_count.most_common(100)
#print(most_words)

words = filter(lambda w: w not in stops,
               word_list)
top_1000_summary = Counter(words).most_common(n=100)
for i in top_1000_summary:
    if wordnet.synsets(i[0]) and i[0].isalpha():
        print(i)
# Out:
# ('high', 282)
# ('galaxies', 250)
# ('large', 238)
# ('observations', 233)
# ('formation', 224)
# ('stars', 223)
# ('science', 217)
# ('galaxy', 212)
# ('new', 204)
# ('mass', 189)
# ('ray', 184)
# ('resolution', 178)
# ('decade', 177)
# ('star', 175)
# ('evolution', 174)
# ('stellar', 172)
# ('next', 170)
# ('understanding', 167)
# ('black', 162)
# ('universe', 162)
# ('cosmic', 160)
# ('astronomy', 156)
# ('space', 151)
# ('survey', 149)
# ('field', 149)
# ('data', 142)
# ('gas', 140)
# ('provide', 136)
# ('energy', 135)
# ('time', 132)
# ('also', 128)
# ('telescope', 124)
# ('planets', 121)
# ('telescopes', 120)
# ('astrophysics', 119)
# ('based', 118)
# ('physics', 112)
# ('surveys', 112)
# ('imaging', 109)
# ('gravitational', 106)
# ('first', 105)
# ('dark', 103)
# ('scientific', 102)
# ('z', 101)
# ('infrared', 101)
# ('properties', 100)
# ('range', 99)
# ('holes', 97)
# ('measurements', 97)
# ('wide', 96)
# ('scale', 95)
# ('spectroscopy', 95)
# ('accretion', 94)
# ('study', 92)
# ('current', 92)
# ('mission', 90)
# ('us', 89)
# ('matter', 88)
# ('key', 88)
# ('ground', 87)
# ('low', 87)
# ('galactic', 85)
# ('studies', 85)
# ('probe', 84)
# ('sources', 84)
# ('future', 84)
# ('radio', 82)
# ('questions', 82)
# ('processes', 81)
# ('planet', 81)
# ('medium', 81)
# ('structure', 81)
# ('well', 80)
# ('many', 80)
# ('uv', 80)
# ('systems', 79)
# ('research', 79)
# ('dust', 77)
# ('facilities', 77)
# ('community', 77)
# ('emission', 76)
# ('one', 76)
# ('physical', 76)
# ('spectral', 75)
# ('solar', 74)
# ('optical', 74)
# ('including', 73)
# ('within', 73)
# ('spectroscopic', 72)
# ('fundamental', 72)
# ('beyond', 71)

# %% [markdown]
# # daily-mail

# %%
pwd
# Out:
# '/Users/brettlv/blog/brettlv.github.io/pythoncode'

# %% [markdown]
# ## arxiv.query

# %%
paper_query=arxiv.query(query="cat:astro-ph AND abs:radio OR abs:AGN OR abs:XRB",
            max_results=50,
            start = 0,
            sort_by="lastUpdatedDate",
            sort_order="descending",
            prune=False,
            iterative=False,
            max_chunk_results=1000)

# %%
len(paper_query)
# Out:
# 50

# %%
paper_query
# Out:
# [{'affiliation': 'University of Bristol',
#   'arxiv_comment': 'Astronomy and Astrophysics Review (2009) 17,1-46. Post-publication\n  version',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0812.3401v2',
#   'author': 'D. M. Worrall',
#   'author_detail': {'name': 'D. M. Worrall'},
#   'authors': ['D. M. Worrall'],
#   'doi': '10.1007/s00159-008-0016-7',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0812.3401v2',
#   'journal_reference': 'Astron.Astrophys.Rev.17:1-46,2009',
#   'links': [{'href': 'http://dx.doi.org/10.1007/s00159-008-0016-7',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0812.3401v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0812.3401v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0812.3401v2',
#   'published': '2008-12-17T21:50:47Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=12, tm_mday=17, tm_hour=21, tm_min=50, tm_sec=47, tm_wday=2, tm_yday=352, tm_isdst=0),
#   'summary': "Jet physics is again flourishing as a result of Chandra's ability to resolve\nhigh-energy emission from the radio-emitting structures of active galaxies and\nseparate it from the X-ray-emitting thermal environments of the jets. These\nenhanced capabilities have coincided with an increasing interest in the link\nbetween the growth of super-massive black holes and galaxies, and an\nappreciation of the likely importance of jets in feedback processes. I review\nthe progress that has been made using Chandra and XMM-Newton observations of\njets and the medium in which they propagate, addressing several important\nquestions, including: Are the radio structures in a state of minimum energy? Do\npowerful large-scale jets have fast spinal speeds? What keeps jets collimated?\nWhere and how does particle acceleration occur? What is jet plasma made of?\nWhat does X-ray emission tell us about the dynamics and energetics of radio\nplasma/gas interactions? Is a jet's fate determined by the central engine?",
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': "Jet physics is again flourishing as a result of Chandra's ability to resolve\nhigh-energy emission from the radio-emitting structures of active galaxies and\nseparate it from the X-ray-emitting thermal environments of the jets. These\nenhanced capabilities have coincided with an increasing interest in the link\nbetween the growth of super-massive black holes and galaxies, and an\nappreciation of the likely importance of jets in feedback processes. I review\nthe progress that has been made using Chandra and XMM-Newton observations of\njets and the medium in which they propagate, addressing several important\nquestions, including: Are the radio structures in a state of minimum energy? Do\npowerful large-scale jets have fast spinal speeds? What keeps jets collimated?\nWhere and how does particle acceleration occur? What is jet plasma made of?\nWhat does X-ray emission tell us about the dynamics and energetics of radio\nplasma/gas interactions? Is a jet's fate determined by the central engine?"},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'The X-ray Jets of Active Galaxies',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The X-ray Jets of Active Galaxies'},
#   'updated': '2018-06-08T12:44:01Z',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=6, tm_mday=8, tm_hour=12, tm_min=44, tm_sec=1, tm_wday=4, tm_yday=159, tm_isdst=0)},
#  {'affiliation': 'HH Wills Physics Laboratory, University of Bristol',
#   'arxiv_comment': 'Post-publication version',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/astro-ph/0410297v2',
#   'author': 'M. Birkinshaw',
#   'author_detail': {'name': 'M. Birkinshaw'},
#   'authors': ['D. M. Worrall', 'M. Birkinshaw'],
#   'doi': '10.1007/3-540-34621-X_2',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/astro-ph/0410297v2',
#   'journal_reference': 'Lect.NotesPhys.693:39-76,2006',
#   'links': [{'href': 'http://dx.doi.org/10.1007/3-540-34621-X_2',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/astro-ph/0410297v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/astro-ph/0410297v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/astro-ph/0410297v2',
#   'published': '2004-10-12T13:13:57Z',
#   'published_parsed': time.struct_time(tm_year=2004, tm_mon=10, tm_mday=12, tm_hour=13, tm_min=13, tm_sec=57, tm_wday=1, tm_yday=286, tm_isdst=0),
#   'summary': 'Over the last few years, high-quality X-ray imaging and spectroscopic data\nfrom Chandra and XMM-Newton have added greatly to the understanding of the\nphysics of radio jets. Here we describe the current state of knowledge with an\nemphasis on the underlying physics used to interpret multiwavelength data in\nterms of physical parameters.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Over the last few years, high-quality X-ray imaging and spectroscopic data\nfrom Chandra and XMM-Newton have added greatly to the understanding of the\nphysics of radio jets. Here we describe the current state of knowledge with an\nemphasis on the underlying physics used to interpret multiwavelength data in\nterms of physical parameters.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'Multiwavelength evidence of the physical processes in radio jets',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Multiwavelength evidence of the physical processes in radio jets'},
#   'updated': '2018-06-08T10:08:11Z',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=6, tm_mday=8, tm_hour=10, tm_min=8, tm_sec=11, tm_wday=4, tm_yday=159, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': '15 pages, 4 figures, published in The Astrophysical Journal,\n  additional supplementary material was not submitted to The Astrophysical\n  Journal and has not been peer reviewed, including ancillary material in the\n  form of Mathematica notebooks and associated PDF documents. Erratum can be\n  found at 10.1088/0004-637X/719/1/985',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0812.3461v3',
#   'author': 'W. van Straten',
#   'author_detail': {'name': 'W. van Straten'},
#   'authors': ['W. van Straten'],
#   'doi': '10.1088/0004-637X/694/2/1413',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0812.3461v3',
#   'journal_reference': 'Astrophys.J.694:1413-1422,2009',
#   'links': [{'href': 'http://dx.doi.org/10.1088/0004-637X/694/2/1413',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0812.3461v3',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0812.3461v3',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0812.3461v3',
#   'published': '2008-12-18T05:50:35Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=12, tm_mday=18, tm_hour=5, tm_min=50, tm_sec=35, tm_wday=3, tm_yday=353, tm_isdst=0),
#   'summary': 'A four-dimensional statistical description of electromagnetic radiation is\ndeveloped and applied to the analysis of radio pulsar polarization. The new\nformalism provides an elementary statistical explanation of the modal\nbroadening phenomenon in single pulse observations. It is also used to argue\nthat the degree of polarization of giant pulses has been poorly defined in past\nstudies. Single and giant pulse polarimetry typically involves sources with\nlarge flux densities and observations with high time resolution, factors that\nnecessitate consideration of source-intrinsic noise and small-number\nstatistics. Self noise is shown to fully explain the excess polarization\ndispersion previously noted in single pulse observations of bright pulsars,\nobviating the need for additional randomly polarized radiation. Rather, these\nobservations are more simply interpreted as an incoherent sum of covariant,\northogonal, partially polarized modes. Based on this premise, the\nfour-dimensional covariance matrix of the Stokes parameters may be used to\nderive mode-separated pulse profiles without any assumptions about the\nintrinsic degrees of mode polarization. Finally, utilizing the small-number\nstatistics of the Stokes parameters, it is established that the degree of\npolarization of an unresolved pulse is fundamentally undefined; therefore,\nprevious claims of highly polarized giant pulses are unsubstantiated.\nUnpublished supplementary material is appended after the bibliography.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'A four-dimensional statistical description of electromagnetic radiation is\ndeveloped and applied to the analysis of radio pulsar polarization. The new\nformalism provides an elementary statistical explanation of the modal\nbroadening phenomenon in single pulse observations. It is also used to argue\nthat the degree of polarization of giant pulses has been poorly defined in past\nstudies. Single and giant pulse polarimetry typically involves sources with\nlarge flux densities and observations with high time resolution, factors that\nnecessitate consideration of source-intrinsic noise and small-number\nstatistics. Self noise is shown to fully explain the excess polarization\ndispersion previously noted in single pulse observations of bright pulsars,\nobviating the need for additional randomly polarized radiation. Rather, these\nobservations are more simply interpreted as an incoherent sum of covariant,\northogonal, partially polarized modes. Based on this premise, the\nfour-dimensional covariance matrix of the Stokes parameters may be used to\nderive mode-separated pulse profiles without any assumptions about the\nintrinsic degrees of mode polarization. Finally, utilizing the small-number\nstatistics of the Stokes parameters, it is established that the degree of\npolarization of an unresolved pulse is fundamentally undefined; therefore,\nprevious claims of highly polarized giant pulses are unsubstantiated.\nUnpublished supplementary material is appended after the bibliography.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'The Statistics of Radio Astronomical Polarimetry: Bright Sources and\n  High Time Resolution',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Statistics of Radio Astronomical Polarimetry: Bright Sources and\n  High Time Resolution'},
#   'updated': '2017-08-02T04:02:42Z',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=8, tm_mday=2, tm_hour=4, tm_min=2, tm_sec=42, tm_wday=2, tm_yday=214, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': 'Published as 2007, ApJ,658,1119',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/astro-ph/0611808v2',
#   'author': 'T. H. Troland',
#   'author_detail': {'name': 'T. H. Troland'},
#   'authors': ['E. W. Pellegrini',
#    'J. A. Baldwin',
#    'C. L. Brogan',
#    'M. M. Hanson',
#    'N. P. Abel',
#    'G. J. Ferland',
#    'H. B. Nemala',
#    'G. Shaw',
#    'T. H. Troland'],
#   'doi': '10.1086/511258',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/astro-ph/0611808v2',
#   'journal_reference': None,
#   'links': [{'href': 'http://dx.doi.org/10.1086/511258',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/astro-ph/0611808v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/astro-ph/0611808v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/astro-ph/0611808v2',
#   'published': '2006-11-27T15:22:57Z',
#   'published_parsed': time.struct_time(tm_year=2006, tm_mon=11, tm_mday=27, tm_hour=15, tm_min=22, tm_sec=57, tm_wday=0, tm_yday=331, tm_isdst=0),
#   'summary': 'The southwestern (SW) part of the Galactic H II region M17 contains an\nobscured ionization front that is most easily seen at infrared and radio\nwavelengths. It is nearly edge-on, thus offering an excellent opportunity to\nstudy the way in which the gas changes from fully ionized to molecular as\nradiation from the ionizing stars penetrates into the gas. M17 is also one of\nthe very few H II regions for which the magnetic field strength can be measured\nin the photodissociation region ( PDR) that forms the interface between the\nionized and molecular gas. Here we model an observed line of sight through the\ngas cloud, including the H+, H0 (PDR), and molecular layers, in a fully\nself-consistent single calculation. An interesting aspect of the M17 SW bar is\nthat the PDR is very extended. We show that the strong magnetic field that is\nobserved to be present inevitably leads to a very deep PDR, because the\nstructure of the neutral and molecular gas is dominated by magnetic pressure,\nrather than by gas pressure, as previously had been supposed.We also show that\na wide variety of observed facts can be explained if a hydrostatic geometry\nprevails, in which the gas pressure from an inner X-ray hot bubble and the\noutward momentum of the stellar radiation field compress the gas and its\nassociated magnetic field in the PDR, as has already been shown to occur in the\nOrion Nebula. The magnetic field compression may also amplify the local\ncosmic-ray density. The pressure in the observed magnetic field balances the\noutward forces, suggesting that the observed geometry is a natural consequence\nof the formation of a star cluster within a molecular cloud.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The southwestern (SW) part of the Galactic H II region M17 contains an\nobscured ionization front that is most easily seen at infrared and radio\nwavelengths. It is nearly edge-on, thus offering an excellent opportunity to\nstudy the way in which the gas changes from fully ionized to molecular as\nradiation from the ionizing stars penetrates into the gas. M17 is also one of\nthe very few H II regions for which the magnetic field strength can be measured\nin the photodissociation region ( PDR) that forms the interface between the\nionized and molecular gas. Here we model an observed line of sight through the\ngas cloud, including the H+, H0 (PDR), and molecular layers, in a fully\nself-consistent single calculation. An interesting aspect of the M17 SW bar is\nthat the PDR is very extended. We show that the strong magnetic field that is\nobserved to be present inevitably leads to a very deep PDR, because the\nstructure of the neutral and molecular gas is dominated by magnetic pressure,\nrather than by gas pressure, as previously had been supposed.We also show that\na wide variety of observed facts can be explained if a hydrostatic geometry\nprevails, in which the gas pressure from an inner X-ray hot bubble and the\noutward momentum of the stellar radiation field compress the gas and its\nassociated magnetic field in the PDR, as has already been shown to occur in the\nOrion Nebula. The magnetic field compression may also amplify the local\ncosmic-ray density. The pressure in the observed magnetic field balances the\noutward forces, suggesting that the observed geometry is a natural consequence\nof the formation of a star cluster within a molecular cloud.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'A Magnetically-Supported Photodissociation Region in M17',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'A Magnetically-Supported Photodissociation Region in M17'},
#   'updated': '2017-08-01T16:57:17Z',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=8, tm_mday=1, tm_hour=16, tm_min=57, tm_sec=17, tm_wday=1, tm_yday=213, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': 'As accepted by Serbian Astronomical Journal',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0806.3605v3',
#   'author': 'A. R. Kosakowski',
#   'author_detail': {'name': 'A. R. Kosakowski'},
#   'authors': ['A. Y. De Horta',
#    'M. D. Filipović',
#    'E. J. Crawford',
#    'F. H. Stootman',
#    'T. G. Pannuti',
#    'L. M. Bozzetto',
#    'J. D. Collier',
#    'E. R. Sommer',
#    'A. R. Kosakowski'],
#   'doi': '10.2298/SAJ140605001H',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0806.3605v3',
#   'journal_reference': None,
#   'links': [{'href': 'http://dx.doi.org/10.2298/SAJ140605001H',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0806.3605v3',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0806.3605v3',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0806.3605v3',
#   'published': '2008-06-23T02:56:11Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=6, tm_mday=23, tm_hour=2, tm_min=56, tm_sec=11, tm_wday=0, tm_yday=175, tm_isdst=0),
#   'summary': "We present an analysis of a new Australia Telescope Compact Array (ATCA)\nradio-continuum observation of supernova remnant (SNR) G1.9+0.3, which at an\nage of $\\sim$181$\\pm$25 years is the youngest known in the Galaxy. We analysed\nall available radio-continuum observations at 6-cm from the ATCA and the Very\nLarge Array. Using this data we estimate an expansion rate for G1.9+0.3 of\n0.563%$\\pm$0.078% per year between 1984 and 2009. We note that in the 1980's\nG1.9+0.3 expanded somewhat slower (0.484% per year) than more recently (0.641%\nper year). We estimate that the average spectral index between 20-cm and 6-cm,\nacross the entire SNR is $\\alpha=-0.72\\pm 0.26$ which is typical for younger\nSNRs. At 6-cm, we detect an average of 6% fractionally polarised radio emission\nwith a peak of 17%$\\pm$3%. The polarised emission follows the contours of the\nstrongest of X-ray emission. Using the new equipartition formula we estimate a\nmagnetic field strength of B$\\approx 273\\mu$G, which to date, is one of the\nhighest magnetic field strength found for any SNR and consistent with G1.9+0.3\nbeing a very young remnant. This magnetic field strength implies a minimum\ntotal energy of the synchrotron radiation of E$_{\\textrm{min}} \\approx$\n1.8$\\times$10$^{48}$ ergs.",
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': "We present an analysis of a new Australia Telescope Compact Array (ATCA)\nradio-continuum observation of supernova remnant (SNR) G1.9+0.3, which at an\nage of $\\sim$181$\\pm$25 years is the youngest known in the Galaxy. We analysed\nall available radio-continuum observations at 6-cm from the ATCA and the Very\nLarge Array. Using this data we estimate an expansion rate for G1.9+0.3 of\n0.563%$\\pm$0.078% per year between 1984 and 2009. We note that in the 1980's\nG1.9+0.3 expanded somewhat slower (0.484% per year) than more recently (0.641%\nper year). We estimate that the average spectral index between 20-cm and 6-cm,\nacross the entire SNR is $\\alpha=-0.72\\pm 0.26$ which is typical for younger\nSNRs. At 6-cm, we detect an average of 6% fractionally polarised radio emission\nwith a peak of 17%$\\pm$3%. The polarised emission follows the contours of the\nstrongest of X-ray emission. Using the new equipartition formula we estimate a\nmagnetic field strength of B$\\approx 273\\mu$G, which to date, is one of the\nhighest magnetic field strength found for any SNR and consistent with G1.9+0.3\nbeing a very young remnant. This magnetic field strength implies a minimum\ntotal energy of the synchrotron radiation of E$_{\\textrm{min}} \\approx$\n1.8$\\times$10$^{48}$ ergs."},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'Radio-Continuum Emission From The Young Galactic Supernova Remnant\n  G1.9+0.3',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Radio-Continuum Emission From The Young Galactic Supernova Remnant\n  G1.9+0.3'},
#   'updated': '2014-08-22T01:27:33Z',
#   'updated_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=22, tm_hour=1, tm_min=27, tm_sec=33, tm_wday=4, tm_yday=234, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': '8 pages, 6 figures; accepted for publication in PASJ (Publications of\n  the Astronomical Society of Japan) Suzaku 3rd special issue: TYPOS in flux\n  density unit were corrected',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0809.2448v2',
#   'author': 'Yuichi Yaji',
#   'author_detail': {'name': 'Yuichi Yaji'},
#   'authors': ['Makoto S. Tashiro',
#    'Naoki Isobe',
#    'Hiromi Seta',
#    'Keiko Matsuta',
#    'Yuichi Yaji'],
#   'doi': '10.1093/pasj/61.sp1.S327',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0809.2448v2',
#   'journal_reference': 'PASJ 61: S327-S335, 2009',
#   'links': [{'href': 'http://dx.doi.org/10.1093/pasj/61.sp1.S327',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0809.2448v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0809.2448v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0809.2448v2',
#   'published': '2008-09-15T07:01:05Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=9, tm_mday=15, tm_hour=7, tm_min=1, tm_sec=5, tm_wday=0, tm_yday=259, tm_isdst=0),
#   'summary': 'An observation of the West lobe of radio galaxy Fornax A (NGC 1316) with\nSuzaku is reported. Since Feigelson et al. (1995) and Kaneda et al. (1995)\ndiscovered the cosmic microwave background boosted inverse-Comptonized (IC)\nX-rays from the radio lobe, the magnetic field and electron energy density in\nthe lobes have been estimated under the assumption that a single component of\nthe relativistic electrons generates both the IC X-rays and the synchrotron\nradio emission. However, electrons generating the observed IC X-rays in the 1\n-- 10 keV band do not possess sufficient energy to radiate the observed\nsynchrotron radio emission under the estimated magnetic field of a few micro-G.\nOn the basis of observations made with Suzaku, we show in the present paper\nthat a 0.7 -- 20 keV spectrum is well described by a single power-law model\nwith an energy index of 0.68 and a flux density of 0.12+/-0.01 micro-Jy at 1\nkeV from the West lobe. The derived multiwavelength spectrum strongly suggests\nthat a single electron energy distribution over a Lorentz factor gamma = 300 -\n90000 is responsible for generating both the X-ray and radio emissions. The\nderived physical quantities are not only consistent with those reported for the\nWest lobe, but are also in very good agreement with those reported for the East\nlobe.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'An observation of the West lobe of radio galaxy Fornax A (NGC 1316) with\nSuzaku is reported. Since Feigelson et al. (1995) and Kaneda et al. (1995)\ndiscovered the cosmic microwave background boosted inverse-Comptonized (IC)\nX-rays from the radio lobe, the magnetic field and electron energy density in\nthe lobes have been estimated under the assumption that a single component of\nthe relativistic electrons generates both the IC X-rays and the synchrotron\nradio emission. However, electrons generating the observed IC X-rays in the 1\n-- 10 keV band do not possess sufficient energy to radiate the observed\nsynchrotron radio emission under the estimated magnetic field of a few micro-G.\nOn the basis of observations made with Suzaku, we show in the present paper\nthat a 0.7 -- 20 keV spectrum is well described by a single power-law model\nwith an energy index of 0.68 and a flux density of 0.12+/-0.01 micro-Jy at 1\nkeV from the West lobe. The derived multiwavelength spectrum strongly suggests\nthat a single electron energy distribution over a Lorentz factor gamma = 300 -\n90000 is responsible for generating both the X-ray and radio emissions. The\nderived physical quantities are not only consistent with those reported for the\nWest lobe, but are also in very good agreement with those reported for the East\nlobe.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'Hard X-Ray Spectrum from West Lobe of Radio Galaxy Fornax A Observed\n  with Suzaku',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Hard X-Ray Spectrum from West Lobe of Radio Galaxy Fornax A Observed\n  with Suzaku'},
#   'updated': '2013-08-02T03:07:32Z',
#   'updated_parsed': time.struct_time(tm_year=2013, tm_mon=8, tm_mday=2, tm_hour=3, tm_min=7, tm_sec=32, tm_wday=4, tm_yday=214, tm_isdst=0)},
#  {'affiliation': 'Universita di Milano - Italy',
#   'arxiv_comment': '20 pages, 21 figures, 6 tables. Extensively revised and enlarged\n  version accepted for publication in Astronomy & Astrophysics. Smaller figures',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0712.3141v2',
#   'author': 'D. Maino',
#   'author_detail': {'name': 'D. Maino'},
#   'authors': ['C. Tello',
#    'T. Villela',
#    'S. Torres',
#    'M. Bersanelli',
#    'G. F. Smoot',
#    'I. S. Ferreira',
#    'A. Cingoz',
#    'J. Lamb',
#    'D. Barbosa',
#    'D. Perez-Becker',
#    'S. Ricciardi',
#    'J. A. Currivan',
#    'P. Platania',
#    'D. Maino'],
#   'doi': None,
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0712.3141v2',
#   'journal_reference': None,
#   'links': [{'href': 'http://arxiv.org/abs/0712.3141v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0712.3141v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0712.3141v2',
#   'published': '2007-12-19T10:06:35Z',
#   'published_parsed': time.struct_time(tm_year=2007, tm_mon=12, tm_mday=19, tm_hour=10, tm_min=6, tm_sec=35, tm_wday=2, tm_yday=353, tm_isdst=0),
#   'summary': 'We present a partial-sky survey of the radio continuum at 2.3 GHz within the\nscope of the Galactic Emission Mapping (GEM) project, an observational program\nconceived and developed to reveal the large-scale properties of Galactic\nsynchrotron radiation through a set of self-consistent surveys of the radio\ncontinuum between 408 MHz and 10 GHz. The GEM experiment uses a portable and\ndouble-shielded 5.5-m radiotelescope in altazimuthal configuration to map\n60-degree-wide declination bands from different observational sites by\ncircularly scanning the sky at zenithal angles of 30 deg from a constantly\nrotating platform. The observations were accomplished with a total power\nreceiver, whose front-end High Electron Mobility Transistor (HEMT) amplifier\nwas matched directly to a cylindrical horn at the prime focus of the parabolic\nreflector. The Moon was used to calibrate the antenna temperature scale and the\npreparation of the map required direct subtraction and destriping algorithms to\nremove ground contamination as the most significant source of systematic error.\nWe used 484 hours of total intensity observations from two locations in\nColombia and Brazil to yield 66% sky coverage from DEC = -51.73 deg to DEC =\n+34.78 deg. The zero-level uncertainty of the combined survey is 103 mK with a\ntemperature scale error of 5% after direct correlation with the Rhodes/HartRAO\nsurvey at 2326 MHz on a T-T plot. The sky brightness distribution into regions\nof low and high emission in the GEM survey is consistent with the appearance of\na transition region as seen in the Haslam 408 MHz and WMAP K-band surveys.\nPreliminary results also show that the temperature spectral index between 408\nMHz and the 2.3 GHz band of the GEM survey has a weak spatial correlation with\nthese regions; but it steepens significantly from high to low emission regions\nwith respect to the WMAP K-band survey.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'We present a partial-sky survey of the radio continuum at 2.3 GHz within the\nscope of the Galactic Emission Mapping (GEM) project, an observational program\nconceived and developed to reveal the large-scale properties of Galactic\nsynchrotron radiation through a set of self-consistent surveys of the radio\ncontinuum between 408 MHz and 10 GHz. The GEM experiment uses a portable and\ndouble-shielded 5.5-m radiotelescope in altazimuthal configuration to map\n60-degree-wide declination bands from different observational sites by\ncircularly scanning the sky at zenithal angles of 30 deg from a constantly\nrotating platform. The observations were accomplished with a total power\nreceiver, whose front-end High Electron Mobility Transistor (HEMT) amplifier\nwas matched directly to a cylindrical horn at the prime focus of the parabolic\nreflector. The Moon was used to calibrate the antenna temperature scale and the\npreparation of the map required direct subtraction and destriping algorithms to\nremove ground contamination as the most significant source of systematic error.\nWe used 484 hours of total intensity observations from two locations in\nColombia and Brazil to yield 66% sky coverage from DEC = -51.73 deg to DEC =\n+34.78 deg. The zero-level uncertainty of the combined survey is 103 mK with a\ntemperature scale error of 5% after direct correlation with the Rhodes/HartRAO\nsurvey at 2326 MHz on a T-T plot. The sky brightness distribution into regions\nof low and high emission in the GEM survey is consistent with the appearance of\na transition region as seen in the Haslam 408 MHz and WMAP K-band surveys.\nPreliminary results also show that the temperature spectral index between 408\nMHz and the 2.3 GHz band of the GEM survey has a weak spatial correlation with\nthese regions; but it steepens significantly from high to low emission regions\nwith respect to the WMAP K-band survey.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'The 2.3 GHz continuum survey of the GEM project',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The 2.3 GHz continuum survey of the GEM project'},
#   'updated': '2013-07-07T04:52:23Z',
#   'updated_parsed': time.struct_time(tm_year=2013, tm_mon=7, tm_mday=7, tm_hour=4, tm_min=52, tm_sec=23, tm_wday=6, tm_yday=188, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': 'This paper has been withdrawn by the author and is superseded by\n  recent works',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/astro-ph/0511368v2',
#   'author': 'Joel N. Bregman',
#   'author_detail': {'name': 'Joel N. Bregman'},
#   'authors': ['Joel N. Bregman'],
#   'doi': None,
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/astro-ph/0511368v2',
#   'journal_reference': None,
#   'links': [{'href': 'http://arxiv.org/abs/astro-ph/0511368v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/astro-ph/0511368v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/astro-ph/0511368v2',
#   'published': '2005-11-11T21:18:57Z',
#   'published_parsed': time.struct_time(tm_year=2005, tm_mon=11, tm_mday=11, tm_hour=21, tm_min=18, tm_sec=57, tm_wday=4, tm_yday=315, tm_isdst=0),
#   'summary': 'An analysis of the radio and X-ray luminosities, along with black hole masses\nhas led to a relationship, the fundamental plane of black hole activity, where\nlogL_R = 0.60logL_X + 0.78logM_BH. We show that this same relationship can be\nobtained by using upper limit data or by randomizing the radio fluxes. In those\ncases, the relationship arises because one is effectively plotting distance vs\ndistance in a flux-limited sample of objects. To correctly establish a\nrelationship between L_R, L_X, and M_BH, one would need to analyze a\nvolume-limited sample of objects. The distance effect can be removed from the\nsample, where a relationship between L_R/L_X and M_BH is found, showing that\nthe L_R rises more quickly than L_X with increasing M_BH. However, until a\nwell-define sample is used, it is unclear the degree to which this relationship\nis influenced by the sample-selection.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'An analysis of the radio and X-ray luminosities, along with black hole masses\nhas led to a relationship, the fundamental plane of black hole activity, where\nlogL_R = 0.60logL_X + 0.78logM_BH. We show that this same relationship can be\nobtained by using upper limit data or by randomizing the radio fluxes. In those\ncases, the relationship arises because one is effectively plotting distance vs\ndistance in a flux-limited sample of objects. To correctly establish a\nrelationship between L_R, L_X, and M_BH, one would need to analyze a\nvolume-limited sample of objects. The distance effect can be removed from the\nsample, where a relationship between L_R/L_X and M_BH is found, showing that\nthe L_R rises more quickly than L_X with increasing M_BH. However, until a\nwell-define sample is used, it is unclear the degree to which this relationship\nis influenced by the sample-selection.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'The Absence of the Fundamental Plane of Black Hole Activity',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The Absence of the Fundamental Plane of Black Hole Activity'},
#   'updated': '2013-04-02T20:41:21Z',
#   'updated_parsed': time.struct_time(tm_year=2013, tm_mon=4, tm_mday=2, tm_hour=20, tm_min=41, tm_sec=21, tm_wday=1, tm_yday=92, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': '5 pages, 2 figures. Astrophysical Journal in press. Some\n  clarifications, additional discussion and references added',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0711.1019v2',
#   'author': 'Masatoshi Shoji',
#   'author_detail': {'name': 'Masatoshi Shoji'},
#   'authors': ['C. Martin Gaskell',
#    'Rene W. Goosmann',
#    'Nelly I. Merkulova',
#    'Nikolay M. Shakhovskoy',
#    'Masatoshi Shoji'],
#   'doi': '10.1088/0004-637X/749/2/148',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0711.1019v2',
#   'journal_reference': None,
#   'links': [{'href': 'http://dx.doi.org/10.1088/0004-637X/749/2/148',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0711.1019v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0711.1019v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0711.1019v2',
#   'published': '2007-11-07T07:02:49Z',
#   'published_parsed': time.struct_time(tm_year=2007, tm_mon=11, tm_mday=7, tm_hour=7, tm_min=2, tm_sec=49, tm_wday=2, tm_yday=311, tm_isdst=0),
#   'summary': 'Observations of the optical polarization of NGC 4151 in 1997-2003 show\nvariations of an order of magnitude in the polarized flux while the\npolarization position angle remains constant. The amplitude of variability of\nthe polarized flux is comparable to the amplitude of variability of the total\nU-band flux, except that the polarized flux follows the total flux with a lag\nof 8 +/- 3 days. The time lag and the constancy of the position angle strongly\nfavor a scattering origin for the variable polarization rather than a\nnon-thermal synchrotron origin. The orientation of the position angle of the\npolarized flux (parallel to the radio axis) and the size of the lag imply that\nthe polarization arises from electron scattering in a flattened region within\nthe low-ionization component of the broad-line-region. Polarization from dust\nscattering in the equatorial torus is ruled out as the source of the lag in\npolarized flux because it would produce a larger lag and, unless the\nhalf-opening angle of the torus is more than 53 degrees, the polarization would\nbe perpendicular to the radio axis. We note a long-term change in the\npercentage of polarization at similar total flux levels and this could be due\neither to changing non-axisymmetry in the optical continuum emission, or a\nchange in the number of scatterers on a timescale of years.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Observations of the optical polarization of NGC 4151 in 1997-2003 show\nvariations of an order of magnitude in the polarized flux while the\npolarization position angle remains constant. The amplitude of variability of\nthe polarized flux is comparable to the amplitude of variability of the total\nU-band flux, except that the polarized flux follows the total flux with a lag\nof 8 +/- 3 days. The time lag and the constancy of the position angle strongly\nfavor a scattering origin for the variable polarization rather than a\nnon-thermal synchrotron origin. The orientation of the position angle of the\npolarized flux (parallel to the radio axis) and the size of the lag imply that\nthe polarization arises from electron scattering in a flattened region within\nthe low-ionization component of the broad-line-region. Polarization from dust\nscattering in the equatorial torus is ruled out as the source of the lag in\npolarized flux because it would produce a larger lag and, unless the\nhalf-opening angle of the torus is more than 53 degrees, the polarization would\nbe perpendicular to the radio axis. We note a long-term change in the\npercentage of polarization at similar total flux levels and this could be due\neither to changing non-axisymmetry in the optical continuum emission, or a\nchange in the number of scatterers on a timescale of years.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'Discovery of Polarization Reverberation in NGC 4151',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Discovery of Polarization Reverberation in NGC 4151'},
#   'updated': '2012-02-24T07:13:49Z',
#   'updated_parsed': time.struct_time(tm_year=2012, tm_mon=2, tm_mday=24, tm_hour=7, tm_min=13, tm_sec=49, tm_wday=4, tm_yday=55, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': '21 pages, accepted by MNRAS',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0805.1581v5',
#   'author': 'C. R. Purcell',
#   'author_detail': {'name': 'C. R. Purcell'},
#   'authors': ['S. J. Curran',
#    'M. T. Whiting',
#    'T. Wiklind',
#    'J. K. Webb',
#    'M. T. Murphy',
#    'C. R. Purcell'],
#   'doi': '10.1111/j.1365-2966.2008.13925.x',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0805.1581v5',
#   'journal_reference': None,
#   'links': [{'href': 'http://dx.doi.org/10.1111/j.1365-2966.2008.13925.x',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0805.1581v5',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0805.1581v5',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0805.1581v5',
#   'published': '2008-05-12T04:50:58Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=5, tm_mday=12, tm_hour=4, tm_min=50, tm_sec=58, tm_wday=0, tm_yday=133, tm_isdst=0),
#   'summary': 'We present the results of a z>2.9 survey for HI 21-cm and molecular\nabsorption in the hosts of radio quasars using the GMRT and the Tidbinbilla\n70-m telescope. Previously published searches, which are overwhelmingly at\nredshifts of z<1, exhibit a 42% detection rate (31 out of 73 sources), and the\ninclusion of our survey yields a 17% detection rate (2 out of 12 sources) at\nz>2.5. We therefore believe that our high redshift selection is responsible for\nour exclusive non-detections, and find that at ultra-violet luminosities of\n>10e23 W/Hz, 21-cm absorption has never been detected. We also find this to not\nonly apply to our targets, but also those at low redshift exhibiting similar\nluminosities, giving zero detections out of a total of 16 sources over z=0.24\nto 3.8. This is in contrast to the < 10e23 W/Hz sources where there is a near\n50% detection rate of 21-cm absorption.\n  The mix of 21-cm detections and non-detections is currently attributed to\norientation effects, where according to unified schemes of active galactic\nnuclei, 21-cm absorption is more likely to occur in sources designated as radio\ngalaxies (type-2 objects, where the nucleus is viewed through dense obscuring\ncircumnuclear gas) than in quasars(type-1 objects, where we have a direct view\nto the nucleus). However, due to the exclusively high ultra-violet luminosities\nof our targets it is not clear whether orientation effects alone can wholly\naccount for the distribution, although there exists the possibility that the\nlarge luminosities are indicative of a changing demographic of galaxy types. We\nalso find that below luminosities of ~10e23 W/Hz, both type-1 and type-2\nobjects have a 50% likelihood of exhibiting 21-cm absorption.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'We present the results of a z>2.9 survey for HI 21-cm and molecular\nabsorption in the hosts of radio quasars using the GMRT and the Tidbinbilla\n70-m telescope. Previously published searches, which are overwhelmingly at\nredshifts of z<1, exhibit a 42% detection rate (31 out of 73 sources), and the\ninclusion of our survey yields a 17% detection rate (2 out of 12 sources) at\nz>2.5. We therefore believe that our high redshift selection is responsible for\nour exclusive non-detections, and find that at ultra-violet luminosities of\n>10e23 W/Hz, 21-cm absorption has never been detected. We also find this to not\nonly apply to our targets, but also those at low redshift exhibiting similar\nluminosities, giving zero detections out of a total of 16 sources over z=0.24\nto 3.8. This is in contrast to the < 10e23 W/Hz sources where there is a near\n50% detection rate of 21-cm absorption.\n  The mix of 21-cm detections and non-detections is currently attributed to\norientation effects, where according to unified schemes of active galactic\nnuclei, 21-cm absorption is more likely to occur in sources designated as radio\ngalaxies (type-2 objects, where the nucleus is viewed through dense obscuring\ncircumnuclear gas) than in quasars(type-1 objects, where we have a direct view\nto the nucleus). However, due to the exclusively high ultra-violet luminosities\nof our targets it is not clear whether orientation effects alone can wholly\naccount for the distribution, although there exists the possibility that the\nlarge luminosities are indicative of a changing demographic of galaxy types. We\nalso find that below luminosities of ~10e23 W/Hz, both type-1 and type-2\nobjects have a 50% likelihood of exhibiting 21-cm absorption.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'A survey for redshifted molecular and atomic absorption lines - II.\n  Associated HI, OH and millimetre lines in the z >~ 3 Parkes quarter-Jansky\n  flat-spectrum sample',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
# ...
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The main observational results from radio continuum and polarization\nobservations about the magnetic field strength and large-scale pattern for\nface-on and edge-on spiral galaxies are summarized and compared within our\nsample of galaxies of different morphological types, inclinations, and star\nformation rates (SFR). We found that galaxies with low SFR have higher thermal\nfractions/smaller synchrotron fractions than those with normal or high SFR.\nAdopting an equipartition model, we conclude that the nonthermal radio emission\nand the \\emph{total magnetic field} strength grow nonlinearly with SFR, while\nthe regular magnetic field strength does not seem to depend on SFR. We also\nstudied the magnetic field structure and disk thicknesses in highly inclined\n(edge-on) galaxies. We found in four galaxies that - despite their different\nradio appearance - the vertical scale heights for both, the thin and thick\ndisk/halo, are about equal (0.3/1.8 kpc at 4.75 GHz), independently of their\ndifferent SFR. This implies that all these galaxies host a galactic wind, in\nwhich the bulk velocity of the cosmic rays (CR) is determined by the total\nfield strength within the galactic disk. The galaxies in our sample also show a\nsimilar large-scale magnetic field configuration, parallel to the midplane and\nX-shaped further away from the disk plane, independent of Hubble type and SFR\nin the disk. Hence we conclude that also the large-scale magnetic field pattern\ndoes not depend on the amount of SFR.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'Magnetic fields and star formation in spiral galaxies',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Magnetic fields and star formation in spiral galaxies'},
#   'updated': '2009-05-07T11:57:18Z',
#   'updated_parsed': time.struct_time(tm_year=2009, tm_mon=5, tm_mday=7, tm_hour=11, tm_min=57, tm_sec=18, tm_wday=3, tm_yday=127, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': 'An invited review article to appear in Front. Phys. China., typos\n  corrected (Possible prompt and very early GeV-TeV emission from GRB 080319B\n  are discussed in Sec. V)',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0805.2221v4',
#   'author': 'Tsvi Piran',
#   'author_detail': {'name': 'Tsvi Piran'},
#   'authors': ['Yi-Zhong Fan', 'Tsvi Piran'],
#   'doi': '10.1007/s11467-008-0033-z',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0805.2221v4',
#   'journal_reference': 'Front.Phys.China3:306-330,2008',
#   'links': [{'href': 'http://dx.doi.org/10.1007/s11467-008-0033-z',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0805.2221v4',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0805.2221v4',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0805.2221v4',
#   'published': '2008-05-15T18:44:54Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=5, tm_mday=15, tm_hour=18, tm_min=44, tm_sec=54, tm_wday=3, tm_yday=136, tm_isdst=0),
#   'summary': 'Gamma-ray bursts (GRBs) are short and intense emission of soft gamma-rays,\nwhich have fascinated astronomers and astrophysicists since their unexpected\ndiscovery in 1960s. The X-ray/optical/radio afterglow observations confirm the\ncosmological origin of GRBs, support the fireball model, and imply a\nlong-activity of the central engine. The high energy gamma-ray emission (>20\nMeV) from GRBs is particularly important because they shed some lights on the\nradiation mechanisms and can help us to constrain the physical processes giving\nrise to the early afterglows. In this work, we review observational and\ntheoretical studies of the high energy emission from GRBs. Special attention is\ngiven to the expected high energy emission signatures accompanying the\ncanonical early-time X-ray afterglow that was observed by the Swift X-ray\nTelescope. We also discuss the detection prospect of the upcoming GLAST\nsatellite and the current ground-based Cerenkov detectors.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'Gamma-ray bursts (GRBs) are short and intense emission of soft gamma-rays,\nwhich have fascinated astronomers and astrophysicists since their unexpected\ndiscovery in 1960s. The X-ray/optical/radio afterglow observations confirm the\ncosmological origin of GRBs, support the fireball model, and imply a\nlong-activity of the central engine. The high energy gamma-ray emission (>20\nMeV) from GRBs is particularly important because they shed some lights on the\nradiation mechanisms and can help us to constrain the physical processes giving\nrise to the early afterglows. In this work, we review observational and\ntheoretical studies of the high energy emission from GRBs. Special attention is\ngiven to the expected high energy emission signatures accompanying the\ncanonical early-time X-ray afterglow that was observed by the Swift X-ray\nTelescope. We also discuss the detection prospect of the upcoming GLAST\nsatellite and the current ground-based Cerenkov detectors.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'High energy gamma-ray emission from Gamma-Ray Bursts -- before GLAST',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'High energy gamma-ray emission from Gamma-Ray Bursts -- before GLAST'},
#   'updated': '2009-05-06T23:31:32Z',
#   'updated_parsed': time.struct_time(tm_year=2009, tm_mon=5, tm_mday=6, tm_hour=23, tm_min=31, tm_sec=32, tm_wday=2, tm_yday=126, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': 'Accepted for publication in Astroparticle Physics',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0812.4604v2',
#   'author': 'Igor Telezhinsky',
#   'author_detail': {'name': 'Igor Telezhinsky'},
#   'authors': ['Igor Telezhinsky'],
#   'doi': '10.1016/j.astropartphys.2009.04.007',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0812.4604v2',
#   'journal_reference': None,
#   'links': [{'href': 'http://dx.doi.org/10.1016/j.astropartphys.2009.04.007',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0812.4604v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0812.4604v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0812.4604v2',
#   'published': '2008-12-25T12:27:30Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=12, tm_mday=25, tm_hour=12, tm_min=27, tm_sec=30, tm_wday=3, tm_yday=360, tm_isdst=0),
#   'summary': 'We consider Vela Jr. as being the old Supernova Remnant (SNR) at the\nbeginning of the transition from adiabatic to radiative stage of evolution.\nAccording to our model, Vela Jr. is situated outside Vela SNR at the distance\nof 600 pc and its age is 17500 yr. We model the high energy fluxes from Vela\nJr. and its broadband spectrum. We find our results compatible with\nexperimental data in radio waves, X- and gamma-rays. Our hydrodynamical model\nof Vela Jr. explains the observed TeV gamma-ray flux by hadronic mechanism. The\nproposed model does not contradict to the low density environment of the SNR\nand does not need extreme fraction of the explosion energy to be transferred to\nCosmic Rays.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'We consider Vela Jr. as being the old Supernova Remnant (SNR) at the\nbeginning of the transition from adiabatic to radiative stage of evolution.\nAccording to our model, Vela Jr. is situated outside Vela SNR at the distance\nof 600 pc and its age is 17500 yr. We model the high energy fluxes from Vela\nJr. and its broadband spectrum. We find our results compatible with\nexperimental data in radio waves, X- and gamma-rays. Our hydrodynamical model\nof Vela Jr. explains the observed TeV gamma-ray flux by hadronic mechanism. The\nproposed model does not contradict to the low density environment of the SNR\nand does not need extreme fraction of the explosion energy to be transferred to\nCosmic Rays.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'A New Model For Vela Jr. Supernova Remnant',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'A New Model For Vela Jr. Supernova Remnant'},
#   'updated': '2009-05-06T07:57:34Z',
#   'updated_parsed': time.struct_time(tm_year=2009, tm_mon=5, tm_mday=6, tm_hour=7, tm_min=57, tm_sec=34, tm_wday=2, tm_yday=126, tm_isdst=0)},
#  {'affiliation': 'None',
#   'arxiv_comment': '17 pages, 6 figures, 2 tables; changed figures, added appendices. To\n  appear in MNRAS',
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'astro-ph'},
#   'arxiv_url': 'http://arxiv.org/abs/0807.1056v2',
#   'author': 'Kris Sigurdson',
#   'author_detail': {'name': 'Kris Sigurdson'},
#   'authors': ['Ue-Li Pen',
#    'Tzu-Ching Chang',
#    'Christopher M. Hirata',
#    'Jeffrey B. Peterson',
#    'Jayanta Roy',
#    'Yashwant Gupta',
#    'Julia Odegova',
#    'Kris Sigurdson'],
#   'doi': '10.1111/j.1365-2966.2009.14980.x',
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/0807.1056v2',
#   'journal_reference': 'Mon.Not.Roy.Astron.Soc.399:181,2009',
#   'links': [{'href': 'http://dx.doi.org/10.1111/j.1365-2966.2009.14980.x',
#     'rel': 'related',
#     'title': 'doi',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/abs/0807.1056v2',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/0807.1056v2',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/0807.1056v2',
#   'published': '2008-07-07T16:05:26Z',
#   'published_parsed': time.struct_time(tm_year=2008, tm_mon=7, tm_mday=7, tm_hour=16, tm_min=5, tm_sec=26, tm_wday=0, tm_yday=189, tm_isdst=0),
#   'summary': 'The GMRT reionization effort aims to map out the large scale structure of the\nUniverse during the epoch of reionization (EoR). Removal of polarized Galactic\nemission is a difficult part of any 21 cm EoR program, and we present new upper\nlimits to diffuse polarized foregrounds at 150 MHz. We find no high\nsignificance evidence of polarized emission in our observed field at mid\ngalactic latitude (J2000 08h26m+26). We find an upper limit on the\n2-dimensional angular power spectrum of diffuse polarized foregrounds of [l^2\nC_l/(2 PI)]^{1/2}< 3K in frequency bins of width 1 MHz at 300<l<1000. The\n3-dimensional power spectrum of polarized emission, which is most directly\nrelevant to EoR observations, is [k^3 P_p(k)/(2 PI^2)]^{1/2}< 2K at k_perp >\n0.03 h/Mpc, k < 0.1 h/Mpc. This can be compared to the expected EoR signal in\ntotal intensity of [k^3 P(k)/ (2 PI^2) ]^{1/2} ~ 10 mK. We find polarized\nstructure is substantially weaker than suggested by extrapolation from higher\nfrequency observations, so the new low upper limits reported here reduce the\nanticipated impact of these foregrounds on EoR experiments. We discuss Faraday\nbeam and depth depolarization models and compare predictions of these models to\nour data. We report on a new technique for polarization calibration using\npulsars, as well as a new technique to remove broadband radio frequency\ninterference. Our data indicate that, on the edges of the main beam at GMRT,\npolarization squint creates ~ 3% leakage of unpolarized power into polarized\nmaps at zero rotation measure. Ionospheric rotation was largely stable during\nthese solar minimum night time observations.',
#   'summary_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The GMRT reionization effort aims to map out the large scale structure of the\nUniverse during the epoch of reionization (EoR). Removal of polarized Galactic\nemission is a difficult part of any 21 cm EoR program, and we present new upper\nlimits to diffuse polarized foregrounds at 150 MHz. We find no high\nsignificance evidence of polarized emission in our observed field at mid\ngalactic latitude (J2000 08h26m+26). We find an upper limit on the\n2-dimensional angular power spectrum of diffuse polarized foregrounds of [l^2\nC_l/(2 PI)]^{1/2}< 3K in frequency bins of width 1 MHz at 300<l<1000. The\n3-dimensional power spectrum of polarized emission, which is most directly\nrelevant to EoR observations, is [k^3 P_p(k)/(2 PI^2)]^{1/2}< 2K at k_perp >\n0.03 h/Mpc, k < 0.1 h/Mpc. This can be compared to the expected EoR signal in\ntotal intensity of [k^3 P(k)/ (2 PI^2) ]^{1/2} ~ 10 mK. We find polarized\nstructure is substantially weaker than suggested by extrapolation from higher\nfrequency observations, so the new low upper limits reported here reduce the\nanticipated impact of these foregrounds on EoR experiments. We discuss Faraday\nbeam and depth depolarization models and compare predictions of these models to\nour data. We report on a new technique for polarization calibration using\npulsars, as well as a new technique to remove broadband radio frequency\ninterference. Our data indicate that, on the edges of the main beam at GMRT,\npolarization squint creates ~ 3% leakage of unpolarized power into polarized\nmaps at zero rotation measure. Ionospheric rotation was largely stable during\nthese solar minimum night time observations.'},
#   'tags': [{'label': None,
#     'scheme': 'http://arxiv.org/schemas/atom',
#     'term': 'astro-ph'}],
#   'title': 'The GMRT EoR Experiment: Limits on Polarized Sky Brightness at 150 MHz',
#   'title_detail': {'base': 'http://export.arxiv.org/api/query?search_query=cat%3Aastro-ph+AND+abs%3Aradio+OR+ti%3AAGN+OR+ti%3AXRB&id_list=&start=0&max_results=50&sortBy=lastUpdatedDate&sortOrder=descending',
#    'language': None,
#    'type': 'text/plain',
#    'value': 'The GMRT EoR Experiment: Limits on Polarized Sky Brightness at 150 MHz'},
#   'updated': '2009-05-05T00:15:08Z',
#   'updated_parsed': time.struct_time(tm_year=2009, tm_mon=5, tm_mday=5, tm_hour=0, tm_min=15, tm_sec=8, tm_wday=1, tm_yday=125, tm_isdst=0)}]

# %% [markdown]
# ## arxivchecker.check_keywords

# %%
# ?arxivchecker.check_keywords

# %%
now = datetime.now() # 获取当前datetime
if os.path.isfile('/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%s-%s-%s.txt'%(now.year,now.month,now.day)):
    os.remove('/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%s-%s-%s.txt'%(now.year,now.month,now.day))
daily_filepath='/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%s-%s-%s.txt'%(now.year,now.month,now.day)
papers_keywords = arxivchecker.check_keywords('astro-ph', ['AGN','XRB','IMBH','ULX','transient','radio'],mute=True)
# Out:
# 	Checking http://arxiv.org/list/astro-ph/new
# Found 22 papers
# 12 hits
# ['agn', 'transient', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    SN2020bvc: a Broad-lined Type Ic Supernova with a Double-peaked Optical  Light C-    %%%
# %%%    urve and a Luminous X-ray and Radio Counterpart                                     %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10406                                                     %%%
# %%%                                                                                        %%%
# %%%    A. Y. Q. Ho, S. R. Kulkarni, D. A. Perley, S. B. Cenko, A. Corsi, S. Schulze, R.-    %%%
# %%%     Lunnan, J. Sollerman, A. Gal-Yam, S. Anand, C. Barbarino, E. Bellm, R. Bruch, E-    %%%
# %%%    . Burns, K. De, R. Dekany, A. Delacroix, D. Duev, C. Fremling, D. Goldstein, Z. -    %%%
# %%%    Golkhou, M. J. Graham, D. Hale, M. M. Kasliwal, T. Kupfer, R. Laher, J. Martikai-    %%%
# %%%    nen, F. J. Masci, J. D. Neill, B. Rusholme, D. L. Shupe, M. T. Soumagnac, N. L. -    %%%
# %%%    Strotjohann, K. Taggart, L. Tartaglia, L. Yan, & J. Zolkower                        %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 7 hits
# ['agn', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    The Star Formation in Radio Survey: 3 - 33 GHz Imaging of Nearby Galaxy  Nuclei -    %%%
# %%%    and Extranuclear Star-forming Regions                                               %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10230                                                     %%%
# %%%                                                                                        %%%
# %%%    S.T. Linden, E.J. Murphy, D. Dong, E. Momjian, R. C. Kennicutt Jr., D.S. Meier, -    %%%
# %%%    E. Schinnerer, & J.L. Turner                                                        %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 7 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    X-ray absorption and 9.7 um silicate feature as a probe of AGN torus  structure     %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10372                                                     %%%
# %%%                                                                                        %%%
# %%%    Jun Xu, Mouyuan Sun, Yongquan Xue, Junyao Li, & Zhicheng He                         %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 5 hits
# ['agn', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    The curious activity in the nucleus of NGC 4151: jet interaction causing  variab-    %%%
# %%%    ility?                                                                              %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10552                                                     %%%
# %%%                                                                                        %%%
# %%%    D. R. A. Williams, R. D. Baldi, I. M. McHardy, R. J. Beswick, F. Panessa, D. May-    %%%
# %%%    , J. Moldón, M. K. Argo, G. Bruni, B. T. Dullo, J. H. Knapen, E. Brinks, D. M. F-    %%%
# %%%    enech, C. G. Mundell, T. W. B. Muxlow, M. Pahari, & J. Westcott                     %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 4 hits
# ['transient']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    A Supernova Shock Break-out Candidate at z=0.092 in XMM-Newton Archival  Data       %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10665                                                     %%%
# %%%                                                                                        %%%
# %%%    G. Novara, P. Esposito, A. Tiengo, G. Vianello, R. Salvaterra, A. Belfiore, A. D-    %%%
# %%%    e Luca, P. D'Avanzo, J. Greiner, M. Scodeggio, S. Rosen, C. Delvaux, E. Pian, S.-    %%%
# %%%     Campana, G. Lisini, & S. Mereghetti                                                %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 4 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Search for magnetically-induced signatures in the arrival directions of  ultra-h-    %%%
# %%%    igh-energy cosmic rays measured at the Pierre Auger Observatory                     %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10591                                                     %%%
# %%%                                                                                        %%%
# %%%    The Pierre Auger Collaboration: A. Aab, P. Abreu, M. Aglietta, J.M. Albury, I. A-    %%%
# %%%    llekotte, A. Almela, J. Alvarez Castillo, J. Alvarez-Muñiz, R. Alves Batista, G.-    %%%
# %%%    A. Anastasi, L. Anchordoqui, B. Andrada, S. Andringa, C. Aramo, P.R. Araújo Ferr-    %%%
# %%%    eira, H. Asorey, P. Assis, G. Avila, A.M. Badescu, A. Bakalova, A. Balaceanu, F.-    %%%
# %%%     Barbato, R.J. Barreira Luz, K.H. Becker, J.A. Bellido, C. Berat, M.E. Bertaina,-    %%%
# %%%     X. Bertou, P.L. Biermann, T. Bister, J. Biteau, A. Blanco, J. Blazek, C. Bleve,-    %%%
# %%%     M. Boháčová, D. Boncioli, C. Bonifazi, L. Bonneau Arbeletche, N. Borodai, A.M. -    %%%
# %%%    Botti, J. Brack, T. Bretz, F.L. Briechle, P. Buchholz, A. Bueno, S. Buitink, M. -    %%%
# %%%    Buscemi, K.S. Caballero-Mora, L. Caccianiga, L. Calcagni, A. Cancio, F. Canfora,-    %%%
# %%%     I. Caracas, J.M. Carceller, R. Caruso, & A. Castellina, et al.                     %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 3 hits
# ['agn', 'transient']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    NuSTAR observation of the Supergiant Fast X-ray Transient IGR  J11215-5952 durin-    %%%
# %%%    g its 2017 outburst                                                                 %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10452                                                     %%%
# %%%                                                                                        %%%
# %%%    L. Sidoli, K. Postnov, A. Tiengo, P. Esposito, V. Sguera, A. Paizis, & G.A. Rodr-    %%%
# %%%    ıguez Castillo                                                                      %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 3 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Laboratory evidence for asymmetric accretion structure upon slanted  matter impa-    %%%
# %%%    ct in young stars                                                                   %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10735                                                     %%%
# %%%                                                                                        %%%
# %%%    K. Burdonov, G. Revet, R. Bonito, C. Argiroffi, J. Beard, S. Bolanos, M. Cerchez-    %%%
# %%%    , S.N. Chen, A. Ciardi, G. Espinosa, E. Fillipov, S. Pikuz, R. Rodriguez, M. Smi-    %%%
# %%%    d, M. Starodubtsev, O. Willi, S. Orlando, & J. Fuchs                                %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Unveiling the physical conditions in NGC 6910                                       %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10500                                                     %%%
# %%%                                                                                        %%%
# %%%    Harmeen Kaur, Saurabh Sharma, Lokesh K. Dewangan, Devendra K. Ojha, Alok Durgapa-    %%%
# %%%    l, & Neelam Panwar                                                                  %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    $K2$ Ultracool Dwarfs Survey. VI. White light superflares observed on an  L5 dwa-    %%%
# %%%    rf and flare rates of L dwarfs                                                      %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10579                                                     %%%
# %%%                                                                                        %%%
# %%%    Rishi R. Paudel, John E. Gizis, D. J. Mullan, Peter K. G. Williams, Adam J. Burg-    %%%
# %%%    asser, & Sarah J. Schmidt                                                           %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Systematic construction of upwind constrained transport schemes for MHD             %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10542                                                     %%%
# %%%                                                                                        %%%
# %%%    Andrea Mignone, & Luca Del Zanna                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Thermal convection in the crust of the dwarf planet (1) Ceres                       %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10504                                                     %%%
# %%%                                                                                        %%%
# %%%    M Formisano, C Federico, J Castillo-Rogez, M.C. De Sanctis, & G Magni               %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Dust Reverberation of 3C273: torus structure and lag -- luminosity  relation        %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10244                                                     %%%
# %%%                                                                                        %%%
# %%%    Catalina Sobrino Figaredo, Martin Haas, Michael Ramolla, Rolf Chini, Julia Blex,-    %%%
# %%%     Klaus-Werner Hodapp, Miguel Murphy, Wolfram Kollatschny, Doron Chelouche, & Sha-    %%%
# %%%    i Kaspi                                                                             %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Measuring Star Formation Histories, Distances, and Metallicities with  Pixel Col-    %%%
# %%%    or-Magnitude Diagrams II: Applications to Nearby Elliptical Galaxies                %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10213                                                     %%%
# %%%                                                                                        %%%
# %%%    B. A. Cook, Charlie Conroy, & Pieter van Dokkum                                     %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Intrinsic properties of the engine and jet that powered the short  gamma-ray bur-    %%%
# %%%    st associated with GW170817                                                         %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10210                                                     %%%
# %%%                                                                                        %%%
# %%%    Davide Lazzati, Riccardo Ciolfi, & Rosalba Perna                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Black Hole Shadow Observations with Space-Ground Interferometers                    %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10429                                                     %%%
# %%%                                                                                        %%%
# %%%    E. V. Mikheeva, S. V. Repin, & V. N. Lukash                                         %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Characterizing aperture masking interferometry in the near-infrared as  an effec-    %%%
# %%%    tive technique for astronomical imaging                                             %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10294                                                     %%%
# %%%                                                                                        %%%
# %%%    Kyle Morgenstein                                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['imbh']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Primordial Intermediate Mass Black Holes as Dark Matter                             %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10540                                                     %%%
# %%%                                                                                        %%%
# %%%    Paul H. Frampton                                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Gravitational wave constraints on the observable inflation                          %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10702                                                     %%%
# %%%                                                                                        %%%
# %%%    Erwin H. Tanin, & Tommi Tenkanen                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Radial-velocity variations due to meridional flows in the Sun and  solar-type st-    %%%
# %%%    ars: impact on exoplanet detectability                                              %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10611                                                     %%%
# %%%                                                                                        %%%
# %%%    Nadège Meunier, & Anne-Marie Lagrange                                               %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    A Model-Insensitive Baryon Acoustic Oscillation Feature in the 21 cm  Signal fro-    %%%
# %%%    m Reionization                                                                      %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10209                                                     %%%
# %%%                                                                                        %%%
# %%%    Christopher Cain, Anson D'Aloisio, Vid Iršič, Matthew McQuinn, & Hy Trac            %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    How to suppress exponential growth -- on the parametric resonance of  photons in-    %%%
# %%%     an axion background                                                                %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.01669                                                     %%%
# %%%                                                                                        %%%
# %%%    Ariel Arza, Thomas Schwetz, & Elisa Todarello                                       %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %% [markdown]
# for i in papers_keywords:
#     print(i,papers_keywords[i])

# %%
# ?arxivchecker.scrape_arxiv

# %%
papers_scrape_arxiv=arxivchecker.scrape_arxiv()

# %%
print(len(papers_keywords))
print()
# Out:
# 22

# %%
papers_keywords_ids=[]
for i in papers_keywords:
    print(i)
    papers_keywords_ids.append(i)
# Out:
# 2004.10406
# 2004.10230
# 2004.10372
# 2004.10552
# 2004.10665
# 2004.10591
# 2004.10452
# 2004.10735
# 2004.10500
# 2004.10579
# 2004.10542
# 2004.10504
# 2004.10244
# 2004.10213
# 2004.10210
# 2004.10429
# 2004.10294
# 2004.10540
# 2004.10702
# 2004.10611
# 2004.10209
# 2004.01669

# %%
len(papers_keywords_ids)
# Out:
# 22

# %%
# ?arxiv.query

# %%
if len(papers_keywords_ids)>0:
    arxiv.query(id_list=papers_keywords_ids,)

# %%
    with open('/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%d-%d-%d.txt'%(now.year,now.month,now.day),'a') as f:
        for paper_id in papers_keywords_ids:
            i=arxiv.query(id_list=['%s'%paper_id])[0] 
            f.write(i['id']+'\n'+i['title']+'\n'+i['author']+'\n'+i['updated']+'\n'+i['summary']+'\n'+'\n')
            #print(i,papers_keywords[i]) 
            print(i['id'],'loaded \n')
        
#!/usr/bin/python
# -*- coding: UTF-8 -*-
# Out:
# 	Checking http://arxiv.org/list/astro-ph/new
# Found 22 papers
# 12 hits
# ['agn', 'transient', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    SN2020bvc: a Broad-lined Type Ic Supernova with a Double-peaked Optical  Light C-    %%%
# %%%    urve and a Luminous X-ray and Radio Counterpart                                     %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10406                                                     %%%
# %%%                                                                                        %%%
# %%%    A. Y. Q. Ho, S. R. Kulkarni, D. A. Perley, S. B. Cenko, A. Corsi, S. Schulze, R.-    %%%
# %%%     Lunnan, J. Sollerman, A. Gal-Yam, S. Anand, C. Barbarino, E. Bellm, R. Bruch, E-    %%%
# %%%    . Burns, K. De, R. Dekany, A. Delacroix, D. Duev, C. Fremling, D. Goldstein, Z. -    %%%
# %%%    Golkhou, M. J. Graham, D. Hale, M. M. Kasliwal, T. Kupfer, R. Laher, J. Martikai-    %%%
# %%%    nen, F. J. Masci, J. D. Neill, B. Rusholme, D. L. Shupe, M. T. Soumagnac, N. L. -    %%%
# %%%    Strotjohann, K. Taggart, L. Tartaglia, L. Yan, & J. Zolkower                        %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 7 hits
# ['agn', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    The Star Formation in Radio Survey: 3 - 33 GHz Imaging of Nearby Galaxy  Nuclei -    %%%
# %%%    and Extranuclear Star-forming Regions                                               %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10230                                                     %%%
# %%%                                                                                        %%%
# %%%    S.T. Linden, E.J. Murphy, D. Dong, E. Momjian, R. C. Kennicutt Jr., D.S. Meier, -    %%%
# %%%    E. Schinnerer, & J.L. Turner                                                        %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 7 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    X-ray absorption and 9.7 um silicate feature as a probe of AGN torus  structure     %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10372                                                     %%%
# %%%                                                                                        %%%
# %%%    Jun Xu, Mouyuan Sun, Yongquan Xue, Junyao Li, & Zhicheng He                         %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 5 hits
# ['agn', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    The curious activity in the nucleus of NGC 4151: jet interaction causing  variab-    %%%
# %%%    ility?                                                                              %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10552                                                     %%%
# %%%                                                                                        %%%
# %%%    D. R. A. Williams, R. D. Baldi, I. M. McHardy, R. J. Beswick, F. Panessa, D. May-    %%%
# %%%    , J. Moldón, M. K. Argo, G. Bruni, B. T. Dullo, J. H. Knapen, E. Brinks, D. M. F-    %%%
# %%%    enech, C. G. Mundell, T. W. B. Muxlow, M. Pahari, & J. Westcott                     %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 4 hits
# ['transient']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    A Supernova Shock Break-out Candidate at z=0.092 in XMM-Newton Archival  Data       %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10665                                                     %%%
# %%%                                                                                        %%%
# %%%    G. Novara, P. Esposito, A. Tiengo, G. Vianello, R. Salvaterra, A. Belfiore, A. D-    %%%
# %%%    e Luca, P. D'Avanzo, J. Greiner, M. Scodeggio, S. Rosen, C. Delvaux, E. Pian, S.-    %%%
# %%%     Campana, G. Lisini, & S. Mereghetti                                                %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 4 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Search for magnetically-induced signatures in the arrival directions of  ultra-h-    %%%
# %%%    igh-energy cosmic rays measured at the Pierre Auger Observatory                     %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10591                                                     %%%
# %%%                                                                                        %%%
# %%%    The Pierre Auger Collaboration: A. Aab, P. Abreu, M. Aglietta, J.M. Albury, I. A-    %%%
# %%%    llekotte, A. Almela, J. Alvarez Castillo, J. Alvarez-Muñiz, R. Alves Batista, G.-    %%%
# %%%    A. Anastasi, L. Anchordoqui, B. Andrada, S. Andringa, C. Aramo, P.R. Araújo Ferr-    %%%
# %%%    eira, H. Asorey, P. Assis, G. Avila, A.M. Badescu, A. Bakalova, A. Balaceanu, F.-    %%%
# %%%     Barbato, R.J. Barreira Luz, K.H. Becker, J.A. Bellido, C. Berat, M.E. Bertaina,-    %%%
# %%%     X. Bertou, P.L. Biermann, T. Bister, J. Biteau, A. Blanco, J. Blazek, C. Bleve,-    %%%
# %%%     M. Boháčová, D. Boncioli, C. Bonifazi, L. Bonneau Arbeletche, N. Borodai, A.M. -    %%%
# %%%    Botti, J. Brack, T. Bretz, F.L. Briechle, P. Buchholz, A. Bueno, S. Buitink, M. -    %%%
# %%%    Buscemi, K.S. Caballero-Mora, L. Caccianiga, L. Calcagni, A. Cancio, F. Canfora,-    %%%
# %%%     I. Caracas, J.M. Carceller, R. Caruso, & A. Castellina, et al.                     %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 3 hits
# ['agn', 'transient']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    NuSTAR observation of the Supergiant Fast X-ray Transient IGR  J11215-5952 durin-    %%%
# %%%    g its 2017 outburst                                                                 %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10452                                                     %%%
# %%%                                                                                        %%%
# %%%    L. Sidoli, K. Postnov, A. Tiengo, P. Esposito, V. Sguera, A. Paizis, & G.A. Rodr-    %%%
# %%%    ıguez Castillo                                                                      %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 3 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Laboratory evidence for asymmetric accretion structure upon slanted  matter impa-    %%%
# %%%    ct in young stars                                                                   %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10735                                                     %%%
# %%%                                                                                        %%%
# %%%    K. Burdonov, G. Revet, R. Bonito, C. Argiroffi, J. Beard, S. Bolanos, M. Cerchez-    %%%
# %%%    , S.N. Chen, A. Ciardi, G. Espinosa, E. Fillipov, S. Pikuz, R. Rodriguez, M. Smi-    %%%
# %%%    d, M. Starodubtsev, O. Willi, S. Orlando, & J. Fuchs                                %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Unveiling the physical conditions in NGC 6910                                       %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10500                                                     %%%
# %%%                                                                                        %%%
# %%%    Harmeen Kaur, Saurabh Sharma, Lokesh K. Dewangan, Devendra K. Ojha, Alok Durgapa-    %%%
# %%%    l, & Neelam Panwar                                                                  %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn', 'radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    $K2$ Ultracool Dwarfs Survey. VI. White light superflares observed on an  L5 dwa-    %%%
# %%%    rf and flare rates of L dwarfs                                                      %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10579                                                     %%%
# %%%                                                                                        %%%
# %%%    Rishi R. Paudel, John E. Gizis, D. J. Mullan, Peter K. G. Williams, Adam J. Burg-    %%%
# %%%    asser, & Sarah J. Schmidt                                                           %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Systematic construction of upwind constrained transport schemes for MHD             %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10542                                                     %%%
# %%%                                                                                        %%%
# %%%    Andrea Mignone, & Luca Del Zanna                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Thermal convection in the crust of the dwarf planet (1) Ceres                       %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10504                                                     %%%
# %%%                                                                                        %%%
# %%%    M Formisano, C Federico, J Castillo-Rogez, M.C. De Sanctis, & G Magni               %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Dust Reverberation of 3C273: torus structure and lag -- luminosity  relation        %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10244                                                     %%%
# %%%                                                                                        %%%
# %%%    Catalina Sobrino Figaredo, Martin Haas, Michael Ramolla, Rolf Chini, Julia Blex,-    %%%
# %%%     Klaus-Werner Hodapp, Miguel Murphy, Wolfram Kollatschny, Doron Chelouche, & Sha-    %%%
# %%%    i Kaspi                                                                             %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Measuring Star Formation Histories, Distances, and Metallicities with  Pixel Col-    %%%
# %%%    or-Magnitude Diagrams II: Applications to Nearby Elliptical Galaxies                %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10213                                                     %%%
# %%%                                                                                        %%%
# %%%    B. A. Cook, Charlie Conroy, & Pieter van Dokkum                                     %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 2 hits
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Intrinsic properties of the engine and jet that powered the short  gamma-ray bur-    %%%
# %%%    st associated with GW170817                                                         %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10210                                                     %%%
# %%%                                                                                        %%%
# %%%    Davide Lazzati, Riccardo Ciolfi, & Rosalba Perna                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Black Hole Shadow Observations with Space-Ground Interferometers                    %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10429                                                     %%%
# %%%                                                                                        %%%
# %%%    E. V. Mikheeva, S. V. Repin, & V. N. Lukash                                         %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['radio']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Characterizing aperture masking interferometry in the near-infrared as  an effec-    %%%
# %%%    tive technique for astronomical imaging                                             %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10294                                                     %%%
# %%%                                                                                        %%%
# %%%    Kyle Morgenstein                                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['imbh']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Primordial Intermediate Mass Black Holes as Dark Matter                             %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10540                                                     %%%
# %%%                                                                                        %%%
# %%%    Paul H. Frampton                                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Gravitational wave constraints on the observable inflation                          %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10702                                                     %%%
# %%%                                                                                        %%%
# %%%    Erwin H. Tanin, & Tommi Tenkanen                                                    %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    Radial-velocity variations due to meridional flows in the Sun and  solar-type st-    %%%
# %%%    ars: impact on exoplanet detectability                                              %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10611                                                     %%%
# %%%                                                                                        %%%
# %%%    Nadège Meunier, & Anne-Marie Lagrange                                               %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    A Model-Insensitive Baryon Acoustic Oscillation Feature in the 21 cm  Signal fro-    %%%
# %%%    m Reionization                                                                      %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.10209                                                     %%%
# %%%                                                                                        %%%
# %%%    Christopher Cain, Anson D'Aloisio, Vid Iršič, Matthew McQuinn, & Hy Trac            %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 1 hit
# ['agn']
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%                                                                                        %%%
# %%%    How to suppress exponential growth -- on the parametric resonance of  photons in-    %%%
# %%%     an axion background                                                                %%%
# %%%                                                                                        %%%
# %%%    http://arxiv.org/abs/2004.01669                                                     %%%
# %%%                                                                                        %%%
# %%%    Ariel Arza, Thomas Schwetz, & Elisa Todarello                                       %%%
# %%%                                                                                        %%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# 22
#
# http://arxiv.org/abs/2004.10406v1 loaded
#
# http://arxiv.org/abs/2004.10230v1 loaded
#
# http://arxiv.org/abs/2004.10372v1 loaded
#
# http://arxiv.org/abs/2004.10552v1 loaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7d3a7bc244a1> in <module>()
#      23     with open('/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%s-%s-%s.txt'%(now.year,now.month,now.day),'a') as f:
#      24         for paper_id in papers_keywords:
# ---> 25             i=arxiv.query(id_list=['%s'%paper_id])[0]
#      26             f.write(i['id']+'\n'+i['title']+'\n'+i['author']+'\n'+i['updated']+'\n'+i['summary']+'\n'+'\n')
#      27             #print(i,papers_keywords[i])
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/arxiv/arxiv.py in query(query, id_list, prune, max_results, start, sort_by, sort_order, max_chunk_results, iterative)
#     223         max_chunk_results=max_chunk_results)
#     224
# --> 225     return search.download(iterative=iterative)
#     226
#     227
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/arxiv/arxiv.py in download(self, iterative)
#     201         else:
#     202             results = list()
# --> 203             for result in self._get_next():
#     204                 # Only append result if title is not empty
#     205                 results = results + result
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/arxiv/arxiv.py in _get_next(self)
#     157                 max_results=min(n_left, self.max_chunk_results))
#     158
# --> 159             results = self._parse(url)
#     160
#     161             # Update the entries left to download
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/arxiv/arxiv.py in _parse(self, url)
#      89         Downloads the data provided by the REST endpoint given in the url.
#      90         """
# ---> 91         result = feedparser.parse(url)
#      92
#      93         if result.get('status') != 200:
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/feedparser.py in parse(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers, response_headers)
#    3838         handlers = [handlers]
#    3839     try:
# -> 3840         f = _open_resource(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers)
#    3841         data = f.read()
#    3842     except Exception as e:
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/feedparser.py in _open_resource(url_file_stream_or_string, etag, modified, agent, referrer, handlers, request_headers)
#    2863         opener.addheaders = [] # RMK - must clear so we only send our custom User-Agent
#    2864         try:
# -> 2865             return opener.open(request)
#    2866         finally:
#    2867             opener.close() # JohnD
#
# /Users/brettlv/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /Users/brettlv/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /Users/brettlv/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Users/brettlv/anaconda3/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /Users/brettlv/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /Users/brettlv/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Users/brettlv/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/brettlv/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/brettlv/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
pwd

# %%
print(now)
# Out:
# 2020-04-23 12:11:29.499249

# %%
"arxiv-analysis-%d-%d-%d"%(now.year,now.month,now.day)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b28e62880866> in <module>()
# ----> 1 "arxiv-analysis-%d-%d-&d"%(now.year,now.month,now.day)
#
# TypeError: not all arguments converted during string formatting

# %%
#mkkneeuoshthbcjc 
my_sender='610721578@qq.com'    # 发件人邮箱账号
my_pass = 'tlejawmwdjzvbdcg'              # 发件人邮箱密码 授权
my_user='brettlv@icloud.com'      # 收件人邮箱账号，我这边发送给自己
#now = datetime.now() # 获取当前datetime
def mail():
    try:
        message = MIMEMultipart() 
        mail_msg = """ 
        <p>邮件内容,python email arxiv</p>
        <p>
        <a href="https://brettlv.github.io/">brettlv-github</a>      
        </p>"""
        
        #邮件正文内容
        text=MIMEText(mail_msg,'html','utf-8') 
        message.attach(text)
        
        # 构造附件1，传送当前目录下的 test.txt 文件
        att1 = MIMEText(open('/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%d-%d-%d.txt'%(now.year,now.month,now.day), 'rb').read(), 'base64', 'utf-8')
        att1["Content-Type"] = 'application/octet-stream'
        
        # 这里的filename可以任意写，写什么名字，邮件中显示什么名字
        att1["Content-Disposition"] = 'attachment; filename="arxiv-daily.txt"'
        message.attach(att1)
        
        # 构造附件2，传送当前目录下的 runoob.txt 文件
         
        message['From']=formataddr(["From brettlv",my_sender])  # 括号里的对应发件人邮箱昵称、发件人邮箱账号
        message['To']=formataddr(["FK",my_user])              # 括号里的对应收件人邮箱昵称、收件人邮箱账号
        message['Subject']="arxiv-analysis-%d-%d-%d"%(now.year,now.month,now.day)# 邮件的主题，也可以说是标题
        server=smtplib.SMTP_SSL("smtp.qq.com", 465)  # 发件人邮箱中的SMTP服务器，端口是25/465?
        #server.set_debugleverl(1)
        #server.ehlo("smtp.qq.com") 
        #server=smtplib.SMTP()
        #server.connect("smtp.qq.com",25)
        server.login(my_sender, my_pass)  # 括号中对应的是发件人邮箱账号、邮箱密码
        server.sendmail(my_sender,my_user,message.as_string())  # 括号中对应的是发件人邮箱账号、收件人邮箱账号、发送邮件
        server.quit()  # 关闭连接
        print("邮件发送成功")
    except smtplib.SMTPException as e:
        print("Error: 无法发送邮件",e)

if os.path.isfile('/Users/brettlv/blog/brettlv.github.io/pythoncode/arxiv-daily/arxiv-daily-%d-%d-%d.txt'%(now.year,now.month,now.day)):
    mail()
else:
    print('no paper found')
# Out:
# 邮件发送成功

# %% [markdown]
# # mail

# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
 
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr
from email.header import Header
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage

#mkkneeuoshthbcjc 
my_sender='610721578@qq.com'    # 发件人邮箱账号
my_pass = 'tlejawmwdjzvbdcg'              # 发件人邮箱密码 授权
my_user='brettlv@icloud.com'      # 收件人邮箱账号，我这边发送给自己
now = datetime.now() # 获取当前datetime




def mail():
    try:
        message = MIMEMultipart() 
        mail_msg = """ 
        <p>填写邮件内容,python email test</p><p>
        <a href="https://brettlv.github.io/">这是一个链接</a></p>"""
        #邮件正文内容
        text=MIMEText(mail_msg,'html','utf-8') 
        message.attach(text)
        
        # 构造附件1，传送当前目录下的 test.txt 文件
        att1 = MIMEText(open('filename.png', 'rb').read(), 'base64', 'utf-8')
        att1["Content-Type"] = 'application/octet-stream'
        
        # 这里的filename可以任意写，写什么名字，邮件中显示什么名字
        att1["Content-Disposition"] = 'attachment; filename="fig.png"'
        message.attach(att1)
        
        # 构造附件2，传送当前目录下的 runoob.txt 文件
'''     att2 = MIMEText(open('filename2.png', 'rb').read(), 'base64', 'utf-8')
        att2["Content-Type"] = 'application/octet-stream'
        # 这里的filename可以任意写，写什么名字，邮件中显示什么名字
        att2["Content-Disposition"] = 'attachment; filename="file.txt"'
        message.attach(att2)  
        '''      
        
        message['From']=formataddr(["From brettlv",my_sender])  # 括号里的对应发件人邮箱昵称、发件人邮箱账号
        message['To']=formataddr(["FK",my_user])              # 括号里的对应收件人邮箱昵称、收件人邮箱账号
        message['Subject']="arxiv-analysis-%d-%d-&d"%(now.year,now.month,now.day)# 邮件的主题，也可以说是标题
        server=smtplib.SMTP_SSL("smtp.qq.com", 465)  # 发件人邮箱中的SMTP服务器，端口是25/465?
        #server.set_debugleverl(1)
        #server.ehlo("smtp.qq.com") 
        #server=smtplib.SMTP()
        #server.connect("smtp.qq.com",25)
        server.login(my_sender, my_pass)  # 括号中对应的是发件人邮箱账号、邮箱密码
        server.sendmail(my_sender,my_user,message.as_string())  # 括号中对应的是发件人邮箱账号、收件人邮箱账号、发送邮件
        server.quit()  # 关闭连接
        print("邮件发送成功")
    except smtplib.SMTPException as e:
        print("Error: 无法发送邮件",e)
mail()
