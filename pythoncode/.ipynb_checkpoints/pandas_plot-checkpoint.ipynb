# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')

from scipy import integrate
import astropy
from astropy.time import Time

import pyfits
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.stats import LombScargle
import matplotlib.ticker as ticker

import numpy as np
from numpy import cov,corrcoef
import matplotlib.pyplot as plt
import astropy.units as u
from scipy.optimize import curve_fit
import scipy
import scipy.stats as stats
import pandas as pd
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

df
# Out:
#    age gender   name  num_children  num_pets       state
# 0   23      M   john             2         5  california
# 1   78      F   mary             0         1          dc
# 2   22      M  peter             0         0  california
# 3   19      M   jeff             3         5          dc
# 4   45      M   bill             2         2  california
# 5   33      F   lisa             1         2       texas
# 6   20      M   jose             4         3       texas

# %%
df.stack()
# Out:
# 0  age                     23
#    gender                   M
#    name                  john
#    num_children             2
#    num_pets                 5
#    state           california
# 1  age                     78
#    gender                   F
#    name                  mary
#    num_children             0
#    num_pets                 1
#    state                   dc
# 2  age                     22
#    gender                   M
#    name                 peter
#    num_children             0
#    num_pets                 0
#    state           california
# 3  age                     19
#    gender                   M
#    name                  jeff
#    num_children             3
#    num_pets                 5
#    state                   dc
# 4  age                     45
#    gender                   M
#    name                  bill
#    num_children             2
#    num_pets                 2
#    state           california
# 5  age                     33
#    gender                   F
#    name                  lisa
#    num_children             1
#    num_pets                 2
#    state                texas
# 6  age                     20
#    gender                   M
#    name                  jose
#    num_children             4
#    num_pets                 3
#    state                texas
# dtype: object

# %%
state=df[df['state']=='california']
state,df
# Out:
# (   age gender   name  num_children  num_pets       state
#  0   23      M   john             2         5  california
#  2   22      M  peter             0         0  california
#  4   45      M   bill             2         2  california,
#     age gender   name  num_children  num_pets       state
#  0   23      M   john             2         5  california
#  1   78      F   mary             0         1          dc
#  2   22      M  peter             0         0  california
#  3   19      M   jeff             3         5          dc
#  4   45      M   bill             2         2  california
#  5   33      F   lisa             1         2       texas
#  6   20      M   jose             4         3       texas)

# %%
dfstack=df.stack().unstack()
dfstack,df
# Out:
# (  age gender   name num_children num_pets       state
#  0  23      M   john            2        5  california
#  1  78      F   mary            0        1          dc
#  2  22      M  peter            0        0  california
#  3  19      M   jeff            3        5          dc
#  4  45      M   bill            2        2  california
#  5  33      F   lisa            1        2       texas
#  6  20      M   jose            4        3       texas,
#     age gender   name  num_children  num_pets       state
#  0   23      M   john             2         5  california
#  1   78      F   mary             0         1          dc
#  2   22      M  peter             0         0  california
#  3   19      M   jeff             3         5          dc
#  4   45      M   bill             2         2  california
#  5   33      F   lisa             1         2       texas
#  6   20      M   jose             4         3       texas)

# %%
def get_namelist(df,name):
    state=df[name]
    stateori=[]
    for i in state:
        if i not in stateori:
            stateori.append(i)
    return stateori
parax='num_children'
paray='num_pets'
paralist='state'
namelist=get_namelist(df,paralist)
namelist
# Out:
# ['california', 'dc', 'texas']

# %%
len(namelist)
# Out:
# 3

# %%
from matplotlib import colors as mcolors

colors=dict(mcolors.BASE_COLORS,**mcolors.CSS4_COLORS)
by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                for name, color in colors.items())
sorted_color_names = [name for hsv, name in by_hsv]

marker=['o','v','^','<','>','1','2','3','4','8','s','p','P','*','h','H','+','x','X','D','d','|','_']
color=['red','sandybrown','tan','gold','olivedrab','chartreuse','darkgreen','blue','m','skyblue','violet','crimson','aqua','purple','magenta','yellow','lime','turquoise','lightcyan','teal','lightblue','indigo','orchid']
print(len(colors),len(marker),len(color))
# Out:
# 156 23 23

# %%
#sorted_color_names

# %%
plt.figure()
for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=df[df[paralist]==i][parax]
    y=df[df[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i,s=(x+1)*20)
plt.plot(np.arange(5),np.arange(5)*0.8+1)
plt.xlabel(parax)
plt.ylabel(paray)
plt.title(paralist)
plt.legend(loc='center', bbox_to_anchor=(1.15, 0.5))
plt.grid()
plt.show()

# %%
state.drop_duplicates()
state
# Out:
# 0    california
# 1            dc
# 2    california
# 3            dc
# 4    california
# 5         texas
# 6         texas
# Name: state, dtype: object

# %%
Name=df['name'].map(str.upper)
Name
# Out:
# 0     JOHN
# 1     MARY
# 2    PETER
# 3     JEFF
# 4     BILL
# 5     LISA
# 6     JOSE
# Name: name, dtype: object

# %%
cali=df[df['state']=='california']
dc=df[df['state']=='dc']
texas=df[df['state']=='texas']
x=np.arange(5)
ax=plt.gca()
cali.plot.scatter(x='num_children',y='num_pets',marker='o',c='num_pets',s=cali['num_pets']*10,label=cali['state'][0],ax=ax)
dc.plot.scatter(x='num_children',y='num_pets',marker='s',label=dc['state'][1],ax=ax)
texas.plot.scatter(x='num_children',y='num_pets',marker='*',label=texas['state'][5],ax=ax)
plt.plot(x,x*0.8+1)
plt.show()

# %%
marker=['o','v','^','<','>','1','2','3','4','8','s','p','P','*','h','H','+','x','X','D','d','|','_']
color=['red','sandybrown','tan','gold','olivedrab','chartreuse','darkgreen','blue','m','skyblue','violet','crimson','aqua','purple','magenta','yellow','lime','turquoise','lightcyan','teal','lightblue','indigo']
marker=marker+marker+marker
color=color+color+color
print(len(marker),len(color))
# Out:
# 69 66

# %%
Lrx=pd.read_csv('lrlx_data.csv')
Lrx
# Out:
#                  Name Class            Lr        Lr_ler        Lr_uer  \
# 0            A0620-00    BH  2.415711e+26  3.279963e+25  3.279963e+25
# 1            A0620-00    BH  1.492718e+26  3.213025e+25  3.213025e+25
# 2       XTE J1118+480    BH  1.011442e+29  0.000000e+00  0.000000e+00
# 3       XTE J1118+480    BH  9.855076e+28  0.000000e+00  0.000000e+00
# 4       XTE J1118+480    BH  7.676585e+28  0.000000e+00  0.000000e+00
# 5       XTE J1118+480    BH  6.863974e+28  0.000000e+00  0.000000e+00
# 6       XTE J1118+480    BH  4.737352e+28  0.000000e+00  0.000000e+00
# 7       XTE J1118+480    BH  4.114926e+28  0.000000e+00  0.000000e+00
# 8       XTE J1118+480    BH  3.215867e+28  0.000000e+00  0.000000e+00
# 9       XTE J1118+480    BH  6.915843e+27  0.000000e+00  0.000000e+00
# 10      XTE J1118+480    BH  8.300000e+25  0.000000e+00  0.000000e+00
# 11      XTE J1118+480    BH  2.560000e+29  0.000000e+00  0.000000e+00
# 12      XTE J1118+480    BH  2.690000e+29  0.000000e+00  0.000000e+00
# 13      XTE J1118+480    BH  2.530000e+29  0.000000e+00  0.000000e+00
# 14      XTE J1118+480    BH  2.480000e+29  0.000000e+00  0.000000e+00
# 353  4.150000e+35  0.000000e+00  0.000000e+00  None
# 354  1.380000e+34  0.000000e+00  0.000000e+00  None
# 355  5.577914e+35  1.300000e+35  1.300000e+35  None
# 356  8.959912e+35  1.300000e+35  1.300000e+35  None
# 357  1.767378e+36  1.300000e+35  1.300000e+35  None
# 358  1.450000e+36  2.050000e+33  2.050000e+33    Lr
# 359  4.280000e+35  1.250000e+33  1.250000e+33    Lr
# 360  1.130000e+35  2.660000e+33  2.660000e+33    Lr
# 361  7.490000e+35  2.820000e+33  2.820000e+33    Lr
# 362  4.290000e+35  4.290000e+33  4.290000e+33    Lr
# 363  3.340000e+36  0.000000e+00  0.000000e+00    Lr
# 364  2.220000e+36  0.000000e+00  0.000000e+00    Lr
# 365  1.540000e+36  0.000000e+00  0.000000e+00    Lr
# 366  2.140000e+36  0.000000e+00  0.000000e+00    Lr
# 367  3.000000e+37  0.000000e+00  0.000000e+00    Lr
# 368  2.690000e+36  1.776000e+35  1.776000e+35  None
# 369  2.764000e+36  1.184000e+35  1.184000e+35  None
# 370  2.500000e+36  0.000000e+00  0.000000e+00    Lr
# 371  3.762255e+36  0.000000e+00  0.000000e+00  None
# 372  4.007675e+36  0.000000e+00  0.000000e+00  None
# 373  1.300000e+36  0.000000e+00  0.000000e+00  None
# 374  1.360000e+32  8.600000e+31  2.300000e+32  None
# 375  5.000000e+30  0.000000e+00  0.000000e+00  None
# 376  2.884000e+30  0.000000e+00  0.000000e+00  None
#
#                                                    Ref
# 0    Gallo et al. 2006, MNRAS, 370, 1351; Dincer et...
# 1    Gallo et al. 2006, MNRAS, 370, 1351; Dincer et...
# 2    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 3    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 4    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 5    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 6    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 7    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 8    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 9    Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 10   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 11   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 12   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 13   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 14   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 15   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 16   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 17   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 18   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 19   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 20   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 21   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 22   Fender et al. 2010, MNRAS, 406, 1425; Gallo et...
# 23                Corbel et al. 2013, MNRAS, 428, 2500
# 24                Corbel et al. 2013, MNRAS, 428, 2500
# 25                Corbel et al. 2013, MNRAS, 428, 2500
# 26                Corbel et al. 2013, MNRAS, 428, 2500
# 27                Corbel et al. 2013, MNRAS, 428, 2500
# 28                Corbel et al. 2013, MNRAS, 428, 2500
# 29                Corbel et al. 2013, MNRAS, 428, 2500
# ..                                                 ...
# 347                 Tudor et al. 2017, MNRAS, 470, 324
# 348                 Tudor et al. 2017, MNRAS, 470, 324
# 349                 Tudor et al. 2017, MNRAS, 470, 324
# 350                 Tudor et al. 2017, MNRAS, 470, 324
# 351                 Tudor et al. 2017, MNRAS, 470, 324
# 352                 Tudor et al. 2017, MNRAS, 470, 324
# 353                 Tudor et al. 2017, MNRAS, 470, 324
# 354                 Tudor et al. 2017, MNRAS, 470, 324
# 355                 Tudor et al. 2017, MNRAS, 470, 324
# 356                 Tudor et al. 2017, MNRAS, 470, 324
# 357                 Tudor et al. 2017, MNRAS, 470, 324
# 358                 Tudor et al. 2017, MNRAS, 470, 324
# 359                 Tudor et al. 2017, MNRAS, 470, 324
# 360                 Tudor et al. 2017, MNRAS, 470, 324
# 361                 Tudor et al. 2017, MNRAS, 470, 324
# 362                 Tudor et al. 2017, MNRAS, 470, 324
# 363                 Tudor et al. 2017, MNRAS, 470, 324
# 364                 Tudor et al. 2017, MNRAS, 470, 324
# 365                 Tudor et al. 2017, MNRAS, 470, 324
# 366  Miller-Jones et al., 2010, ATel, 2377; Tetaren...
# 367  Miller-Jones et al., 2010, ATel, 2377; Tetaren...
# 368                 Tetarenko et al. 2017, ATel, 10894
# 369                 Tetarenko et al. 2017, ATel, 10894
# 370                      Tudor et al. 2016, ATel, 8914
# 371             Migliari et al. 2011, MNRAS, 415, 2407
# 372             Migliari et al. 2011, MNRAS, 415, 2407
# 373  van den Eijnden et al. 2018, ATel, 11487; Stro...
# 374              Russell et al. 2016, MNRAS, 460, 3720
# 375  Eracleous et al. 1991, ApJ, 382, 290; Abada-Si...
# 376                 Marsh et al. 2016, Natur, 537, 374
#
# [377 rows x 10 columns]

# %%
def get_namelist(df,name):
    state=df[name]
    stateori=[]
    for i in state:
        if i not in stateori:
            stateori.append(i)
    return stateori
# Out:
# 48

# %%
parax='Lx'
paray='Lr'
paralist='Name'
namelistall=get_namelist(Lrx,paralist)
namelist=namelistall[:]
#namelist=['V 404 Cyg']
Lr15=np.array([1.43e29,3.47e28,2.72e28])
Lx15=np.array([3.89e34,8.27e33,9.92e33])
len(namelistall)

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=Lrx[Lrx[paralist]==i][parax]
    y=Lrx[Lrx[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i)#,s=(x+1)*20)
    plt.xscale('log')
    plt.yscale('log')
    
plt.plot(fit_x,fit_y)
plt.scatter(Lx15,Lr15,marker='^',color='y')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.75, 0.5),ncol=3)
plt.grid()
plt.show()

# %%
parax='Lx'
paray='Lr'
paralist='Name'
#namelistall=get_namelist(Lrx,paralist)
#namelist=namelistall[:]
namelist=['V 404 Cyg']
Lr15=np.array([1.43e29,3.47e28,2.72e28])
Lx15=np.array([3.89e34,8.27e33,9.92e33])
len(namelistall)

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=Lrx[Lrx[paralist]==i][parax]
    y=Lrx[Lrx[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i)#,s=(x+1)*20)
    plt.xscale('log')
    plt.yscale('log')
    
plt.plot(fit_x,fit_y)
plt.scatter(Lx15,Lr15,marker='^',color='y')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.15, 0.5),ncol=1)
plt.grid()
plt.show()

# %%
parax='Lx'
paray='Lr'
paralist='Class'
namelistall=get_namelist(Lrx,paralist)
print(len(namelistall))

namelist=namelistall[:]
#namelist=['V 404 Cyg']

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=Lrx[Lrx[paralist]==i][parax]
    y=Lrx[Lrx[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i)#,s=(x+1)*20)
    plt.xscale('log')
    plt.yscale('log')
    
plt.plot(fit_x,fit_y)
plt.scatter(Lx15,Lr15,marker='^',color='y')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.15, 0.5),ncol=1)
plt.grid()
plt.show()
# Out:
# 7

# %%
xc=dict(list(df.groupby('state')))['california']['num_children']
yc=dict(list(df.groupby('state')))['california']['num_pets']
xd=dict(list(df.groupby('state')))['dc']['num_children']
yd=dict(list(df.groupby('state')))['dc']['num_pets']
xt=dict(list(df.groupby('state')))['texas']['num_children']
yt=dict(list(df.groupby('state')))['texas']['num_pets']

# %%
df.plot.scatter(x='num_children',y='num_pets',label=df['state'])
plt.show()

# %%
plt.scatter(xc,yc,marker='o',label='california')
plt.scatter(xd,yd,marker='*',label='dc')
plt.scatter(xt,yt,marker='s',label='texas')
plt.legend()
plt.show()

# %%
# Out:
# (<pandas.core.groupby.SeriesGroupBy object at 0x110768320>,
#  <pandas.core.groupby.SeriesGroupBy object at 0x110768748>)

# %%
for num_c,num_p in df.groupby(df['state']):
    print(num_c,num_p)
# Out:
# california    age gender   name  num_children  num_pets       state
# 0   23      M   john             2         5  california
# 2   22      M  peter             0         0  california
# 4   45      M   bill             2         2  california
# dc    age gender  name  num_children  num_pets state
# 1   78      F  mary             0         1    dc
# 3   19      M  jeff             3         5    dc
# texas    age gender  name  num_children  num_pets  state
# 5   33      F  lisa             1         2  texas
# 6   20      M  jose             4         3  texas

# %%
ax=plt.gca()
df.plot(kind='bar',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)
plt.show()

# %%
#pd.read_excel
#pd.read_csv
#pd.set_option('precision',10)

# %%
mutime=pd.read_excel('HM Cnc 08h06m22.9s +15d27m31s.xlsx')
mutime
# Out:
#          date         Time(mjd)           P(s)       Mu(mHz)   Instrument  \
# 0   1994-1995  49648.9000000000  321.539300000  3.1100397000        ROSAT
# 1     2001-02  52226.2580000000  321.533520000  3.1100956000  VLT and NOT
# 2     2001-02  52281.4160000000  321.533140000  3.1100993000      VLT+NOT
# 3        2003  52619.0000000000  321.530382200  3.1101259900        Swift
# 4        2003  52645.4430000000  321.529570000  3.1101338000          NOT
# 5        2003  52649.5290000000  321.530070000  3.1101290000          NOT
# 6   2001-2004  53009.8899437530            NaN  3.1101382400      Chandra
# 7        2004  53009.8899437530            NaN  3.1101425000      Chandra
# 8   2003-2004  53030.3950000000  321.528320000  3.1101459000      INT+NOT
# 9     2005-06  53802.8044649643  321.518906100  3.1102370060      Chandra
# 10    2004all  53009.8824927000  321.528000000  3.1101426700    Chandrare
# 11    2009all  55185.8956688000  321.524000000  3.1101820100    Chandrare
# 12       2004  53314.7209522000            NaN  3.1101372600        XMMre
# 13       2017  58042.0414652300  321.492599585  3.1104915052    NICER03re
# 14       2017  58086.1210794300  321.510806607  3.1103153594    NICER07re
#
#            Paper Valid
# 0     Hakala2003   yes
# 1     Hakala2003   yes
# 2     Hakala2004   yes
# 3   Esposito2013   yes
# 4     Hakala2003   yes
# 5     Hakala2004   yes
# 6   Strohmayer05   yes
# 7   Strohmayer05   yes
# 8     Hakala2004   yes
# 9   Strohmayer08    no
# 10       reduced   yes
# 11       reduced   yes
# 12       reduced   yes
# 13       reduced    no
# 14       reduced   yes

# %%
filename=mutime
parax='Time(mjd)'
paray='Mu(mHz)'
paralist='Instrument'
namelistall=get_namelist(filename,paralist)
print(len(namelistall))

namelist=namelistall[:]
#namelist=['V 404 Cyg']

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=filename[filename[paralist]==i][parax]
    y=filename[filename[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i,s=100)#,s=(x+1)*20)
    plt.ylim(3.11,3.1106)
    #plt.xscale('log')
    #plt.yscale('log')
    
#plt.plot(fit_x,fit_y)
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.2, 0.5),ncol=1)
plt.grid()
plt.savefig('MutimeofHMCNC_instrument.png')
plt.show()
# Out:
# 11

# %%
filename=mutime
parax='Time(mjd)'
paray='Mu(mHz)'
paralist='Paper'
namelistall=get_namelist(filename,paralist)
print(len(namelistall))

namelist=namelistall[:]
#namelist=['V 404 Cyg']

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=filename[filename[paralist]==i][parax]
    y=filename[filename[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i,s=100)#,s=(x+1)*20)
    plt.ylim(3.11,3.1106)
    #plt.xscale('log')
    #plt.yscale('log')
    
#plt.plot(fit_x,fit_y)
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.2, 0.5),ncol=1)
plt.grid()
plt.savefig('MutimeofHMCNC_paper.png')
plt.show()
# Out:
# 6

# %%
filename=mutime
parax='Time(mjd)'
paray='Mu(mHz)'
paralist='Valid'
namelistall=get_namelist(filename,paralist)
print(len(namelistall))

namelist=namelistall[:]
#namelist=['V 404 Cyg']

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=filename[filename[paralist]==i][parax]
    y=filename[filename[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,label=i,s=50)#,s=(x+1)*20)
    plt.ylim(3.11,3.1106)
    #plt.xscale('log')
    #plt.yscale('log')
    
#plt.plot(fit_x,fit_y)
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.2, 0.5),ncol=1)
plt.grid()
plt.savefig('MutimeofHMCNC_valid.png')
plt.show()
# Out:
# 2

# %%
def mudotdottime(t,mudot,muzero,mudotdot):
    #mudotdot=0
    tzero=t[0]
    return muzero+(t-tzero)*mudot*86400+0.5*mudotdot*(t-tzero)**2*86400**2


def mudottime(t,mudot,muzero):
    #mudotdot=0
    tzero=t[0]
    return muzero+(t-tzero)*mudot*86400

# %%
filename=mutime
parax='Time(mjd)'
paray='Mu(mHz)'
paralist='Valid'
namelistall=get_namelist(filename,paralist)
namelist=['yes']

plt.figure()
fit_x=np.logspace(30,38,base=10)
fit_y=pow(fit_x,0.61)*pow(10,29.65+0.15-0.61*36.32)

for i,m,c,in zip(namelist,marker[:len(namelist)],color[:len(namelist)]):
    x=filename[filename[paralist]==i][parax]
    y=filename[filename[paralist]==i][paray]
    plt.scatter(x,y,marker=m,color=c,s=50)#,s=(x+1)*20)
    plt.ylim(3.11,3.1104)
    #plt.xscale('log')
    #plt.yscale('log')
#plt.plot(fit_x,fit_y)
plt.xlabel(parax)
plt.ylabel(paray)
plt.title('%s vs %s'%(paray,parax))
plt.legend(loc='center', bbox_to_anchor=(1.2, 0.5),ncol=1)
plt.grid(True)
plt.savefig('MutimeofHMCNC_fit.png')
plt.show()

# %%
x=filename[filename[paralist]=='yes'][parax]
y=filename[filename[paralist]=='yes'][paray]

# %%
# Out:
# 49648.900000000001

# %%
def mudotdottime(t,mudot,muzero,mudotdot):
    #mudotdot=0
    tzero=t[0]
    return muzero+(t-tzero)*mudot*86400+0.5*mudotdot*(t-tzero)**2*86400**2

def mudottime(t,mudot,muzero):
    #mudotdot=0
    tzero=t[0]
    return muzero+(t-tzero)*mudot*86400

# %%
popt,pcov=curve_fit(mudottime,x,y)
perr=np.sqrt(np.diag(pcov))
print('mudot_mHz',popt[0])
print('muzero_mHz',popt[1],'t_zero',x[0])
print('error',perr)
t=np.linspace(49000,59000,100)
tfit=popt[1]+(t-x[0])*popt[0]*86400

plt.scatter(x,y,s=10,c='b',marker='.')
plt.plot(t,tfit)
plt.ylim(3.11,3.1104)
plt.xlabel("TIME/MJD")
plt.ylabel("FREQ/Hz")
plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.8f'))
# Out:
# mudot_mHz 3.72763755637e-13
# muzero_mHz 3.11002838101 t_zero 49648.9
# error [  2.21510634e-14   7.52522504e-06]

# %%
popt,pcov=curve_fit(mudotdottime,x,y)
perr=np.sqrt(np.diag(pcov))
print('mudot_mHz',popt[0])
print('muzero_mHz',popt[1],'t_zero',x[0])
print('mudotdot_mHz',popt[2])

print('error',perr)
t=np.linspace(49000,59000,100)
tfit=popt[1]+(t-x[0])*popt[0]*86400+0.5*popt[2]*(t-x[0])**2*86400**2

plt.scatter(x,y,s=10,c='b',marker='.')
plt.plot(t,tfit)
plt.ylim(3.11,3.1104)
plt.xlabel("TIME/MJD")
plt.ylabel("FREQ/Hz")
plt.gca().xaxis.set_major_formatter(ticker.FormatStrFormatter('%.1f'))
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('%.8f'))
# Out:
# mudot_mHz 2.83936445333e-13
# muzero_mHz 3.11004187295 t_zero 49648.9
# mudotdot_mHz 2.29450886747e-22
# error [  6.15523757e-14   1.13021004e-05   1.49567981e-22]
