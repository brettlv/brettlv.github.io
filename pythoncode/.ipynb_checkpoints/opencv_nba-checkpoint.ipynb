# %%
pwd
# Out:
# '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/logonba'

# %%
import numpy as np
import cv2

# %%
cv2.imread(path, flags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-56572af738f5> in <module>()
# ----> 1 cv2.imread(path, flags)
#
# NameError: name 'path' is not defined

# %%
ls *.png
# Out:
# 0.png                         curve03.png
# 1.png                         curve04.png
# 10.png                        curve05.png
# 11.png                        curve06.png
# 12.png                        curve07.png
# 13.png                        curveall.png
# 14.png                        fit_bb.png
# 15.png                        gwpytest01.png
# 16.png                        high_state_HID_down.png
# 17.png                        high_state_HID_updown.png
# 17696.png                     lovecurve.png
# 17697.png                     low_state_HID_less100.png
# 18.png                        low_state_HID_less1000.png
# 19.png                        low_state_HID_less200.png
# 2.png                         low_state_HID_less500.png
# 3.png                         mid_state_HID_downup.png
# 4.png                         testls.png
# 5.png                         total_HID.png
# 6.png                         total_HID_1.png
# 7.png                         triangle.png
# 8.png                         v404_0620_lc.png
# 9.png                         v404_0620_lc_left.png
# Bfrac.png                     v404_0620_lc_right.png
# FIRST_range.png               v404_0620_pds.png
# MutimeofHMCNC_fit.png         v404_0620_pds_left.png
# MutimeofHMCNC_instrument.png  v404_0620_pds_right.png
# MutimeofHMCNC_paper.png       v404_0622.png
# MutimeofHMCNC_valid.png       v404_0622_lc.png
# bb.png                        v404_0622_pds.png
# curve01.png                   v404_062526_lc.png
# curve02.png                   v404_062526_pds.png

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('bb.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # 隐藏x、y轴
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-61d480f30119> in <module>()
#       4
#       5 img = cv2.imread('bb.jpg',0)
# ----> 6 plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#       7 plt.xticks([]), plt.yticks([])  # 隐藏x、y轴
#       8 plt.show()
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3156                         filternorm=filternorm, filterrad=filterrad,
#    3157                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3158                         **kwargs)
#    3159     finally:
#    3160         ax._hold = washold
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5116                               resample=resample, **kwargs)
#    5117
# -> 5118         im.set_data(X)
#    5119         im.set_alpha(alpha)
#    5120         if im.get_clip_path() is None:
#
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     543         if (self._A.dtype != np.uint8 and
#     544                 not np.can_cast(self._A.dtype, np.float)):
# --> 545             raise TypeError("Image data can not convert to float")
#     546
#     547         if (self._A.ndim not in (2, 3) or
#
# TypeError: Image data can not convert to float

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt


from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,AnnotationBbox)
from matplotlib.cbook import get_sample_data
import os
import skimage.io as io
from skimage import data_dir

# %%
lalor=data[data['Team']=='Los Angeles Lakers']['ORtg']
laldr=data[data['Team']=='Los Angeles Lakers']['DRtg']

# %%
print(lalor)
print(laldr)
# Out:
# 13    108.67
# Name: ORtg, dtype: float64
# 13    107.99
# Name: DRtg, dtype: float64

# %%
teamname=(data['Team'])
print(teamname)
# Out:
# 0            Milwaukee Bucks
# 1             Denver Nuggets
# 2            Toronto Raptors
# 3       Los Angeles Clippers
# 4      Oklahoma City Thunder
# 5      Golden State Warriors
# 6             Boston Celtics
# 7     Portland Trail Blazers
# 8          Charlotte Hornets
# 9             Indiana Pacers
# 10        Philadelphia 76ers
# 11         Memphis Grizzlies
# 12      New Orleans Pelicans
# 13        Los Angeles Lakers
# 14          Dallas Mavericks
# 15    Minnesota Timberwolves
# 16           Houston Rockets
# 17           Detroit Pistons
# 18                 Utah Jazz
# 19          Sacramento Kings
# 20             Orlando Magic
# 21             Brooklyn Nets
# 22                Miami Heat
# 23         San Antonio Spurs
# 24        Washington Wizards
# 25           New York Knicks
# 26              Phoenix Suns
# 27             Chicago Bulls
# 28       Cleveland Cavaliers
# 29             Atlanta Hawks
# Name: Team, dtype: object

# %%
from lxml.html import parse
from urllib.request import urlopen
from pandas.io.parsers import TextParser
from pandas import Series
import urllib,requests
import pandas as pd
from bs4 import BeautifulSoup


url_nba='https://stats.nba.com/teams/advanced/?sort=W&dir=-1'
url_nba='https://www.basketball-reference.com/leagues/NBA_2019_ratings.html'
#url_laker='https://www.basketball-reference.com/teams/LAL/2019.html'

# %%
def _unpack(row,kind='td'):
    elts=row.findall('.//%s' %kind)
    return [val.text_content() for val in elts]

def parse_options_data(table):
    rows=table.findall('.//tr')
    header=_unpack(rows[0],kind='th')
    data=[_unpack(r) for r in rows[1:]]
    #return data
    return TextParser(data,names=header).get_chunk()

# %%
parsedurl=parse(urlopen(url_nba))
url=parsedurl.getroot()
tables=url.findall('.//table')
url_link_pos_all=url.findall('.//a')

# %%
links=url.findall('.//a')
urls=[lnk.get('href') for lnk in url_link_pos_all]

# %%
end=tables[0]
rows=end.findall('.//tr')
header=_unpack(rows[1],kind='th')
print(header)
data=[_unpack(r) for r in rows[2:]]
data=TextParser(data,names=header[1:]).get_chunk()
# Out:
# ['Rk', 'Team', 'Conf', 'Div', 'W', 'L', 'W/L%', 'MOV', 'ORtg', 'DRtg', 'NRtg', 'MOV/A', 'ORtg/A', 'DRtg/A', 'NRtg/A']

# %%
data
# Out:
#                       Team Conf Div   W   L   W/L%    MOV    ORtg    DRtg  \
# 0          Milwaukee Bucks    E   C  15   6  0.714  10.67  116.18  106.30
# 1           Denver Nuggets    W  NW  15   7  0.682   7.68  113.03  105.30
# 2          Toronto Raptors    E   A  19   4  0.826   8.65  116.38  107.78
# 3     Los Angeles Clippers    W   P  15   6  0.714   5.29  114.50  109.27
# 4    Oklahoma City Thunder    W  NW  14   7  0.667   6.43  109.12  102.75
# 5    Golden State Warriors    W   P  15   8  0.652   4.96  115.82  110.98
# 6           Boston Celtics    E   A  12  10  0.545   4.18  108.18  104.14
# 7   Portland Trail Blazers    W  NW  13   9  0.591   1.91  112.78  110.47
# 8        Charlotte Hornets    E  SE  11  11  0.500   4.32  113.84  109.45
# 9           Indiana Pacers    E   C  13   9  0.591   3.73  109.05  105.13
# 10      Philadelphia 76ers    E   A  16   8  0.667   2.13  110.68  108.65
# 11       Memphis Grizzlies    W  SW  13   8  0.619   1.76  108.19  106.50
# 12    New Orleans Pelicans    W  SW  11  12  0.478   1.26  113.57  112.35
# 13      Los Angeles Lakers    W   P  13   9  0.591   0.68  108.67  107.99
# 14        Dallas Mavericks    W  SW  10  10  0.500   1.85  110.42  108.49
# 15  Minnesota Timberwolves    W  NW  11  11  0.500  -0.32  109.97  110.24
# 16         Houston Rockets    W  SW  10  11  0.476  -0.48  113.33  113.73
# 17         Detroit Pistons    E   C  12   7  0.632   2.05  109.88  107.70
# 18               Utah Jazz    W  NW  11  12  0.478  -2.30  106.43  108.98
# 19        Sacramento Kings    W   P  10  11  0.476  -3.00  109.34  112.24
# 20           Orlando Magic    E  SE  11  12  0.478  -2.30  107.60  109.90
# 21           Brooklyn Nets    E   A   8  15  0.348  -1.96  110.58  112.58
# 22              Miami Heat    E  SE   8  13  0.381  -1.57  107.36  109.05
# 23       San Antonio Spurs    W  SW  10  12  0.455  -3.59  109.63  113.48
# 24      Washington Wizards    E  SE   8  14  0.364  -6.27  108.89  114.96
# 25         New York Knicks    E   A   7  16  0.304  -5.91  107.58  113.43
# 26            Phoenix Suns    W   P   4  18  0.182 -10.14  103.83  113.87
# 27           Chicago Bulls    E   C   5  18  0.217  -9.30  102.06  111.14
# 28     Cleveland Cavaliers    E   C   4  17  0.190  -8.19  107.15  115.67
# 29           Atlanta Hawks    E  SE   5  18  0.217 -10.65  102.22  112.24
#
#      NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A
# 0    9.88  11.58  116.58  105.75   10.83
# 1    7.74   8.10  113.28  105.18    8.10
# 2    8.60   7.52  116.07  108.62    7.46
# 3    5.23   5.60  114.36  108.79    5.57
# 4    6.37   5.28  107.25  102.01    5.25
# 5    4.84   4.91  115.89  111.10    4.79
# 6    4.04   4.24  108.41  104.30    4.11
# 7    2.31   3.24  113.25  109.66    3.59
# 8    4.39   3.36  114.80  111.38    3.42
# 9    3.91   2.27  108.36  105.95    2.42
# 10   2.02   1.49  110.33  108.94    1.39
# 11   1.69   1.43  107.77  106.45    1.32
# 12   1.22   1.04  113.20  112.20    1.00
# 13   0.68   0.40  108.37  107.92    0.45
# 14   1.93   0.35  110.51  110.08    0.43
# 15  -0.28   0.20  109.63  109.44    0.19
# 16  -0.41  -0.24  113.42  113.58   -0.16
# 17   2.18  -0.32  108.69  108.86   -0.18
# 18  -2.55  -0.67  107.26  108.18   -0.93
# 19  -2.90  -1.75  110.54  112.26   -1.71
# 20  -2.29  -1.94  107.12  109.05   -1.93
# 21  -2.00  -2.35  110.08  112.47   -2.39
# 22  -1.68  -3.14  106.45  109.59   -3.13
# 23  -3.85  -3.45  109.55  113.25   -3.70
# 24  -6.06  -5.37  108.61  113.76   -5.15
# 25  -5.85  -5.82  108.26  113.99   -5.72
# 26 -10.04  -8.03  105.74  113.75   -8.00
# 27  -9.08  -8.41  101.90  110.12   -8.23
# 28  -8.52  -8.09  108.09  116.42   -8.33
# 29 -10.02 -10.34  102.31  112.02   -9.71

# %%
pwd
# Out:
# '/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/lakerplayer'

# %%
ls *.csv
# Out:
# ls: *.csv: No such file or directory

# %%
data.to_csv('/Users/brettlv/blog/brettlv.github.io/pythoncode/nba.csv')

# %%
data
# Out:
#                       Team Conf Div   W   L   W/L%    MOV    ORtg    DRtg  \
# 0          Milwaukee Bucks    E   C  15   6  0.714  10.67  116.18  106.30
# 1           Denver Nuggets    W  NW  15   7  0.682   7.68  113.03  105.30
# 2          Toronto Raptors    E   A  19   4  0.826   8.65  116.38  107.78
# 3     Los Angeles Clippers    W   P  15   6  0.714   5.29  114.50  109.27
# 4    Oklahoma City Thunder    W  NW  14   7  0.667   6.43  109.12  102.75
# 5    Golden State Warriors    W   P  15   8  0.652   4.96  115.82  110.98
# 6           Boston Celtics    E   A  12  10  0.545   4.18  108.18  104.14
# 7   Portland Trail Blazers    W  NW  13   9  0.591   1.91  112.78  110.47
# 8        Charlotte Hornets    E  SE  11  11  0.500   4.32  113.84  109.45
# 9           Indiana Pacers    E   C  13   9  0.591   3.73  109.05  105.13
# 10      Philadelphia 76ers    E   A  16   8  0.667   2.13  110.68  108.65
# 11       Memphis Grizzlies    W  SW  13   8  0.619   1.76  108.19  106.50
# 12    New Orleans Pelicans    W  SW  11  12  0.478   1.26  113.57  112.35
# 13      Los Angeles Lakers    W   P  13   9  0.591   0.68  108.67  107.99
# 14        Dallas Mavericks    W  SW  10  10  0.500   1.85  110.42  108.49
# 15  Minnesota Timberwolves    W  NW  11  11  0.500  -0.32  109.97  110.24
# 16         Houston Rockets    W  SW  10  11  0.476  -0.48  113.33  113.73
# 17         Detroit Pistons    E   C  12   7  0.632   2.05  109.88  107.70
# 18               Utah Jazz    W  NW  11  12  0.478  -2.30  106.43  108.98
# 19        Sacramento Kings    W   P  10  11  0.476  -3.00  109.34  112.24
# 20           Orlando Magic    E  SE  11  12  0.478  -2.30  107.60  109.90
# 21           Brooklyn Nets    E   A   8  15  0.348  -1.96  110.58  112.58
# 22              Miami Heat    E  SE   8  13  0.381  -1.57  107.36  109.05
# 23       San Antonio Spurs    W  SW  10  12  0.455  -3.59  109.63  113.48
# 24      Washington Wizards    E  SE   8  14  0.364  -6.27  108.89  114.96
# 25         New York Knicks    E   A   7  16  0.304  -5.91  107.58  113.43
# 26            Phoenix Suns    W   P   4  18  0.182 -10.14  103.83  113.87
# 27           Chicago Bulls    E   C   5  18  0.217  -9.30  102.06  111.14
# 28     Cleveland Cavaliers    E   C   4  17  0.190  -8.19  107.15  115.67
# 29           Atlanta Hawks    E  SE   5  18  0.217 -10.65  102.22  112.24
#
#      NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A
# 0    9.88  11.58  116.58  105.75   10.83
# 1    7.74   8.10  113.28  105.18    8.10
# 2    8.60   7.52  116.07  108.62    7.46
# 3    5.23   5.60  114.36  108.79    5.57
# 4    6.37   5.28  107.25  102.01    5.25
# 5    4.84   4.91  115.89  111.10    4.79
# 6    4.04   4.24  108.41  104.30    4.11
# 7    2.31   3.24  113.25  109.66    3.59
# 8    4.39   3.36  114.80  111.38    3.42
# 9    3.91   2.27  108.36  105.95    2.42
# 10   2.02   1.49  110.33  108.94    1.39
# 11   1.69   1.43  107.77  106.45    1.32
# 12   1.22   1.04  113.20  112.20    1.00
# 13   0.68   0.40  108.37  107.92    0.45
# 14   1.93   0.35  110.51  110.08    0.43
# 15  -0.28   0.20  109.63  109.44    0.19
# 16  -0.41  -0.24  113.42  113.58   -0.16
# 17   2.18  -0.32  108.69  108.86   -0.18
# 18  -2.55  -0.67  107.26  108.18   -0.93
# 19  -2.90  -1.75  110.54  112.26   -1.71
# 20  -2.29  -1.94  107.12  109.05   -1.93
# 21  -2.00  -2.35  110.08  112.47   -2.39
# 22  -1.68  -3.14  106.45  109.59   -3.13
# 23  -3.85  -3.45  109.55  113.25   -3.70
# 24  -6.06  -5.37  108.61  113.76   -5.15
# 25  -5.85  -5.82  108.26  113.99   -5.72
# 26 -10.04  -8.03  105.74  113.75   -8.00
# 27  -9.08  -8.41  101.90  110.12   -8.23
# 28  -8.52  -8.09  108.09  116.42   -8.33
# 29 -10.02 -10.34  102.31  112.02   -9.71

# %%
file_dir='/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/logonba'
#imgslist=os.listdir(file_dir)
os.chdir(file_dir)
coll=io.ImageCollection(file_dir+'/*')
#print(coll)
#plt.figure(figsize=(16,16))
fig, ax = plt.subplots(figsize=(16,16))
#x=np.random.randint(50,120,30)
#x=np.linspace(50,200,30)
#y=np.random.randint(80,150,30)
#y=np.linspace(50,200,30)

x=data.sort_values('Team')['ORtg'].values
y=data.sort_values('Team')['DRtg'].values
print(min(x),max(x),min(y),max(y))
print(np.average(x),np.average(y))

for i,(logo_,x_,y_) in enumerate(zip(coll,x,y)):
    imagebox = OffsetImage(logo_, zoom=0.4)
    imagebox.image.axes = ax
    ab = AnnotationBbox(imagebox,xy = [x_,y_],xycoords='data',pad=0.0,)
    ax.add_artist(ab)
    
#img=Image.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/logonba/los-angeles-lakers-logo-vector-200x200.png')
#arr_img=plt.imread('/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/logonba/los-angeles-lakers-logo-vector-200x200.png',format='png')
#imagebox = OffsetImage(img, zoom=0.2)
#imagebox = OffsetImage(arr_img, zoom=0.3)
#imagebox.image.axes = ax
#ab = AnnotationBbox(imagebox,xy = [100,120],xycoords='data',pad=0.0,)
#ax.add_artist(ab)

ax.plot(x,y,'o')
ax.plot(np.linspace(100,120,10),np.linspace(100,120,10))
plt.vlines(np.average(x),100,120)
plt.hlines(np.average(y),100,120)
plt.xlim(100,120)
plt.ylim(120,100)
plt.xlabel('Offensive_rating')
plt.ylabel('Defensive_rating')
plt.text(117,102,"Good_Offense_Good_defense")
plt.text(104,102,"Bad_Offense_Good_defense")
plt.text(104,117,"Bad_Offense_Bad_defense")
plt.text(117,112,"Good_Offense_Bad_defense")
plt.title("Offense_VS_Defense_1201")
plt.grid()
plt.savefig('/Users/brettlv/nba_12_01.png',dpi=300)
plt.show()
# Out:
# 102.06 116.38 102.75 115.67
# 109.875333333 109.825333333
