# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyfits

from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

# %%
def get_lc_path(path):   
    lightcurve=pyfits.open(path)
    #barylc=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/RX_J0806/nicer/bary01.lc')
    header=lightcurve[0].header
    print('originlc:')
    print(repr(header[:]),'\n')
    obstime=header['DATE-OBS']
    time=lightcurve[1].data['TIME']
    count=lightcurve[1].data['RATE']
    plt.plot(time,count)
    plt.xticks(np.arange(0,time[-1]+1000,1000),rotation=30)
    return time,count,obstime

# %%
def get_interval_time(time):
    size=len(time)
    index=[]
    index1=[0]
    for i in np.arange(len(time)-1):
        if time[i+1]-time[i]>20:
            index.append(i)
            index1.append(i+1)
    index.append(len(time)-1)        
    return time[index],time[index1]

# %%
def lc_pds(time,count,timemin,timemax):
    t=[]
    x=[]
    for index,(t_,c_) in enumerate(zip(time,count)):
        if (t_>=timemin and t_<timemax):
            t.append(t_)
            x.append(c_)   
    xF = np.fft.fft(x)
    freq = np.fft.fftfreq(len(t))
    ls = LombScargle(t, x)
    freq_ls, power_ls = ls.autopower(normalization='standard',
                           minimum_frequency=0,
                           maximum_frequency=0.5,
                           samples_per_peak=10)
    plt.figure(figsize=(6,6))
    plt.subplot(311)
    plt.title('%s:from %d to %d'%(obstime,t[0],t[-1]))
    plt.plot(t,x)
    #plt.xticks(np.arange(0,t[-1]+1000,1000),rotation=30)
    #plt.semilogy()
    plt.xlabel('time')
    plt.ylabel('count')
    plt.subplot(312)
    plt.plot(freq,abs(xF)**2)
    plt.semilogx()
    plt.semilogy()
    plt.ylabel('power/fft')
    plt.subplot(313)
    plt.plot(freq_ls,power_ls)
    plt.semilogx()
    plt.semilogy()
    plt.xlabel('frequency/Hz')
    plt.ylabel('power/ls')
    plt.tight_layout()

# %%
def get_lc__pds_path(path):   
    lightcurve=pyfits.open(path)
    #barylc=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/RX_J0806/nicer/bary01.lc')
    header=lightcurve[0].header
    obstime=header['DATE-OBS']
    time=lightcurve[1].data['TIME']
    count=lightcurve[1].data['RATE']
    indexleft,indexright=get_interval_time(time)
    for i,(indexleft_,indexright_) in enumerate(zip(indexleft,indexright)):
        print(i,indexright_,indexleft_)
        lc_pds(time,count,indexright_,indexleft_)

# %%
lc_pds(time,count,timemin=min(time),timemax=max(time))

# %%
path='/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0622/00031403049_xrt/src.lc'
time,count,obstime=get_lc_path(path)
get_lc__pds_path(path)
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 2.995764524579048E+03 / On-source time
# DEADC   =       9.98336375E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 2.990780695101886E+03 / Exposure time
# LIVETIME= 2.990780695101886E+03 / Deadtime corrected on-source time
# DATE-OBS= '2015-06-22T08:32:24' / Start date of observations
# DATE-END= '2015-06-22T13:14:44' / End date of observations
# TSTART  = 4.566547471708292E+08 / time start
# TSTOP   = 4.566716870006002E+08 / time stop
# TELAPSE = 1.693982977098227E+04 / elapsed time
# MJD-OBS = 5.719535661290312E+04 / MJD of data start time
# MJDREFI =                51910 / MJD reference day
# MJDREFF = 7.428703700000000E-04 / MJD reference (fraction of day)
# TIMEREF = 'LOCAL   '           / reference time
# TIMESYS = 'TT      '           / time measured from
# TIMEUNIT= 's       '           / unit for time keywords
# EQUINOX =            2.000E+03 / Equinox of celestial coord system
# RADECSYS= 'FK5     '           / celestial coord system
# USER    = 'brett   '           / User name of creator
# FILIN001= 'sw00031403049xwtw2po_cl.evt' / Input file name
# CREATOR = 'extractor v5.32'    / Extractor version
# DATE    = '2018-11-12T08:15:32' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'NASA/GSFC'          / origin of fits file
# TIMEDEL = 1.000000000000000E+00 / Binning factor
# HISTORY extractor v5.32
# CHECKSUM= 'MqPcMnObMnObMnOb'   / HDU checksum updated 2018-11-12T08:15:32
# DATASUM = '         0'         / data unit checksum updated 2018-11-12T08:15:32
#
# 0 0.0 214.0
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/astropy/stats/lombscargle/implementations/fast_impl.py:93: RuntimeWarning: invalid value encountered in true_divide
#   tan_2omega_tau = (S2 - 2 * S * C) / (C2 - (C * C - S * S))
# 1 5017.0 5193.0
# 2 9815.0 10714.0
# 3 11767.0 12093.0
# 4 15560.0 16939.0

# %%
path='/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0622/00031403047_xrt/src.lc'
time,count,obstime=get_lc_path(path)
get_lc__pds_path(path)
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 1.912410204529762E+03 / On-source time
# DEADC   =       9.98335183E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 1.909226390873032E+03 / Exposure time
# LIVETIME= 1.909226390873032E+03 / Deadtime corrected on-source time
# DATE-OBS= '2015-06-22T09:59:31' / Start date of observations
# DATE-END= '2015-06-22T11:47:57' / End date of observations
# TSTART  = 4.566599740374190E+08 / time start
# TSTOP   = 4.566664791997460E+08 / time stop
# TELAPSE = 6.505162326931953E+03 / elapsed time
# MJD-OBS = 5.719541710904420E+04 / MJD of data start time
# MJDREFI =                51910 / MJD reference day
# MJDREFF = 7.428703700000000E-04 / MJD reference (fraction of day)
# TIMEREF = 'LOCAL   '           / reference time
# TIMESYS = 'TT      '           / time measured from
# TIMEUNIT= 's       '           / unit for time keywords
# EQUINOX =            2.000E+03 / Equinox of celestial coord system
# RADECSYS= 'FK5     '           / celestial coord system
# USER    = 'brett   '           / User name of creator
# FILIN001= 'sw00031403047xwtw2po_cl.evt' / Input file name
# CREATOR = 'extractor v5.32'    / Extractor version
# DATE    = '2018-11-12T09:00:38' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'NASA/GSFC'          / origin of fits file
# TIMEDEL = 1.000000000000000E+00 / Binning factor
# HISTORY extractor v5.32
# CHECKSUM= 'X2Mda1MaR1MaX1Ma'   / HDU checksum updated 2018-11-12T09:00:38
# DATASUM = '         0'         / data unit checksum updated 2018-11-12T09:00:38
#
# 0 0.0 927.0
# 1 5520.0 6505.0
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/astropy/stats/lombscargle/implementations/fast_impl.py:93: RuntimeWarning: invalid value encountered in true_divide
#   tan_2omega_tau = (S2 - 2 * S * C) / (C2 - (C * C - S * S))

# %%
path='/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0622/00031403045_xrt/src.lc'
time,count,obstime=get_lc_path(path)
get_lc__pds_path(path)
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 9.446140580177307E+02 / On-source time
# DEADC   =       9.98334944E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 9.430412229471966E+02 / Exposure time
# LIVETIME= 9.430412229471966E+02 / Deadtime corrected on-source time
# DATE-OBS= '2015-06-22T02:08:12' / Start date of observations
# DATE-END= '2015-06-22T02:23:58' / End date of observations
# TSTART  = 4.566316951872740E+08 / time start
# TSTOP   = 4.566326398013321E+08 / time stop
# TELAPSE = 9.446140580773354E+02 / elapsed time
# MJD-OBS = 5.719508980753789E+04 / MJD of data start time
# MJDREFI =                51910 / MJD reference day
# MJDREFF = 7.428703700000000E-04 / MJD reference (fraction of day)
# TIMEREF = 'LOCAL   '           / reference time
# TIMESYS = 'TT      '           / time measured from
# TIMEUNIT= 's       '           / unit for time keywords
# EQUINOX =            2.000E+03 / Equinox of celestial coord system
# RADECSYS= 'FK5     '           / celestial coord system
# USER    = 'brett   '           / User name of creator
# FILIN001= 'sw00031403045xwtw2po_cl.evt' / Input file name
# CREATOR = 'extractor v5.32'    / Extractor version
# DATE    = '2018-11-01T04:31:14' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'NASA/GSFC'          / origin of fits file
# TIMEDEL = 1.000000000000000E+00 / Binning factor
# HISTORY extractor v5.32
# CHECKSUM= 'W7Saa5RTY5RZa5RZ'   / HDU checksum updated 2018-11-01T04:31:14
# DATASUM = '         0'         / data unit checksum updated 2018-11-01T04:31:14
#
# 0 0.0 944.0
# /Users/brettlv/anaconda3/lib/python3.6/site-packages/astropy/stats/lombscargle/implementations/fast_impl.py:93: RuntimeWarning: invalid value encountered in true_divide
#   tan_2omega_tau = (S2 - 2 * S * C) / (C2 - (C * C - S * S))
