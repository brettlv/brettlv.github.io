# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyfits

from astropy.stats import LombScargle
plt.style.use('seaborn-whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
#%config InlineBackend.figure_format='retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

fs = 1000
t = np.linspace(0, 0.3, 301)
A = np.array([5, 8]).reshape(-1, 1)
f = np.array([150, 40]).reshape(-1, 1)
xn = (A * np.sin(2 * np.pi * f * t)).sum(axis=0) + 5 * np.random.randn(*t.shape)
print(xn.size)
yticks = np.arange(-50, 30, 10)
xticks = np.arange(0,550,100)
plt.subplots_adjust(hspace=0.45, wspace=0.3)
plt.subplot(1,2,1)
plt.psd(xn, NFFT=301, Fs=fs, window=mlab.window_none, pad_to=1024,
    scale_by_freq=True)
plt.title('Periodogram')
plt.yticks(yticks)
plt.xticks(xticks)
plt.grid(True)

plt.subplot(1,2,2)
plt.psd(xn, NFFT=150, Fs=fs, window=mlab.window_none, noverlap=75, pad_to=512,
    scale_by_freq=True)
plt.title('Welch')
plt.xticks(xticks)
plt.yticks(yticks)
plt.ylabel('')
plt.grid(True)
plt.show()
# Out:
# 301

# %%
from matplotlib.mlab import psd 
psdensity,freq=psd(xn, NFFT=301, Fs=fs, window=mlab.window_none, pad_to=1024,scale_by_freq=True)

psd2,freq2=psd(xn, NFFT=150, Fs=fs, window=mlab.window_none, noverlap=75, pad_to=512,scale_by_freq=True)

# %%
plt.plot(freq,psdensity)
plt.plot(freq2,psd2)
plt.show()

# %%
xn.size,t
# Out:
# (301, array([ 0.   ,  0.001,  0.002,  0.003,  0.004,  0.005,  0.006,  0.007,
#          0.008,  0.009,  0.01 ,  0.011,  0.012,  0.013,  0.014,  0.015,
#          0.016,  0.017,  0.018,  0.019,  0.02 ,  0.021,  0.022,  0.023,
#          0.024,  0.025,  0.026,  0.027,  0.028,  0.029,  0.03 ,  0.031,
#          0.032,  0.033,  0.034,  0.035,  0.036,  0.037,  0.038,  0.039,
#          0.04 ,  0.041,  0.042,  0.043,  0.044,  0.045,  0.046,  0.047,
#          0.048,  0.049,  0.05 ,  0.051,  0.052,  0.053,  0.054,  0.055,
#          0.056,  0.057,  0.058,  0.059,  0.06 ,  0.061,  0.062,  0.063,
#          0.064,  0.065,  0.066,  0.067,  0.068,  0.069,  0.07 ,  0.071,
#          0.072,  0.073,  0.074,  0.075,  0.076,  0.077,  0.078,  0.079,
#          0.08 ,  0.081,  0.082,  0.083,  0.084,  0.085,  0.086,  0.087,
#          0.088,  0.089,  0.09 ,  0.091,  0.092,  0.093,  0.094,  0.095,
#          0.096,  0.097,  0.098,  0.099,  0.1  ,  0.101,  0.102,  0.103,
# ...

# %%
import numpy as np
from scipy.fftpack import fft,ifft
import matplotlib.pyplot as plt
import seaborn


#采样点选择1400个，因为设置的信号频率分量最高为600赫兹，根据采样定理知采样频率要大于信号频率2倍，所以这里设置采样频率为1400赫兹（即一秒内有1400个采样点，一样意思的）
x=np.linspace(0,1,1400)      

#设置需要采样的信号，频率分量有180，390和600
y=7*np.sin(2*np.pi*180*x) + 2.8*np.sin(2*np.pi*390*x)+5.1*np.sin(2*np.pi*600*x)

yy=fft(y)                     #快速傅里叶变换
yreal = yy.real               # 获取实数部分
yimag = yy.imag               # 获取虚数部分

yf=abs(fft(y))                # 取绝对值
yf1=abs(fft(y))/len(x)           #归一化处理
yf2 = yf1[range(int(len(x)/2))]  #由于对称性，只取一半区间

xf = np.arange(len(y))        # 频率
xf1 = xf
xf2 = xf[range(int(len(x)/2))]  #取一半区间


plt.subplot(221)
plt.plot(x[0:50],y[0:50])   
plt.title('Original wave')

plt.subplot(222)
plt.plot(xf,yf,'r')
plt.title('FFT of Mixed wave(two sides frequency range)',fontsize=7,color='#7A378B')  #注意这里的颜色可以查询颜色代码表

plt.subplot(223)
plt.plot(xf1,yf1,'g')
plt.title('FFT of Mixed wave(normalization)',fontsize=9,color='r')

plt.subplot(224)
plt.plot(xf2,yf2,'b')
plt.title('FFT of Mixed wave)',fontsize=10,color='#F08080')


plt.show()

# %%
x[0],x[-1],len(x),x
# Out:
# (0.0,
#  1.0,
#  1400,
#  array([  0.00000000e+00,   7.14796283e-04,   1.42959257e-03, ...,
#           9.98570407e-01,   9.99285204e-01,   1.00000000e+00]))

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn



Fs = 150.0;                 # sampling rate采样率
Ts = 1.0/Fs;                # sampling interval 采样区间
t = np.arange(0,1,Ts)       # time vector,这里Ts也是步长

ff = 25;                    # frequency of the signal
y = np.sin(2*np.pi*ff*t)

n = len(y)                  # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T                   # two sides frequency range
frq1 = frq[range(int(n/2))] # one side frequency range

YY = np.fft.fft(y)          # 未归一化
Y = np.fft.fft(y)/n         # fft computing and normalization 归一化
Y1 = Y[range(int(n/2))]

fig, ax = plt.subplots(4, 1)

ax[0].plot(t,y)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Amplitude')

ax[1].plot(frq,abs(YY),'r') # plotting the spectrum
ax[1].set_xlabel('Freq (Hz)')
ax[1].set_ylabel('|Y(freq)|')

ax[2].plot(frq,abs(Y),'G')  # plotting the spectrum
ax[2].set_xlabel('Freq (Hz)')
ax[2].set_ylabel('|Y(freq)|')

ax[3].plot(frq1,abs(Y1),'B') # plotting the spectrum
ax[3].set_xlabel('Freq (Hz)')
ax[3].set_ylabel('|Y(freq)|')

plt.show()

# %% [markdown]
# for i in np.arange(10):
#     for j in np.arange(10):
#         print(i+j)

# %%
lightcurve=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0622/00031403045_xrt/src.lc')
#barylc=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/RX_J0806/nicer/bary01.lc')
header=lightcurve[0].header
print('originlc:')
print(repr(header[:]),'\n')
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 9.446140580177307E+02 / On-source time
# DEADC   =       9.98334944E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 9.430412229471966E+02 / Exposure time
# LIVETIME= 9.430412229471966E+02 / Deadtime corrected on-source time
# ...

# %%
time=lightcurve[1].data['TIME']
count=lightcurve[1].data['RATE']
plt.plot(time,count)
plt.semilogy()
plt.savefig('v404_0622_lc.png')

# %%
t.shape[-1]
# Out:
# 945

# %%
fs = 1.0
t = time
x = count
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.savefig('v404_0622_pds.png')
#plt.xlim(0,1)

# %%
1/18*1000,1/73*1000,1/1.03,1/136*1000,1/0.124,1/0.251
# Out:
# (55.55555555555555,
#  13.698630136986301,
#  0.970873786407767,
#  7.352941176470588,
#  8.064516129032258,
#  3.9840637450199203)

# %%
lightcurve=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0620/00031403040_xrt/src.lc')
#barylc=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/RX_J0806/nicer/bary01.lc')
header=lightcurve[0].header
print('originlc:')
print(repr(header[:]),'\n')

time=lightcurve[1].data['TIME']
count=lightcurve[1].data['RATE']
plt.plot(time,count)
plt.savefig('v404_0620_lc.png')
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 1.448618990182877E+03 / On-source time
# DEADC   =       9.98335838E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 1.446208253967410E+03 / Exposure time
# LIVETIME= 1.446208253967410E+03 / Deadtime corrected on-source time
# ...

# %%
plt.plot(time,count)
plt.xlim(0,600)
#plt.semilogx()
plt.semilogy()
plt.savefig('v404_0620_lc_left.png')

# %%
time.shape,time[560:570],time[0],1450-564
# Out:
# ((1450,),
#  array([  560.,   561.,   562.,   563.,   564.,  5558.,  5559.,  5560.,
#          5561.,  5562.]),
#  0.0,
#  886)

# %%
plt.plot(time,count)
#plt.semilogx()
plt.semilogy()
plt.xlim(5550,6500)
plt.savefig('v404_0620_lc_right.png')

# %%
fs = 1.0
t = time[:564]
x = count[:564]
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.savefig('v404_0620_pds_left.png')
#plt.xlim(0,1)

# %%
fs = 1.0
t = time[565:]-time[565]
x = count[565:]
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.savefig('v404_0620_pds_right.png')
#plt.xlim(0,1)

# %%
lightcurve=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0625_0626/00031403055_xrt/src.lc')
#barylc=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/RX_J0806/nicer/bary01.lc')
header=lightcurve[0].header
print('originlc:')
print(repr(header[:]),'\n')

time=lightcurve[1].data['TIME']
count=lightcurve[1].data['RATE']
plt.plot(time,count)
plt.savefig('v404_062526_lc.png')
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 1.029766867995262E+03 / On-source time
# DEADC   =       9.98335183E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 1.028052494264246E+03 / Exposure time
# LIVETIME= 1.028052494264246E+03 / Deadtime corrected on-source time
# ...

# %%
fs = 1.0
t = time
x = count
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.savefig('v404_062526_pds.png')

# %%
lightcurve=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/V404cyg/xrt0622/00031403049_xrt/src.lc')
#barylc=pyfits.open('/Volumes/Seagate_Backup_Plus_Drive_Lvb/RX_J0806/nicer/bary01.lc')
header=lightcurve[0].header
print('originlc:')
print(repr(header[:]),'\n')

time=lightcurve[1].data['TIME']
count=lightcurve[1].data['RATE']
plt.plot(time,count)
#plt.savefig('v404_0622_lc.png')
# Out:
# originlc:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# TELESCOP= 'SWIFT   '           / Telescope (mission) name
# DATAMODE= 'WINDOWED'           / Datamode
# DETNAM  = 'NONE    '           / Detector
# INSTRUME= 'XRT     '           / Instrument name
# OBJECT  = 'V404Cyg '           / Name of observed object
# ONTIME  = 2.995764524579048E+03 / On-source time
# DEADC   =       9.98336375E-01 / Deadtime correction
# DEADAPP =                    F / Has DEADC been applied to data
# EXPOSURE= 2.990780695101886E+03 / Exposure time
# LIVETIME= 2.990780695101886E+03 / Deadtime corrected on-source time
# ...

# %%
time.size
# Out:
# 2999

# %%
def get_interval_time(time):
    size=len(time)
    index=[0]
    for i in np.arange(len(time)-1):
        if time[i+1]-time[i]>1:
            index.append(i)    
    return index

# %%
index=get_interval_time(time)
print(index)
# Out:
# [0, 214, 391, 1291, 1618]

# %%
plt.figure(figsize=(12,9))
plt.subplot(511)
plt.plot(time[index[0]:index[1]],count[index[0]:index[1]])
plt.subplot(512)
plt.plot(time[index[1]+1:index[2]],count[index[1]+1:index[2]])
plt.subplot(513)
plt.plot(time[index[2]+1:index[3]],count[index[2]+1:index[3]])
plt.subplot(514)
plt.plot(time[index[3]+1:index[4]],count[index[3]+1:index[4]])
plt.subplot(515)
plt.plot(time[index[4]+1:],count[index[4]+1:])
plt.tight_layout()

# %%
fs = 1.0
t = time[index[0]+1:index[1]]
x = count[index[0]+1:index[1]]
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.subplot(211)
plt.plot(np.arange(len(t)),x)
plt.xlabel('time')
plt.ylabel('count')
plt.subplot(212)
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.tight_layout()

# %%
fs = 1.0
t = time[index[1]+1:index[2]]
x = count[index[1]+1:index[2]]
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.subplot(211)
plt.plot(np.arange(len(t)),x)
plt.xlabel('time')
plt.ylabel('count')
plt.subplot(212)
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.tight_layout()

# %%
fs = 1.0
t = time[index[2]+1:index[3]]
x = count[index[2]+1:index[3]]

xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.subplot(211)
plt.plot(np.arange(len(t)),x)
plt.xlabel('time')
plt.ylabel('count')
plt.subplot(212)
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.tight_layout()

# %%
fs = 1.0
t = time[index[3]+1:index[4]]
x = count[index[3]+1:index[4]]
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.subplot(211)
plt.plot(np.arange(len(t)),x)
plt.xlabel('time')
plt.ylabel('count')
plt.subplot(212)
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.tight_layout()

# %%
fs = 1.0
t = time[index[4]+1:]
x = count[index[4]+1:]
xF = np.fft.fft(x)
freq = np.fft.fftfreq(t.shape[-1])
plt.subplot(211)
plt.plot(np.arange(len(t)),x)
plt.xlabel('time')
plt.ylabel('count')
plt.subplot(212)
plt.plot(freq,abs(xF)**2)
plt.semilogx()
plt.semilogy()
plt.xlabel('frequency/Hz')
plt.ylabel('power')
plt.tight_layout()
