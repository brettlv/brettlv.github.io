# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from marvin.tools.cube import Cube
cube = Cube(plateifu='7443-12703')
# Out:
# INFO: No release version set. Setting default to DR15
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/marvin/__init__.py:369: MarvinUserWarning: path /Users/brettlv/sas/dr15/manga/spectro/redux/v2_4_3/drpall-v2_4_3.fits cannot be found. Setting drpall to None.
#   .format(value), MarvinUserWarning)
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/astropy/table/np_utils.py:19: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import _np_utils
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/astropy/io/ascii/fastbasic.py:9: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from . import cparser
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/astropy/stats/lombscargle/implementations/main.py:21: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .cython_impl import lombscargle_cython

# %%
spaxel = cube.getSpaxel(0,0)
spaxel.flux.plot()

# %%
spaxel=cube.getSpaxel(ra=229.525575871,dec=42.7458424664)

# %%
maps = cube.getMaps()
# Out:
# DEBUG:Brain:local mode failed. Trying remote now.

# %%
hamap = maps.getMap('emline_sflux',channel='ha_6564')
hamap.plot()
# Out:
# (<matplotlib.figure.Figure at 0x127eb6450>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x127eb6a10>)
