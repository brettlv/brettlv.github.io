# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import sys
import copy

import numpy as np

import astropy.units as u
from astropy import wcs
from astropy.io import fits
from astropy.table import Table, QTable
from astropy.coordinates import SkyCoord
from astropy.visualization import make_lupton_rgb
from astropy.utils.data import download_file, clear_download_cache

import matplotlib.pyplot as plt
from matplotlib import colors
# Out:
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 1 ('<!DOCTYPE html>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 2 ('<html lang="en">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 3 ('  <head>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4 ('    <meta charset="utf-8">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 6 ('  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 7 ('  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 8 ('  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 9 ('  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 10 ('  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 11 ('  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 43 ('  <meta name="viewport" content="width=device-width">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 45 ('  <title>matplotlib/matplotlibrc.template at master · matplotlib/matplotlib · GitHub</title>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 47 ('    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 50 ('  <meta name="apple-itunes-app" content="app-id=1477376905" />')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 66 ('  <meta name="github-keyboard-shortcuts" content="repository,source-code" data-pjax-transient="true" />')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 70 ('  <meta name="selected-link" value="repo_source" data-pjax-transient>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 72 ('    <meta name="google-site-verification" content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 73 ('  <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 74 ('  <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 75 ('  <meta name="google-site-verification" content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 79 ('  <meta name="analytics-location" content="/&lt;user-name&gt;/&lt;repo-name&gt;/blob/show" data-pjax-transient="true" />')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 86 ('  <!-- To prevent page flashing, the optimizely JS needs to be loaded in the')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 87 ('    <head> tag before the DOM renders -->')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 94 ('      <meta name="hostname" content="github.com">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 95 ('    <meta name="user-login" content="">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 98 ('      <meta name="expected-hostname" content="github.com">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 101 ('    <meta name="enabled-features" content="CORPORATE_SPONSORS_CREDIT_CARD,MARKETPLACE_PENDING_INSTALLATIONS">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 103 ('  <meta http-equiv="x-pjax-version" content="e10aed81cde4de4df611467c50f6db64d4b7769696a68a9571c9408d08cb1b18">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 110 ('  <meta name="octolytics-dimension-user_id" content="215947" /><meta name="octolytics-dimension-user_login" content="matplotlib" /><meta name="octolytics-dimension-repository_id" content="1385122" /><meta name="octolytics-dimension-repository_nwo" content="matplotlib/matplotlib" /><meta name="octolytics-dimension-repository_public" content="true" /><meta name="octolytics-dimension-repository_is_fork" content="false" /><meta name="octolytics-dimension-repository_network_root_id" content="1385122" /><meta name="octolytics-dimension-repository_network_root_nwo" content="matplotlib/matplotlib" /><meta name="octolytics-dimension-repository_explore_github_marketplace_ci_cta_shown" content="false" />')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 127 ('<meta name="theme-color" content="#1e2327">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 128 ('  <meta name="color-scheme" content="light dark">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 131 ('  <link rel="manifest" href="/manifest.json" crossOrigin="use-credentials">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 133 ('  </head>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 135 ('  <body class="logged-out env-production page-responsive page-blob">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 138 ('    <div class="position-relative js-header-wrapper ">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 139 ('      <a href="#start-of-content" class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content">Skip to content</a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 140 ('      <span class="progress-pjax-loader width-full js-pjax-loader-bar Progress position-fixed">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 142 ('</span>      ')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 146 ('            <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 147 ('  <div class="container-xl d-lg-flex flex-items-center p-responsive">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 148 ('    <div class="d-flex flex-justify-between flex-items-center">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 150 ('          <svg height="32" class="octicon octicon-mark-github text-white" viewBox="0 0 16 16" version="1.1" width="32" aria-hidden="true"><path fill-rule="evenodd" d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 151 ('        </a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 153 ('          <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 156 ('          </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 158 ('        <div class="d-flex flex-items-center">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 159 ('              <a href="/join?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source=header-repo"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 160 ('                class="d-inline-block d-lg-none f5 text-white no-underline border border-gray-dark rounded-2 px-2 py-1 mr-3 mr-sm-5"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 163 ('                Sign&nbsp;up')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 164 ('              </a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 166 ('          <button class="btn-link d-lg-none mt-1 js-details-target" type="button" aria-label="Toggle navigation" aria-expanded="false">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 167 ('            <svg height="24" class="octicon octicon-three-bars text-white" viewBox="0 0 16 16" version="1.1" width="24" aria-hidden="true"><path fill-rule="evenodd" d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 168 ('          </button>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 169 ('        </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 170 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 172 ('    <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 173 ('      <div class="d-flex d-lg-none flex-justify-end border-bottom bg-gray-light p-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 174 ('        <button class="btn-link js-details-target" type="button" aria-label="Toggle navigation" aria-expanded="false">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 175 ('          <svg height="24" class="octicon octicon-x text-gray" viewBox="0 0 24 24" version="1.1" width="24" aria-hidden="true"><path fill-rule="evenodd" d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 176 ('        </button>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 177 ('      </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 179 ('        <nav class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0" aria-label="Global">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 180 ('          <ul class="d-lg-flex list-style-none">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 181 ('              <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center ">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 182 ('                <details class="HeaderMenu-details details-overlay details-reset width-full">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 183 ('                  <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 184 ('                    Why GitHub?')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 186 ('                      <path d="M1,1l6.2,6L13,1"></path>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 187 ('                    </svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 188 ('                  </summary>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 189 ('                  <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 190 ('                    <a href="/features" class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features">Features <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 191 ('                    <ul class="list-style-none f5 pb-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 192 ('                      <li class="edge-item-fix"><a href="/features/code-review/" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code review">Code review</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 193 ('                      <li class="edge-item-fix"><a href="/features/project-management/" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Project management">Project management</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 194 ('                      <li class="edge-item-fix"><a href="/features/integrations" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Integrations">Integrations</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 195 ('                      <li class="edge-item-fix"><a href="/features/actions" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Actions">Actions</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 196 ('                      <li class="edge-item-fix"><a href="/features/packages" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to GitHub Packages">Packages</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 197 ('                      <li class="edge-item-fix"><a href="/features/security" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Security">Security</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 198 ('                      <li class="edge-item-fix"><a href="/features#team-management" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Team management">Team management</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 199 ('                      <li class="edge-item-fix"><a href="/features#hosting" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code hosting">Hosting</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 200 ('                      <li class="edge-item-fix hide-xl"><a href="/mobile" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Mobile">Mobile</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 201 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 203 ('                    <ul class="list-style-none mb-0 border-lg-top pt-lg-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 204 ('                      <li class="edge-item-fix"><a href="/customer-stories" class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Customer stories">Customer stories <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 205 ('                      <li class="edge-item-fix"><a href="/security" class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Security">Security <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 206 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 207 ('                  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 208 ('                </details>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 209 ('              </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 210 ('              <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 211 ('                <a href="/team" class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Team">Team</a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 212 ('              </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 213 ('              <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 214 ('                <a href="/enterprise" class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Enterprise">Enterprise</a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 215 ('              </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 217 ('              <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center ">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 218 ('                <details class="HeaderMenu-details details-overlay details-reset width-full">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 219 ('                  <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 220 ('                    Explore')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 221 ('                    <svg x="0px" y="0px" viewBox="0 0 14 8" xml:space="preserve" fill="none" class="icon-chevon-down-mktg position-absolute position-lg-relative">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 222 ('                      <path d="M1,1l6.2,6L13,1"></path>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 223 ('                    </svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 224 ('                  </summary>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 226 ('                  <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 227 ('                    <ul class="list-style-none mb-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 228 ('                      <li class="edge-item-fix"><a href="/explore" class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Explore">Explore GitHub <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 229 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 231 ('                    <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">Learn &amp; contribute</h4>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 232 ('                    <ul class="list-style-none mb-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 233 ('                      <li class="edge-item-fix"><a href="/topics" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Topics">Topics</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 234 ('                        <li class="edge-item-fix"><a href="/collections" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Collections">Collections</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 235 ('                      <li class="edge-item-fix"><a href="/trending" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Trending">Trending</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 237 ('                      <li class="edge-item-fix"><a href="https://opensource.guide" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Open source guides">Open source guides</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 238 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 240 ('                    <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">Connect with others</h4>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 241 ('                    <ul class="list-style-none mb-0">')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 242 ('                      <li class="edge-item-fix"><a href="https://github.com/events" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Events">Events</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 243 ('                      <li class="edge-item-fix"><a href="https://github.community" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Community forum">Community forum</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 244 ('                      <li class="edge-item-fix"><a href="https://education.github.com" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to GitHub Education">GitHub Education</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 245 ('                      <li class="edge-item-fix"><a href="https://stars.github.com" class="py-2 pb-0 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to GitHub Stars Program">GitHub Stars program</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 246 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 247 ('                  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 248 ('                </details>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 249 ('              </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 251 ('              <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 252 ('                <a href="/marketplace" class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Marketplace">Marketplace</a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 253 ('              </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 255 ('              <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center ">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 256 ('                <details class="HeaderMenu-details details-overlay details-reset width-full">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 257 ('                  <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 258 ('                    Pricing')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 259 ('                    <svg x="0px" y="0px" viewBox="0 0 14 8" xml:space="preserve" fill="none" class="icon-chevon-down-mktg position-absolute position-lg-relative">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 260 ('                       <path d="M1,1l6.2,6L13,1"></path>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 261 ('                    </svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 262 ('                  </summary>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 264 ('                  <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-4 mt-0 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 265 ('                    <a href="/pricing" class="pb-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Pricing">Plans <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 267 ('                    <ul class="list-style-none mb-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 268 ('                      <li class="edge-item-fix"><a href="/pricing#feature-comparison" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Compare plans">Compare plans</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 269 ('                      <li class="edge-item-fix"><a href="https://enterprise.github.com/contact" class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Contact Sales">Contact Sales</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 270 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 272 ('                    <ul class="list-style-none mb-0 border-lg-top pt-lg-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 273 ('                      <li class="edge-item-fix"><a href="/nonprofit" class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Nonprofits">Nonprofit <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 274 ('                      <li class="edge-item-fix"><a href="https://education.github.com" class="py-2 pb-0 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover"  data-ga-click="(Logged out) Header, go to Education">Education <span class="Bump-link-symbol float-right text-normal text-gray-light">&rarr;</span></a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 275 ('                    </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 276 ('                  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 277 ('                </details>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 278 ('              </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 279 ('          </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 280 ('        </nav>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 282 ('      <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 283 ('          <div class="d-lg-flex mb-3 mb-lg-0">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 284 ('            <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 285 ('  role="combobox"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 286 ('  aria-owns="jump-to-results"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 287 ('  aria-label="Search or jump to"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 288 ('  aria-haspopup="listbox"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 289 ('  aria-expanded="false"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 290 ('>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 291 ('  <div class="position-relative">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 292 ('    <!-- \'"` --><!-- </textarea></xmp> --></option></form><form class="js-site-search-form" role="search" aria-label="Site" data-flagged-in="false" data-scope-type="Repository" data-scope-id="1385122" data-scoped-search-url="/matplotlib/matplotlib/search" data-owner-scoped-search-url="/orgs/matplotlib/search" data-unscoped-search-url="/search" action="/matplotlib/matplotlib/search" accept-charset="UTF-8" method="get">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 293 ('      <label class="form-control input-sm header-search-wrapper p-0 js-chromeless-input-container header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 294 ('        <input type="text"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 295 ('          class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus js-site-search-field is-clearable"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 296 ('          data-hotkey="s,/"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 297 ('          name="q"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 298 ('          value=""')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 299 ('          placeholder="Search"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 300 ('          data-unscoped-placeholder="Search GitHub"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 301 ('          data-scoped-placeholder="Search"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 302 ('          autocapitalize="off"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 303 ('          aria-autocomplete="list"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 304 ('          aria-controls="jump-to-results"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 305 ('          aria-label="Search"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 306 ('          data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 307 ('          spellcheck="false"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 308 ('          autocomplete="off"')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 309 ('          >')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 310 ('          <input type="hidden" data-csrf="true" class="js-data-jump-to-suggestions-path-csrf" value="5l1hF+H00FuHKNBv6AtyrPjZQlwAFG9newItM7I+JPZ61aUliT9P21U6h+JMNH7+FMJBqgC2o0PMK+KUOSYEMw==" />')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 311 ('          <input type="hidden" class="js-site-search-type-field" name="type" >')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 314 ('            <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 316 ('<ul class="d-none js-jump-to-suggestions-template-container">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 319 ('<li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 320 ('  <a tabindex="-1" class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" data-item-type="suggestion">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 321 ('    <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 322 ('      <svg height="16" width="16" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" title="Repository" aria-label="Repository" viewBox="0 0 16 16" version="1.1" role="img"><path fill-rule="evenodd" d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 323 ('      <svg height="16" width="16" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" title="Project" aria-label="Project" viewBox="0 0 16 16" version="1.1" role="img"><path fill-rule="evenodd" d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 324 ('      <svg height="16" width="16" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" title="Search" aria-label="Search" viewBox="0 0 16 16" version="1.1" role="img"><path fill-rule="evenodd" d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 325 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 327 ('    <img class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" alt="" aria-label="Team" src="" width="28" height="28">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 329 ('    <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 330 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 332 ('    <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 333 ('      <span class="js-jump-to-badge-search-text-default d-none" aria-label="in this repository">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 334 ('        In this repository')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 335 ('      </span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 336 ('      <span class="js-jump-to-badge-search-text-global d-none" aria-label="in all of GitHub">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 337 ('        All GitHub')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 338 ('      </span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 339 ('      <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 340 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 342 ('    <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 343 ('      Jump to')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 344 ('      <span class="d-inline-block ml-1 v-align-middle">↵</span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 345 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 346 ('  </a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 347 ('</li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 349 ('</ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 351 ('<ul class="d-none js-jump-to-no-results-template-container">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 352 ('  <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 353 ('    <span class="text-gray">No suggested jump to results</span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 354 ('  </li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 355 ('</ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 357 ('<ul id="jump-to-results" role="listbox" class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 360 ('<li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 361 ('  <a tabindex="-1" class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" data-item-type="scoped_search">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 362 ('    <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 363 ('      <svg height="16" width="16" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" title="Repository" aria-label="Repository" viewBox="0 0 16 16" version="1.1" role="img"><path fill-rule="evenodd" d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 364 ('      <svg height="16" width="16" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" title="Project" aria-label="Project" viewBox="0 0 16 16" version="1.1" role="img"><path fill-rule="evenodd" d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 365 ('      <svg height="16" width="16" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" title="Search" aria-label="Search" viewBox="0 0 16 16" version="1.1" role="img"><path fill-rule="evenodd" d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 366 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 368 ('    <img class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" alt="" aria-label="Team" src="" width="28" height="28">')
# ...
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4272 ('        <svg height="24" class="octicon octicon-mark-github" viewBox="0 0 16 16" version="1.1" width="24" aria-hidden="true"><path fill-rule="evenodd" d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4273 ('</a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4274 ('      <ul class="list-style-none d-flex flex-wrap col-12 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4275 ('        <li class="mr-3 mr-lg-0">&copy; 2020 GitHub, Inc.</li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4278 ('            <li class="js-cookie-consent-preferences-link-container mr-3 mr-lg-0" hidden="hidden">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4280 ('</li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4285 ('          <li class="mr-3 mr-lg-0"><a href="https://github.com/pricing" data-ga-click="Footer, go to Pricing, text:Pricing">Pricing</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4286 ('        <li class="mr-3 mr-lg-0"><a href="https://docs.github.com" data-ga-click="Footer, go to api, text:api">API</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4287 ('        <li class="mr-3 mr-lg-0"><a href="https://services.github.com" data-ga-click="Footer, go to training, text:training">Training</a></li>')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4288 ('          <li class="mr-3 mr-lg-0"><a href="https://github.blog" data-ga-click="Footer, go to blog, text:blog">Blog</a></li>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4290 ('      </ul>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4291 ('    </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4292 ('  <div class="d-flex flex-justify-center pb-6">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4293 ('    <span class="f6 text-gray-light"></span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4294 ('  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4297 ('</div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4301 ('  <div id="ajax-error-message" class="ajax-error-message flash flash-error">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4302 ('    <svg class="octicon octicon-alert" viewBox="0 0 16 16" version="1.1" width="16" height="16" aria-hidden="true"><path fill-rule="evenodd" d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4303 ('    <button type="button" class="flash-close js-ajax-error-dismiss" aria-label="Dismiss error">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4304 ('      <svg class="octicon octicon-x" viewBox="0 0 16 16" version="1.1" width="16" height="16" aria-hidden="true"><path fill-rule="evenodd" d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4305 ('    </button>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4306 ('    You can’t perform that action at this time.')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4307 ('  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4310 ('  <div class="js-stale-session-flash flash flash-warn flash-banner" hidden')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4311 ('    >')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4312 ('    <svg class="octicon octicon-alert" viewBox="0 0 16 16" version="1.1" width="16" height="16" aria-hidden="true"><path fill-rule="evenodd" d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4313 ('    <span class="js-stale-session-flash-signed-in" hidden>You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4314 ('    <span class="js-stale-session-flash-signed-out" hidden>You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4315 ('  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4316 ('    <template id="site-details-dialog">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4317 ('  <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark hx_rsm" open>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4318 ('    <summary role="button" aria-label="Close dialog"></summary>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4319 ('    <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4320 ('      <button class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" type="button" aria-label="Close dialog" data-close-dialog>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4321 ('        <svg class="octicon octicon-x" viewBox="0 0 16 16" version="1.1" width="16" height="16" aria-hidden="true"><path fill-rule="evenodd" d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z"></path></svg>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4322 ('      </button>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4323 ('      <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4324 ('    </details-dialog>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4325 ('  </details>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4326 ('</template>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4330 ('  </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4331 ('</div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4333 ('      <div class="js-cookie-consent-banner" hidden>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4334 ('  <div class="hx_cookie-banner p-2 p-sm-3 p-md-4">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4336 ('    <div class="Box-body border-0 py-0 px-3 px-md-4">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4337 ('      <div class="js-main-cookie-banner hx_cookie-banner-main">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4338 ('          <div class="d-md-flex flex-items-center py-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4339 ('            <p class="f5 flex-1 mb-3 mb-md-0">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4341 ('  We use <span class="text-bold">optional</span> third-party analytics cookies to understand how you use GitHub.com so we can build better products.')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4343 ('              <span class="btn-link js-cookie-consent-learn-more">Learn more</span>.')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4344 ('            </p>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4345 ('            <div class="d-flex d-md-block flex-wrap flex-sm-nowrap">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4346 ('              <button class="btn btn-outline flex-1 mr-1 mx-sm-1 m-md-0 ml-md-2 js-cookie-consent-accept">Accept</button>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4347 ('              <button class="btn btn-outline flex-1 ml-1 m-md-0 ml-md-2 js-cookie-consent-reject">Reject</button>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4348 ('            </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4349 ('          </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4350 ('        </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4352 ('        <div class="js-cookie-details hx_cookie-banner-details" hidden>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4353 ('          <div class="d-md-flex flex-items-center py-3">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4354 ('            <p class="f5 flex-1 mb-2 mb-md-0">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4356 ('  We use <span class="text-bold">optional</span> third-party analytics cookies to understand how you use GitHub.com so we can build better products.')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4358 ('              <br>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4359 ('              You can always update your selection by clicking <span class="text-bold">Cookie Preferences</span> at the bottom of the page.')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4361 ('            </p>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4362 ('          </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4364 ('          <div class="d-md-flex flex-items-center py-3 border-top">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4365 ('            <div class="f5 flex-1 mb-2 mb-md-0">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4366 ('              <h5 class="mb-1">Essential cookies</h5>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4367 ('              <p class="f6 mb-md-0">We use essential cookies to perform essential website functions, e.g. they\'re used to log you in. ')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4369 ('              </p>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4370 ('            </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4371 ('            <div class="text-right">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4372 ('              <h5 class="text-blue">Always active</h5>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4373 ('            </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4374 ('          </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4376 ('          <div class="d-md-flex flex-items-center py-3 border-top">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4377 ('            <div class="f5 flex-1 mb-2 mb-md-0">')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4378 ('              <h5 class="mb-1">Analytics cookies</h5>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4379 ('              <p class="f6 mb-md-0">We use analytics cookies to understand how you use our websites so we can make them better, e.g. they\'re used to gather information about the pages you visit and how many clicks you need to accomplish a task. ')
# Duplicate key in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4380 ('                <a href="https://docs.github.com/en/github/site-policy/github-subprocessors-and-cookies">Learn more</a>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4381 ('              </p>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4382 ('            </div>')
# Missing colon in file PosixPath('/Users/brettlv/.matplotlib/stylelib/notebook.mplstyle'), line 4383 ('            <div class="text-right">')

# %% [markdown]
# # Download Necessary HSC Data
#
# - We are going to use `unagi` tool to access HSC data through the NAOJ public data release:
#     - Please visit [HSC SSP website](https://hsc.mtk.nao.ac.jp/ssp/) for basic information of the survey
#     - We will be using the [Public Data Release 2](https://hsc-release.mtk.nao.ac.jp/doc/). Please use this website for related publications and technical details.
#     - You need to register an account to use the data. Please use the [form here](https://hsc-release.mtk.nao.ac.jp/datasearch/new_user/new)
#     - **Important**: NAOJ will assign you a random and complex password. You _WON'T_ be able to change it to something you can easily remember. So write it down somewhere safe! The good people at NAOJ take cyber security really seriously.
#     - Once you have the account, you can use the [online data access interface](https://hsc-release.mtk.nao.ac.jp/doc/index.php/tools-2/) to access data. Please feel free to explore.
#     - Meanwhile, for easy access of data in `Python` and `Jupyter` notebook. We are going to use the `unagi` library.
#
# ### `unagi`
#
# - [`unagi`](https://github.com/dr-guangtou/unagi) is a simple `Python` tool I created to search and download data from Hyper Suprime-Cam (HSC) Subaru Strategic Survey (SSP).
#     - You should be able to install it using just `pip install unagi`. Please make sure you are using `Python 3`.
#     - You should also feel free to explore the code in the github repo.
#     - I have prepared [some demo notebooks](https://github.com/dr-guangtou/unagi/tree/master/demo) to help you become familiar with both HSC data and `unagi`.
#     - **Important**: I strongly recommend you go through a few demos in the following order:
#         - [Basic of HSC database setup](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_config.ipynb)
#         - [How to use HSC filters](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_filters.ipynb)
#         - [Basics about HSC cutout generation](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_cutout.ipynb)
#         - [Basics about HSC PSF model](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_psf.ipynb)
#         - [Basics about the mask planes used by HSC](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_mask.ipynb)
#         - [How to generate three-color pictures of HSC object](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_color_image.ipynb)
#     - Once you have went through the above ones, you will have no problem understanding what's going on below.
#
# ### Credits:
#
# - **Important**: If you find `unagi` or this demo useful. Please remember that 99.9% of the credit goes to the great HSC SSP team in Japan, Princeton, and ASIA for preparing the data; and to the wonderful people at NAOJ for creating these useful tools.
# - If you are using HSC data or this demo for teaching/researching, please be sure to follow the appropriate rules for citation and acknowledgement.

# %%
from unagi import config
from unagi import hsc
from unagi import mask
from unagi import plotting
from unagi.task import hsc_cutout, hsc_psf

# Setup the HSC PDR2 data archive.
# If you want the Deep or Ultra-Deep data, please set the rerun to `pdr2_dud`.
#pdr2 = hsc.Hsc(dr='pdr2', rerun='pdr2_wide')

pdr2 = hsc.Hsc(dr='pdr2', rerun='pdr2_dud')
# Out:
# Public Data Release Username : brettlv
# Password : ········
# # Get table list from /Users/brettlv/anaconda3/lib/python3.8/site-packages/unagi/data/pdr2_dud/pdr2_dud_tables.fits

# %%
WIor0kLLf5nTNZSj9tMpG9LV+3NuSNYnn+ORtOrQ

# %% [markdown]
# ### Galaxy sample
#
# - The minimum information you need to generate cutouts (or post-stamps) is just a catalog with (RA, Dec) of the objects in them.
#     - You can also indicate the size of the cutouts or the name of the objects (we will demonstrate later).
#     - For cutout size, `unagi` allows bother **angular** and **physical** size.
#
# - Here we are going to use three random low surface brightness galaxies in HSC
#     - (provided by Jia-Xuan Li from PKU/Princeton).

# %%
#RA DEC
#243.88821 42.92376
#244.83857 42.25044
#236.74121 42.59723

ra = [243.88821, 244.83857, 236.74121]
dec = [42.92376, 42.25044, 42.59723]

sample = Table(
    [ra, dec], names=['ra', 'dec']
)

# %% [markdown]
# ## Example for a single object
#
# - Here we will generate cutouts in a single band: HSC $i$-band.
#     - In HSC, $i$-band typically has the best seeing. It is usually a good choice to study the structure of nearby galaxies.
# - The cutout size will be 60 arcsec x 60 arcsec.
#     - Unfortunately, I choose to use `cutout_size` as the keyword...It is more like the "half_size" or "radius" if you want...So be careful!
#         - **TODO**: My bad, I will fix it later (probably never...)
# - We will keep the output data in a folder called `data` and in case we have downloaded the data in that folder, we will not do that again (by setting `use_saved=True`).
# - We will get both the image and the variance ($\sigma^2$; for pixel-to-pixel uncertainty) and the mask planes that indicate the data quality and potential issues. We need the last two because they are necessary for image modeling...and because we are serious scientist.
# - Here, we will provide a simple prefix, `dwarf_demo`, to name the downloaded files. They will be named as `dwarf_demo_1/2/3`
# - And we are going to use the `plotting.display_all` function to check out the data.

# %%
sample
# Out:
# <Table length=3>
#     ra      dec
#  float64  float64
# --------- --------
# 243.88821 42.92376
# 244.83857 42.25044
# 236.74121 42.59723

# %%
# Download an example mask plane
ra_obj, dec_obj = sample[0]['ra'], sample[0]['dec']
coord = SkyCoord(ra_obj, dec_obj, frame='icrs', unit='deg')

# Size of the cutout should be large enough to contain all the fluxes of the galaxy
#    we want to study and also leave enough space to evaluate background level.
s_ang = 30 * u.arcsec

cutout = hsc_cutout(
    coord, cutout_size=s_ang, filters='i', archive=pdr2,
    use_saved=True, verbose=True, save_output=True, mask=True, variance=True, 
    prefix='dwarf_demo_1', output_dir='data')
# Out:
# # Read in saved FITS file: data/dwarf_demo_1_i.fits

# %%
cutout.info()
# Out:
# Filename: data/dwarf_demo_1_i.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      18   (43, 43)   float64

# %%
label_list = [r"$\rm {}$".format(label) for label in ['Image', 'Mask', 'Variance']]
_ = plotting.display_all(
    cutout, hdu_list=True, img_size=4, label_list=label_list, 
    fontsize=30, fontcolor='w')

# %% [markdown]
# - Cutout image we downloaded has three HDUs.
#     - There is no Primary HDU.
#     - HDU 1 is the image it self.
#     - HDU 2 is the mask plane.
#     - HDU 3 is the variance array.

# %%
i_img = cutout[1].data
i_msk = cutout[2].data
i_var = cutout[3].data

# %% [markdown]
# ### Basics of HSC image and object detection
#
# - Here we are going to briefly mention a few words about the image data. What's the unit? What's the "S/N" of these images.
#      - The pixel value on the science image reflects the flux density measured at a given pixel. We call it "flux density" because we normalize the flux to the total (or effective) exposure time.
#         - This is the science **signal** we rely on.
#         - **Important**: so the image have effective exposure time of 1 second. This is important to know for modeling galaxies. For example, for tools like `galfit` or `imfit`, you need to provide the correct "sigma image" to use them.
#     - The flux density value has been calibrated to system called the [AB magnitude system](https://en.wikipedia.org/wiki/AB_magnitude)
#         - For a flux measurement at any given HSC band, you can convert the image pixel value into AB magnitude using a constant **zeropoint=27.0 mag**.
#         - $m_{\rm AB} = -2.5 \log_{10}f_{\rm pixel} + 27.0$
#         - The magnitude system does not really much sense outside astronomy, but it has been adopdate for weird reasons for more than a century...so it is very hard to change. Just keep reminding yourself that brigther object has higher flux, but has lower value in the magnitude system.
#     - At the same time, the variance map provides measurements of the uncertainty of flux density measurement.
#         - In some way, it measure the **noise** of the signal we want to detect. But also remember that this is not just the statistical "noise" or random uncertainties but also include **systematic uncertainties**.
#         - Also remember that variance is square of the uncertainty value.
#     - There is a lot to be said in the **detection** of astronomical object.
#         - But, to the zeroth order, we basically apply a signal-to-noise (S/N) ratio cut to the image. e.g. We only think we actually detect something when S/N > 5. We can naively call this a "5-sigma" detection.
#         - This will give us all the pixels with flux density value above certain significance level.

# %%
# Convert the variance map into uncertainty map (or `sigma` map).
i_sig = np.sqrt(i_var)

# Then we can get a simple S/N map
i_s2n = i_img / i_sig

# Although this looks very similar to the science image, the value distribution is different.
# This is what the object detection algorithm "sees". 
# Notice that this is very over-simplified: S/N can't be negative; 
#    but we are dealing with background subtracted image, so a lot of the pixels
#    have negative values. This doesn't mean the pixel has "negative" flux, but 
#    the pixel value is below the mean background level.

_ = plotting.display_single(i_s2n)

# %% [markdown]
# - **Question**: Do you think this "Signal-to-Noise" map is accurate? If not, why?

# %% [markdown]
# ### Mask plane
#
# - Please see [this demo](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_mask.ipynb) to understand the meaning of each mask plane
# - To model the galaxy on the image, we usually want to treat the following three planes as "bad pixels", though the bright star plane is optional depending on whether the bright star bothers your target.
#     1. `SAT`: Saturated pixels
#     2. `BAD`: Bad pixels
#     3. `BRIGHT_OBJECT` regions that are affected by a bright star.
# - In this demo, we are very lucky: there is no bad pixel; both saturation and bright stars do not bother us.
# - The `DETECTED` mask plane can also help us later: it means the `hscPipe` pipeline "thinks" these pixels belong to an object.

# %%
# We first convert the single mask plane into something that is easier to understand
mask_demo = mask.Mask(i_msk, data_release='pdr2')

# The following mask planes are occupied
print(mask_demo.name_used())

# Visualizing these mask planes can help you understand what's going on during the image reduction process.
# So we have a few saturated pixels which we will need to mask out (SAT & NO_DATA)
# CR stands for cosmic ray, these pixels have been interpolated over (INTRP)
# We don't have bright star mask on this image.
_, mm = mask_demo.show_used()

# %% [markdown]
# ### PSF model
#
# - We also want the PSF model at the center of the object so that we can use it when modeling the galaxy.
#     - Please check [this demo](https://github.com/dr-guangtou/unagi/blob/master/demo/demo_hsc_psf.ipynb) for more information.
#     - And please read the [HSC SSP Pipeline](https://arxiv.org/abs/1705.06766) paper for details about the PSF modeling process.
#         - If you know the famous `PSFex` algorithm, it is pretty similar to what has been used for HSC.

# %%
# Getting PSF image is rather simple...
# Get single band PSF image

psf_model = hsc_psf(coord, filters='i', archive=pdr2, output_dir='data/', prefix='dwarf_demo_1')

_ = plotting.display_single(psf_model[0].data, scale_bar_length=1.0)

# %% [markdown]
# - The PSF image looks pretty boring, which is GOOD!

# %% [markdown]
# ## Batch download image and PSF
#
# - Just bundle the above procedures into a function, you are good to go.
#
# - Let's update the table to show how to name your targets and generate cutouts of different sizes.
#
# - And we will use `gri` to download data in three filters. You can do `grizy` for all five HSC band if you want.

# %%
# Name of the object
name = ['gal_a', 'gal_b', 'gal_c']

# Half-size of the cutout.
half_size = [20, 15, 30]  # in arcsec

# Sometime you can forget what's the unit your are using, arcsec? kpc? pixel? (not likely in our case...)
# You can use the astropy.units.Quantity and the "Quantity" table for it.
half_size *= u.Unit("arcsec")

# Make a QTable
sample = QTable(
    [name, ra, dec, half_size], names=['name', 'ra', 'dec', 'radius']
)

# %%
def download_cutout(
    obj, archive, filters='i', use_saved=True, ra='ra', dec='dec', name='name', 
    radius='radius', output_dir='data', verbose=False):
    """Download cutout image and the PSF for a single object."""

    coord = SkyCoord(obj[ra], obj[dec], frame='icrs', unit='deg')
    
    if name is not None:
        prefix = obj[name].strip()

    cutout = hsc_cutout(
        coord, cutout_size=obj[radius], filters=filters, archive=archive,
        use_saved=use_saved, verbose=verbose, save_output=True, 
        mask=True, variance=True, prefix=prefix, output_dir=output_dir)

    psf = hsc_psf(
        coord, filters=filters, archive=archive, output_dir=output_dir, 
        verbose=verbose, prefix=prefix)

    return cutout, psf

# %%
# Test it
_ = download_cutout(
    sample[0], pdr2, filters='gri', output_dir='data', verbose=True)

# %%
# Batch download

_ = [download_cutout(obj, pdr2, filters='gri', output_dir='data', verbose=False) for obj in sample]

# %% [markdown]
# **Important**: For a large sample, you may rightfully want to paralle the process to speed things up. It is still unclear to me how much you can speed things up...before NAOJ thinks you are abusing the API...I haven't stress tested it yet. So be mindful, and not try to submit 100 API calls at the same time.
