# %%
from astroquery.irsa import Irsa

# %%
Irsa.list_catalogs()
# Out:
# {'a1763t2': 'Abell 1763 Source Catalog',
#  'a1763t3': 'Abell 1763 MIPS 70 micron Catalog',
#  'acmccat': 'ACMC Catalog',
#  'acs_iphot_sep07': 'COSMOS ACS I-band photometry catalog September 2007',
#  'akari_fis': 'AKARI/FIS Bright Source Catalogue',
#  'akari_irc': 'AKARI/IRC Point Source Catalogue',
#  'akariastflux': 'AKARI Asteroid Flux Catalog',
#  'allsky_2band_p1ba_mch': 'WISE Post-Cryo Single Exposure (L1b) Known SSO Possible Association List ( Caution )',
#  'allsky_2band_p1bl_lod': 'WISE Post-Cryo Single Exposure (L1b) Scan Inventory Table',
#  'allsky_2band_p1bm_frm': 'WISE Post-Cryo Single Exposure (L1b) Image Inventory Table',
#  'allsky_2band_p1bs_frm': 'WISE Post-Cryo Single Exposure (L1b) Frame Metadata Table',
#  'allsky_2band_p1bs_psd': 'WISE Post-Cryo Single Exposure (L1b) Source Table',
#  'allsky_3band_p1ba_mch': 'WISE 3-Band Cryo Known Solar System Object Possible Association List ( Caution )',
# ...

# %%
import astropy.units as u
table_allwise_p3as_mep = Irsa.query_region("NGC1566", catalog="allwise_p3as_mep", spatial="Cone",
                         radius=0.1 * u.arcmin)

# %%
table_allwise_p3as_mep
# Out:
# <Table length=107>
#     source_id_mf          ra         dec     ... moon_masked   dist     angle
#                          deg         deg     ...              arcsec     deg
#        object          float64     float64   ...    object   float64   float64
# -------------------- ----------- ----------- ... ----------- -------- ----------
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# 0638m546_ac51-023895  65.0016417 -54.9379439 ...        0000 0.531535 204.921134
# ...

# %%
table_neowiser_p1bs_psd = Irsa.query_region("NGC1566", catalog="neowiser_p1bs_psd", spatial="Cone",
                         radius=0.1 * u.arcmin)

# %%
table_neowiser_p1bs_psd
# Out:
# <Table length=460>
#      ra         dec         clon     ... k_msig_2mass   dist     angle
#     deg         deg                  ...     mag       arcsec     deg
#   float64     float64      object    ...   float64    float64   float64
# ----------- ----------- ------------ ... ------------ -------- ----------
#  65.0017965 -54.9378401 04h20m00.43s ...       0.0850 0.144883 138.412164
#  65.0017456 -54.9378553 04h20m00.42s ...       0.0850 0.163334 183.193672
#  65.0017570 -54.9378583 04h20m00.42s ...       0.0850 0.174492 175.240774
#  65.0017092 -54.9378529 04h20m00.41s ...       0.0850 0.175974 208.649716
#  65.0018051 -54.9378542 04h20m00.43s ...       0.0850 0.195722 144.392375
#  65.0017217 -54.9378640 04h20m00.41s ...       0.0850  0.20302 196.755047
#  65.0016611 -54.9378402 04h20m00.40s ...       0.0850 0.213587 239.402189
#  65.0017777 -54.9378712 04h20m00.43s ...       0.0850 0.227653 165.425204
#  65.0017525 -54.9378751 04h20m00.42s ...       0.0850  0.23442 178.736212
# ...

# %%
import astropy.units as u
table_allwise_p3as_mep = Irsa.query_region("NGC1365", catalog="allwise_p3as_mep", spatial="Cone",
                         radius=0.1 * u.arcmin)

# %%
table_allwise_p3as_mep
# Out:
# <Table length=58>
#     source_id_mf          ra         dec     ... moon_masked   dist     angle
#                          deg         deg     ...              arcsec     deg
#        object          float64     float64   ...    object   float64   float64
# -------------------- ----------- ----------- ... ----------- -------- ---------
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# 0540m364_ac51-039790  53.4016965 -36.1401859 ...        0000 0.880613 28.924699
# ...

# %%
table_neowiser_p1bs_psd = Irsa.query_region("NGC1365", catalog="neowiser_p1bs_psd", spatial="Cone",
                         radius=0.1 * u.arcmin)

# %%
table_neowiser_p1bs_psd
