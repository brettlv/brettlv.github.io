# %%
from astropy import units

# %%
124900*units.m/units.second*3600
# Out:
# <Quantity 4.4964e+08 m / s>

# %%
pwd
# Out:
# '/Users/brettlv/blog/brettlv.github.io/pythoncode/sss_code'

# %%
from lxml.html import parse
from urllib.request import urlopen
from pandas.io.parsers import TextParser
from pandas import Series
import urllib,requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
root_url='https://www.jipinfanhao.com/259luxu/'

# %%
import re
import urllib.request
 
def getlink(url):
    headers = ("User-Agent", "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36")
    opener = urllib.request.build_opener()
    opener.addheaders = [headers]
    urllib.request.install_opener(opener)
    file = urllib.request.urlopen(url,timeout=5).read()
    file = file.decode('utf-8')
    soup = BeautifulSoup(file,'html.parser')   
    pattern = '(https?://[^\s)";]+(\.(\w|/)*))'
    link = re.compile(pattern).findall(file)
    url_a=soup.find_all('a')
    #去重
    #link = list(set(link))
    return url_a,link
#url = root_url

# %% [markdown]
# # 259luxu

# %%
import os
#os.mkdir('/Volumes/Seagate_Backup_Plus_Drive_Lvb/backupmac/259luxu')
data_download_path='/Volumes/ExtremeSSD/brettlv/sss/sss_fanhao/259luxu/'
list_path='/Volumes/ExtremeSSD/brettlv/sss/sss_fanhao/'

# %% [markdown]
# os.listdir(data_download_path)

# %%
os.listdir(list_path)
# Out:
# ['259luxu.zip',
#  '300mium.zip',
#  '259luxu',
#  '300mium',
#  '259luxu_list_v1.txt',
#  '259luxu_list_v0.txt',
#  '300mium_list_v0.txt',
#  'siro']

# %% [markdown]
# ## get urls_lists

# %%
urls_lists=[]
import time

for i in range(44):
    if i==0:
        url=root_url
    else:
        url='https://www.jipinfanhao.com/259luxu/page/%d/'%(i+1)        
    url_a,linklist = getlink(url)
    for i in url_a:
        i_=i.get('href')
    #print(i_)
        try: 
            if i_.startswith('https://www.jipinfanhao.com/259luxu/259luxu') and i_ not in urls_lists:
                urls_lists.append(i_)
                print(i_)                  
        except: 
            time.sleep(4)
            print()
# Out:
# https://www.jipinfanhao.com/259luxu/259luxu-1399/
# https://www.jipinfanhao.com/259luxu/259luxu-1400/
# https://www.jipinfanhao.com/259luxu/259luxu-1388/
# https://www.jipinfanhao.com/259luxu/259luxu-1374/
# https://www.jipinfanhao.com/259luxu/259luxu-1395/
# https://www.jipinfanhao.com/259luxu/259luxu-1382/
# https://www.jipinfanhao.com/259luxu/259luxu-1387/
# https://www.jipinfanhao.com/259luxu/259luxu-1393/
# https://www.jipinfanhao.com/259luxu/259luxu-1389/
# https://www.jipinfanhao.com/259luxu/259luxu-1378/
# https://www.jipinfanhao.com/259luxu/259luxu-959/
#
# https://www.jipinfanhao.com/259luxu/259luxu-1390/
# https://www.jipinfanhao.com/259luxu/259luxu-1386/
# https://www.jipinfanhao.com/259luxu/259luxu-1391/
# https://www.jipinfanhao.com/259luxu/259luxu-1383/
# https://www.jipinfanhao.com/259luxu/259luxu-1385/
# https://www.jipinfanhao.com/259luxu/259luxu-1384/
# https://www.jipinfanhao.com/259luxu/259luxu-1379/
# https://www.jipinfanhao.com/259luxu/259luxu-1381/
# ...

# %% [markdown]
# with open('%s/259luxu_list_v1.txt'%list_path,'w+') as f:
#     for i in urls_lists:
#         f.write(i+'\n')

# %% [markdown]
# with open("%s/259luxu_list_v0.txt"%list_path, "r") as fo:
#     lines = fo.readlines()

# %%
def gettext(url):
    headers = ("User-Agent", "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36")
    opener = urllib.request.build_opener()
    opener.addheaders = [headers]
    urllib.request.install_opener(opener)
    file = urllib.request.urlopen(url,timeout=10).read()
    file = file.decode('utf-8')
    soup = BeautifulSoup(file,'html.parser')   
    pattern = '(https?://[^\s)";]+(\.(\w|/)*))'
    link = re.compile(pattern).findall(file)
    text_p=soup.find_all('p')
    return text_p

# %%
from urllib import  request
from bs4 import BeautifulSoup
def getimg(url):
    headers = ("User-Agent", "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36")
    opener = urllib.request.build_opener()
    opener.addheaders = [headers]
    urllib.request.install_opener(opener)
    file = urllib.request.urlopen(url,timeout=10).read()
    file = file.decode('utf-8')
    soup = BeautifulSoup(file,'html.parser')   
    pattern = '(https?://[^\s)";]+(\.(\w|/)*))'
    link = re.compile(pattern).findall(file)
    img_=soup.find_all('img')[1]
    #去重
    #link = list(set(link))
    return img_['src']

# %%
pwd
# Out:
# '/Users/brettlv/blog/brettlv.github.io/pythoncode/sss_code'

# %% [markdown]
# text_p=gettext(urls_lists[0])
# for i in range(1,5):
#     print(text_p[i].text)

# %%
data_download_path
# Out:
# '/Volumes/ExtremeSSD/brettlv/sss/sss_fanhao/259luxu/'

# %%
urls_lists[0].split('/')[-2],urls_lists[0].split('/')[-1]
# Out:
# ('259luxu-1399', '')

# %%
for i in urls_lists:    
    name=i.split('/')[-2]   
    text_p=gettext(i)
    print('txt,',name,text_p[1].text)

# %% [markdown]
# ## write_txt_png

# %%
for i in urls_lists:    
    name=i.split('/')[-2]   
    if not os.path.exists(os.path.join(data_download_path,name)+'.txt'):
        text_p=gettext(i)
        print('txt,',name,text_p[1].text)
        
        try:
            with open(os.path.join(data_download_path,name)+'.txt','a') as f:
                for j in range(1,5):
                    f.write(text_p[j].text)  
        except:
            time.sleep(4)
            
    if not os.path.exists(os.path.join(data_download_path,name)+'.jpg'):
        print('img,',name,)
        try:
            img_=getimg(i)
            request.urlretrieve(img_, os.path.join(data_download_path,name)+'.jpg')            
        except:
            time.sleep(5)
# Out:
# img, 259luxu-994

# %% [markdown]
# for i in urls_lists:
#     name=i.split('/')[-2]
#     if not os.path.isfile(os.path.join(data_download_path,name)+'.jpg'):
#         print(name,'jpg')
#     if not os.path.isfile(os.path.join(data_download_path,name)+'.txt'):
#         print(name,'txt')

# %%
for i in urls_lists:    
    name=i.split('/')[-2]  
    if  os.path.exists(os.path.join(data_download_path,name)+'.jpg'):
        size=os.path.getsize(os.path.join(data_download_path,name)+'.jpg')
        if size/1024<50:
            os.remove(os.path.join(data_download_path,name)+'.jpg')
            print(name,size/1024,'kb')
# Out:
# 259luxu-1387 38.505859375 kb
# 259luxu-1381 42.564453125 kb
# 259luxu-1373 44.6591796875 kb
# 259luxu-1352 43.59765625 kb
# 259luxu-1331 42.982421875 kb
# 259luxu-1324 46.908203125 kb
# 259luxu-1307 46.681640625 kb
# 259luxu-1269 41.6533203125 kb
# 259luxu-1267 47.4814453125 kb
# 259luxu-1248 46.0966796875 kb
# 259luxu-1254 45.943359375 kb
# 259luxu-1264 44.4228515625 kb
# 259luxu-1206 45.51171875 kb
# 259luxu-1205 49.3583984375 kb

# %%
len(urls_lists)*2
# Out:
# 878

# %%
urls_lists[0]
# Out:
# 'https://www.jipinfanhao.com/259luxu/259luxu-1399/'

# %%
#url = root_url
url = urls_lists[0]
headers = ("User-Agent", "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36")
opener = urllib.request.build_opener()
opener.addheaders = [headers]
urllib.request.install_opener(opener)
file = urllib.request.urlopen(url).read()
file = file.decode('utf-8')
soup = BeautifulSoup(file,'html.parser') 
img_=soup.find_all('img')
img_[2]['src']
# Out:
# 'https://www.jipinfanhao.com/wp-content/themes/Nana/images/gongzhongha1o.jpg'

# %% [markdown]
# # 300mium/

# %%
root_url_300mium='https://www.jipinfanhao.com/300mium/'
#urls_lists=[]
data_download_path_300mium='/Volumes/ExtremeSSD/brettlv/sss/sss_fanhao/300mium/'

# %%
for i in range(700,200,-1):
    url=root_url_300mium+'300mium-'+str(i)+'/'
    name=url.split('/')[-2]
    if  os.path.exists(os.path.join(data_download_path_300mium,name)+'.jpg'):
        size=os.path.getsize(os.path.join(data_download_path_300mium,name)+'.jpg')
        if size/1024<10:
            os.remove(os.path.join(data_download_path_300mium,name)+'.jpg')
            print(name,size/1024,'kb')

# %%
for i in range(700,200,-1):
    url=root_url_300mium+'300mium-'+str(i)+'/'
    if checkUrl(url):
        name=url.split('/')[-2]             
        if not os.path.exists(os.path.join(data_download_path_300mium,name)+'.txt'):
            print(url)   
            text_p=gettext(url)
            print('txt,',name,text_p[1].text)
        
            try:
                with open(os.path.join(data_download_path_300mium,name)+'.txt','a') as f:
                    for j in range(1,5):
                        f.write(text_p[j].text)  
            except:
                time.sleep(4)
            
        if not os.path.exists(os.path.join(data_download_path_300mium,name)+'.jpg'):
            print('img,',name,)
            try:
                img_=getimg(url)
                request.urlretrieve(img_, os.path.join(data_download_path_300mium,name)+'.jpg')            
            except:
                time.sleep(5)
# Out:
# https://www.jipinfanhao.com/300mium/300mium-694/
# txt, 300mium-694 300MIUM系列-300MIUM-694 雅酱22岁美容机器制造商宣传
# img, 300mium-694
# https://www.jipinfanhao.com/300mium/300mium-692/
# txt, 300mium-692 300MIUM系列-300MIUM-692 爱26岁原保育员
# img, 300mium-692
# https://www.jipinfanhao.com/300mium/300mium-691/
# txt, 300mium-691 300MIUM系列-300MIUM-691 这位是23岁健康食品的营业员
# img, 300mium-691
# https://www.jipinfanhao.com/300mium/300mium-689/
# txt, 300mium-689 300MIUM系列-300MIUM-689 35岁原模特高木丽奈
# img, 300mium-689
# https://www.jipinfanhao.com/300mium/300mium-686/
# txt, 300mium-686 300MIUM系列-300MIUM-686 Nacchan 20岁的保姆
# img, 300mium-686
# https://www.jipinfanhao.com/300mium/300mium-685/
# txt, 300mium-685 300MIUM系列-300MIUM-685 小葵20岁的时候正好喝啤酒的护士学生
# img, 300mium-685
# https://www.jipinfanhao.com/300mium/300mium-684/
# txt, 300mium-684 300MIUM系列-300MIUM-684 出版社工作/远野先生/入社第2年
# img, 300mium-684
# https://www.jipinfanhao.com/300mium/300mium-683/
# txt, 300mium-683 300MIUM系列-300MIUM-683 28岁现役赛车女王夫人
# ...

# %% [markdown]
# with open('%s/300mium_list_v1.txt'%list_path,'w+') as f:
#     for i in urls_lists_300mium:
#         f.write(i+'\n')

# %%
with open("%s/300mium_list_v0.txt"%list_path, "r") as fo:
    lines = fo.readlines()

# %% [markdown]
# # siro

# %%
root_url_siro='https://www.jipinfanhao.com/siro/'
#urls_lists=[]
data_download_path_siro='/Volumes/ExtremeSSD/brettlv/sss/sss_fanhao/siro/'

# %%
'https://www.jipinfanhao.com/siro/'.split('/')[-2]
# Out:
# 'siro'

# %%
4466-3406

# %%
102*10

# %%
import requests

def checkUrl(url):
    request = requests.get(url) #Here is where im getting the error
    if request.status_code == 200:
        return True

# %%
for i in range(4466,4466-10,-1):
    print(i)
# Out:
# 4466
# 4465
# 4464
# 4463
# 4462
# 4461
# 4460
# 4459
# 4458
# 4457

# %%
for i in range(4466,3000,-1):
    url=root_url_siro+'siro-'+str(i)+'/'
    name=url.split('/')[-2]
    if  os.path.exists(os.path.join(data_download_path_siro,name)+'.jpg'):
        size=os.path.getsize(os.path.join(data_download_path_siro,name)+'.jpg')
        if size/1024<10:
            os.remove(os.path.join(data_download_path_siro,name)+'.jpg')
            print(name,size/1024,'kb')
# Out:
# siro-3527 8.11328125 kb
# siro-3448 8.11328125 kb

# %%
for i in range(4466,3000,-1):
    url=root_url_siro+'siro-'+str(i)+'/'
    if checkUrl(url):
        name=url.split('/')[-2]             
        if not os.path.exists(os.path.join(data_download_path_siro,name)+'.txt'):
            print(url)   
            text_p=gettext(url)
            print('txt,',name,text_p[1].text)
        
            try:
                with open(os.path.join(data_download_path_siro,name)+'.txt','a') as f:
                    for j in range(1,5):
                        f.write(text_p[j].text)  
            except:
                time.sleep(4)
            
        if not os.path.exists(os.path.join(data_download_path_siro,name)+'.jpg'):
            print('img,',name,)
            try:
                img_=getimg(url)
                request.urlretrieve(img_, os.path.join(data_download_path_siro,name)+'.jpg')            
            except:
                time.sleep(5)

# %%
for i in range(3000,4466,):
    url=root_url_siro+'siro-'+str(i)+'/'    
    name=url.split('/')[-2]             
    if  os.path.exists(os.path.join(data_download_path_siro,name)+'.txt'):
        print(url) 
        with open(os.path.join(data_download_path_siro,name)+'.txt','r') as f:
            line=f.readline()
            print(line)
# Out:
# https://www.jipinfanhao.com/siro/siro-3374/
# SIRO系列番号：SIRO-3374，片长60分钟，发片时间是2018/05/14，女主是19岁大学生。大学生的“胡桃”19岁。因为对AV感兴趣，所以试着应征了。这是一个稳重大方的性格，用纤细的声音给人很可爱的印象，不过是一个很不错的肉食系女子！首次体验是18岁。经验人数为15人。一年里竟然有这样的经验！听了详细情况，“有点吃力的话就增加了w”是啊w很喜欢可爱的脸，以吃吃的感觉来渔人的魔性女人“胡桃”♪很喜欢H的事情！可爱的奶也大。杯子是E杯♪如果是这样的女儿，被这样的女儿玩弄也不会有怨言的♪不愧是丁丁，灵敏度很好！只要揉奶就敏感地反应！如果舔了乳头的话，就会发出可爱的喘气声。ma○个的灵敏度也很好，她喘息的时候兴奋倍增！！渔人魔性的女人“胡桃”。我也被她的俘虏了w
#
# https://www.jipinfanhao.com/siro/siro-3391/
# SIRO系列番号：SIRO-3391，片长56分钟，发片时间是2018/05/27，女主是26岁补习班的接待处。平时在接受升学补习班的裕子先生。说话方式和动作很礼貌，很能接受。我羡慕这样美女姐姐每次去补习班的学生。一想到总是坐在桌子上的姐姐出演AV的话会很紧张。为了尽快推荐拍摄，顺便去了一下，皮肤白的美丽的皮肤会突出。从后面揉奶的话是有弹性的尺寸也容易揉的尺寸。如果脱了衣服直接享受皮肤的话，会有反应的话，
#
# https://www.jipinfanhao.com/siro/siro-3393/
# SIRO系列番号：SIRO-3393，片长58分钟，发片时间是2018/05/15，女主是24岁化妆品销售员。轻盈的嘴唇，丰盈的胸是很棒的玲。第一次见面的时候，这两个地方容易映入眼帘，但她真正的魅力隐藏在看不见的地方。首先是声音。平时用沉稳的低沉的声音说话，感觉到了心情舒畅的地方，就会露出像铃铛一样可爱的声音。另外，如果注意到将穿的东西全部剥掉的话，就像铃铛一样可爱。用手指摆弄那个的话，像铃铛一样的喘息声溢出不停。被声音邀请的时候，一直都想玩弄栗子……我们这样命名了她。“Ring my bel（我的铃响了）……”如果是铃铛的话，我们也不会输。两个铃铛的大合唱开始了。不要错过，听不开。
#
# ...
