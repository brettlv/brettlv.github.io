# %% [markdown]
# # Analysing the arXiv
#
# *This notebook first appeared as a [blog post](//betatim.github.io/posts/analysing-the-arxiv) on [Tim Head](//betatim.github.io)'s blog.*
#
# *License: [MIT](http://opensource.org/licenses/MIT)*
#
# *(C) 2014, Tim Head.*
# *Feel free to use, distribute, and modify with the above attribution.*

# %% [markdown]
# This post is about what you can learn about scientific articles posted on the [arXiv](http://arxiv.org) by using Natural Language Processing (NLP). Said differently: I had some questions about papers posted on the arXiv and used it as an excuse to teach myself the basics of NLP. We also look at citation counts and reveal the top cited paper of 2014!
#
# The arXiv makes its data available via a simple API which allows you to download almost everything about an article short of its full text. For each article we can look up information about who has been citing it on [inspire](http://inspirehep.net/). Combined this is a powerful dataset that can answer some interesting questions like: what are the most used words, can we auto generate abstracts, what about summarising abstracts or finding the most cited article of 2014.
#
# Let's get going!
#
# First some standard imports that we will need later. Some of them you might need to install but nothing too obscure:

# %%
import time
import urllib2# python2
import urllib
import datetime
from itertools import ifilter
from collections import Counter, defaultdict
import xml.etree.ElementTree as ET
import h5py
from bs4 import BeautifulSoup
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import bibtexparser

pd.set_option('mode.chained_assignment','warn')

# %%
# %matplotlib inline

# %% [markdown]
# The `harvest` function will query the arXiv API for all articles modified between January, 1st 2010 and the end of the year 2014. This is a subtlety worth noting: with this query you will also get articles _created_ before 2010 if their entry was modified after 2010.
#
# The arXiv itself covers so many topics that it is organised into seperate arxivs (I know unfortunate doulbe use of the name arxiv), one for each topic. By default `harvest` will collect articles from the `physics:hep-ex` arxiv. This is because I am a experimental particle physicist. If you are into theory try `physics:hep-th` or `stats` if you are a stats guru. The API gives you a [full list of all sets of topics](http://export.arxiv.org/oai2?verb=ListSets) to explore.
#
# If you do not care for the technicalities of how to scrape the data skip right ahead to the first [factoid](#factoid).
#
#
# ## Harvesting articles
#
# Most of `harvest` is pretty straight forward. The API returns a big XML document containing information about at most 1000 articles which we can parse with `ElementTree` and store. If there are more than 1000 articles for a particular query we can get those using the `resumptionToken` in the XML. API access can be throttled so on occasion the arXiv will reply with a 503 error asking us to retry later. The information we harvest is stored in a `pandas` dataframe.

# %% [markdown]
# <set>
# <setSpec>physics:astro-ph</setSpec>
# <setName>Astrophysics</setName>
# </set>

# %%
OAI = "{http://www.openarchives.org/OAI/2.0/}"
ARXIV = "{http://arxiv.org/OAI/arXiv/}"

def harvest(arxiv="physics:astro-ph",yearstart=2017):
    df = pd.DataFrame(columns=("title", "abstract", "categories", "created", "id", "doi"))
    base_url = "http://export.arxiv.org/oai2?verb=ListRecords&"
    url = (base_url +
           "from=%i-01-01&until=%i-12-31&"%(yearstart,yearstart) +
           "metadataPrefix=arXiv&set=%s"%arxiv)
    
    while True:
        print "fetching", url
        try:
            response = urllib2.urlopen(url)
            
        except urllib2.HTTPError, e:
            if e.code == 503:
                to = int(e.hdrs.get("retry-after", 30))
                print "Got 503. Retrying after {0:d} seconds.".format(to)

                time.sleep(to)
                continue
                
            else:
                raise
            
        xml = response.read()

        root = ET.fromstring(xml)

        for record in root.find(OAI+'ListRecords').findall(OAI+"record"):
            arxiv_id = record.find(OAI+'header').find(OAI+'identifier')
            meta = record.find(OAI+'metadata')
            info = meta.find(ARXIV+"arXiv")
            created = info.find(ARXIV+"created").text
            created = datetime.datetime.strptime(created, "%Y-%m-%d")
            categories = info.find(ARXIV+"categories").text

            # if there is more than one DOI use the first one
            # often the second one (if it exists at all) refers
            # to an eratum or similar
            doi = info.find(ARXIV+"doi")
            if doi is not None:
                doi = doi.text.split()[0]
                
            contents = {'title': info.find(ARXIV+"title").text,
                        'id': info.find(ARXIV+"id").text,#arxiv_id.text[4:],
                        'abstract': info.find(ARXIV+"abstract").text.strip(),
                        'created': created,
                        'categories': categories.split(),
                        'doi': doi,
                        }

            df = df.append(contents, ignore_index=True)

        # The list of articles returned by the API comes in chunks of
        # 1000 articles. The presence of a resumptionToken tells us that
        # there is more to be fetched.
        token = root.find(OAI+'ListRecords').find(OAI+"resumptionToken")
        if token is None or token.text is None:
            break

        else:
            url = base_url + "resumptionToken=%s"%(token.text)
            
    return df

# %% [markdown]
# Set `harvest` running and go chat with someone for a few minutes while it gathers the information about your articles.

# %%
df = harvest(arxiv="physics:astro-ph",yearstart=2017)
# Out:
# fetching http://export.arxiv.org/oai2?verb=ListRecords&from=2017-01-01&until=2017-12-31&metadataPrefix=arXiv&set=physics:astro-ph
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|1001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|2001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|3001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|4001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|5001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|6001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|7001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|8001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|9001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|10001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|11001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|12001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|13001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|14001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|15001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=3124377|16001

# %% [markdown]
# What does all that stuff we just downloaded look like? Here are the first five entries in the dataframe:

# %%
# Out:
# (100710, 117495, 100710, 100710)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## First factoid
# <a id="factoid"></a>

# %%
def bar_chart(items):
    """Make a bar chart showing the count associated with each key
    
    `items` is a list of (key, count) pairs.
    """
    width = 0.5
    ind = np.arange(len(items))
    fig, ax = plt.subplots(figsize=(8,8))
    rects1 = ax.bar(ind, zip(*items)[1], width, color='r')
    ax.set_xticks(ind+width)
    ax.set_xticklabels(zip(*items)[0])
    fig.autofmt_xdate()
    plt.show()

edits_per_year = Counter(df.created.map(lambda x: x.year))
bar_chart(edits_per_year.items())
new_articles = sum(edits_per_year[year] for year in (2017))
print "Unique arXiv IDs edited between 2017-01-01 and 2017-12-31:", len(df.id.unique())
print "of which %i entries were created in 2017."%(new_articles)
# Out:
# Unique arXiv IDs edited between 2015 and 2017: 16785
# of which 15561 entries were created in that time period.

# %%
edits_per_year

# %% [markdown]
# Here is our first factoid about the arXiv: There are about 16000 articles in `hep-ex` which were edited between the beginning of 2010 and the end of 2014. Including about 12000 newly created articles. The other 4000 papers were created before 2010 and were updated after creation. Amazing to see that papers created in 1994 were still being edited almost ten years later!
#
# Let's take a look at those, maybe there is something interesting:

# %%
df[df.created<datetime.date(2017,1,1)].size,df[df.created>datetime.date(2017,1,1)].size
# Out:
# (34866, 65766)

# %%
df[df.created<datetime.date(2005,1,1)]
# Out:
#                                                    title  \
# 16303              Probing the Cosmic Dark Age in X-rays
# 16304  Formation of Molecular Gas in the debris of vi...
# 16305  Resolving the extragalactic hard X-ray background
# 16306       The Mystery of Ultra-High Energy Cosmic Rays
# 16307  Detection of weak gravitational lensing distor...
# 16308  Galactic Worm 123.4-1.5: A Mushroom-shaped HI ...
# 16309                                         Supernovae
# 16310  The Quest for Quantum Gravity: Testing Times f...
# 16311                           Cosmic Phase Transitions
# 16312  The exact solution of the Riemann problem with...
# 16313                 The Solar Core and Solar Neutrinos
# 16314                        Looking Back with Neutrinos
# 16315  The Initial Mass Function of Low-Mass Stars an...
# 16316  CO and Near-Infrared Observations of High-Reds...
# 16317         The Nature of Faint Submillimeter Galaxies
# 16318                   Cosmology with Varying Constants
# 16319       High redshift CO line emission: perspectives
# 16320  Selection effects in high-redshift submillimet...
# 16321  A Submillimeter Selected Quasar in the Field o...
# 16322  Atmospheric Secondary Particles In Near Earth ...
# 16323  The brighter side of sub-mm source counts: a S...
# 16324        Sub-mm counterparts to Lyman-break galaxies
# 16325  Probing the Structure of Dark Matter in Galaxy...
# 16326                      Wide Field Imaging at 250 GHz
# 16327  Observational Approaches to the Topology of th...
# 16328  Observations of Mkn 421 with the CELESTE Exper...
# 16329                    Known and unknown SCUBA sources
# 16330  Can dusty Lyman break galaxies produce the sub...
# 16331                        Supernova Studies at ORLaND
# 16332  Searching for Supersymmetric Dark Matter- The ...
# ...                                                  ...
# 16744  SuperGZK neutrinos: testing physics beyond the...
# 16745                 Cosmology at the Turn of Centuries
# 16746  Electroweak baryogenesis and primordial hyperm...
# 16747  Simulation of the radio signal from ultrahigh ...
# 16748  Thermal Production of Axinos in the Early Univ...
# 16749  Progress in nonequilibrium quantum field theor...
# 16750      NuTeV Anomaly & Strange-Antistrange Asymmetry
# 16754  Remarks on parametric resonance of neutrino os...
# 16755  The $\nu_\mu \leftrightarrow \nu_s$ interpreta...
# 16756      TASI Lectures: Cosmology for String Theorists
# 16757                     Inflation and String Cosmology
# 16758  Self-tuning solutions of the cosmological cons...
# 16759                        Quintessence Model Building
# 16760  Diluting Cosmological Constant via Large Dista...
# 16761  Trans-Planckian Physics and Inflationary Cosmo...
# 16762               Tachyon Dynamics and Brane Cosmology
# 16763  Lectures on the Theory of Cosmological Perturb...
# 16764  Late-time effects of Planck-scale cosmology: d...
# 16765  Noncommutative inflation and the large-scale d...
# 16768  The Black Hole: Scatterer, Absorber and Emitte...
# 16769  Hawking Radiation in String Theory and the Str...
# 16771  Open Questions in Stellar Helium Burning Addre...
# 16772  Soft Modes, Quantum Transport and Kinetic Entropy
# 16773  Strange hadronic stellar matter within the Bru...
# 16774  Nuclear Aspects of Nucleosynthesis in Massive ...
# 16775                Neutrino Effects in Nucleosynthesis
# 16776  Cooling of Neutron Stars Revisited: Applicatio...
# 16777       Hyperonic crystallization in hadronic matter
# 16778  Reaction Rates and Nuclear Properties Relevant...
# 16782                    Topics in Neutrino Astrophysics
#
#                                                 abstract  \
# 16303  Empirical studies of the first generation of s...
# 16304  In many gravitational interactions between gal...
# 16305  The origin of the hard (2-10 keV) X-ray backgr...
# 16306  The origin of cosmic rays with energies higher...
# 16307  Most of the matter in the universe is not lumi...
# 16308  The Dominion Radio Astrophysical Observatory's...
# 16309  The properties of supernovae (SNe) are reviewe...
# 16310  I discuss some theoretical ideas concerning th...
# 16311  The sequence of phase transitions during the h...
# 16312  We have generalised the exact solution of the ...
# 16313  The long-standing deficit of measured versus p...
# 16314  We briefly discuss the history of suggestions ...
# 16315  By combining deep optical imaging and infrared...
# 16316  I discuss our ongoing Owens Valley Millimeter ...
# 16317  We summarise the main results on the faint sub...
# 16318  I motivate and discuss some recent work on the...
# 16319  Although about a dozen high redshift (z larger...
# 16320  The results of the first generation of submill...
# 16321  We report the discovery of a z=2.83 quasar in ...
# 16322  The Alpha Magnetic Spectrometer detects a larg...
# 16323  We present an 11 X 11 arcminute map centred on...
# 16324  We summarize the main results from our SCUBA s...
# 16325  A new method for measuring gravitational lensi...
# 16326  We summarize results from sensitive, wide-fiel...
# 16327  Many different and complementary strategies fo...
# 16328  The CELESTE experiment uses the heliostats of ...
# 16329  Summary and discussion of some projects to use...
# 16330  Can the submillimeter counts and background be...
# 16331  A new facility to measure neutrino mass differ...
# 16332  The detection of the theoretically expected da...
# ...                                                  ...
# 16744  The sources and fluxes of superGZK neutrinos, ...
# 16745  A brief review of the present-day development ...
# 16746  The origin of the matter-antimatter asymmetry ...
# 16747  PeV neutrinos produce particle showers when th...
# 16748  We compute the thermal axino production rate i...
# 16749  We review recent developments for the descript...
# 16750  The NuTeV Collaboration reported a value of $\...
# 16754  Neutrino oscillations in matter can exhibit a ...
# 16755  The data on atmospheric neutrinos can be expla...
# 16756  These notes provide a brief introduction to mo...
# 16757  Inflationary theory is already 20 years old, a...
# 16758  I briefly review the cosmological constant pro...
# 16759  A short review of some of the aspects of quint...
# 16760  We review a solution of the cosmological const...
# 16761  Due to the quasi-exponential red-shifting whic...
# 16762  We discuss the cosmological implications of so...
# 16763  The theory of cosmological perturbations has b...
# 16764  We present a model of dark energy based on the...
# 16765  We show that a certain class of short-distance...
# 16768  Accurate and powerful computational methods de...
# 16769  The quantum string emission by Black Holes is ...
# 16771  The outcome of helium burning is the formation...
# 16772  The effects of the propagation of particles wh...
# 16773  In the framework of the non-relativistic Bruec...
# 16774  Preliminary results of a new set of stellar ev...
# 16775  The nucleosynthesis within a Type II supernova...
# 16776  Cooling of neutrons stars proceeds mainly via ...
# 16777  Published in Hadrons, Nuclei and Applications,...
# 16778  Explosive nuclear burning in astrophysical env...
# 16782  These lectures cover three topics in neutrino ...
#
#                                          categories    created  \
# 16303                                    [astro-ph] 2000-01-14
# 16304                                    [astro-ph] 2000-02-08
# 16305                                    [astro-ph] 2000-02-16
# 16306                                    [astro-ph] 2000-03-01
# 16307                                    [astro-ph] 2000-03-01
# 16308                                    [astro-ph] 2000-03-06
# 16309                                    [astro-ph] 2000-03-06
# 16310                     [astro-ph, gr-qc, hep-ph] 2000-04-17
# 16311                           [astro-ph, nucl-th] 2000-04-28
# 16774   nucl-th/0008065                         10.1142/9789812810922_0051
# 16775   nucl-th/0012063                         10.1142/9789812811714_0003
# 16776   nucl-th/0012073                         10.1142/9789812810922_0054
# 16777   nucl-th/0105031                         10.1142/9789812810922_0060
# 16778   nucl-th/0302046                         10.1142/9789812795151_0043
# 16782   nucl-th/9901076                         10.1142/9789812813497_0007
#
# [405 rows x 6 columns]

# %% [markdown]
# After scrolling through the list I can not spot a particular pattern to the edits. Though it does seem like the list contains articles on interesting topics like evidence for the top quark (index 15148), PeV $\tau$ neutrinos (index 16113) and an article about determining the weak mixing angle at SLD (index 15149).
#
# ## Collecting citations
#
# Unfortunately Inspire does not provide a real API, so we have to scrape their webpages to get what we want. The `get_cites` function will look up the citations of an article by its `arxiv_id`. Having to make one HTTP request per article means this takes quite a while. So set it going and come back after a few hours. We process articles in chunks of 1000 to get some feedback as well as being able to resume if something goes wrong:

# %%
len(df)
# Out:
# 16785

# %%
def get_cites(arxiv_id):
    cites = []
    base_url = "http://inspirehep.net/search?p=refersto:%s&of=hx&rg=250&jrec=%i"
    offset = 1
    
    while True:
        print base_url%(arxiv_id, offset)
        response = urllib2.urlopen(base_url%(arxiv_id, offset))
        xml = response.read()
        soup = BeautifulSoup(xml)

        refs = "\n".join(cite.get_text() for cite in soup.findAll("pre"))

        bib_database = bibtexparser.loads(refs)
        if bib_database.entries:
            cites += bib_database.entries
            offset += 250
            
        else:
            break

    return cites
# Out:
# http://inspirehep.net/search?p=refersto:0704.0603&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0704.2108&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0704.2108&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0705.1208&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0705.1208&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0705.1240&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0705.1240&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0705.1771&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0705.1771&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0705.2017&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0705.2017&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0706.0278&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0706.0278&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0706.1279&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0706.1279&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0706.3209&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0706.3209&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0706.4146&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0706.4146&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0707.0472&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.0472&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0707.0687&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.2334&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.2425&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.2425&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0707.3867&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.3867&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0707.4074&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.4074&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0707.4342&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0707.4342&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.0073&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.0073&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.0113&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.0113&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.0134&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.0134&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.0852&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.0852&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.0898&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.0898&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.1201&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.1201&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.1441&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.1441&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.1804&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.1804&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.2002&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.2002&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.3536&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.3536&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.3716&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.3716&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.3833&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.3833&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.3968&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.3968&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0708.4227&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0708.4227&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0709.1580&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0709.1580&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0709.2414&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0709.2414&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0709.3151&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0709.3151&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0709.3798&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0709.3798&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0709.4315&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0709.4315&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0710.0382&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.0382&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0710.0846&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.0846&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0710.1528&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.2605&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.2605&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0710.3067&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.4248&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.5010&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.5010&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0710.5388&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0710.5388&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.0359&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.0991&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.0991&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.1044&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.1201&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.1201&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.1454&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.1454&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.1912&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.1912&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.2282&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.2282&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.2308&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.2308&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.2715&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.2715&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.2823&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.2823&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.2853&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.2853&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.2962&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.2962&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.3234&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.3234&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.3393&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.3393&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.4018&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.4018&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0711.4779&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0711.4779&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.0280&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.0280&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.0874&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.0874&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.0877&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.0877&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.1866&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.1866&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.3072&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.3072&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.3984&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.3984&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:0712.4190&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:0712.4190&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:
of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:1203.6334&of=hx&rg=250&jrec=1
# http://inspirehep.net/search?p=refersto:1203.6334&of=hx&rg=250&jrec=251
# http://inspirehep.net/search?p=refersto:1203.6651&of=hx&rg=250&jrec=1
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-54-910541937dd2> in <module>()
#      23 step = 1000
#      24 for N in range(0,1):
# ---> 25     cites = df['id'][N*step:(N+1)*step].map(get_cites)
#      26     df.ix[N*step:(N+1)*step -1,'cited_by'] = cites
#      27     print N
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in map(self, arg, na_action)
#    2175             new_values = algos.take_1d(arg._values, indexer)
#    2176         else:
# -> 2177             new_values = map_f(values, arg)
#    2178
#    2179         return self._constructor(new_values,
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:66124)()
#
# <ipython-input-54-910541937dd2> in get_cites(arxiv_id)
#      12         refs = "\n".join(cite.get_text() for cite in soup.findAll("pre"))
#      13
# ---> 14         bib_database = bibtexparser.loads(refs)
#      15         if bib_database.entries:
#      16             cites += bib_database.entries
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/bibtexparser/__init__.pyc in loads(bibtex_str, parser)
#      46     if parser is None:
#      47         parser = bparser.BibTexParser()
# ---> 48     return parser.parse(bibtex_str)
#      49
#      50
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/bibtexparser/bparser.pyc in parse(self, bibtex_str, partial)
#     149             logger.error("Could not parse properly, starting at %s", exc.line)
#     150             if not partial:
# --> 151                 raise exc
#     152         return self.bib_database
#     153
#
# ParseException: Expected end of text (at char 1207), (line:39, col:1)

# %%
step = 1000
for N in range(0,1):
    cites = df['id'][N*step:(N+1)*step].map(get_cites)
    df.ix[N*step:(N+1)*step -1,'cited_by'] = cites
    print N

# %%
for N in range(5,8):
    cites = df['id'][N*step:(N+1)*step].map(get_cites)
    df.ix[N*step:(N+1)*step -1,'cited_by'] = cites
    print N

# %%
for N in range(9,12):
    cites = df['id'][N*step:(N+1)*step].map(get_cites)
    df.ix[N*step:(N+1)*step -1,'cited_by'] = cites
    print N

# %%
for N in range(13,17):
    cites = df['id'][N*step:(N+1)*step].map(get_cites)
    df.ix[N*step:(N+1)*step -1,'cited_by'] = cites
    print N

# %%
df['cited_by']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-94dfb919d204> in <module>()
# ----> 1 df['cited_by']
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'cited_by'

# %%
ls ./arxiv-experiments/*
# Out:
# ./arxiv-experiments/astro-ph2017.csv  ./arxiv-experiments/astro-ph2017.pkl
# ./arxiv-experiments/astro-ph2017.h5

# %% [markdown]
# ## Data preservation
#
# After investing so much time to gather the raw data it is a good idea to store it locally so we do not have to scrape it all again later:

# %%
#mkdir arxiv-experiments
df.to_csv("./arxiv-experiments/astro-ph2017.csv",encoding='utf-8')
df2017csv=pd.read_csv("./arxiv-experiments/astro-ph2017.csv")

df.to_pickle("./arxiv-experiments/astro-ph2017.pkl")  # where to save it, usually as a .pkl
df2017pkl = pd.read_pickle("./arxiv-experiments/astro-ph2017.pkl") # load it back using

store = pd.HDFStore('./arxiv-experiments/astro-ph2017.h5')
store['df'] = df  # save it
df2017h5=store['df']  # load it
store.close()
df.size,df2017csv.size,df2017pkl.size,df2017h5.size

# %%
df.head()
# Out:
#                                                title  \
# 0  The height dependence of temperature - velocit...
# 1  A Near-Infrared Study of the Highly-Obscured A...
# 2  Utilization of photon orbital angular momentum...
# 3  Quark-nova explosion inside a collapsar: appli...
# 4  Performance of the Charge Injection Capability...
#
#                                             abstract  \
# 0  We derive correlation coefficients between tem...
# 1  We present wide-field JHKs-band photometric ob...
# 2  We show numerically that vector antenna arrays...
# 3  If a quark-nova occurs inside a collapsar, the...
# 4  A charge injection technique is applied to the...
#
#                      categories    created         id  \
# 0                    [astro-ph] 2007-04-04  0704.0603
# 1                    [astro-ph] 2007-04-17  0704.2108
# 2  [astro-ph, physics.class-ph] 2007-05-09  0705.1208
# 3                    [astro-ph] 2007-05-09  0705.1240
# 4                    [astro-ph] 2007-05-12  0705.1771
#
#                              doi
# 0                           None
# 1     10.5303/JKAS.2007.40.1.017
# 2  10.1103/PhysRevLett.99.087701
# 3            10.1155/2009/463521
# 4         10.1093/pasj/60.sp1.S1

# %%
pwd

# %% [markdown]
# ## Word counts
#
# Let's get to answering some questions. What are the ten most used words in `hep-ex` abstracts?

# %%
word_bag = " ".join(df.abstract.apply(lambda t: t.lower()))

Counter(word_bag.split()).most_common(n=100)[20:]

# %% [markdown]
# Not too enlightening, boring little words close out the top ten. These words are known as stopwords and the `NLTK` library provides a list of all of them. So let's remove them as well as basic mathematical symbols:

# %%
from nltk.corpus import stopwords

stops = [word for word in stopwords.words('english')]
stops += ["=", "->","find",'two','one','using','also','show','use']
words = filter(lambda w: w not in stops,
               word_bag.split())
top_twenty = Counter(words).most_common(n=20)

bar_chart(top_twenty)

# %% [markdown]
# Experimental physics is all about data afterall! A shame that `model` beats `detector` but probably that is inevitable as there are many more theoretical models than experimental detectors. The `higgs` boson beats the `neutrino` but they reign supreme over all the other particles.
#
# Towards the bottom we have `measurements` and `measured`. These should probably be counted as one entry, together with `measurement`, `measuring`, etc. The easiest way to achieve this is to stem the words before counting. [Stemming](http://en.wikipedia.org/wiki/Stemming) is the process of reducing derived words to their stem, for example:

# %%
import nltk.stem as stem

porter = stem.PorterStemmer()
for w in ("measurement", "measurements", "measured", "measure"):
    print w, "->", porter.stem(w)
# Out:
# measurement -> measur
# measurements -> measur
# measured -> measur
# measure -> measur

# %% [markdown]
# Like in this case the stem does not have to be a real word itself. By stemming words before counting how often they occur the entries for `measurements` and `measured` get added together. Using the stem of every word we get the following ranking:

# %%
word_stems = map(lambda w: (porter.stem(w),w), words)
stem2words = defaultdict(set)
for stem, word in word_stems:
    stem2words[stem].add(word)

top_twenty = Counter(w[0] for w in word_stems).most_common(n=20)

bar_chart(top_twenty)

# list all words which correspond to each top twenty stem
for stem,count in top_twenty:
    print stem, "<-", ", ".join(stem2words[stem])
# Out:
# observ <- observational, observable, observation, observer, observes, observing, observed, observe, observations, observationally, observables, observability, observers, observably
# model <- models, modelings, modellers, modeled, modelization, modelling, modelized, modelled, modeling, model, modelers
# star <- star, stars
# galaxi <- galaxies, galaxy
# mass <- masse, masses, mass
# result <- resulted, resultant, resulting, results, result
# field <- field, fielding, fields
# present <- presently, presented, presentations, presents, presenting, presentation, present
# stellar <- stellar, stellare
# data <- data
# use <- use, used, useful, usefully, uses, usefulness
# measur <- measuring, measures, measureables, measurements, measure, measurable, measurably, measurability, measurement, measured
# detect <- detect, detectability, detections, detectably, detection, detected, detectable, detecting, detects, detectabilities
# studi <- studying, study, studied, studies
# emiss <- emissive, emissivities, emission, emissivity, emissions
# energi <- energies, energy
# differ <- different, differences, differ, differing, differents, differently, differed, differs, difference
# magnet <- magnetically, magnetization, magnetic, magnetized, magnet, magnetism, magnets, magnetizations
# sourc <- source, sourcing, sourced, sources
# effect <- effected, effectivity, effective, effect, effectively, effects, effectiveness

# %% [markdown]
# Turns out experimental phsics is all about measuring things. The stemming is not perfect, but good enough for now.
#
#
# ## Cite me, cite me, no cite me!
#
# In science citations is the currency used to measure the success of a paper. What does the distribution of citations look like then?
#
# A simple question to ask is: how often are articles cited? As articles have to be read and understood before they can be cited we only look at articles created before the beginning of 2014.

# %%
before_2017 = datetime.datetime(2017,1,1)
plt.hist(df[df.created<before_2017].cited_by.map(len),
         bins=200, normed=True, range=(0,200))
plt.xlabel("Number of citations")
plt.ylabel("Fraction")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-2644bb7281c6> in <module>()
#       1 before_2014 = datetime.datetime(2017,1,1)
# ----> 2 plt.hist(df[df.created<before_2014].cited_by.map(len),
#       3          bins=200, normed=True, range=(0,200))
#       4 plt.xlabel("Number of citations")
#       5 plt.ylabel("Fraction")
#
# /Users/brettlv/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cited_by'

# %% [markdown]
# This plot shows the fraction of articles cited zero, one, two, three, ... times. The single most likely number of citations for an article on `hep-ex` is zero! A whopping 13% of articles never get cited and nearly a third of articles are cited less than four times.

# %%
df['citation_count'] = df.cited_by.map(len)
df[df.created<before_2014]['citation_count'].describe()
# Out:
# count    14059.000000
# mean        32.630486
# std        100.773436
# min          0.000000
# 25%          2.000000
# 50%         10.000000
# 75%         31.000000
# max       4138.000000
# Name: citation_count, dtype: float64

# %% [markdown]
# The average number of citations is about 33. The average is misleading for a steeply falling distribution like this, afterall we reach the 50% percentile at only 10 citations!
#
# ## Citations top ten
# <a id="topten"></a>
#
# The prize for most cited paper with a whopping 4138 citations goes to:

# %%
df.iloc[df.citation_count.idxmax()]
# Out:
# title             New Generation of Parton Distributions with Un...
# abstract          A new generation of parton distribution functi...
# categories                                         [hep-ph, hep-ex]
# created                                         2002-01-21 00:00:00
# id                                                   hep-ph/0201195
# doi                                   10.1088/1126-6708/2002/07/012
# cited_by          [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...
# citation_count                                                 4138
# Name: 15779, dtype: object

# %% [markdown]
# Read the paper yourself: [New Generation of Parton Distributions with Uncertainties from Global QCD Analysis](http://arxiv.org/abs/hep-ph/0201195) and see if you agree.
#
# We can also easily compute the top ten papers. This is an interesting mix of articles. Number two and three are the papers by the [ATLAS](http://atlas.ch) and [CMS](http://cms.web.cern.ch/) experiments reporting on the discovery of the [Higgs boson](http://en.wikipedia.org/wiki/Higgs_boson). While most of the papers in the top ten are older these two were only published in 2012 and have already overtaken the top quark discovery which was published in 1995! Curious fact, the ATLAS paper has ever so few more citations than the CMS one.

# %%
df.sort('citation_count', ascending=False).head(10)
# Out:
#                                                    title  \
# 15779  New Generation of Parton Distributions with Un...
# 7371   Observation of a new particle in the search fo...
# 7372   Observation of a new boson at a mass of 125 Ge...
# 15181  Observation of Top Quark Production in Pbar-P ...
# 16241  Direct Evidence for Neutrino Flavor Transforma...
# 15690  HERWIG 6.5: an event generator for Hadron Emis...
# 14026  First Results from KamLAND: Evidence for React...
# 16152                             A Supersymmetry Primer
# 16235  Measurement of the rate of nu_e + d --> p + p ...
# 13678                                 The BABAR Detector
#
#                                                 abstract  \
# 15779  A new generation of parton distribution functi...
# 7371   A search for the Standard Model Higgs boson in...
# 7372   Results are presented from searches for the st...
# 15181  We establish the existence of the top quark us...
# 16241  Observations of neutral current neutrino inter...
# 15690  HERWIG is a general-purpose Monte Carlo event ...
# 14026  KamLAND has been used to measure the flux of $...
# 16152  I provide a pedagogical introduction to supers...
# 16235  Solar neutrinos from the decay of $^8$B have b...
# 13678  BABAR, the detector for the SLAC PEP-II asymme...
#
#                      categories    created               id  \
# 15779          [hep-ph, hep-ex] 2002-01-21   hep-ph/0201195
# 7371                   [hep-ex] 2012-07-31        1207.7214
# 7372                   [hep-ex] 2012-07-31        1207.7235
# 15181          [hep-ex, hep-ph] 1995-03-02   hep-ex/9503002
# 16241         [nucl-ex, hep-ex] 2002-04-21  nucl-ex/0204008
# 15690          [hep-ph, hep-ex] 2000-11-29   hep-ph/0011363
# 14026         [hep-ex, nucl-ex] 2002-12-09   hep-ex/0212021
# 16152  [hep-ph, hep-ex, hep-th] 1997-09-15   hep-ph/9709356
# 16235         [nucl-ex, hep-ex] 2001-06-18  nucl-ex/0106015
# 13678                  [hep-ex] 2001-05-16   hep-ex/0105044
#
#                                   doi  \
# 15779   10.1088/1126-6708/2002/07/012
# 7371   10.1016/j.physletb.2012.08.020
# 7372   10.1016/j.physletb.2012.08.021
# 15181     10.1103/PhysRevLett.74.2626
# 16241   10.1103/PhysRevLett.89.011301
# 15690   10.1088/1126-6708/2001/01/010
# 14026   10.1103/PhysRevLett.90.021802
# 16152                            None
# 16235   10.1103/PhysRevLett.87.071301
# 13678   10.1016/S0168-9002(01)02012-5
#
#                                                 cited_by  citation_count
# 15779  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            4138
# 7371   [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            3653
# 7372   [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            3592
# 15181  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2519
# 16241  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2425
# 15690  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2324
# 14026  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2235
# 16152  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2160
# 16235  [{u'slaccitation': u'%%CITATION = ARXIV:1412.4...            2030
# 13678  [{u'title': u'Measurement of the Partial Branc...            1828

# %% [markdown]
# There are many more interesting things to be done with analysing the words used in abstracts as well as anlysing who cites who. This will be covered in the second part of this post as this one is already fairly lengthy.
#
# Just one more thing, the top cited paper of 2014: [First combination of Tevatron and LHC measurements of the top-quark mass](http://arxiv.org/abs/1403.4427) celebrating collaboration across the globe:

# %%
df.iloc[df[df.created>before_2014].citation_count.idxmax()]
# Out:
# title             First combination of Tevatron and LHC measurem...
# abstract          We present a combination of measurements of th...
# categories                                                 [hep-ex]
# created                                         2014-03-18 00:00:00
# id                                                        1403.4427
# doi                                                            None
# cited_by          [{u'slaccitation': u'%%CITATION = ARXIV:1412.1...
# citation_count                                                  118
# Name: 11494, dtype: object
